# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# #  Real Madrid Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %% [markdown]
# ##### READ THE TWEETS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedTweets/RealMadridTweets.csv"

#Import the CSV into a pandas DataFrame
Tweets_df = pd.read_csv(csv_path, low_memory = False)
Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220262391734206464"
# 1     "1220146629052944385"
# 2     "1220111675094945795"
# 3     "1220111398031646722"
# 4     "1220106390452297730"
# ...                     ...
# 3195  "1110529756573982720"
# 3196  "1110270130485813248"
# 3197  "1110239928997367808"
# 3198  "1110164434591338497"
# 3199  "1110104405691547648"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/realmadrid/status/12202623...  2020-01-23 08:30:00
# 1     https://twitter.com/realmadrid/status/12201466...  2020-01-23 00:50:00
# 2     https://twitter.com/realmadrid/status/12201116...  2020-01-22 22:31:06
# 3     https://twitter.com/realmadrid/status/12201113...  2020-01-22 22:30:00
# 4     https://twitter.com/realmadrid/status/12201063...  2020-01-22 22:10:06
# ...                                                 ...                  ...
# 3195  https://twitter.com/realmadrid/status/11105297...  2019-03-26 13:11:41
# 3196  https://twitter.com/realmadrid/status/11102701...  2019-03-25 20:00:01
# 3197  https://twitter.com/realmadrid/status/11102399...  2019-03-25 18:00:00
# 3198  https://twitter.com/realmadrid/status/11101644...  2019-03-25 13:00:01
# 3199  https://twitter.com/realmadrid/status/11101044...  2019-03-25 09:01:29
#
#                                           Tweet Content Tweet Type  \
# 0     "🔀🏆👑 ¡Clasificados para octavos de la Copa del...      Tweet
# 1     "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...      Tweet
# 2     "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...      Tweet
# 3     "💬👔 #Zidane analizó nuestro partido en Salaman...      Tweet
# 4     "💬 @fedeevalverde habló con los medios nada má...      Tweet
# ...                                                 ...        ...
# 3195  "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...      Tweet
# 3196  "💪 La temporada de @Benzema:\n⚽ Pichichi del e...      Tweet
# 3197  "✅ Primera sesión de la semana.\n🌱 #RMCity htt...      Tweet
# 3198  "😃 ¡Así fue la experiencia VIP de 12 Coderista...      Tweet
# 3199  "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...      Tweet
#
#                        Client  Retweets received  Likes received     User Id  \
# 0     Twitter for Advertisers                 91             930  "14872237"
# 1        Twitter Media Studio                629            5256  "14872237"
# 2        Twitter Media Studio               1105           11218  "14872237"
# 3        Twitter Media Studio                192            1984  "14872237"
# 4        Twitter Media Studio                359            3752  "14872237"
# ...                       ...                ...             ...         ...
# 3195                TweetDeck                250            2334  "14872237"
# 3196     Twitter Media Studio                399            4732  "14872237"
# 3197                TweetDeck                243            3074  "14872237"
# 3198     Twitter Media Studio                174            2633  "14872237"
# 3199     Twitter Media Studio                253            3065  "14872237"
#
#                      Name    Username Verified or Non-Verified  \
# 0     "Real Madrid C.F.⚽"  realmadrid                 Verified
# 1     "Real Madrid C.F.⚽"  realmadrid                 Verified
# 2     "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3     "Real Madrid C.F.⚽"  realmadrid                 Verified
# 4     "Real Madrid C.F.⚽"  realmadrid                 Verified
# ...                   ...         ...                      ...
# 3195  "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3196  "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3197  "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3198  "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3199  "Real Madrid C.F.⚽"  realmadrid                 Verified
#
#                          Profile URL Protected or Not Protected
# 0     https://twitter.com/realmadrid              Not Protected
# 1     https://twitter.com/realmadrid              Not Protected
# 2     https://twitter.com/realmadrid              Not Protected
# 3     https://twitter.com/realmadrid              Not Protected
# 4     https://twitter.com/realmadrid              Not Protected
# ...                              ...                        ...
# 3195  https://twitter.com/realmadrid              Not Protected
# 3196  https://twitter.com/realmadrid              Not Protected
# 3197  https://twitter.com/realmadrid              Not Protected
# 3198  https://twitter.com/realmadrid              Not Protected
# 3199  https://twitter.com/realmadrid              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Tweet Content", "Retweets received", "Likes received",
                       "Tweet Posted Time"]]
# "User Id",
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 7)

# %%
#Print the dataframe
Tweets_df.head()
# Out:
#                 Tweet Id                 Name    Username  \
# 0  "1220262391734206464"  "Real Madrid C.F.⚽"  realmadrid
# 1  "1220146629052944385"  "Real Madrid C.F.⚽"  realmadrid
# 2  "1220111675094945795"  "Real Madrid C.F.⚽"  realmadrid
# 3  "1220111398031646722"  "Real Madrid C.F.⚽"  realmadrid
# 4  "1220106390452297730"  "Real Madrid C.F.⚽"  realmadrid
#
#                                        Tweet Content  Retweets received  \
# 0  "🔀🏆👑 ¡Clasificados para octavos de la Copa del...                 91
# 1  "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...                629
# 2  "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...               1105
# 3  "💬👔 #Zidane analizó nuestro partido en Salaman...                192
# 4  "💬 @fedeevalverde habló con los medios nada má...                359
#
#    Likes received    Tweet Posted Time
# 0             930  2020-01-23 08:30:00
# 1            5256  2020-01-23 00:50:00
# 2           11218  2020-01-22 22:31:06
# 3            1984  2020-01-22 22:30:00
# 4            3752  2020-01-22 22:10:06

# %% [markdown]
# ##### FILTER THROUGH TWEET CONTENTS TO EXTRACT HASHTAGS (#) AND MENTIONS(@)

# %%
df1 = Tweets_df[['Tweet Content']]
mention = df1['Tweet Content'].str.findall(r'@.*?(?=\s|$)')
hashtag = df1['Tweet Content'].str.findall(r'#.*?(?=\s|$)')
Tweets_df['Mentions(@)'] = mention
Tweets_df['Hashtags(#)'] = hashtag
#Tweets_df.head()
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ##### CREATE COLUMNS FOR THE COUNT OF #COMMENTS AND @MENTIONS PER ROW

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "#" in tag:
                count+=1
    return count 
                
Tweets_df['Total #'] = Tweets_df['Hashtags(#)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "@" in tag:
                count+=1
    return count 
                
Tweets_df['Total @'] = Tweets_df['Mentions(@)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id                 Name    Username  \
# 0     "1220262391734206464"  "Real Madrid C.F.⚽"  realmadrid
# 1     "1220146629052944385"  "Real Madrid C.F.⚽"  realmadrid
# 2     "1220111675094945795"  "Real Madrid C.F.⚽"  realmadrid
# 3     "1220111398031646722"  "Real Madrid C.F.⚽"  realmadrid
# 4     "1220106390452297730"  "Real Madrid C.F.⚽"  realmadrid
# ...                     ...                  ...         ...
# 3195  "1110529756573982720"  "Real Madrid C.F.⚽"  realmadrid
# 3196  "1110270130485813248"  "Real Madrid C.F.⚽"  realmadrid
# 3197  "1110239928997367808"  "Real Madrid C.F.⚽"  realmadrid
# 3198  "1110164434591338497"  "Real Madrid C.F.⚽"  realmadrid
# 3199  "1110104405691547648"  "Real Madrid C.F.⚽"  realmadrid
#
#                                           Tweet Content  Retweets received  \
# 0     "🔀🏆👑 ¡Clasificados para octavos de la Copa del...                 91
# 1     "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...                629
# 2     "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...               1105
# 3     "💬👔 #Zidane analizó nuestro partido en Salaman...                192
# 4     "💬 @fedeevalverde habló con los medios nada má...                359
# ...                                                 ...                ...
# 3195  "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...                250
# 3196  "💪 La temporada de @Benzema:\n⚽ Pichichi del e...                399
# 3197  "✅ Primera sesión de la semana.\n🌱 #RMCity htt...                243
# 3198  "😃 ¡Así fue la experiencia VIP de 12 Coderista...                174
# 3199  "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...                253
#
#       Likes received    Tweet Posted Time  \
# 0                930  2020-01-23 08:30:00
# 1               5256  2020-01-23 00:50:00
# 2              11218  2020-01-22 22:31:06
# 3               1984  2020-01-22 22:30:00
# 4               3752  2020-01-22 22:10:06
# ...              ...                  ...
# 3195            2334  2019-03-26 13:11:41
# 3196            4732  2019-03-25 20:00:01
# 3197            3074  2019-03-25 18:00:00
# 3198            2633  2019-03-25 13:00:01
# 3199            3065  2019-03-25 09:01:29
#
#                                             Mentions(@)  \
# 0                                                    []
# 1     [@UnionistasCF, @realmadrid, @GarethBale11, @B...
# 2                                             [@Brahim]
# 3                                                    []
# 4                      [@fedeevalverde, @UnionistasCF.]
# ...                                                 ...
# 3195                                    [@AthleticClub]
# 3196                                        [@Benzema:]
# 3197                                                 []
# 3198                    [@realmadrid!, @CodereApuestas]
# 3199  [@raphaelvarane, @fedeevalverde, @JesusVallejo...
#
#                            Hashtags(#)  Total #  Total @
# 0              [#RMCopa, #HalaMadrid"]        2        0
# 1               [#RMCopa, #HalaMadrid]        2        4
# 2     [#RMFans!, #RMCopa, #HalaMadrid]        3        1
# 3      [#Zidane, #RMCopa, #HalaMadrid]        3        0
# 4               [#RMCopa, #HalaMadrid]        2        2
# ...                                ...      ...      ...
# 3195                     [#⃣, #RMLiga]        2        1
# 3196                     [#HalaMadrid]        1        1
# 3197                         [#RMCity]        1        0
# 3198                     [#HalaMadrid]        1        2
# 3199                                []        0        4
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Tweets_df['Tweet Posted Time'] = Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Tweets_df["Date"] = date

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Tweets_df["Time"] = time
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 12)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id                 Name    Username  \
# 0     "1220262391734206464"  "Real Madrid C.F.⚽"  realmadrid
# 1     "1220146629052944385"  "Real Madrid C.F.⚽"  realmadrid
# 2     "1220111675094945795"  "Real Madrid C.F.⚽"  realmadrid
# 3     "1220111398031646722"  "Real Madrid C.F.⚽"  realmadrid
# 4     "1220106390452297730"  "Real Madrid C.F.⚽"  realmadrid
# ...                     ...                  ...         ...
# 3195  "1110529756573982720"  "Real Madrid C.F.⚽"  realmadrid
# 3196  "1110270130485813248"  "Real Madrid C.F.⚽"  realmadrid
# 3197  "1110239928997367808"  "Real Madrid C.F.⚽"  realmadrid
# 3198  "1110164434591338497"  "Real Madrid C.F.⚽"  realmadrid
# 3199  "1110104405691547648"  "Real Madrid C.F.⚽"  realmadrid
#
#                                           Tweet Content  Retweets received  \
# 0     "🔀🏆👑 ¡Clasificados para octavos de la Copa del...                 91
# 1     "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...                629
# 2     "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...               1105
# 3     "💬👔 #Zidane analizó nuestro partido en Salaman...                192
# 4     "💬 @fedeevalverde habló con los medios nada má...                359
# ...                                                 ...                ...
# 3195  "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...                250
# 3196  "💪 La temporada de @Benzema:\n⚽ Pichichi del e...                399
# 3197  "✅ Primera sesión de la semana.\n🌱 #RMCity htt...                243
# 3198  "😃 ¡Así fue la experiencia VIP de 12 Coderista...                174
# 3199  "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...                253
#
#       Likes received                                        Mentions(@)  \
# 0                930                                                 []
# 1               5256  [@UnionistasCF, @realmadrid, @GarethBale11, @B...
# 2              11218                                          [@Brahim]
# 3               1984                                                 []
# 4               3752                   [@fedeevalverde, @UnionistasCF.]
# ...              ...                                                ...
# 3195            2334                                    [@AthleticClub]
# 3196            4732                                        [@Benzema:]
# 3197            3074                                                 []
# 3198            2633                    [@realmadrid!, @CodereApuestas]
# 3199            3065  [@raphaelvarane, @fedeevalverde, @JesusVallejo...
#
#                            Hashtags(#)  Total #  Total @        Date      Time
# 0              [#RMCopa, #HalaMadrid"]        2        0  2020-01-23  08:30:00
# 1               [#RMCopa, #HalaMadrid]        2        4  2020-01-23  00:50:00
# 2     [#RMFans!, #RMCopa, #HalaMadrid]        3        1  2020-01-22  22:31:06
# 3      [#Zidane, #RMCopa, #HalaMadrid]        3        0  2020-01-22  22:30:00
# 4               [#RMCopa, #HalaMadrid]        2        2  2020-01-22  22:10:06
# ...                                ...      ...      ...         ...       ...
# 3195                     [#⃣, #RMLiga]        2        1  2019-03-26  13:11:41
# 3196                     [#HalaMadrid]        1        1  2019-03-25  20:00:01
# 3197                         [#RMCity]        1        0  2019-03-25  18:00:00
# 3198                     [#HalaMadrid]        1        2  2019-03-25  13:00:01
# 3199                                []        0        4  2019-03-25  09:01:29
#
# [3200 rows x 12 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE IMAGES CSV

# %%
#Create reference to CSV file
csv_path = "RenamedImages/RealMadridImages.csv"

#Import the CSV into a pandas DataFrame
Images_df = pd.read_csv(csv_path, low_memory = False)
Images_df
# Out:
#                    Tweet Id               Media Id  \
# 0     "1220105378236715008"  "1220105097293848577"
# 1     "1220101280066080776"  "1220101264920522753"
# 2     "1220097633810812928"  "1220097585827995649"
# 3     "1220097633810812928"  "1220097600986275840"
# 4     "1220096317432745985"  "1220096273560363011"
# ...                     ...                    ...
# 1135  "1111986235977986048"  "1111986046529687552"
# 1136  "1110862780016451584"  "1110860129090588672"
# 1137  "1110583439286140929"  "1110571159698001921"
# 1138  "1110529756573982720"  "1110529719823421440"
# 1139  "1110239928997367808"  "1110232897628356609"
#
#                                             Media URL                Tweet URL
# 0     https://pbs.twimg.com/media/EO6vHyDX4AEaFwn.jpg  https://t.co/8lNQtBi6I0
# 1     https://pbs.twimg.com/media/EO6rotWXsAEkYnb.jpg  https://t.co/kA4YSl9QBd
# 2     https://pbs.twimg.com/media/EO6oSjqW4AEexzG.jpg  https://t.co/JU26TIpjvE
# 3     https://pbs.twimg.com/media/EO6oTcIX4AAzRoY.jpg  https://t.co/JU26TIpjvE
# 4     https://pbs.twimg.com/media/EO6nGLFX4AMdkyk.jpg  https://t.co/Z4sEQ6dUlh
# ...                                               ...                      ...
# 1135  https://pbs.twimg.com/media/D26RavKX0AAIaIH.jpg  https://t.co/crC0WSQmfS
# 1136  https://pbs.twimg.com/media/D2qRZt2W0AA81YG.jpg  https://t.co/cbYpGYzSMw
# 1137  https://pbs.twimg.com/media/D2mKle-X0AEPhvw.jpg  https://t.co/DGHwT91Duc
# 1138  https://pbs.twimg.com/media/D2lk5XaW0AA89oi.jpg  https://t.co/jU0qbdqfgS
# 1139  https://pbs.twimg.com/media/D2hW8CkXQAEUz32.jpg  https://t.co/nJL7iyUMUX
#
# [1140 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Images_df = Images_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1140, 1)

# %% [markdown]
# ##### ADD A IMAGES COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Images column for images
Images_df['Images'] = "Image added"

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1140, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Images_df
# Out:
#                    Tweet Id       Images
# 0     "1220105378236715008"  Image added
# 1     "1220101280066080776"  Image added
# 2     "1220097633810812928"  Image added
# 3     "1220097633810812928"  Image added
# 4     "1220096317432745985"  Image added
# ...                     ...          ...
# 1135  "1111986235977986048"  Image added
# 1136  "1110862780016451584"  Image added
# 1137  "1110583439286140929"  Image added
# 1138  "1110529756573982720"  Image added
# 1139  "1110239928997367808"  Image added
#
# [1140 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Images_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id                 Name    Username  \
# 0     "1220262391734206464"  "Real Madrid C.F.⚽"  realmadrid
# 1     "1220146629052944385"  "Real Madrid C.F.⚽"  realmadrid
# 2     "1220111675094945795"  "Real Madrid C.F.⚽"  realmadrid
# 3     "1220111398031646722"  "Real Madrid C.F.⚽"  realmadrid
# 4     "1220106390452297730"  "Real Madrid C.F.⚽"  realmadrid
# ...                     ...                  ...         ...
# 3465  "1110529756573982720"  "Real Madrid C.F.⚽"  realmadrid
# 3466  "1110270130485813248"  "Real Madrid C.F.⚽"  realmadrid
# 3467  "1110239928997367808"  "Real Madrid C.F.⚽"  realmadrid
# 3468  "1110164434591338497"  "Real Madrid C.F.⚽"  realmadrid
# 3469  "1110104405691547648"  "Real Madrid C.F.⚽"  realmadrid
#
#                                           Tweet Content  Retweets received  \
# 0     "🔀🏆👑 ¡Clasificados para octavos de la Copa del...                 91
# 1     "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...                629
# 2     "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...               1105
# 3     "💬👔 #Zidane analizó nuestro partido en Salaman...                192
# 4     "💬 @fedeevalverde habló con los medios nada má...                359
# ...                                                 ...                ...
# 3465  "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...                250
# 3466  "💪 La temporada de @Benzema:\n⚽ Pichichi del e...                399
# 3467  "✅ Primera sesión de la semana.\n🌱 #RMCity htt...                243
# 3468  "😃 ¡Así fue la experiencia VIP de 12 Coderista...                174
# 3469  "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...                253
#
#       Likes received                                        Mentions(@)  \
# 0                930                                                 []
# 1               5256  [@UnionistasCF, @realmadrid, @GarethBale11, @B...
# 2              11218                                          [@Brahim]
# 3               1984                                                 []
# 4               3752                   [@fedeevalverde, @UnionistasCF.]
# ...              ...                                                ...
# 3465            2334                                    [@AthleticClub]
# 3466            4732                                        [@Benzema:]
# 3467            3074                                                 []
# 3468            2633                    [@realmadrid!, @CodereApuestas]
# 3469            3065  [@raphaelvarane, @fedeevalverde, @JesusVallejo...
#
#                            Hashtags(#)  Total #  Total @        Date  \
# 0              [#RMCopa, #HalaMadrid"]        2        0  2020-01-23
# 1               [#RMCopa, #HalaMadrid]        2        4  2020-01-23
# 2     [#RMFans!, #RMCopa, #HalaMadrid]        3        1  2020-01-22
# 3      [#Zidane, #RMCopa, #HalaMadrid]        3        0  2020-01-22
# 4               [#RMCopa, #HalaMadrid]        2        2  2020-01-22
# ...                                ...      ...      ...         ...
# 3465                     [#⃣, #RMLiga]        2        1  2019-03-26
# 3466                     [#HalaMadrid]        1        1  2019-03-25
# 3467                         [#RMCity]        1        0  2019-03-25
# 3468                     [#HalaMadrid]        1        2  2019-03-25
# 3469                                []        0        4  2019-03-25
#
#           Time       Images
# 0     08:30:00          NaN
# 1     00:50:00          NaN
# 2     22:31:06          NaN
# 3     22:30:00          NaN
# 4     22:10:06          NaN
# ...        ...          ...
# 3465  13:11:41  Image added
# 3466  20:00:01          NaN
# 3467  18:00:00  Image added
# 3468  13:00:01          NaN
# 3469  09:01:29          NaN
#
# [3470 rows x 13 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE VIDEOS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedVideos/RealMadridVideos.csv"

#Import the CSV into a pandas DataFrame
Videos_df = pd.read_csv(csv_path, low_memory = False)
Videos_df
# Out:
#                    Tweet Id               Media Id  \
# 0     "1220146629052944385"  "1220144694300160001"
# 1     "1220111675094945795"  "1220111157257756680"
# 2     "1220111398031646722"  "1220106115339505666"
# 3     "1220106390452297730"  "1220104627875721217"
# 4     "1220100858811158530"  "1220100821691568128"
# ...                     ...                    ...
# 1686  "1110613638476259329"  "1110492691622776834"
# 1687  "1110549469903282182"  "1110544965271199744"
# 1688  "1110270130485813248"  "1110265326489489414"
# 1689  "1110164434591338497"  "1110123078573527040"
# 1690  "1110104405691547648"  "1109845329791385601"
#
#                                               Media URL  \
# 0     https://video.twimg.com/amplify_video/12201446...
# 1     https://video.twimg.com/amplify_video/12201111...
# 2     https://video.twimg.com/amplify_video/12201061...
# 3     https://video.twimg.com/amplify_video/12201046...
# 4     https://video.twimg.com/tweet_video/EO6rO6MWkA...
# ...                                                 ...
# 1686  https://video.twimg.com/amplify_video/11104926...
# 1687  https://video.twimg.com/amplify_video/11105449...
# 1688  https://video.twimg.com/amplify_video/11102653...
# 1689  https://video.twimg.com/amplify_video/11101230...
# 1690  https://video.twimg.com/amplify_video/11098453...
#
#                     Tweet URL
# 0     https://t.co/cX6VuHzO1V
# 1     https://t.co/mJccQGW1Ap
# 2     https://t.co/oD1bTkKJsW
# 3     https://t.co/p4hEU0qQUq
# 4     https://t.co/VKN7HPoaJ5
# ...                       ...
# 1686  https://t.co/YY6Vul6yQV
# 1687  https://t.co/NPMDJmguLM
# 1688  https://t.co/KyHkA9Iwpi
# 1689  https://t.co/MVfbkuuU67
# 1690  https://t.co/4kHhWbtGLR
#
# [1691 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Videos_df = Videos_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1691, 1)

# %% [markdown]
# ##### ADD A VIDEOS COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Videos column for images
Videos_df['Videos'] = "Video added"

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1691, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Videos_df
# Out:
#                    Tweet Id       Videos
# 0     "1220146629052944385"  Video added
# 1     "1220111675094945795"  Video added
# 2     "1220111398031646722"  Video added
# 3     "1220106390452297730"  Video added
# 4     "1220100858811158530"  Video added
# ...                     ...          ...
# 1686  "1110613638476259329"  Video added
# 1687  "1110549469903282182"  Video added
# 1688  "1110270130485813248"  Video added
# 1689  "1110164434591338497"  Video added
# 1690  "1110104405691547648"  Video added
#
# [1691 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Videos_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id                 Name    Username  \
# 0     "1220262391734206464"  "Real Madrid C.F.⚽"  realmadrid
# 1     "1220146629052944385"  "Real Madrid C.F.⚽"  realmadrid
# 2     "1220111675094945795"  "Real Madrid C.F.⚽"  realmadrid
# 3     "1220111398031646722"  "Real Madrid C.F.⚽"  realmadrid
# 4     "1220106390452297730"  "Real Madrid C.F.⚽"  realmadrid
# ...                     ...                  ...         ...
# 3465  "1110529756573982720"  "Real Madrid C.F.⚽"  realmadrid
# 3466  "1110270130485813248"  "Real Madrid C.F.⚽"  realmadrid
# 3467  "1110239928997367808"  "Real Madrid C.F.⚽"  realmadrid
# 3468  "1110164434591338497"  "Real Madrid C.F.⚽"  realmadrid
# 3469  "1110104405691547648"  "Real Madrid C.F.⚽"  realmadrid
#
#                                           Tweet Content  Retweets received  \
# 0     "🔀🏆👑 ¡Clasificados para octavos de la Copa del...                 91
# 1     "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...                629
# 2     "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...               1105
# 3     "💬👔 #Zidane analizó nuestro partido en Salaman...                192
# 4     "💬 @fedeevalverde habló con los medios nada má...                359
# ...                                                 ...                ...
# 3465  "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...                250
# 3466  "💪 La temporada de @Benzema:\n⚽ Pichichi del e...                399
# 3467  "✅ Primera sesión de la semana.\n🌱 #RMCity htt...                243
# 3468  "😃 ¡Así fue la experiencia VIP de 12 Coderista...                174
# 3469  "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...                253
#
#       Likes received                                        Mentions(@)  \
# 0                930                                                 []
# 1               5256  [@UnionistasCF, @realmadrid, @GarethBale11, @B...
# 2              11218                                          [@Brahim]
# 3               1984                                                 []
# 4               3752                   [@fedeevalverde, @UnionistasCF.]
# ...              ...                                                ...
# 3465            2334                                    [@AthleticClub]
# 3466            4732                                        [@Benzema:]
# 3467            3074                                                 []
# 3468            2633                    [@realmadrid!, @CodereApuestas]
# 3469            3065  [@raphaelvarane, @fedeevalverde, @JesusVallejo...
#
#                            Hashtags(#)  Total #  Total @        Date  \
# 0              [#RMCopa, #HalaMadrid"]        2        0  2020-01-23
# 1               [#RMCopa, #HalaMadrid]        2        4  2020-01-23
# 2     [#RMFans!, #RMCopa, #HalaMadrid]        3        1  2020-01-22
# 3      [#Zidane, #RMCopa, #HalaMadrid]        3        0  2020-01-22
# 4               [#RMCopa, #HalaMadrid]        2        2  2020-01-22
# ...                                ...      ...      ...         ...
# 3465                     [#⃣, #RMLiga]        2        1  2019-03-26
# 3466                     [#HalaMadrid]        1        1  2019-03-25
# 3467                         [#RMCity]        1        0  2019-03-25
# 3468                     [#HalaMadrid]        1        2  2019-03-25
# 3469                                []        0        4  2019-03-25
#
#           Time       Images       Videos
# 0     08:30:00          NaN          NaN
# 1     00:50:00          NaN  Video added
# 2     22:31:06          NaN  Video added
# 3     22:30:00          NaN  Video added
# 4     22:10:06          NaN  Video added
# ...        ...          ...          ...
# 3465  13:11:41  Image added          NaN
# 3466  20:00:01          NaN  Video added
# 3467  18:00:00  Image added          NaN
# 3468  13:00:01          NaN  Video added
# 3469  09:01:29          NaN  Video added
#
# [3470 rows x 14 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Gender column 
Tweets_df['Gender'] = "Organisation"

#Create an Vocation column 
Tweets_df['Vocation'] = "Sports"

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3470, 16)

# %%
#REPLACE ALL "NaN" FOR "-"
Tweets_df['Images'] = Tweets_df['Images'].fillna("-")
Tweets_df['Videos'] = Tweets_df['Videos'].fillna("-")

# %% [markdown]
# ##### RENAME THE COLUMNS FOR VISUAL PURPOSES

# %%
Tweets_df = Tweets_df.rename(columns={"Tweet Content":"Tweets"})
Tweets_df = Tweets_df.rename(columns={"Retweets received":"Retweets"})
Tweets_df = Tweets_df.rename(columns={"Likes received":"Likes"})

# %% [markdown]
# ##### REMOVE THE TWEETS COLUMN

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweets'], axis = 1)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id                 Name    Username  Retweets  Likes  \
# 0     "1220262391734206464"  "Real Madrid C.F.⚽"  realmadrid        91    930
# 1     "1220146629052944385"  "Real Madrid C.F.⚽"  realmadrid       629   5256
# 2     "1220111675094945795"  "Real Madrid C.F.⚽"  realmadrid      1105  11218
# 3     "1220111398031646722"  "Real Madrid C.F.⚽"  realmadrid       192   1984
# 4     "1220106390452297730"  "Real Madrid C.F.⚽"  realmadrid       359   3752
# ...                     ...                  ...         ...       ...    ...
# 3465  "1110529756573982720"  "Real Madrid C.F.⚽"  realmadrid       250   2334
# 3466  "1110270130485813248"  "Real Madrid C.F.⚽"  realmadrid       399   4732
# 3467  "1110239928997367808"  "Real Madrid C.F.⚽"  realmadrid       243   3074
# 3468  "1110164434591338497"  "Real Madrid C.F.⚽"  realmadrid       174   2633
# 3469  "1110104405691547648"  "Real Madrid C.F.⚽"  realmadrid       253   3065
#
#                                             Mentions(@)  \
# 0                                                    []
# 1     [@UnionistasCF, @realmadrid, @GarethBale11, @B...
# 2                                             [@Brahim]
# 3                                                    []
# 4                      [@fedeevalverde, @UnionistasCF.]
# ...                                                 ...
# 3465                                    [@AthleticClub]
# 3466                                        [@Benzema:]
# 3467                                                 []
# 3468                    [@realmadrid!, @CodereApuestas]
# 3469  [@raphaelvarane, @fedeevalverde, @JesusVallejo...
#
#                            Hashtags(#)  Total #  Total @        Date  \
# 0              [#RMCopa, #HalaMadrid"]        2        0  2020-01-23
# 1               [#RMCopa, #HalaMadrid]        2        4  2020-01-23
# 2     [#RMFans!, #RMCopa, #HalaMadrid]        3        1  2020-01-22
# 3      [#Zidane, #RMCopa, #HalaMadrid]        3        0  2020-01-22
# 4               [#RMCopa, #HalaMadrid]        2        2  2020-01-22
# ...                                ...      ...      ...         ...
# 3465                     [#⃣, #RMLiga]        2        1  2019-03-26
# 3466                     [#HalaMadrid]        1        1  2019-03-25
# 3467                         [#RMCity]        1        0  2019-03-25
# 3468                     [#HalaMadrid]        1        2  2019-03-25
# 3469                                []        0        4  2019-03-25
#
#           Time       Images       Videos        Gender Vocation
# 0     08:30:00            -            -  Organisation   Sports
# 1     00:50:00            -  Video added  Organisation   Sports
# 2     22:31:06            -  Video added  Organisation   Sports
# 3     22:30:00            -  Video added  Organisation   Sports
# 4     22:10:06            -  Video added  Organisation   Sports
# ...        ...          ...          ...           ...      ...
# 3465  13:11:41  Image added            -  Organisation   Sports
# 3466  20:00:01            -  Video added  Organisation   Sports
# 3467  18:00:00  Image added            -  Organisation   Sports
# 3468  13:00:01            -  Video added  Organisation   Sports
# 3469  09:01:29            -  Video added  Organisation   Sports
#
# [3470 rows x 15 columns]

# %% [markdown]
# ##### RE-ORDER THE COLUMNS FOR VISUAL PURPOSES

# %%
#Re-organise the columns for visual purposes
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Gender", "Vocation", "Hashtags(#)", "Total #", "Mentions(@)", 
                       "Total @", "Likes", "Retweets", "Images", "Videos", "Date", "Time"]]

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Tweets_df = Tweets_df.set_index('Tweet Id')
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3470, 14)

# %%
#Print the dataframe
Tweets_df
# Out:
#                                       Name    Username        Gender Vocation  \
# Tweet Id
# "1220262391734206464"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# "1220146629052944385"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# "1220111675094945795"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# "1220111398031646722"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# "1220106390452297730"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# ...                                    ...         ...           ...      ...
# "1110529756573982720"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# "1110270130485813248"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# "1110239928997367808"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# "1110164434591338497"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
# "1110104405691547648"  "Real Madrid C.F.⚽"  realmadrid  Organisation   Sports
#
#                                             Hashtags(#)  Total #  \
# Tweet Id
# "1220262391734206464"           [#RMCopa, #HalaMadrid"]        2
# "1220146629052944385"            [#RMCopa, #HalaMadrid]        2
# "1220111675094945795"  [#RMFans!, #RMCopa, #HalaMadrid]        3
# "1220111398031646722"   [#Zidane, #RMCopa, #HalaMadrid]        3
# "1220106390452297730"            [#RMCopa, #HalaMadrid]        2
# ...                                                 ...      ...
# "1110529756573982720"                     [#⃣, #RMLiga]        2
# "1110270130485813248"                     [#HalaMadrid]        1
# "1110239928997367808"                         [#RMCity]        1
# "1110164434591338497"                     [#HalaMadrid]        1
# "1110104405691547648"                                []        0
#
#                                                              Mentions(@)  \
# Tweet Id
# "1220262391734206464"                                                 []
# "1220146629052944385"  [@UnionistasCF, @realmadrid, @GarethBale11, @B...
# "1220111675094945795"                                          [@Brahim]
# "1220111398031646722"                                                 []
# "1220106390452297730"                   [@fedeevalverde, @UnionistasCF.]
# ...                                                                  ...
# "1110529756573982720"                                    [@AthleticClub]
# "1110270130485813248"                                        [@Benzema:]
# "1110239928997367808"                                                 []
# "1110164434591338497"                    [@realmadrid!, @CodereApuestas]
# "1110104405691547648"  [@raphaelvarane, @fedeevalverde, @JesusVallejo...
#
#                        Total @  Likes  Retweets       Images       Videos  \
# Tweet Id
# "1220262391734206464"        0    930        91            -            -
# "1220146629052944385"        4   5256       629            -  Video added
# "1220111675094945795"        1  11218      1105            -  Video added
# "1220111398031646722"        0   1984       192            -  Video added
# "1220106390452297730"        2   3752       359            -  Video added
# ...                        ...    ...       ...          ...          ...
# "1110529756573982720"        1   2334       250  Image added            -
# "1110270130485813248"        1   4732       399            -  Video added
# "1110239928997367808"        0   3074       243  Image added            -
# "1110164434591338497"        2   2633       174            -  Video added
# "1110104405691547648"        4   3065       253            -  Video added
#
#                              Date      Time
# Tweet Id
# "1220262391734206464"  2020-01-23  08:30:00
# "1220146629052944385"  2020-01-23  00:50:00
# "1220111675094945795"  2020-01-22  22:31:06
# "1220111398031646722"  2020-01-22  22:30:00
# "1220106390452297730"  2020-01-22  22:10:06
# ...                           ...       ...
# "1110529756573982720"  2019-03-26  13:11:41
# "1110270130485813248"  2019-03-25  20:00:01
# "1110239928997367808"  2019-03-25  18:00:00
# "1110164434591338497"  2019-03-25  13:00:01
# "1110104405691547648"  2019-03-25  09:01:29
#
# [3470 rows x 14 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Tweets_df.to_csv('NewDataframes/RealMadrid_df.csv')
