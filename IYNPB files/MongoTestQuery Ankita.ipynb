# %%
# Doesnt work!! 


# import pymongo

# client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
# mongo_db = client["Tweets_DB"]
# mongo_collection = mongo_db["Combined_Tweets"]

# for x in mongo_collection.find({},{ "_id": 0, "Hashtags(#)": 1, "Identity": "Akshay Kumar"}).limit(10):
#   print(x)
#     dict_result = x.to_dict()

# %%
# Set Up PyMongo
import pymongo
import pandas as pd
import numpy as np
from flask import jsonify

client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Combined_Tweets"]

# Define A Person to Query
# Searches for non-empty hashtag results 
QueryIdentity = "Katy Perry"
testoutput =  mongo_collection.find( { "Identity": QueryIdentity, "Hashtags(#)": {"$ne" : '[]'} },{ "_id": 0, "Hashtags(#)": 1} ).limit(50)

test_df = pd.DataFrame(list(testoutput))
test_df.head(50)
# Out:
#                                        Hashtags(#)
# 0                             ['#ShoesdayTuesday']
# 1                             ['#ShoesdayTuesday']
# 2                             ['#ShoesdayTuesday']
# 3   ['#ProtectYourEnergy2020', '#ShoesdayTuesday']
# 4   ['#ProtectYourEnergy2020', '#ShoesdayTuesday']
# 5   ['#ProtectYourEnergy2020', '#ShoesdayTuesday']
# 6                                         ['#FBF']
# 7                             ['#ShoesdayTuesday']
# 8                             ['#ShoesdayTuesday']
# 9                             ['#ShoesdayTuesday']
# 10                                       ['#2020']
# 11                            ['#ShoesdayTuesday']
# 12                            ['#ShoesdayTuesday']
# 13                            ['#ShoesdayTuesday']
# 14                       ['#CozyLittleChristmas,']
# 15                        ['#CozyLittleChristmas']
# 16                        ['#CozyLittleChristmas']
# ...

# %%
eval(test_df['Hashtags(#)'][0])
# Out:
# ['#ShoesdayTuesday']

# %%
import numpy as np 
# [eval(x) for x in test_df["Hashtags(#)"]]
testarray = [eval(x) for x in test_df["Hashtags(#)"]]
testarray
flatten_list = []
for l1 in testarray:
    for l2 in l1:
        l2 = l2.replace('"','')
        flatten_list.append(l2)
        
flatten_list
# Out:
# ['#ShoesdayTuesday',
#  '#ShoesdayTuesday',
#  '#ShoesdayTuesday',
#  '#ProtectYourEnergy2020',
#  '#ShoesdayTuesday',
#  '#ProtectYourEnergy2020',
#  '#ShoesdayTuesday',
#  '#ProtectYourEnergy2020',
#  '#ShoesdayTuesday',
#  '#FBF',
#  '#ShoesdayTuesday',
#  '#ShoesdayTuesday',
#  '#ShoesdayTuesday',
#  '#2020',
#  '#ShoesdayTuesday',
#  '#ShoesdayTuesday',
#  '#ShoesdayTuesday',
#  '#CozyLittleChristmas,',
#  '#CozyLittleChristmas',
#  '#CozyLittleChristmas',
#  '#CozyLittleChristmas',
#  '#CozyLittleChristmas',
#  '#iHeartOnCW',
#  '#CozyLittleChristmas',
#  '#HarleysInHawaii',
#  '#ShoesdayTuesday',
#  '#ShoesdayTuesday',
#  '#ShoesdayTuesday',
#  '#CozyLittleChristmas',
#  '#CozyLittleChristmasMusicVideo',
#  '#CozyLittleChristmasMusicVideo',
#  '#CozyLittleChristmasMusicVideo',
#  '#CozyLittleChristmasMusicVideo',
#  '#CozyLittleChristmasMusicVideo',
#  '#CozyLittleChristmasMusicVideo',
#  '#JingleBall',
#  '#shoesdaytuesday',
#  '#katypursey',
#  '#shoesdaytuesday',
# ...

# %%
#converts to json
test_df.to_dict('records')
# Out:
# [{'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ProtectYourEnergy2020', '#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ProtectYourEnergy2020', '#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ProtectYourEnergy2020', '#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#FBF']"},
#  {'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#2020']"},
#  {'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#ShoesdayTuesday']"},
#  {'Hashtags(#)': "['#CozyLittleChristmas,']"},
#  {'Hashtags(#)': "['#CozyLittleChristmas']"},
#  {'Hashtags(#)': "['#CozyLittleChristmas']"},
#  {'Hashtags(#)': "['#CozyLittleChristmas']"},
#  {'Hashtags(#)': "['#CozyLittleChristmas']"},
#  {'Hashtags(#)': "['#iHeartOnCW']"},
#  {'Hashtags(#)': "['#CozyLittleChristmas']"},
# ...

# %%
# Set up Pandas, Query Atlas for ALL results matching the twitter Identity 

identity_df = pd.DataFrame(list(mongo_collection.find({"Identity": QueryIdentity})))

# %%
identity_df['Time'] = pd.to_datetime(identity_df["Time"],format='%H:%M:%S')
# mega_df["Time"] = mega_df["Time"].dt.time
identity_df["Date"] = pd.to_datetime(identity_df["Date"],format="%Y-%m-%d")

# %%
identity_df
# Out:
#                            _id  level_0  index               Tweet Id  \
# 0     60be2af24a7a5d65a6b52b62    67767      0  "1219799180723359744"
# 1     60be2af24a7a5d65a6b52b63    67768      1  "1219799180723359744"
# 2     60be2af24a7a5d65a6b52b64    67769      2  "1219799180723359744"
# 3     60be2af24a7a5d65a6b52b65    67770      3  "1219701567961600001"
# 4     60be2af24a7a5d65a6b52b66    67771      4  "1219169657250168832"
# ...                        ...      ...    ...                    ...
# 3345  60be2af24a7a5d65a6b53873    71112   3345   "758966211455569922"
# 3346  60be2af24a7a5d65a6b53874    71113   3346   "758966024687329281"
# 3347  60be2af24a7a5d65a6b53875    71114   3347   "758965291191631872"
# 3348  60be2af24a7a5d65a6b53876    71115   3348   "758964275557769216"
# 3349  60be2af24a7a5d65a6b53877    71116   3349   "758963797444792321"
#
#               Name   Username  Gender Vocation           Hashtags(#)  Total #  \
# ...

# %%
identity_df.head()
# Out:
#                         _id  level_0  index               Tweet Id  \
# 0  60be2af24a7a5d65a6b52b62    67767      0  "1219799180723359744"
# 1  60be2af24a7a5d65a6b52b63    67768      1  "1219799180723359744"
# 2  60be2af24a7a5d65a6b52b64    67769      2  "1219799180723359744"
# 3  60be2af24a7a5d65a6b52b65    67770      3  "1219701567961600001"
# 4  60be2af24a7a5d65a6b52b66    67771      4  "1219169657250168832"
#
#            Name   Username  Gender Vocation           Hashtags(#)  Total #  \
# 0  "KATY PERRY"  katyperry  Female    Music  ['#ShoesdayTuesday']        1
# 1  "KATY PERRY"  katyperry  Female    Music  ['#ShoesdayTuesday']        1
# 2  "KATY PERRY"  katyperry  Female    Music  ['#ShoesdayTuesday']        1
# 3  "KATY PERRY"  katyperry  Female    Music                    []        0
# 4  "KATY PERRY"  katyperry  Female    Music                    []        0
#
#                                          Mentions(@)  Total @  Likes  \
# ...

# %%
#total daily
identity_df.groupby(pd.Grouper(key='Date', freq='D'))
identity_df.sum()
# Out:
# level_0                                                232629025
# index                                                    5609575
# Tweet Id       "1219799180723359744""1219799180723359744""121...
# Name           "KATY PERRY""KATY PERRY""KATY PERRY""KATY PERR...
# Username       katyperrykatyperrykatyperrykatyperrykatyperryk...
# Gender         FemaleFemaleFemaleFemaleFemaleFemaleFemaleFema...
# Vocation       MusicMusicMusicMusicMusicMusicMusicMusicMusicM...
# Hashtags(#)    ['#ShoesdayTuesday']['#ShoesdayTuesday']['#Sho...
# Total #                                                     1914
# Mentions(@)    ['@kpcollections']['@kpcollections']['@kpcolle...
# Total @                                                     2374
# Likes                                                   39071236
# Retweets                                                 9215971
# Images         Image addedImage addedImage addedImage added-I...
# ...

# %%
#daily mean
identity_df.groupby(pd.Grouper(key='Date', freq='D'))
identity_df.mean()
# Out:
# <ipython-input-46-709129e43ad3>:3: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   identity_df.mean()
# level_0     69441.500000
# index        1674.500000
# Total #         0.571343
# Total @         0.708657
# Likes       11663.055522
# Retweets     2751.036119
# dtype: float64

# %%
#daily median
identity_df.groupby(pd.Grouper(key='Date', freq='D'))
identity_df.median()
# Out:
# <ipython-input-35-ec9b5e2f6dd5>:2: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   identity_df.median()
# level_0     56255.5
# index        1614.5
# Total #         1.0
# Total @         1.0
# Likes        1612.5
# Retweets      168.0
# dtype: float64

# %%
identity_df.groupby(pd.Grouper(key='Date', freq='D'))
max_tweet_info_df = identity_df.max()
sum_tweet_info_df = identity_df.sum()
count_tweet_info_df = identity_df.sum()
# Out:
# _id                60be2af24a7a5d65a6b504b9
# level_0                               57870
# index                                  3229
# Tweet Id               "999991043184627713"
# Name           "🏳️‍🌈Gandalf the Gay ⁷ 🏳️‍🌈"
# Username                       zacbrownband
# Gender                                 Male
# Vocation                      Entertainment
# Hashtags(#)                              []
# Total #                                   6
# Mentions(@)                              []
# Total @                                   9
# Likes                               1178118
# Retweets                             407455
# Images                          Image added
# Videos                          Video added
# Date                    2020-01-21 00:00:00
# Time                    1900-01-01 23:59:48
# Identity                       Jimmy Fallon
# dtype: object

# %%
new_identity_dict=identity_df.to_dict('records')

# %%
new_identity_dict
# Out:
# [{'_id': ObjectId('60be2af24a7a5d65a6b52b62'),
#   'level_0': 67767,
#   'index': 0,
#   'Tweet Id': '"1219799180723359744"',
#   'Name': '"KATY PERRY"',
#   'Username': 'katyperry',
#   'Gender': 'Female',
#   'Vocation': 'Music',
#   'Hashtags(#)': "['#ShoesdayTuesday']",
#   'Total #': 1,
#   'Mentions(@)': "['@kpcollections']",
#   'Total @': 1,
#   'Likes': 4037,
#   'Retweets': 503,
#   'Images': 'Image added',
#   'Videos': '-',
#   'Date': Timestamp('2020-01-22 00:00:00'),
#   'Time': Timestamp('1900-01-01 01:49:22'),
#   'Identity': 'Katy Perry'},
#  {'_id': ObjectId('60be2af24a7a5d65a6b52b63'),
#   'level_0': 67768,
#   'index': 1,
#   'Tweet Id': '"1219799180723359744"',
#   'Name': '"KATY PERRY"',
#   'Username': 'katyperry',
#   'Gender': 'Female',
#   'Vocation': 'Music',
#   'Hashtags(#)': "['#ShoesdayTuesday']",
#   'Total #': 1,
#   'Mentions(@)': "['@kpcollections']",
#   'Total @': 1,
#   'Likes': 4037,
#   'Retweets': 503,
#   'Images': 'Image added',
# ...
