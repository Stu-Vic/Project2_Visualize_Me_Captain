# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# #  Bill Gates Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %% [markdown]
# ##### READ THE TWEETS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedTweets/BillGatesTweets.csv"

#Import the CSV into a pandas DataFrame
Tweets_df = pd.read_csv(csv_path, low_memory = False)
Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220006544789532678"
# 1     "1220006293282230277"
# 2     "1219750261268209664"
# 3     "1218240511137370112"
# 4     "1217863316548116480"
# ...                     ...
# 3195           "8984143579"
# 3196           "8983423241"
# 3197           "8983404594"
# 3198           "8981191030"
# 3199           "8972846963"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/billgates/status/122000654...  2020-01-22 15:33:21
# 1     https://twitter.com/billgates/status/122000629...  2020-01-22 15:32:21
# 2     https://twitter.com/billgates/status/121975026...  2020-01-21 22:34:58
# 3     https://twitter.com/billgates/status/121824051...  2020-01-17 18:35:46
# 4     https://twitter.com/billgates/status/121786331...  2020-01-16 17:36:56
# ...                                                 ...                  ...
# 3195    https://twitter.com/billgates/status/8984143579  2010-02-11 23:59:46
# 3196    https://twitter.com/billgates/status/8983423241  2010-02-11 23:40:36
# 3197    https://twitter.com/billgates/status/8983404594  2010-02-11 23:40:06
# 3198    https://twitter.com/billgates/status/8981191030  2010-02-11 22:41:32
# 3199    https://twitter.com/billgates/status/8972846963  2010-02-11 18:51:05
#
#                                           Tweet Content Tweet Type  \
# 0     "@gavi There are still too many children—many ...      Reply
# 1     "For twenty years, @gavi has worked to ensure ...      Tweet
# 2     "I had a fascinating conversation with Vaclav ...      Tweet
# 3     "It's great to see Microsoft's leadership in t...      Tweet
# 4     "These global health heroes have helped Bangla...      Tweet
# ...                                                 ...        ...
# 3195  "RT @bing: Blaise talks Spatial Search to the ...      Tweet
# 3196  "Here is the URL - RT @sacca: @BillGates A goo...      Tweet
# 3197                       "@sacca thanks for the URL!"      Reply
# 3198  "Afternoon TED session open w LXD dancers - an...      Tweet
# 3199  "RT @nothingbutnets: RT @GoodSamCA: Our @nothi...      Tweet
#
#                     Client  Retweets received  Likes received     User Id  \
# 0          Twitter Web App                168            1139  "50393960"
# 1          Twitter Web App                272            2366  "50393960"
# 2     Twitter Media Studio                650            4008  "50393960"
# 3          Twitter Web App               1280           10820  "50393960"
# 4     Twitter Media Studio               1082            3549  "50393960"
# ...                    ...                ...             ...         ...
# 3195    Twitter Web Client                 64              41  "50393960"
# 3196    Twitter Web Client                 91              48  "50393960"
# 3197    Twitter Web Client                  8               7  "50393960"
# 3198    Twitter Web Client                 55              22  "50393960"
# 3199    Twitter Web Client                 43              11  "50393960"
#
#               Name   Username Verified or Non-Verified  \
# 0     "Bill Gates"  billgates                 Verified
# 1     "Bill Gates"  billgates                 Verified
# 2     "Bill Gates"  billgates                 Verified
# 3     "Bill Gates"  billgates                 Verified
# 4     "Bill Gates"  billgates                 Verified
# ...            ...        ...                      ...
# 3195  "Bill Gates"  billgates                 Verified
# 3196  "Bill Gates"  billgates                 Verified
# 3197  "Bill Gates"  billgates                 Verified
# 3198  "Bill Gates"  billgates                 Verified
# 3199  "Bill Gates"  billgates                 Verified
#
#                         Profile URL Protected or Not Protected
# 0     https://twitter.com/billgates              Not Protected
# 1     https://twitter.com/billgates              Not Protected
# 2     https://twitter.com/billgates              Not Protected
# 3     https://twitter.com/billgates              Not Protected
# 4     https://twitter.com/billgates              Not Protected
# ...                             ...                        ...
# 3195  https://twitter.com/billgates              Not Protected
# 3196  https://twitter.com/billgates              Not Protected
# 3197  https://twitter.com/billgates              Not Protected
# 3198  https://twitter.com/billgates              Not Protected
# 3199  https://twitter.com/billgates              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Tweet Content", "Retweets received", "Likes received",
                       "Tweet Posted Time"]]
# "User Id",
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 7)

# %%
#Print the dataframe
Tweets_df.head()
# Out:
#                 Tweet Id          Name   Username  \
# 0  "1220006544789532678"  "Bill Gates"  billgates
# 1  "1220006293282230277"  "Bill Gates"  billgates
# 2  "1219750261268209664"  "Bill Gates"  billgates
# 3  "1218240511137370112"  "Bill Gates"  billgates
# 4  "1217863316548116480"  "Bill Gates"  billgates
#
#                                        Tweet Content  Retweets received  \
# 0  "@gavi There are still too many children—many ...                168
# 1  "For twenty years, @gavi has worked to ensure ...                272
# 2  "I had a fascinating conversation with Vaclav ...                650
# 3  "It's great to see Microsoft's leadership in t...               1280
# 4  "These global health heroes have helped Bangla...               1082
#
#    Likes received    Tweet Posted Time
# 0            1139  2020-01-22 15:33:21
# 1            2366  2020-01-22 15:32:21
# 2            4008  2020-01-21 22:34:58
# 3           10820  2020-01-17 18:35:46
# 4            3549  2020-01-16 17:36:56

# %% [markdown]
# ##### FILTER THROUGH TWEET CONTENTS TO EXTRACT HASHTAGS (#) AND MENTIONS(@)

# %%
df1 = Tweets_df[['Tweet Content']]
mention = df1['Tweet Content'].str.findall(r'@.*?(?=\s|$)')
hashtag = df1['Tweet Content'].str.findall(r'#.*?(?=\s|$)')
Tweets_df['Mentions(@)'] = mention
Tweets_df['Hashtags(#)'] = hashtag
#Tweets_df.head()
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ##### CREATE COLUMNS FOR THE COUNT OF #COMMENTS AND @MENTIONS PER ROW

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "#" in tag:
                count+=1
    return count 
                
Tweets_df['Total #'] = Tweets_df['Hashtags(#)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "@" in tag:
                count+=1
    return count 
                
Tweets_df['Total @'] = Tweets_df['Mentions(@)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name   Username  \
# 0     "1220006544789532678"  "Bill Gates"  billgates
# 1     "1220006293282230277"  "Bill Gates"  billgates
# 2     "1219750261268209664"  "Bill Gates"  billgates
# 3     "1218240511137370112"  "Bill Gates"  billgates
# 4     "1217863316548116480"  "Bill Gates"  billgates
# ...                     ...           ...        ...
# 3195           "8984143579"  "Bill Gates"  billgates
# 3196           "8983423241"  "Bill Gates"  billgates
# 3197           "8983404594"  "Bill Gates"  billgates
# 3198           "8981191030"  "Bill Gates"  billgates
# 3199           "8972846963"  "Bill Gates"  billgates
#
#                                           Tweet Content  Retweets received  \
# 0     "@gavi There are still too many children—many ...                168
# 1     "For twenty years, @gavi has worked to ensure ...                272
# 2     "I had a fascinating conversation with Vaclav ...                650
# 3     "It's great to see Microsoft's leadership in t...               1280
# 4     "These global health heroes have helped Bangla...               1082
# ...                                                 ...                ...
# 3195  "RT @bing: Blaise talks Spatial Search to the ...                 64
# 3196  "Here is the URL - RT @sacca: @BillGates A goo...                 91
# 3197                       "@sacca thanks for the URL!"                  8
# 3198  "Afternoon TED session open w LXD dancers - an...                 55
# 3199  "RT @nothingbutnets: RT @GoodSamCA: Our @nothi...                 43
#
#       Likes received    Tweet Posted Time  \
# 0               1139  2020-01-22 15:33:21
# 1               2366  2020-01-22 15:32:21
# 2               4008  2020-01-21 22:34:58
# 3              10820  2020-01-17 18:35:46
# 4               3549  2020-01-16 17:36:56
# ...              ...                  ...
# 3195              41  2010-02-11 23:59:46
# 3196              48  2010-02-11 23:40:36
# 3197               7  2010-02-11 23:40:06
# 3198              22  2010-02-11 22:41:32
# 3199              11  2010-02-11 18:51:05
#
#                                            Mentions(@)       Hashtags(#)  \
# 0                                              [@gavi]  [#VaccinesWork"]
# 1                                              [@gavi]                []
# 2                                                   []                []
# 3                                                   []                []
# 4                                                   []                []
# ...                                                ...               ...
# 3195                                          [@bing:]            [#TED]
# 3196                             [@sacca:, @BillGates]                []
# 3197                                          [@sacca]                []
# 3198                                                []                []
# 3199  [@nothingbutnets:, @GoodSamCA:, @nothingbutnets]                []
#
#       Total #  Total @
# 0           1        1
# 1           0        1
# 2           0        0
# 3           0        0
# 4           0        0
# ...       ...      ...
# 3195        1        1
# 3196        0        2
# 3197        0        1
# 3198        0        0
# 3199        0        3
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Tweets_df['Tweet Posted Time'] = Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Tweets_df["Date"] = date

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Tweets_df["Time"] = time
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 12)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name   Username  \
# 0     "1220006544789532678"  "Bill Gates"  billgates
# 1     "1220006293282230277"  "Bill Gates"  billgates
# 2     "1219750261268209664"  "Bill Gates"  billgates
# 3     "1218240511137370112"  "Bill Gates"  billgates
# 4     "1217863316548116480"  "Bill Gates"  billgates
# ...                     ...           ...        ...
# 3195           "8984143579"  "Bill Gates"  billgates
# 3196           "8983423241"  "Bill Gates"  billgates
# 3197           "8983404594"  "Bill Gates"  billgates
# 3198           "8981191030"  "Bill Gates"  billgates
# 3199           "8972846963"  "Bill Gates"  billgates
#
#                                           Tweet Content  Retweets received  \
# 0     "@gavi There are still too many children—many ...                168
# 1     "For twenty years, @gavi has worked to ensure ...                272
# 2     "I had a fascinating conversation with Vaclav ...                650
# 3     "It's great to see Microsoft's leadership in t...               1280
# 4     "These global health heroes have helped Bangla...               1082
# ...                                                 ...                ...
# 3195  "RT @bing: Blaise talks Spatial Search to the ...                 64
# 3196  "Here is the URL - RT @sacca: @BillGates A goo...                 91
# 3197                       "@sacca thanks for the URL!"                  8
# 3198  "Afternoon TED session open w LXD dancers - an...                 55
# 3199  "RT @nothingbutnets: RT @GoodSamCA: Our @nothi...                 43
#
#       Likes received                                       Mentions(@)  \
# 0               1139                                           [@gavi]
# 1               2366                                           [@gavi]
# 2               4008                                                []
# 3              10820                                                []
# 4               3549                                                []
# ...              ...                                               ...
# 3195              41                                          [@bing:]
# 3196              48                             [@sacca:, @BillGates]
# 3197               7                                          [@sacca]
# 3198              22                                                []
# 3199              11  [@nothingbutnets:, @GoodSamCA:, @nothingbutnets]
#
#            Hashtags(#)  Total #  Total @        Date      Time
# 0     [#VaccinesWork"]        1        1  2020-01-22  15:33:21
# 1                   []        0        1  2020-01-22  15:32:21
# 2                   []        0        0  2020-01-21  22:34:58
# 3                   []        0        0  2020-01-17  18:35:46
# 4                   []        0        0  2020-01-16  17:36:56
# ...                ...      ...      ...         ...       ...
# 3195            [#TED]        1        1  2010-02-11  23:59:46
# 3196                []        0        2  2010-02-11  23:40:36
# 3197                []        0        1  2010-02-11  23:40:06
# 3198                []        0        0  2010-02-11  22:41:32
# 3199                []        0        3  2010-02-11  18:51:05
#
# [3200 rows x 12 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE IMAGES CSV

# %%
#Create reference to CSV file
csv_path = "RenamedImages/BillGatesImages.csv"

#Import the CSV into a pandas DataFrame
Images_df = pd.read_csv(csv_path, low_memory = False)
Images_df
# Out:
#                    Tweet Id               Media Id  \
# 0     "1208204298401787905"  "1208204296577265669"
# 1     "1206631210530656256"  "1206624356819857408"
# 2     "1205168553583923201"  "1205168551973273607"
# 3     "1202283177211047940"  "1202283174706987008"
# 4     "1199479929768947712"  "1199479927311081472"
# ...                     ...                    ...
# 1069   "180082661547708420"   "180082661556097024"
# 1070   "162611965104099328"   "162611965112487936"
# 1071   "132231748900749312"   "132231748909137920"
# 1072   "128627696245809153"   "128627696254197760"
# 1073   "128600461971435521"   "128600461979824129"
#
#                                               Media URL  \
# 0       https://pbs.twimg.com/media/EMRnaAmWsAUoMKN.jpg
# 1     https://pbs.twimg.com/amplify_video_thumb/1206...
# 2       https://pbs.twimg.com/media/ELmeaarWwAcya7H.jpg
# 3       https://pbs.twimg.com/media/EK9eLWvWwAA4t14.jpg
# 4       https://pbs.twimg.com/media/EKVoo4aWoAALV9q.jpg
# ...                                                 ...
# 1069    https://pbs.twimg.com/media/An_IOgBCEAA2_GS.jpg
# 1070    https://pbs.twimg.com/media/AkG2uIDCEAA3rX_.jpg
# 1071    https://pbs.twimg.com/media/AdXIEzXCAAAO_W9.jpg
# 1072    https://pbs.twimg.com/media/Acj6NU-CIAAIkWG.jpg
# 1073    https://pbs.twimg.com/media/AcjhcFZCMAEpwJ7.jpg
#
#                     Tweet URL
# 0     https://t.co/wuXsQdUsBW
# 1     https://t.co/XZguGFYssO
# 2     https://t.co/tQTEyIaQj3
# 3     https://t.co/JQjdxFGxle
# 4     https://t.co/3rhl9PSfQt
# ...                       ...
# 1069     http://t.co/MM5x3saQ
# 1070     http://t.co/fqtmlcCU
# 1071     http://t.co/K3wjVAJa
# 1072     http://t.co/PdIhmr8L
# 1073     http://t.co/0UdaeXyF
#
# [1074 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Images_df = Images_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1074, 1)

# %% [markdown]
# ##### ADD A IMAGES COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Images column for images
Images_df['Images'] = "Image added"

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1074, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Images_df
# Out:
#                    Tweet Id       Images
# 0     "1208204298401787905"  Image added
# 1     "1206631210530656256"  Image added
# 2     "1205168553583923201"  Image added
# 3     "1202283177211047940"  Image added
# 4     "1199479929768947712"  Image added
# ...                     ...          ...
# 1069   "180082661547708420"  Image added
# 1070   "162611965104099328"  Image added
# 1071   "132231748900749312"  Image added
# 1072   "128627696245809153"  Image added
# 1073   "128600461971435521"  Image added
#
# [1074 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Images_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name   Username  \
# 0     "1220006544789532678"  "Bill Gates"  billgates
# 1     "1220006293282230277"  "Bill Gates"  billgates
# 2     "1219750261268209664"  "Bill Gates"  billgates
# 3     "1218240511137370112"  "Bill Gates"  billgates
# 4     "1217863316548116480"  "Bill Gates"  billgates
# ...                     ...           ...        ...
# 3245           "8984143579"  "Bill Gates"  billgates
# 3246           "8983423241"  "Bill Gates"  billgates
# 3247           "8983404594"  "Bill Gates"  billgates
# 3248           "8981191030"  "Bill Gates"  billgates
# 3249           "8972846963"  "Bill Gates"  billgates
#
#                                           Tweet Content  Retweets received  \
# 0     "@gavi There are still too many children—many ...                168
# 1     "For twenty years, @gavi has worked to ensure ...                272
# 2     "I had a fascinating conversation with Vaclav ...                650
# 3     "It's great to see Microsoft's leadership in t...               1280
# 4     "These global health heroes have helped Bangla...               1082
# ...                                                 ...                ...
# 3245  "RT @bing: Blaise talks Spatial Search to the ...                 64
# 3246  "Here is the URL - RT @sacca: @BillGates A goo...                 91
# 3247                       "@sacca thanks for the URL!"                  8
# 3248  "Afternoon TED session open w LXD dancers - an...                 55
# 3249  "RT @nothingbutnets: RT @GoodSamCA: Our @nothi...                 43
#
#       Likes received                                       Mentions(@)  \
# 0               1139                                           [@gavi]
# 1               2366                                           [@gavi]
# 2               4008                                                []
# 3              10820                                                []
# 4               3549                                                []
# ...              ...                                               ...
# 3245              41                                          [@bing:]
# 3246              48                             [@sacca:, @BillGates]
# 3247               7                                          [@sacca]
# 3248              22                                                []
# 3249              11  [@nothingbutnets:, @GoodSamCA:, @nothingbutnets]
#
#            Hashtags(#)  Total #  Total @        Date      Time Images
# 0     [#VaccinesWork"]        1        1  2020-01-22  15:33:21    NaN
# 1                   []        0        1  2020-01-22  15:32:21    NaN
# 2                   []        0        0  2020-01-21  22:34:58    NaN
# 3                   []        0        0  2020-01-17  18:35:46    NaN
# 4                   []        0        0  2020-01-16  17:36:56    NaN
# ...                ...      ...      ...         ...       ...    ...
# 3245            [#TED]        1        1  2010-02-11  23:59:46    NaN
# 3246                []        0        2  2010-02-11  23:40:36    NaN
# 3247                []        0        1  2010-02-11  23:40:06    NaN
# 3248                []        0        0  2010-02-11  22:41:32    NaN
# 3249                []        0        3  2010-02-11  18:51:05    NaN
#
# [3250 rows x 13 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE VIDEOS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedVideos/BillGatesVideos.csv"

#Import the CSV into a pandas DataFrame
Videos_df = pd.read_csv(csv_path, low_memory = False)
Videos_df
# Out:
#                   Tweet Id               Media Id  \
# 0    "1219750261268209664"  "1219748106062876672"
# 1    "1217863316548116480"  "1217549205591351296"
# 2    "1203887178192785411"  "1203887118956683264"
# 3    "1201876939427987459"  "1201876822146854912"
# 4    "1201591581385486336"  "1201589664806629376"
# ..                     ...                    ...
# 171   "658777527813558273"   "658777526999846912"
# 172   "657666563349348353"   "657666562313310212"
# 173   "636222254288896000"   "636222253986881536"
# 174   "560503503274008576"   "560503502326071296"
# 175   "514746736683016192"   "514746735693152256"
#
#                                              Media URL  \
# 0    https://video.twimg.com/amplify_video/12197481...
# 1    https://video.twimg.com/amplify_video/12175492...
# 2    https://video.twimg.com/tweet_video/ELUQ9MsU4A...
# 3    https://video.twimg.com/ext_tw_video/120187682...
# 4    https://video.twimg.com/amplify_video/12015896...
# ..                                                 ...
# 171  https://video.twimg.com/tweet_video/CSRyq6LWEA...
# 172  https://video.twimg.com/tweet_video/CSCAQQNWUA...
# 173  https://video.twimg.com/tweet_video/CNRQxOcWIA...
# 174  https://video.twimg.com/tweet_video/B8dO9zeCAA...
# 175  https://video.twimg.com/tweet_video/ByS_bcpIQA...
#
#                    Tweet URL
# 0    https://t.co/NBSLul2iMj
# 1    https://t.co/Kl6ADN43ux
# 2    https://t.co/kDnM81w8IF
# 3    https://t.co/VjIycC6Kig
# 4    https://t.co/2GkWeB6Ojj
# ..                       ...
# 171  https://t.co/zTpko8ZakU
# 172  https://t.co/XxrWqtxscX
# 173   http://t.co/NTXNoPAaG8
# 174   http://t.co/Ni7lJR17K6
# 175   http://t.co/L0tTe6tbGl
#
# [176 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Videos_df = Videos_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (176, 1)

# %% [markdown]
# ##### ADD A VIDEOS COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Videos column for images
Videos_df['Videos'] = "Video added"

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (176, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Videos_df
# Out:
#                   Tweet Id       Videos
# 0    "1219750261268209664"  Video added
# 1    "1217863316548116480"  Video added
# 2    "1203887178192785411"  Video added
# 3    "1201876939427987459"  Video added
# 4    "1201591581385486336"  Video added
# ..                     ...          ...
# 171   "658777527813558273"  Video added
# 172   "657666563349348353"  Video added
# 173   "636222254288896000"  Video added
# 174   "560503503274008576"  Video added
# 175   "514746736683016192"  Video added
#
# [176 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Videos_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name   Username  \
# 0     "1220006544789532678"  "Bill Gates"  billgates
# 1     "1220006293282230277"  "Bill Gates"  billgates
# 2     "1219750261268209664"  "Bill Gates"  billgates
# 3     "1218240511137370112"  "Bill Gates"  billgates
# 4     "1217863316548116480"  "Bill Gates"  billgates
# ...                     ...           ...        ...
# 3245           "8984143579"  "Bill Gates"  billgates
# 3246           "8983423241"  "Bill Gates"  billgates
# 3247           "8983404594"  "Bill Gates"  billgates
# 3248           "8981191030"  "Bill Gates"  billgates
# 3249           "8972846963"  "Bill Gates"  billgates
#
#                                           Tweet Content  Retweets received  \
# 0     "@gavi There are still too many children—many ...                168
# 1     "For twenty years, @gavi has worked to ensure ...                272
# 2     "I had a fascinating conversation with Vaclav ...                650
# 3     "It's great to see Microsoft's leadership in t...               1280
# 4     "These global health heroes have helped Bangla...               1082
# ...                                                 ...                ...
# 3245  "RT @bing: Blaise talks Spatial Search to the ...                 64
# 3246  "Here is the URL - RT @sacca: @BillGates A goo...                 91
# 3247                       "@sacca thanks for the URL!"                  8
# 3248  "Afternoon TED session open w LXD dancers - an...                 55
# 3249  "RT @nothingbutnets: RT @GoodSamCA: Our @nothi...                 43
#
#       Likes received                                       Mentions(@)  \
# 0               1139                                           [@gavi]
# 1               2366                                           [@gavi]
# 2               4008                                                []
# 3              10820                                                []
# 4               3549                                                []
# ...              ...                                               ...
# 3245              41                                          [@bing:]
# 3246              48                             [@sacca:, @BillGates]
# 3247               7                                          [@sacca]
# 3248              22                                                []
# 3249              11  [@nothingbutnets:, @GoodSamCA:, @nothingbutnets]
#
#            Hashtags(#)  Total #  Total @        Date      Time Images  \
# 0     [#VaccinesWork"]        1        1  2020-01-22  15:33:21    NaN
# 1                   []        0        1  2020-01-22  15:32:21    NaN
# 2                   []        0        0  2020-01-21  22:34:58    NaN
# 3                   []        0        0  2020-01-17  18:35:46    NaN
# 4                   []        0        0  2020-01-16  17:36:56    NaN
# ...                ...      ...      ...         ...       ...    ...
# 3245            [#TED]        1        1  2010-02-11  23:59:46    NaN
# 3246                []        0        2  2010-02-11  23:40:36    NaN
# 3247                []        0        1  2010-02-11  23:40:06    NaN
# 3248                []        0        0  2010-02-11  22:41:32    NaN
# 3249                []        0        3  2010-02-11  18:51:05    NaN
#
#            Videos
# 0             NaN
# 1             NaN
# 2     Video added
# 3             NaN
# 4     Video added
# ...           ...
# 3245          NaN
# 3246          NaN
# 3247          NaN
# 3248          NaN
# 3249          NaN
#
# [3250 rows x 14 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Gender column 
Tweets_df['Gender'] = "Male"

#Create an Vocation column 
Tweets_df['Vocation'] = "Technology"

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3250, 16)

# %%
#REPLACE ALL "NaN" FOR "-"
Tweets_df['Images'] = Tweets_df['Images'].fillna("-")
Tweets_df['Videos'] = Tweets_df['Videos'].fillna("-")

# %% [markdown]
# ##### RENAME THE COLUMNS FOR VISUAL PURPOSES

# %%
Tweets_df = Tweets_df.rename(columns={"Tweet Content":"Tweets"})
Tweets_df = Tweets_df.rename(columns={"Retweets received":"Retweets"})
Tweets_df = Tweets_df.rename(columns={"Likes received":"Likes"})

# %% [markdown]
# ##### REMOVE THE TWEETS COLUMN

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweets'], axis = 1)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name   Username  Retweets  Likes  \
# 0     "1220006544789532678"  "Bill Gates"  billgates       168   1139
# 1     "1220006293282230277"  "Bill Gates"  billgates       272   2366
# 2     "1219750261268209664"  "Bill Gates"  billgates       650   4008
# 3     "1218240511137370112"  "Bill Gates"  billgates      1280  10820
# 4     "1217863316548116480"  "Bill Gates"  billgates      1082   3549
# ...                     ...           ...        ...       ...    ...
# 3245           "8984143579"  "Bill Gates"  billgates        64     41
# 3246           "8983423241"  "Bill Gates"  billgates        91     48
# 3247           "8983404594"  "Bill Gates"  billgates         8      7
# 3248           "8981191030"  "Bill Gates"  billgates        55     22
# 3249           "8972846963"  "Bill Gates"  billgates        43     11
#
#                                            Mentions(@)       Hashtags(#)  \
# 0                                              [@gavi]  [#VaccinesWork"]
# 1                                              [@gavi]                []
# 2                                                   []                []
# 3                                                   []                []
# 4                                                   []                []
# ...                                                ...               ...
# 3245                                          [@bing:]            [#TED]
# 3246                             [@sacca:, @BillGates]                []
# 3247                                          [@sacca]                []
# 3248                                                []                []
# 3249  [@nothingbutnets:, @GoodSamCA:, @nothingbutnets]                []
#
#       Total #  Total @        Date      Time Images       Videos Gender  \
# 0           1        1  2020-01-22  15:33:21      -            -   Male
# 1           0        1  2020-01-22  15:32:21      -            -   Male
# 2           0        0  2020-01-21  22:34:58      -  Video added   Male
# 3           0        0  2020-01-17  18:35:46      -            -   Male
# 4           0        0  2020-01-16  17:36:56      -  Video added   Male
# ...       ...      ...         ...       ...    ...          ...    ...
# 3245        1        1  2010-02-11  23:59:46      -            -   Male
# 3246        0        2  2010-02-11  23:40:36      -            -   Male
# 3247        0        1  2010-02-11  23:40:06      -            -   Male
# 3248        0        0  2010-02-11  22:41:32      -            -   Male
# 3249        0        3  2010-02-11  18:51:05      -            -   Male
#
#         Vocation
# 0     Technology
# 1     Technology
# 2     Technology
# 3     Technology
# 4     Technology
# ...          ...
# 3245  Technology
# 3246  Technology
# 3247  Technology
# 3248  Technology
# 3249  Technology
#
# [3250 rows x 15 columns]

# %% [markdown]
# ##### RE-ORDER THE COLUMNS FOR VISUAL PURPOSES

# %%
#Re-organise the columns for visual purposes
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Gender", "Vocation", "Hashtags(#)", "Total #", "Mentions(@)", 
                       "Total @", "Likes", "Retweets", "Images", "Videos", "Date", "Time"]]

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Tweets_df = Tweets_df.set_index('Tweet Id')
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3250, 14)

# %%
#Print the dataframe
Tweets_df
# Out:
#                                Name   Username Gender    Vocation  \
# Tweet Id
# "1220006544789532678"  "Bill Gates"  billgates   Male  Technology
# "1220006293282230277"  "Bill Gates"  billgates   Male  Technology
# "1219750261268209664"  "Bill Gates"  billgates   Male  Technology
# "1218240511137370112"  "Bill Gates"  billgates   Male  Technology
# "1217863316548116480"  "Bill Gates"  billgates   Male  Technology
# ...                             ...        ...    ...         ...
# "8984143579"           "Bill Gates"  billgates   Male  Technology
# "8983423241"           "Bill Gates"  billgates   Male  Technology
# "8983404594"           "Bill Gates"  billgates   Male  Technology
# "8981191030"           "Bill Gates"  billgates   Male  Technology
# "8972846963"           "Bill Gates"  billgates   Male  Technology
#
#                             Hashtags(#)  Total #  \
# Tweet Id
# "1220006544789532678"  [#VaccinesWork"]        1
# "1220006293282230277"                []        0
# "1219750261268209664"                []        0
# "1218240511137370112"                []        0
# "1217863316548116480"                []        0
# ...                                 ...      ...
# "8984143579"                     [#TED]        1
# "8983423241"                         []        0
# "8983404594"                         []        0
# "8981191030"                         []        0
# "8972846963"                         []        0
#
#                                                             Mentions(@)  \
# Tweet Id
# "1220006544789532678"                                           [@gavi]
# "1220006293282230277"                                           [@gavi]
# "1219750261268209664"                                                []
# "1218240511137370112"                                                []
# "1217863316548116480"                                                []
# ...                                                                 ...
# "8984143579"                                                   [@bing:]
# "8983423241"                                      [@sacca:, @BillGates]
# "8983404594"                                                   [@sacca]
# "8981191030"                                                         []
# "8972846963"           [@nothingbutnets:, @GoodSamCA:, @nothingbutnets]
#
#                        Total @  Likes  Retweets Images       Videos  \
# Tweet Id
# "1220006544789532678"        1   1139       168      -            -
# "1220006293282230277"        1   2366       272      -            -
# "1219750261268209664"        0   4008       650      -  Video added
# "1218240511137370112"        0  10820      1280      -            -
# "1217863316548116480"        0   3549      1082      -  Video added
# ...                        ...    ...       ...    ...          ...
# "8984143579"                 1     41        64      -            -
# "8983423241"                 2     48        91      -            -
# "8983404594"                 1      7         8      -            -
# "8981191030"                 0     22        55      -            -
# "8972846963"                 3     11        43      -            -
#
#                              Date      Time
# Tweet Id
# "1220006544789532678"  2020-01-22  15:33:21
# "1220006293282230277"  2020-01-22  15:32:21
# "1219750261268209664"  2020-01-21  22:34:58
# "1218240511137370112"  2020-01-17  18:35:46
# "1217863316548116480"  2020-01-16  17:36:56
# ...                           ...       ...
# "8984143579"           2010-02-11  23:59:46
# "8983423241"           2010-02-11  23:40:36
# "8983404594"           2010-02-11  23:40:06
# "8981191030"           2010-02-11  22:41:32
# "8972846963"           2010-02-11  18:51:05
#
# [3250 rows x 14 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Tweets_df.to_csv('NewDataframes/BillGates_df.csv')
