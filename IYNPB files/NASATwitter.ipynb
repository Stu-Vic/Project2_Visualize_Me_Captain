# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# #  NASA Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %% [markdown]
# ##### READ THE TWEETS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedTweets/NASATweets.csv"

#Import the CSV into a pandas DataFrame
Tweets_df = pd.read_csv(csv_path, low_memory = False)
Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220149150765002752"
# 1     "1220126500843814912"
# 2     "1220124092336082946"
# 3     "1220107625980973056"
# 4     "1220092526738247680"
# ...                     ...
# 3195  "1124018015740289024"
# 3196  "1123965610004758528"
# 3197  "1123959959249661953"
# 3198  "1123952508920004608"
# 3199  "1123945236219215874"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/nasa/status/12201491507650...  2020-01-23 01:00:01
# 1     https://twitter.com/nasa/status/12201265008438...  2020-01-22 23:30:01
# 2     https://twitter.com/jimbridenstine/status/1220...  2020-01-22 23:20:27
# 3     https://twitter.com/nasa/status/12201076259809...  2020-01-22 22:15:01
# 4     https://twitter.com/nasa/status/12200925267382...  2020-01-22 21:15:01
# ...                                                 ...                  ...
# 3195  https://twitter.com/iss_research/status/112401...  2019-05-02 18:29:12
# 3196  https://twitter.com/nasa/status/11239656100047...  2019-05-02 15:00:58
# 3197  https://twitter.com/nasa/status/11239599592496...  2019-05-02 14:38:31
# 3198  https://twitter.com/nasa/status/11239525089200...  2019-05-02 14:08:54
# 3199  https://twitter.com/nasa/status/11239452362192...  2019-05-02 13:40:00
#
#                                           Tweet Content Tweet Type  \
# 0     "Burn scars left by wildfires in southeastern ...      Tweet
# 1     "The search is on! Are you:\n\n☑️Curious about...      Tweet
# 2     "The team has successfully lowered the @NASA_S...    Retweet
# 3     "To help return astronauts to the Moon, our #A...      Tweet
# 4     "The legacy of @NASASpitzer will live on! Afte...      Tweet
# ...                                                 ...        ...
# 3195  "The #science aboard @SpaceX #Dragon will help...    Retweet
# 3196  "LIVE from @NASAKennedy: Experts from @SpaceX,...      Tweet
# 3197  "We’re preparing to launch a rocket tomorrow! ...      Tweet
# 3198  "This morning, Mission Control teams successfu...      Tweet
# 3199  "3-2-1… LIFTOFF! 🚀 @BlueOrigin’s #NewShepard r...      Tweet
#
#                     Client  Retweets received  Likes received      User Id  \
# 0                 Sprinklr                312            1192   "11348282"
# 1                 Sprinklr                170            1098   "11348282"
# 2          Twitter Web App                304            2107  "243418245"
# 3                 Sprinklr                454            2888   "11348282"
# 4                 Sprinklr                662            3578   "11348282"
# ...                    ...                ...             ...          ...
# 3195  Twitter Media Studio                385            1725  "189253902"
# 3196              Sprinklr                171            1147   "11348282"
# 3197              Sprinklr                426            2948   "11348282"
# 3198              Sprinklr                256            1699   "11348282"
# 3199          SnappyTV.com               1393            6656   "11348282"
#
#                    Name        Username Verified or Non-Verified  \
# 0                "NASA"            nasa                 Verified
# 1                "NASA"            nasa                 Verified
# 2     "Jim Bridenstine"  jimbridenstine                 Verified
# 3                "NASA"            nasa                 Verified
# 4                "NASA"            nasa                 Verified
# ...                 ...             ...                      ...
# 3195     "ISS Research"    iss_research                 Verified
# 3196             "NASA"            nasa                 Verified
# 3197             "NASA"            nasa                 Verified
# 3198             "NASA"            nasa                 Verified
# 3199             "NASA"            nasa                 Verified
#
#                              Profile URL Protected or Not Protected
# 0               https://twitter.com/nasa              Not Protected
# 1               https://twitter.com/nasa              Not Protected
# 2     https://twitter.com/jimbridenstine              Not Protected
# 3               https://twitter.com/nasa              Not Protected
# 4               https://twitter.com/nasa              Not Protected
# ...                                  ...                        ...
# 3195    https://twitter.com/iss_research              Not Protected
# 3196            https://twitter.com/nasa              Not Protected
# 3197            https://twitter.com/nasa              Not Protected
# 3198            https://twitter.com/nasa              Not Protected
# 3199            https://twitter.com/nasa              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Tweet Content", "Retweets received", "Likes received",
                       "Tweet Posted Time"]]
# "User Id",
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 7)

# %%
#Print the dataframe
Tweets_df.head()
# Out:
#                 Tweet Id               Name        Username  \
# 0  "1220149150765002752"             "NASA"            nasa
# 1  "1220126500843814912"             "NASA"            nasa
# 2  "1220124092336082946"  "Jim Bridenstine"  jimbridenstine
# 3  "1220107625980973056"             "NASA"            nasa
# 4  "1220092526738247680"             "NASA"            nasa
#
#                                        Tweet Content  Retweets received  \
# 0  "Burn scars left by wildfires in southeastern ...                312
# 1  "The search is on! Are you:\n\n☑️Curious about...                170
# 2  "The team has successfully lowered the @NASA_S...                304
# 3  "To help return astronauts to the Moon, our #A...                454
# 4  "The legacy of @NASASpitzer will live on! Afte...                662
#
#    Likes received    Tweet Posted Time
# 0            1192  2020-01-23 01:00:01
# 1            1098  2020-01-22 23:30:01
# 2            2107  2020-01-22 23:20:27
# 3            2888  2020-01-22 22:15:01
# 4            3578  2020-01-22 21:15:01

# %% [markdown]
# ##### FILTER THROUGH TWEET CONTENTS TO EXTRACT HASHTAGS (#) AND MENTIONS(@)

# %%
df1 = Tweets_df[['Tweet Content']]
mention = df1['Tweet Content'].str.findall(r'@.*?(?=\s|$)')
hashtag = df1['Tweet Content'].str.findall(r'#.*?(?=\s|$)')
Tweets_df['Mentions(@)'] = mention
Tweets_df['Hashtags(#)'] = hashtag
#Tweets_df.head()
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ##### CREATE COLUMNS FOR THE COUNT OF #COMMENTS AND @MENTIONS PER ROW

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "#" in tag:
                count+=1
    return count 
                
Tweets_df['Total #'] = Tweets_df['Hashtags(#)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "@" in tag:
                count+=1
    return count 
                
Tweets_df['Total @'] = Tweets_df['Mentions(@)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id               Name        Username  \
# 0     "1220149150765002752"             "NASA"            nasa
# 1     "1220126500843814912"             "NASA"            nasa
# 2     "1220124092336082946"  "Jim Bridenstine"  jimbridenstine
# 3     "1220107625980973056"             "NASA"            nasa
# 4     "1220092526738247680"             "NASA"            nasa
# ...                     ...                ...             ...
# 3195  "1124018015740289024"     "ISS Research"    iss_research
# 3196  "1123965610004758528"             "NASA"            nasa
# 3197  "1123959959249661953"             "NASA"            nasa
# 3198  "1123952508920004608"             "NASA"            nasa
# 3199  "1123945236219215874"             "NASA"            nasa
#
#                                           Tweet Content  Retweets received  \
# 0     "Burn scars left by wildfires in southeastern ...                312
# 1     "The search is on! Are you:\n\n☑️Curious about...                170
# 2     "The team has successfully lowered the @NASA_S...                304
# 3     "To help return astronauts to the Moon, our #A...                454
# 4     "The legacy of @NASASpitzer will live on! Afte...                662
# ...                                                 ...                ...
# 3195  "The #science aboard @SpaceX #Dragon will help...                385
# 3196  "LIVE from @NASAKennedy: Experts from @SpaceX,...                171
# 3197  "We’re preparing to launch a rocket tomorrow! ...                426
# 3198  "This morning, Mission Control teams successfu...                256
# 3199  "3-2-1… LIFTOFF! 🚀 @BlueOrigin’s #NewShepard r...               1393
#
#       Likes received    Tweet Posted Time  \
# 0               1192  2020-01-23 01:00:01
# 1               1098  2020-01-22 23:30:01
# 2               2107  2020-01-22 23:20:27
# 3               2888  2020-01-22 22:15:01
# 4               3578  2020-01-22 21:15:01
# ...              ...                  ...
# 3195            1725  2019-05-02 18:29:12
# 3196            1147  2019-05-02 15:00:58
# 3197            2948  2019-05-02 14:38:31
# 3198            1699  2019-05-02 14:08:54
# 3199            6656  2019-05-02 13:40:00
#
#                                             Mentions(@)          Hashtags(#)  \
# 0                                    [@NOAA/@NASAEarth]                   []
# 1                                       [@NASA_Wallops]        [#NASASocial]
# 2                             [@NASA_SLS, @NASAStennis]                   []
# 3                                                    []           [#Artemis]
# 4                                        [@NASASpitzer]                   []
# ...                                                 ...                  ...
# 3195                                          [@SpaceX]  [#science, #Dragon]
# 3196  [@NASAKennedy:, @SpaceX,, @NASAKennedy,, @Spac...           [#AskNASA]
# 3197         [@SpaceX,, @Space_Station, @45thSpaceWing]           [#AskNASA]
# 3198                                   [@Space_Station]                   []
# 3199        [@BlueOrigin’s, @NASA_Technology-supported]        [#NewShepard]
#
#       Total #  Total @
# 0           0        1
# 1           1        1
# 2           0        2
# 3           1        0
# 4           0        1
# ...       ...      ...
# 3195        2        1
# 3196        1        5
# 3197        1        3
# 3198        0        1
# 3199        1        2
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Tweets_df['Tweet Posted Time'] = Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Tweets_df["Date"] = date

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Tweets_df["Time"] = time
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 12)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id               Name        Username  \
# 0     "1220149150765002752"             "NASA"            nasa
# 1     "1220126500843814912"             "NASA"            nasa
# 2     "1220124092336082946"  "Jim Bridenstine"  jimbridenstine
# 3     "1220107625980973056"             "NASA"            nasa
# 4     "1220092526738247680"             "NASA"            nasa
# ...                     ...                ...             ...
# 3195  "1124018015740289024"     "ISS Research"    iss_research
# 3196  "1123965610004758528"             "NASA"            nasa
# 3197  "1123959959249661953"             "NASA"            nasa
# 3198  "1123952508920004608"             "NASA"            nasa
# 3199  "1123945236219215874"             "NASA"            nasa
#
#                                           Tweet Content  Retweets received  \
# 0     "Burn scars left by wildfires in southeastern ...                312
# 1     "The search is on! Are you:\n\n☑️Curious about...                170
# 2     "The team has successfully lowered the @NASA_S...                304
# 3     "To help return astronauts to the Moon, our #A...                454
# 4     "The legacy of @NASASpitzer will live on! Afte...                662
# ...                                                 ...                ...
# 3195  "The #science aboard @SpaceX #Dragon will help...                385
# 3196  "LIVE from @NASAKennedy: Experts from @SpaceX,...                171
# 3197  "We’re preparing to launch a rocket tomorrow! ...                426
# 3198  "This morning, Mission Control teams successfu...                256
# 3199  "3-2-1… LIFTOFF! 🚀 @BlueOrigin’s #NewShepard r...               1393
#
#       Likes received                                        Mentions(@)  \
# 0               1192                                 [@NOAA/@NASAEarth]
# 1               1098                                    [@NASA_Wallops]
# 2               2107                          [@NASA_SLS, @NASAStennis]
# 3               2888                                                 []
# 4               3578                                     [@NASASpitzer]
# ...              ...                                                ...
# 3195            1725                                          [@SpaceX]
# 3196            1147  [@NASAKennedy:, @SpaceX,, @NASAKennedy,, @Spac...
# 3197            2948         [@SpaceX,, @Space_Station, @45thSpaceWing]
# 3198            1699                                   [@Space_Station]
# 3199            6656        [@BlueOrigin’s, @NASA_Technology-supported]
#
#               Hashtags(#)  Total #  Total @        Date      Time
# 0                      []        0        1  2020-01-23  01:00:01
# 1           [#NASASocial]        1        1  2020-01-22  23:30:01
# 2                      []        0        2  2020-01-22  23:20:27
# 3              [#Artemis]        1        0  2020-01-22  22:15:01
# 4                      []        0        1  2020-01-22  21:15:01
# ...                   ...      ...      ...         ...       ...
# 3195  [#science, #Dragon]        2        1  2019-05-02  18:29:12
# 3196           [#AskNASA]        1        5  2019-05-02  15:00:58
# 3197           [#AskNASA]        1        3  2019-05-02  14:38:31
# 3198                   []        0        1  2019-05-02  14:08:54
# 3199        [#NewShepard]        1        2  2019-05-02  13:40:00
#
# [3200 rows x 12 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE IMAGES CSV

# %%
#Create reference to CSV file
csv_path = "RenamedImages/NASAImages.csv"

#Import the CSV into a pandas DataFrame
Images_df = pd.read_csv(csv_path, low_memory = False)
Images_df
# Out:
#                    Tweet Id               Media Id  \
# 0     "1220149150765002752"  "1220149149368311812"
# 1     "1220126500843814912"  "1220126499065466881"
# 2     "1220124092336082946"  "1220124085801422853"
# 3     "1220107625980973056"  "1220107624064212993"
# 4     "1220092526738247680"  "1220092524955602944"
# ...                     ...                    ...
# 2176  "1124358972977422336"  "1124358670043766784"
# 2177  "1124132721742237697"  "1124132720400064513"
# 2178  "1124064272072552455"  "1124064270961061893"
# 2179  "1123959959249661953"  "1123959957597114368"
# 2180  "1123952508920004608"  "1123952507225505792"
#
#                                             Media URL                Tweet URL
# 0     https://pbs.twimg.com/media/EO7XL80X4AQJgL4.jpg  https://t.co/jXZ2pDkRVg
# 1     https://pbs.twimg.com/media/EO7Clh3WkAEGEQQ.jpg  https://t.co/GfFSCHGgr3
# 2     https://pbs.twimg.com/media/EO7AZDwXkAUpIwE.jpg  https://t.co/giC8Una8NC
# 3     https://pbs.twimg.com/media/EO6xa3AX4AEIDbo.jpg  https://t.co/TYfmUaV9q5
# 4     https://pbs.twimg.com/media/EO6jr-cWkAAyJVB.jpg  https://t.co/brWOYQNtaz
# ...                                               ...                      ...
# 2176  https://pbs.twimg.com/media/D5qGQNgW4AAUZxP.jpg  https://t.co/5wpGrWnIWi
# 2177  https://pbs.twimg.com/media/D5m4wNfW4AEtIos.jpg  https://t.co/V4zxY7PHwF
# 2178  https://pbs.twimg.com/media/D5l6f7dXsAUKmNp.jpg  https://t.co/8j1sTTXUiO
# 2179  https://pbs.twimg.com/media/D5kboF5W0AA-l8C.jpg  https://t.co/xJo7XEUp88
# 2180  https://pbs.twimg.com/media/D5kU2bGWAAAswbw.jpg  https://t.co/QD8lpvxpbQ
#
# [2181 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Images_df = Images_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2181, 1)

# %% [markdown]
# ##### ADD A IMAGES COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Images column for images
Images_df['Images'] = "Image added"

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2181, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Images_df
# Out:
#                    Tweet Id       Images
# 0     "1220149150765002752"  Image added
# 1     "1220126500843814912"  Image added
# 2     "1220124092336082946"  Image added
# 3     "1220107625980973056"  Image added
# 4     "1220092526738247680"  Image added
# ...                     ...          ...
# 2176  "1124358972977422336"  Image added
# 2177  "1124132721742237697"  Image added
# 2178  "1124064272072552455"  Image added
# 2179  "1123959959249661953"  Image added
# 2180  "1123952508920004608"  Image added
#
# [2181 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Images_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id               Name        Username  \
# 0     "1220149150765002752"             "NASA"            nasa
# 1     "1220126500843814912"             "NASA"            nasa
# 2     "1220124092336082946"  "Jim Bridenstine"  jimbridenstine
# 3     "1220107625980973056"             "NASA"            nasa
# 4     "1220092526738247680"             "NASA"            nasa
# ...                     ...                ...             ...
# 3802  "1124018015740289024"     "ISS Research"    iss_research
# 3803  "1123965610004758528"             "NASA"            nasa
# 3804  "1123959959249661953"             "NASA"            nasa
# 3805  "1123952508920004608"             "NASA"            nasa
# 3806  "1123945236219215874"             "NASA"            nasa
#
#                                           Tweet Content  Retweets received  \
# 0     "Burn scars left by wildfires in southeastern ...                312
# 1     "The search is on! Are you:\n\n☑️Curious about...                170
# 2     "The team has successfully lowered the @NASA_S...                304
# 3     "To help return astronauts to the Moon, our #A...                454
# 4     "The legacy of @NASASpitzer will live on! Afte...                662
# ...                                                 ...                ...
# 3802  "The #science aboard @SpaceX #Dragon will help...                385
# 3803  "LIVE from @NASAKennedy: Experts from @SpaceX,...                171
# 3804  "We’re preparing to launch a rocket tomorrow! ...                426
# 3805  "This morning, Mission Control teams successfu...                256
# 3806  "3-2-1… LIFTOFF! 🚀 @BlueOrigin’s #NewShepard r...               1393
#
#       Likes received                                        Mentions(@)  \
# 0               1192                                 [@NOAA/@NASAEarth]
# 1               1098                                    [@NASA_Wallops]
# 2               2107                          [@NASA_SLS, @NASAStennis]
# 3               2888                                                 []
# 4               3578                                     [@NASASpitzer]
# ...              ...                                                ...
# 3802            1725                                          [@SpaceX]
# 3803            1147  [@NASAKennedy:, @SpaceX,, @NASAKennedy,, @Spac...
# 3804            2948         [@SpaceX,, @Space_Station, @45thSpaceWing]
# 3805            1699                                   [@Space_Station]
# 3806            6656        [@BlueOrigin’s, @NASA_Technology-supported]
#
#               Hashtags(#)  Total #  Total @        Date      Time       Images
# 0                      []        0        1  2020-01-23  01:00:01  Image added
# 1           [#NASASocial]        1        1  2020-01-22  23:30:01  Image added
# 2                      []        0        2  2020-01-22  23:20:27  Image added
# 3              [#Artemis]        1        0  2020-01-22  22:15:01  Image added
# 4                      []        0        1  2020-01-22  21:15:01  Image added
# ...                   ...      ...      ...         ...       ...          ...
# 3802  [#science, #Dragon]        2        1  2019-05-02  18:29:12          NaN
# 3803           [#AskNASA]        1        5  2019-05-02  15:00:58          NaN
# 3804           [#AskNASA]        1        3  2019-05-02  14:38:31  Image added
# 3805                   []        0        1  2019-05-02  14:08:54  Image added
# 3806        [#NewShepard]        1        2  2019-05-02  13:40:00          NaN
#
# [3807 rows x 13 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE VIDEOS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedVideos/NASAVideos.csv"

#Import the CSV into a pandas DataFrame
Videos_df = pd.read_csv(csv_path, low_memory = False)
Videos_df
# Out:
#                    Tweet Id               Media Id  \
# 0     "1219792769272684545"  "1219792757952274432"
# 1     "1219747031020982273"  "1218215124974043137"
# 2     "1219420549513994241"  "1219420465598488576"
# 3     "1219408395297529859"  "1219408379904434177"
# 4     "1219350405064396802"  "1219350316002566146"
# ...                     ...                    ...
# 1036  "1124194883416285184"  "1124194859605217280"
# 1037  "1124092377591840769"  "1124086091387158528"
# 1038  "1124018015740289024"  "1122970775307411457"
# 1039  "1123965610004758528"  "1123965585891762176"
# 1040  "1123945236219215874"  "1123945127230300161"
#
#                                               Media URL  \
# 0     https://video.twimg.com/tweet_video/EO2TDPVW4A...
# 1     https://video.twimg.com/amplify_video/12182151...
# 2     https://video.twimg.com/ext_tw_video/121942046...
# 3     https://video.twimg.com/tweet_video/EOw1dfhWoA...
# 4     https://video.twimg.com/ext_tw_video/121935031...
# ...                                                 ...
# 1036  https://video.twimg.com/tweet_video/D5nxRMEW0A...
# 1037  https://video.twimg.com/amplify_video/11240860...
# 1038  https://video.twimg.com/amplify_video/11229707...
# 1039  https://video.twimg.com/tweet_video/D5kgvs7XoA...
# 1040  https://video.twimg.com/amplify_video/11239451...
#
#                     Tweet URL
# 0     https://t.co/CVBd2a5E9B
# 1     https://t.co/hwB0CD3NTU
# 2     https://t.co/2LtmOn54Nu
# 3     https://t.co/urRMrjac7E
# 4     https://t.co/6pTrXra14b
# ...                       ...
# 1036  https://t.co/Gdg8KVzsFb
# 1037  https://t.co/8XGrfljeg5
# 1038  https://t.co/SEUsUr9Tvo
# 1039  https://t.co/2vlH7JYbnM
# 1040  https://t.co/UzZdkhaozB
#
# [1041 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Videos_df = Videos_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1041, 1)

# %% [markdown]
# ##### ADD A VIDEOS COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Videos column for images
Videos_df['Videos'] = "Video added"

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1041, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Videos_df
# Out:
#                    Tweet Id       Videos
# 0     "1219792769272684545"  Video added
# 1     "1219747031020982273"  Video added
# 2     "1219420549513994241"  Video added
# 3     "1219408395297529859"  Video added
# 4     "1219350405064396802"  Video added
# ...                     ...          ...
# 1036  "1124194883416285184"  Video added
# 1037  "1124092377591840769"  Video added
# 1038  "1124018015740289024"  Video added
# 1039  "1123965610004758528"  Video added
# 1040  "1123945236219215874"  Video added
#
# [1041 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Videos_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id               Name        Username  \
# 0     "1220149150765002752"             "NASA"            nasa
# 1     "1220126500843814912"             "NASA"            nasa
# 2     "1220124092336082946"  "Jim Bridenstine"  jimbridenstine
# 3     "1220107625980973056"             "NASA"            nasa
# 4     "1220092526738247680"             "NASA"            nasa
# ...                     ...                ...             ...
# 3802  "1124018015740289024"     "ISS Research"    iss_research
# 3803  "1123965610004758528"             "NASA"            nasa
# 3804  "1123959959249661953"             "NASA"            nasa
# 3805  "1123952508920004608"             "NASA"            nasa
# 3806  "1123945236219215874"             "NASA"            nasa
#
#                                           Tweet Content  Retweets received  \
# 0     "Burn scars left by wildfires in southeastern ...                312
# 1     "The search is on! Are you:\n\n☑️Curious about...                170
# 2     "The team has successfully lowered the @NASA_S...                304
# 3     "To help return astronauts to the Moon, our #A...                454
# 4     "The legacy of @NASASpitzer will live on! Afte...                662
# ...                                                 ...                ...
# 3802  "The #science aboard @SpaceX #Dragon will help...                385
# 3803  "LIVE from @NASAKennedy: Experts from @SpaceX,...                171
# 3804  "We’re preparing to launch a rocket tomorrow! ...                426
# 3805  "This morning, Mission Control teams successfu...                256
# 3806  "3-2-1… LIFTOFF! 🚀 @BlueOrigin’s #NewShepard r...               1393
#
#       Likes received                                        Mentions(@)  \
# 0               1192                                 [@NOAA/@NASAEarth]
# 1               1098                                    [@NASA_Wallops]
# 2               2107                          [@NASA_SLS, @NASAStennis]
# 3               2888                                                 []
# 4               3578                                     [@NASASpitzer]
# ...              ...                                                ...
# 3802            1725                                          [@SpaceX]
# 3803            1147  [@NASAKennedy:, @SpaceX,, @NASAKennedy,, @Spac...
# 3804            2948         [@SpaceX,, @Space_Station, @45thSpaceWing]
# 3805            1699                                   [@Space_Station]
# 3806            6656        [@BlueOrigin’s, @NASA_Technology-supported]
#
#               Hashtags(#)  Total #  Total @        Date      Time  \
# 0                      []        0        1  2020-01-23  01:00:01
# 1           [#NASASocial]        1        1  2020-01-22  23:30:01
# 2                      []        0        2  2020-01-22  23:20:27
# 3              [#Artemis]        1        0  2020-01-22  22:15:01
# 4                      []        0        1  2020-01-22  21:15:01
# ...                   ...      ...      ...         ...       ...
# 3802  [#science, #Dragon]        2        1  2019-05-02  18:29:12
# 3803           [#AskNASA]        1        5  2019-05-02  15:00:58
# 3804           [#AskNASA]        1        3  2019-05-02  14:38:31
# 3805                   []        0        1  2019-05-02  14:08:54
# 3806        [#NewShepard]        1        2  2019-05-02  13:40:00
#
#            Images       Videos
# 0     Image added          NaN
# 1     Image added          NaN
# 2     Image added          NaN
# 3     Image added          NaN
# 4     Image added          NaN
# ...           ...          ...
# 3802          NaN  Video added
# 3803          NaN  Video added
# 3804  Image added          NaN
# 3805  Image added          NaN
# 3806          NaN  Video added
#
# [3807 rows x 14 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Gender column 
Tweets_df['Gender'] = "Organisation"

#Create an Vocation column 
Tweets_df['Vocation'] = "Technology"

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3807, 16)

# %%
#REPLACE ALL "NaN" FOR "-"
Tweets_df['Images'] = Tweets_df['Images'].fillna("-")
Tweets_df['Videos'] = Tweets_df['Videos'].fillna("-")

# %% [markdown]
# ##### RENAME THE COLUMNS FOR VISUAL PURPOSES

# %%
Tweets_df = Tweets_df.rename(columns={"Tweet Content":"Tweets"})
Tweets_df = Tweets_df.rename(columns={"Retweets received":"Retweets"})
Tweets_df = Tweets_df.rename(columns={"Likes received":"Likes"})

# %% [markdown]
# ##### REMOVE THE TWEETS COLUMN

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweets'], axis = 1)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id               Name        Username  Retweets  \
# 0     "1220149150765002752"             "NASA"            nasa       312
# 1     "1220126500843814912"             "NASA"            nasa       170
# 2     "1220124092336082946"  "Jim Bridenstine"  jimbridenstine       304
# 3     "1220107625980973056"             "NASA"            nasa       454
# 4     "1220092526738247680"             "NASA"            nasa       662
# ...                     ...                ...             ...       ...
# 3802  "1124018015740289024"     "ISS Research"    iss_research       385
# 3803  "1123965610004758528"             "NASA"            nasa       171
# 3804  "1123959959249661953"             "NASA"            nasa       426
# 3805  "1123952508920004608"             "NASA"            nasa       256
# 3806  "1123945236219215874"             "NASA"            nasa      1393
#
#       Likes                                        Mentions(@)  \
# 0      1192                                 [@NOAA/@NASAEarth]
# 1      1098                                    [@NASA_Wallops]
# 2      2107                          [@NASA_SLS, @NASAStennis]
# 3      2888                                                 []
# 4      3578                                     [@NASASpitzer]
# ...     ...                                                ...
# 3802   1725                                          [@SpaceX]
# 3803   1147  [@NASAKennedy:, @SpaceX,, @NASAKennedy,, @Spac...
# 3804   2948         [@SpaceX,, @Space_Station, @45thSpaceWing]
# 3805   1699                                   [@Space_Station]
# 3806   6656        [@BlueOrigin’s, @NASA_Technology-supported]
#
#               Hashtags(#)  Total #  Total @        Date      Time  \
# 0                      []        0        1  2020-01-23  01:00:01
# 1           [#NASASocial]        1        1  2020-01-22  23:30:01
# 2                      []        0        2  2020-01-22  23:20:27
# 3              [#Artemis]        1        0  2020-01-22  22:15:01
# 4                      []        0        1  2020-01-22  21:15:01
# ...                   ...      ...      ...         ...       ...
# 3802  [#science, #Dragon]        2        1  2019-05-02  18:29:12
# 3803           [#AskNASA]        1        5  2019-05-02  15:00:58
# 3804           [#AskNASA]        1        3  2019-05-02  14:38:31
# 3805                   []        0        1  2019-05-02  14:08:54
# 3806        [#NewShepard]        1        2  2019-05-02  13:40:00
#
#            Images       Videos        Gender    Vocation
# 0     Image added            -  Organisation  Technology
# 1     Image added            -  Organisation  Technology
# 2     Image added            -  Organisation  Technology
# 3     Image added            -  Organisation  Technology
# 4     Image added            -  Organisation  Technology
# ...           ...          ...           ...         ...
# 3802            -  Video added  Organisation  Technology
# 3803            -  Video added  Organisation  Technology
# 3804  Image added            -  Organisation  Technology
# 3805  Image added            -  Organisation  Technology
# 3806            -  Video added  Organisation  Technology
#
# [3807 rows x 15 columns]

# %% [markdown]
# ##### RE-ORDER THE COLUMNS FOR VISUAL PURPOSES

# %%
#Re-organise the columns for visual purposes
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Gender", "Vocation", "Hashtags(#)", "Total #", "Mentions(@)", 
                       "Total @", "Likes", "Retweets", "Images", "Videos", "Date", "Time"]]

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Tweets_df = Tweets_df.set_index('Tweet Id')
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3807, 14)

# %%
#Print the dataframe
Tweets_df
# Out:
#                                     Name        Username        Gender  \
# Tweet Id
# "1220149150765002752"             "NASA"            nasa  Organisation
# "1220126500843814912"             "NASA"            nasa  Organisation
# "1220124092336082946"  "Jim Bridenstine"  jimbridenstine  Organisation
# "1220107625980973056"             "NASA"            nasa  Organisation
# "1220092526738247680"             "NASA"            nasa  Organisation
# ...                                  ...             ...           ...
# "1124018015740289024"     "ISS Research"    iss_research  Organisation
# "1123965610004758528"             "NASA"            nasa  Organisation
# "1123959959249661953"             "NASA"            nasa  Organisation
# "1123952508920004608"             "NASA"            nasa  Organisation
# "1123945236219215874"             "NASA"            nasa  Organisation
#
#                          Vocation          Hashtags(#)  Total #  \
# Tweet Id
# "1220149150765002752"  Technology                   []        0
# "1220126500843814912"  Technology        [#NASASocial]        1
# "1220124092336082946"  Technology                   []        0
# "1220107625980973056"  Technology           [#Artemis]        1
# "1220092526738247680"  Technology                   []        0
# ...                           ...                  ...      ...
# "1124018015740289024"  Technology  [#science, #Dragon]        2
# "1123965610004758528"  Technology           [#AskNASA]        1
# "1123959959249661953"  Technology           [#AskNASA]        1
# "1123952508920004608"  Technology                   []        0
# "1123945236219215874"  Technology        [#NewShepard]        1
#
#                                                              Mentions(@)  \
# Tweet Id
# "1220149150765002752"                                 [@NOAA/@NASAEarth]
# "1220126500843814912"                                    [@NASA_Wallops]
# "1220124092336082946"                          [@NASA_SLS, @NASAStennis]
# "1220107625980973056"                                                 []
# "1220092526738247680"                                     [@NASASpitzer]
# ...                                                                  ...
# "1124018015740289024"                                          [@SpaceX]
# "1123965610004758528"  [@NASAKennedy:, @SpaceX,, @NASAKennedy,, @Spac...
# "1123959959249661953"         [@SpaceX,, @Space_Station, @45thSpaceWing]
# "1123952508920004608"                                   [@Space_Station]
# "1123945236219215874"        [@BlueOrigin’s, @NASA_Technology-supported]
#
#                        Total @  Likes  Retweets       Images       Videos  \
# Tweet Id
# "1220149150765002752"        1   1192       312  Image added            -
# "1220126500843814912"        1   1098       170  Image added            -
# "1220124092336082946"        2   2107       304  Image added            -
# "1220107625980973056"        0   2888       454  Image added            -
# "1220092526738247680"        1   3578       662  Image added            -
# ...                        ...    ...       ...          ...          ...
# "1124018015740289024"        1   1725       385            -  Video added
# "1123965610004758528"        5   1147       171            -  Video added
# "1123959959249661953"        3   2948       426  Image added            -
# "1123952508920004608"        1   1699       256  Image added            -
# "1123945236219215874"        2   6656      1393            -  Video added
#
#                              Date      Time
# Tweet Id
# "1220149150765002752"  2020-01-23  01:00:01
# "1220126500843814912"  2020-01-22  23:30:01
# "1220124092336082946"  2020-01-22  23:20:27
# "1220107625980973056"  2020-01-22  22:15:01
# "1220092526738247680"  2020-01-22  21:15:01
# ...                           ...       ...
# "1124018015740289024"  2019-05-02  18:29:12
# "1123965610004758528"  2019-05-02  15:00:58
# "1123959959249661953"  2019-05-02  14:38:31
# "1123952508920004608"  2019-05-02  14:08:54
# "1123945236219215874"  2019-05-02  13:40:00
#
# [3807 rows x 14 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Tweets_df.to_csv('NewDataframes/NASA_df.csv')
