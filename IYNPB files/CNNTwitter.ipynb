# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# #  CNN Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %% [markdown]
# ##### READ THE TWEETS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedTweets/CNNTweets.csv"

#Import the CSV into a pandas DataFrame
Tweets_df = pd.read_csv(csv_path, low_memory = False)
Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220260325783756800"
# 1     "1220256373105184768"
# 2     "1220253611504099328"
# 3     "1220252471756566533"
# 4     "1220250580431536128"
# ...                     ...
# 3195  "1213148285172535296"
# 3196  "1213145517099749377"
# 3197  "1213143006934683649"
# 3198  "1213140493716140033"
# 3199  "1213137973279100929"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/cnn/status/122026032578375...  2020-01-23 08:21:47
# 1     https://twitter.com/cnn/status/122025637310518...  2020-01-23 08:06:05
# 2     https://twitter.com/cnn/status/122025361150409...  2020-01-23 07:55:06
# 3     https://twitter.com/cnn/status/122025247175656...  2020-01-23 07:50:35
# 4     https://twitter.com/cnn/status/122025058043153...  2020-01-23 07:43:04
# ...                                                 ...                  ...
# 3195  https://twitter.com/cnn/status/121314828517253...  2020-01-03 17:21:05
# 3196  https://twitter.com/cnn/status/121314551709974...  2020-01-03 17:10:05
# 3197  https://twitter.com/cnn/status/121314300693468...  2020-01-03 17:00:06
# 3198  https://twitter.com/cnn/status/121314049371614...  2020-01-03 16:50:07
# 3199  https://twitter.com/cnn/status/121313797327910...  2020-01-03 16:40:06
#
#                                           Tweet Content Tweet Type  \
# 0     "Airports around the world are increasing heal...      Tweet
# 1     "A state of emergency has been extended in New...      Tweet
# 2     "Three American crew members have died in Aust...      Tweet
# 3     "Police issued an arrest warrant for former NF...      Tweet
# 4     "Here are some things you can do to protect yo...      Tweet
# ...                                                 ...        ...
# 3195  "A rafflesia that recently bloomed in a West S...      Tweet
# 3196  "Kentucky's Attorney General says he's asking ...      Tweet
# 3197  "The American Kennel Club has announced two ne...      Tweet
# 3198  "Google has disabled access of Xiaomi devices ...      Tweet
# 3199  "Republican Sen. Lindsey Graham of South Carol...      Tweet
#
#           Client  Retweets received  Likes received   User Id   Name Username  \
# 0     SocialFlow                158             234  "759251"  "CNN"      cnn
# 1     SocialFlow                 91             251  "759251"  "CNN"      cnn
# 2     SocialFlow                 87             211  "759251"  "CNN"      cnn
# 3     SocialFlow                 41             109  "759251"  "CNN"      cnn
# 4     SocialFlow                135             257  "759251"  "CNN"      cnn
# ...          ...                ...             ...       ...    ...      ...
# 3195  SocialFlow                467            1742  "759251"  "CNN"      cnn
# 3196  SocialFlow                 69             326  "759251"  "CNN"      cnn
# 3197  SocialFlow                 60             246  "759251"  "CNN"      cnn
# 3198  SocialFlow                189             319  "759251"  "CNN"      cnn
# 3199  SocialFlow                630            1397  "759251"  "CNN"      cnn
#
#      Verified or Non-Verified              Profile URL  \
# 0                    Verified  https://twitter.com/cnn
# 1                    Verified  https://twitter.com/cnn
# 2                    Verified  https://twitter.com/cnn
# 3                    Verified  https://twitter.com/cnn
# 4                    Verified  https://twitter.com/cnn
# ...                       ...                      ...
# 3195                 Verified  https://twitter.com/cnn
# 3196                 Verified  https://twitter.com/cnn
# 3197                 Verified  https://twitter.com/cnn
# 3198                 Verified  https://twitter.com/cnn
# 3199                 Verified  https://twitter.com/cnn
#
#      Protected or Not Protected
# 0                 Not Protected
# 1                 Not Protected
# 2                 Not Protected
# 3                 Not Protected
# 4                 Not Protected
# ...                         ...
# 3195              Not Protected
# 3196              Not Protected
# 3197              Not Protected
# 3198              Not Protected
# 3199              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Tweet Content", "Retweets received", "Likes received",
                       "Tweet Posted Time"]]
# "User Id",
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 7)

# %%
#Print the dataframe
Tweets_df.head()
# Out:
#                 Tweet Id   Name Username  \
# 0  "1220260325783756800"  "CNN"      cnn
# 1  "1220256373105184768"  "CNN"      cnn
# 2  "1220253611504099328"  "CNN"      cnn
# 3  "1220252471756566533"  "CNN"      cnn
# 4  "1220250580431536128"  "CNN"      cnn
#
#                                        Tweet Content  Retweets received  \
# 0  "Airports around the world are increasing heal...                158
# 1  "A state of emergency has been extended in New...                 91
# 2  "Three American crew members have died in Aust...                 87
# 3  "Police issued an arrest warrant for former NF...                 41
# 4  "Here are some things you can do to protect yo...                135
#
#    Likes received    Tweet Posted Time
# 0             234  2020-01-23 08:21:47
# 1             251  2020-01-23 08:06:05
# 2             211  2020-01-23 07:55:06
# 3             109  2020-01-23 07:50:35
# 4             257  2020-01-23 07:43:04

# %% [markdown]
# ##### FILTER THROUGH TWEET CONTENTS TO EXTRACT HASHTAGS (#) AND MENTIONS(@)

# %%
df1 = Tweets_df[['Tweet Content']]
mention = df1['Tweet Content'].str.findall(r'@.*?(?=\s|$)')
hashtag = df1['Tweet Content'].str.findall(r'#.*?(?=\s|$)')
Tweets_df['Mentions(@)'] = mention
Tweets_df['Hashtags(#)'] = hashtag
#Tweets_df.head()
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ##### CREATE COLUMNS FOR THE COUNT OF #COMMENTS AND @MENTIONS PER ROW

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "#" in tag:
                count+=1
    return count 
                
Tweets_df['Total #'] = Tweets_df['Hashtags(#)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "@" in tag:
                count+=1
    return count 
                
Tweets_df['Total @'] = Tweets_df['Mentions(@)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id   Name Username  \
# 0     "1220260325783756800"  "CNN"      cnn
# 1     "1220256373105184768"  "CNN"      cnn
# 2     "1220253611504099328"  "CNN"      cnn
# 3     "1220252471756566533"  "CNN"      cnn
# 4     "1220250580431536128"  "CNN"      cnn
# ...                     ...    ...      ...
# 3195  "1213148285172535296"  "CNN"      cnn
# 3196  "1213145517099749377"  "CNN"      cnn
# 3197  "1213143006934683649"  "CNN"      cnn
# 3198  "1213140493716140033"  "CNN"      cnn
# 3199  "1213137973279100929"  "CNN"      cnn
#
#                                           Tweet Content  Retweets received  \
# 0     "Airports around the world are increasing heal...                158
# 1     "A state of emergency has been extended in New...                 91
# 2     "Three American crew members have died in Aust...                 87
# 3     "Police issued an arrest warrant for former NF...                 41
# 4     "Here are some things you can do to protect yo...                135
# ...                                                 ...                ...
# 3195  "A rafflesia that recently bloomed in a West S...                467
# 3196  "Kentucky's Attorney General says he's asking ...                 69
# 3197  "The American Kennel Club has announced two ne...                 60
# 3198  "Google has disabled access of Xiaomi devices ...                189
# 3199  "Republican Sen. Lindsey Graham of South Carol...                630
#
#       Likes received    Tweet Posted Time Mentions(@) Hashtags(#)  Total #  \
# 0                234  2020-01-23 08:21:47          []          []        0
# 1                251  2020-01-23 08:06:05          []          []        0
# 2                211  2020-01-23 07:55:06          []          []        0
# 3                109  2020-01-23 07:50:35          []          []        0
# 4                257  2020-01-23 07:43:04          []          []        0
# ...              ...                  ...         ...         ...      ...
# 3195            1742  2020-01-03 17:21:05          []          []        0
# 3196             326  2020-01-03 17:10:05          []          []        0
# 3197             246  2020-01-03 17:00:06          []          []        0
# 3198             319  2020-01-03 16:50:07          []          []        0
# 3199            1397  2020-01-03 16:40:06          []          []        0
#
#       Total @
# 0           0
# 1           0
# 2           0
# 3           0
# 4           0
# ...       ...
# 3195        0
# 3196        0
# 3197        0
# 3198        0
# 3199        0
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Tweets_df['Tweet Posted Time'] = Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Tweets_df["Date"] = date

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Tweets_df["Time"] = time
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 12)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id   Name Username  \
# 0     "1220260325783756800"  "CNN"      cnn
# 1     "1220256373105184768"  "CNN"      cnn
# 2     "1220253611504099328"  "CNN"      cnn
# 3     "1220252471756566533"  "CNN"      cnn
# 4     "1220250580431536128"  "CNN"      cnn
# ...                     ...    ...      ...
# 3195  "1213148285172535296"  "CNN"      cnn
# 3196  "1213145517099749377"  "CNN"      cnn
# 3197  "1213143006934683649"  "CNN"      cnn
# 3198  "1213140493716140033"  "CNN"      cnn
# 3199  "1213137973279100929"  "CNN"      cnn
#
#                                           Tweet Content  Retweets received  \
# 0     "Airports around the world are increasing heal...                158
# 1     "A state of emergency has been extended in New...                 91
# 2     "Three American crew members have died in Aust...                 87
# 3     "Police issued an arrest warrant for former NF...                 41
# 4     "Here are some things you can do to protect yo...                135
# ...                                                 ...                ...
# 3195  "A rafflesia that recently bloomed in a West S...                467
# 3196  "Kentucky's Attorney General says he's asking ...                 69
# 3197  "The American Kennel Club has announced two ne...                 60
# 3198  "Google has disabled access of Xiaomi devices ...                189
# 3199  "Republican Sen. Lindsey Graham of South Carol...                630
#
#       Likes received Mentions(@) Hashtags(#)  Total #  Total @        Date  \
# 0                234          []          []        0        0  2020-01-23
# 1                251          []          []        0        0  2020-01-23
# 2                211          []          []        0        0  2020-01-23
# 3                109          []          []        0        0  2020-01-23
# 4                257          []          []        0        0  2020-01-23
# ...              ...         ...         ...      ...      ...         ...
# 3195            1742          []          []        0        0  2020-01-03
# 3196             326          []          []        0        0  2020-01-03
# 3197             246          []          []        0        0  2020-01-03
# 3198             319          []          []        0        0  2020-01-03
# 3199            1397          []          []        0        0  2020-01-03
#
#           Time
# 0     08:21:47
# 1     08:06:05
# 2     07:55:06
# 3     07:50:35
# 4     07:43:04
# ...        ...
# 3195  17:21:05
# 3196  17:10:05
# 3197  17:00:06
# 3198  16:50:07
# 3199  16:40:06
#
# [3200 rows x 12 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE IMAGES CSV

# %%
#Create reference to CSV file
csv_path = "RenamedImages/CNNImages.csv"

#Import the CSV into a pandas DataFrame
Images_df = pd.read_csv(csv_path, low_memory = False)
Images_df
# Out:
#                   Tweet Id               Media Id  \
# 0    "1220260325783756800"  "1220260323590012928"
# 1    "1220244816262574080"  "1220244807492259840"
# 2    "1220244816262574080"  "1220244810554126336"
# 3    "1220242563153780736"  "1220242557587902465"
# 4    "1220242563153780736"  "1220242560817549312"
# ..                     ...                    ...
# 229  "1213456061396594688"  "1213456059907616768"
# 230  "1213274629592289280"  "1213274627855671297"
# 231  "1213220924369055745"  "1213220922259197952"
# 232  "1213217249751916544"  "1213217232945180672"
# 233  "1213203444896608257"  "1213203442832949249"
#
#                                            Media URL                Tweet URL
# 0    https://pbs.twimg.com/media/EO88TJEWAAAo2Xw.jpg  https://t.co/kNtuRhos5K
# 1    https://pbs.twimg.com/media/EO8uL_GXUAA5l5o.jpg  https://t.co/xE7kGslI14
# 2    https://pbs.twimg.com/media/EO8uMKgXsAAOZh_.jpg  https://t.co/xE7kGslI14
# 3    https://pbs.twimg.com/media/EO8sJBjXUAE4k0N.jpg  https://t.co/NFkAG305cb
# 4    https://pbs.twimg.com/media/EO8sJNlX0AATwUL.jpg  https://t.co/NFkAG305cb
# ..                                               ...                      ...
# 229  https://pbs.twimg.com/media/ENcP23lWsAAqrmt.jpg  https://t.co/7evA6AxGeV
# 230  https://pbs.twimg.com/media/ENZq2IhU4AEeV2o.jpg  https://t.co/v2V3wzzfr5
# 231  https://pbs.twimg.com/media/ENY6ADlU0AAlXRW.jpg  https://t.co/EifdRGZmG0
# 232  https://pbs.twimg.com/media/ENY2pT0UcAAenj5.jpg  https://t.co/El51Y6PAm0
# 233  https://pbs.twimg.com/media/ENYqGnpWwAEeKiL.jpg  https://t.co/ZYPCZG2Ts7
#
# [234 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Images_df = Images_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (234, 1)

# %% [markdown]
# ##### ADD A IMAGES COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Images column for images
Images_df['Images'] = "Image added"

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (234, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Images_df
# Out:
#                   Tweet Id       Images
# 0    "1220260325783756800"  Image added
# 1    "1220244816262574080"  Image added
# 2    "1220244816262574080"  Image added
# 3    "1220242563153780736"  Image added
# 4    "1220242563153780736"  Image added
# ..                     ...          ...
# 229  "1213456061396594688"  Image added
# 230  "1213274629592289280"  Image added
# 231  "1213220924369055745"  Image added
# 232  "1213217249751916544"  Image added
# 233  "1213203444896608257"  Image added
#
# [234 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Images_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id   Name Username  \
# 0     "1220260325783756800"  "CNN"      cnn
# 1     "1220256373105184768"  "CNN"      cnn
# 2     "1220253611504099328"  "CNN"      cnn
# 3     "1220252471756566533"  "CNN"      cnn
# 4     "1220250580431536128"  "CNN"      cnn
# ...                     ...    ...      ...
# 3240  "1213148285172535296"  "CNN"      cnn
# 3241  "1213145517099749377"  "CNN"      cnn
# 3242  "1213143006934683649"  "CNN"      cnn
# 3243  "1213140493716140033"  "CNN"      cnn
# 3244  "1213137973279100929"  "CNN"      cnn
#
#                                           Tweet Content  Retweets received  \
# 0     "Airports around the world are increasing heal...                158
# 1     "A state of emergency has been extended in New...                 91
# 2     "Three American crew members have died in Aust...                 87
# 3     "Police issued an arrest warrant for former NF...                 41
# 4     "Here are some things you can do to protect yo...                135
# ...                                                 ...                ...
# 3240  "A rafflesia that recently bloomed in a West S...                467
# 3241  "Kentucky's Attorney General says he's asking ...                 69
# 3242  "The American Kennel Club has announced two ne...                 60
# 3243  "Google has disabled access of Xiaomi devices ...                189
# 3244  "Republican Sen. Lindsey Graham of South Carol...                630
#
#       Likes received Mentions(@) Hashtags(#)  Total #  Total @        Date  \
# 0                234          []          []        0        0  2020-01-23
# 1                251          []          []        0        0  2020-01-23
# 2                211          []          []        0        0  2020-01-23
# 3                109          []          []        0        0  2020-01-23
# 4                257          []          []        0        0  2020-01-23
# ...              ...         ...         ...      ...      ...         ...
# 3240            1742          []          []        0        0  2020-01-03
# 3241             326          []          []        0        0  2020-01-03
# 3242             246          []          []        0        0  2020-01-03
# 3243             319          []          []        0        0  2020-01-03
# 3244            1397          []          []        0        0  2020-01-03
#
#           Time       Images
# 0     08:21:47  Image added
# 1     08:06:05          NaN
# 2     07:55:06          NaN
# 3     07:50:35          NaN
# 4     07:43:04          NaN
# ...        ...          ...
# 3240  17:21:05          NaN
# 3241  17:10:05          NaN
# 3242  17:00:06          NaN
# 3243  16:50:07          NaN
# 3244  16:40:06          NaN
#
# [3245 rows x 13 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE VIDEOS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedVideos/CNNVideos.csv"

#Import the CSV into a pandas DataFrame
Videos_df = pd.read_csv(csv_path, low_memory = False)
Videos_df
# Out:
#                   Tweet Id               Media Id  \
# 0    "1220240024190492672"  "1219321716758827013"
# 1    "1220236263363620864"  "1220206613052690435"
# 2    "1220228703583637504"  "1220165060510867457"
# 3    "1220224935647481856"  "1220207650903941120"
# 4    "1220221165253296129"  "1220201290338373632"
# ..                     ...                    ...
# 714  "1213165663193309184"  "1212824833437949952"
# 715  "1213160634352836609"  "1212480780737372164"
# 716  "1213155583794319361"  "1212826502691278850"
# 717  "1213153110127992833"  "1213152918444134401"
# 718  "1213143006934683649"  "1213141993355927553"
#
#                                              Media URL  \
# 0    https://video.twimg.com/amplify_video/12193217...
# 1    https://video.twimg.com/amplify_video/12202066...
# 2    https://video.twimg.com/amplify_video/12201650...
# 3    https://video.twimg.com/amplify_video/12202076...
# 4    https://video.twimg.com/amplify_video/12202012...
# ..                                                 ...
# 714  https://video.twimg.com/amplify_video/12128248...
# 715  https://video.twimg.com/amplify_video/12124807...
# 716  https://video.twimg.com/amplify_video/12128265...
# 717  https://video.twimg.com/amplify_video/12131529...
# 718  https://video.twimg.com/amplify_video/12131419...
#
#                    Tweet URL
# 0    https://t.co/b1PCJptd6k
# 1    https://t.co/Zfsx6Oh1dw
# 2    https://t.co/ktSwDUKkqF
# 3    https://t.co/I6kslUcw8z
# 4    https://t.co/B0tBJHRate
# ..                       ...
# 714  https://t.co/zGJHcZDb5F
# 715  https://t.co/hRAUt1B6j6
# 716  https://t.co/QFOsjKiaxR
# 717  https://t.co/cZV1xCRGt9
# 718  https://t.co/UXLnxwulUP
#
# [719 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Videos_df = Videos_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (719, 1)

# %% [markdown]
# ##### ADD A VIDEOS COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Videos column for images
Videos_df['Videos'] = "Video added"

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (719, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Videos_df
# Out:
#                   Tweet Id       Videos
# 0    "1220240024190492672"  Video added
# 1    "1220236263363620864"  Video added
# 2    "1220228703583637504"  Video added
# 3    "1220224935647481856"  Video added
# 4    "1220221165253296129"  Video added
# ..                     ...          ...
# 714  "1213165663193309184"  Video added
# 715  "1213160634352836609"  Video added
# 716  "1213155583794319361"  Video added
# 717  "1213153110127992833"  Video added
# 718  "1213143006934683649"  Video added
#
# [719 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Videos_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id   Name Username  \
# 0     "1220260325783756800"  "CNN"      cnn
# 1     "1220256373105184768"  "CNN"      cnn
# 2     "1220253611504099328"  "CNN"      cnn
# 3     "1220252471756566533"  "CNN"      cnn
# 4     "1220250580431536128"  "CNN"      cnn
# ...                     ...    ...      ...
# 3240  "1213148285172535296"  "CNN"      cnn
# 3241  "1213145517099749377"  "CNN"      cnn
# 3242  "1213143006934683649"  "CNN"      cnn
# 3243  "1213140493716140033"  "CNN"      cnn
# 3244  "1213137973279100929"  "CNN"      cnn
#
#                                           Tweet Content  Retweets received  \
# 0     "Airports around the world are increasing heal...                158
# 1     "A state of emergency has been extended in New...                 91
# 2     "Three American crew members have died in Aust...                 87
# 3     "Police issued an arrest warrant for former NF...                 41
# 4     "Here are some things you can do to protect yo...                135
# ...                                                 ...                ...
# 3240  "A rafflesia that recently bloomed in a West S...                467
# 3241  "Kentucky's Attorney General says he's asking ...                 69
# 3242  "The American Kennel Club has announced two ne...                 60
# 3243  "Google has disabled access of Xiaomi devices ...                189
# 3244  "Republican Sen. Lindsey Graham of South Carol...                630
#
#       Likes received Mentions(@) Hashtags(#)  Total #  Total @        Date  \
# 0                234          []          []        0        0  2020-01-23
# 1                251          []          []        0        0  2020-01-23
# 2                211          []          []        0        0  2020-01-23
# 3                109          []          []        0        0  2020-01-23
# 4                257          []          []        0        0  2020-01-23
# ...              ...         ...         ...      ...      ...         ...
# 3240            1742          []          []        0        0  2020-01-03
# 3241             326          []          []        0        0  2020-01-03
# 3242             246          []          []        0        0  2020-01-03
# 3243             319          []          []        0        0  2020-01-03
# 3244            1397          []          []        0        0  2020-01-03
#
#           Time       Images       Videos
# 0     08:21:47  Image added          NaN
# 1     08:06:05          NaN          NaN
# 2     07:55:06          NaN          NaN
# 3     07:50:35          NaN          NaN
# 4     07:43:04          NaN          NaN
# ...        ...          ...          ...
# 3240  17:21:05          NaN          NaN
# 3241  17:10:05          NaN          NaN
# 3242  17:00:06          NaN  Video added
# 3243  16:50:07          NaN          NaN
# 3244  16:40:06          NaN          NaN
#
# [3245 rows x 14 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Gender column 
Tweets_df['Gender'] = "Organisation"

#Create an Vocation column 
Tweets_df['Vocation'] = "News/Media"

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3245, 16)

# %%
#REPLACE ALL "NaN" FOR "-"
Tweets_df['Images'] = Tweets_df['Images'].fillna("-")
Tweets_df['Videos'] = Tweets_df['Videos'].fillna("-")

# %% [markdown]
# ##### RENAME THE COLUMNS FOR VISUAL PURPOSES

# %%
Tweets_df = Tweets_df.rename(columns={"Tweet Content":"Tweets"})
Tweets_df = Tweets_df.rename(columns={"Retweets received":"Retweets"})
Tweets_df = Tweets_df.rename(columns={"Likes received":"Likes"})

# %% [markdown]
# ##### REMOVE THE TWEETS COLUMN

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweets'], axis = 1)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id   Name Username  Retweets  Likes Mentions(@)  \
# 0     "1220260325783756800"  "CNN"      cnn       158    234          []
# 1     "1220256373105184768"  "CNN"      cnn        91    251          []
# 2     "1220253611504099328"  "CNN"      cnn        87    211          []
# 3     "1220252471756566533"  "CNN"      cnn        41    109          []
# 4     "1220250580431536128"  "CNN"      cnn       135    257          []
# ...                     ...    ...      ...       ...    ...         ...
# 3240  "1213148285172535296"  "CNN"      cnn       467   1742          []
# 3241  "1213145517099749377"  "CNN"      cnn        69    326          []
# 3242  "1213143006934683649"  "CNN"      cnn        60    246          []
# 3243  "1213140493716140033"  "CNN"      cnn       189    319          []
# 3244  "1213137973279100929"  "CNN"      cnn       630   1397          []
#
#      Hashtags(#)  Total #  Total @        Date      Time       Images  \
# 0             []        0        0  2020-01-23  08:21:47  Image added
# 1             []        0        0  2020-01-23  08:06:05            -
# 2             []        0        0  2020-01-23  07:55:06            -
# 3             []        0        0  2020-01-23  07:50:35            -
# 4             []        0        0  2020-01-23  07:43:04            -
# ...          ...      ...      ...         ...       ...          ...
# 3240          []        0        0  2020-01-03  17:21:05            -
# 3241          []        0        0  2020-01-03  17:10:05            -
# 3242          []        0        0  2020-01-03  17:00:06            -
# 3243          []        0        0  2020-01-03  16:50:07            -
# 3244          []        0        0  2020-01-03  16:40:06            -
#
#            Videos        Gender    Vocation
# 0               -  Organisation  News/Media
# 1               -  Organisation  News/Media
# 2               -  Organisation  News/Media
# 3               -  Organisation  News/Media
# 4               -  Organisation  News/Media
# ...           ...           ...         ...
# 3240            -  Organisation  News/Media
# 3241            -  Organisation  News/Media
# 3242  Video added  Organisation  News/Media
# 3243            -  Organisation  News/Media
# 3244            -  Organisation  News/Media
#
# [3245 rows x 15 columns]

# %% [markdown]
# ##### RE-ORDER THE COLUMNS FOR VISUAL PURPOSES

# %%
#Re-organise the columns for visual purposes
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Gender", "Vocation", "Hashtags(#)", "Total #", "Mentions(@)", 
                       "Total @", "Likes", "Retweets", "Images", "Videos", "Date", "Time"]]

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Tweets_df = Tweets_df.set_index('Tweet Id')
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3245, 14)

# %%
#Print the dataframe
Tweets_df
# Out:
#                         Name Username        Gender    Vocation Hashtags(#)  \
# Tweet Id
# "1220260325783756800"  "CNN"      cnn  Organisation  News/Media          []
# "1220256373105184768"  "CNN"      cnn  Organisation  News/Media          []
# "1220253611504099328"  "CNN"      cnn  Organisation  News/Media          []
# "1220252471756566533"  "CNN"      cnn  Organisation  News/Media          []
# "1220250580431536128"  "CNN"      cnn  Organisation  News/Media          []
# ...                      ...      ...           ...         ...         ...
# "1213148285172535296"  "CNN"      cnn  Organisation  News/Media          []
# "1213145517099749377"  "CNN"      cnn  Organisation  News/Media          []
# "1213143006934683649"  "CNN"      cnn  Organisation  News/Media          []
# "1213140493716140033"  "CNN"      cnn  Organisation  News/Media          []
# "1213137973279100929"  "CNN"      cnn  Organisation  News/Media          []
#
#                        Total # Mentions(@)  Total @  Likes  Retweets  \
# Tweet Id
# "1220260325783756800"        0          []        0    234       158
# "1220256373105184768"        0          []        0    251        91
# "1220253611504099328"        0          []        0    211        87
# "1220252471756566533"        0          []        0    109        41
# "1220250580431536128"        0          []        0    257       135
# ...                        ...         ...      ...    ...       ...
# "1213148285172535296"        0          []        0   1742       467
# "1213145517099749377"        0          []        0    326        69
# "1213143006934683649"        0          []        0    246        60
# "1213140493716140033"        0          []        0    319       189
# "1213137973279100929"        0          []        0   1397       630
#
#                             Images       Videos        Date      Time
# Tweet Id
# "1220260325783756800"  Image added            -  2020-01-23  08:21:47
# "1220256373105184768"            -            -  2020-01-23  08:06:05
# "1220253611504099328"            -            -  2020-01-23  07:55:06
# "1220252471756566533"            -            -  2020-01-23  07:50:35
# "1220250580431536128"            -            -  2020-01-23  07:43:04
# ...                            ...          ...         ...       ...
# "1213148285172535296"            -            -  2020-01-03  17:21:05
# "1213145517099749377"            -            -  2020-01-03  17:10:05
# "1213143006934683649"            -  Video added  2020-01-03  17:00:06
# "1213140493716140033"            -            -  2020-01-03  16:50:07
# "1213137973279100929"            -            -  2020-01-03  16:40:06
#
# [3245 rows x 14 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Tweets_df.to_csv('NewDataframes/CNN_df.csv')
