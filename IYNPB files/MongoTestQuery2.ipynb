# %%
# Set Up PyMongo
import pymongo
import pandas as pd
from flask import jsonify

client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Combined_Tweets"]

# Define A Person to Query
# Searches for non-empty hashtag results 
QueryIdentity = "Jimmy Fallon"
testoutput =  mongo_collection.find( { "Identity": QueryIdentity, "Hashtags(#)": {"$ne" : '[]'} },{ "_id": 0, "Hashtags(#)": 1} )

test_df = pd.DataFrame(list(testoutput))
test_df.head(50)
# Out:
#                                           Hashtags(#)
# 0                              ['#ThereShouldBeALaw']
# 1                              ['#ThereShouldBeALaw']
# 2                              ['#happybirthdaylin"']
# 3                                            ['#40"']
# 4                                  ['#FallonTonight']
# 5                            ['#DumbestFamilyFight"']
# 6                            ['#DumbestFamilyFight.']
# 7                                 ['#FallonTonight"']
# 8                         ['#FallonTonight', '#NBC"']
# 9                                 ['#FallonTonight"']
# 10                        ['#RuinAMovieWithOneWord"']
# 11                        ['#RuinAMovieWithOneWord.']
# 12                 ['#CNNNYE', '#JäGer', '#imagine"']
# 13                      ['#CNNNYE', '#HappyNewYear"']
# 14                                 ['#FallonTonight']
# 15                                    ['#ThisIsBaby']
# ...

# %%
eval(test_df['Hashtags(#)'][0])
# Out:
# ['#ThereShouldBeALaw']

# %%
import numpy as np 
# [eval(x) for x in test_df["Hashtags(#)"]]
testarray = [eval(x) for x in test_df["Hashtags(#)"]]
testarray
# Out:
# [['#ThereShouldBeALaw'],
#  ['#ThereShouldBeALaw'],
#  ['#happybirthdaylin"'],
#  ['#40"'],
#  ['#FallonTonight'],
#  ['#DumbestFamilyFight"'],
#  ['#DumbestFamilyFight.'],
#  ['#FallonTonight"'],
#  ['#FallonTonight', '#NBC"'],
#  ['#FallonTonight"'],
#  ['#RuinAMovieWithOneWord"'],
#  ['#RuinAMovieWithOneWord.'],
#  ['#CNNNYE', '#JäGer', '#imagine"'],
#  ['#CNNNYE', '#HappyNewYear"'],
#  ['#FallonTonight'],
#  ['#ThisIsBaby'],
#  ['#SNL'],
#  ['#HappyHolidays', '#GetTheF**kOutOfMyHouse'],
#  ['#JonathanGroff'],
#  ['#FallonTonight"'],
#  ['#InTheHeightsMovie', '#Summer2020'],
#  ['#FallonTonight'],
#  ['#FallonTonight"'],
#  ['#QLS'],
#  ['#2019MAMA'],
#  ['#TheSeriousGoose', '#GivingTuesday!'],
#  ['#FallonTonight"'],
#  ['#FallonTonight', '#PartyPatrol'],
#  ['#HappyThanksgiving', '#FallonThanksgiving'],
#  ['#MacysDayParade!', '#FallonThanksgiving', '#HappyThanksgiving"'],
#  ['#babyyoda', '#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
# ...

# %%
flatten_list = []
for l1 in testarray:
    for l2 in l1:
        l2 = l2.replace('"','')
        flatten_list.append(l2)
        
flatten_list
# Out:
# ['#ThereShouldBeALaw',
#  '#ThereShouldBeALaw',
#  '#happybirthdaylin',
#  '#40',
#  '#FallonTonight',
#  '#DumbestFamilyFight',
#  '#DumbestFamilyFight.',
#  '#FallonTonight',
#  '#FallonTonight',
#  '#NBC',
#  '#FallonTonight',
#  '#RuinAMovieWithOneWord',
#  '#RuinAMovieWithOneWord.',
#  '#CNNNYE',
#  '#JäGer',
#  '#imagine',
#  '#CNNNYE',
#  '#HappyNewYear',
#  '#FallonTonight',
#  '#ThisIsBaby',
#  '#SNL',
#  '#HappyHolidays',
#  '#GetTheF**kOutOfMyHouse',
#  '#JonathanGroff',
#  '#FallonTonight',
#  '#InTheHeightsMovie',
#  '#Summer2020',
#  '#FallonTonight',
#  '#FallonTonight',
#  '#QLS',
#  '#2019MAMA',
#  '#TheSeriousGoose',
#  '#GivingTuesday!',
#  '#FallonTonight',
#  '#FallonTonight',
#  '#PartyPatrol',
#  '#HappyThanksgiving',
#  '#FallonThanksgiving',
#  '#MacysDayParade!',
#  '#FallonThanksgiving',
#  '#HappyThanksgiving',
#  '#babyyoda',
#  '#FallonThanksgiving',
#  '#FallonThanksgiving',
#  '#FallonThanksgiving',
#  '#FallonThanksgiving',
#  '#FallonThanksgiving',
# ...

# %%
# def word_count(str):
#     counts = dict()
#     words = str.split()

#     for word in words:
#         if word in counts:
#             counts[word] += 1
#         else:
#             counts[word] = 1

#     return counts

# the_dict = word_count(flatten_list)
# the_dict

def word_count(input):
    counts = dict()
    
    for word in input:
        if word in counts:
            counts[word] += 1
        else:
            counts[word] = 1
    return counts
    
hashtag_dict = word_count(flatten_list)
hashtag_dict
# Out:
# {'#ThereShouldBeALaw': 2,
#  '#happybirthdaylin': 1,
#  '#40': 1,
#  '#FallonTonight': 1220,
#  '#DumbestFamilyFight': 1,
#  '#DumbestFamilyFight.': 1,
#  '#NBC': 16,
#  '#RuinAMovieWithOneWord': 1,
#  '#RuinAMovieWithOneWord.': 1,
#  '#CNNNYE': 2,
#  '#JäGer': 1,
#  '#imagine': 1,
#  '#HappyNewYear': 2,
#  '#ThisIsBaby': 8,
#  '#SNL': 8,
#  '#HappyHolidays': 1,
#  '#GetTheF**kOutOfMyHouse': 1,
#  '#JonathanGroff': 1,
#  '#InTheHeightsMovie': 1,
#  '#Summer2020': 1,
#  '#QLS': 1,
#  '#2019MAMA': 1,
#  '#TheSeriousGoose': 1,
#  '#GivingTuesday!': 1,
#  '#PartyPatrol': 1,
#  '#HappyThanksgiving': 5,
#  '#FallonThanksgiving': 16,
#  '#MacysDayParade!': 1,
#  '#babyyoda': 1,
#  '#thankful': 1,
#  '#FallonThanksGiving': 1,
#  '#ThanksGivingRuined': 1,
#  '#FeedingAmerica': 1,
#  '#StarWars': 1,
#  '#ReyRapRecap': 1,
#  '#TurkeyDayTraditions': 1,
#  '#TurkeyDayTraditions.': 1,
#  '#AmericanUtopia': 4,
#  '#Frozen2': 1,
#  '#FallonTonight!': 11,
#  '#BeiBei': 1,
#  '#DemDebate,': 1,
# ...

# %%
# sort_dict = sorted(the_dict.items(), key=lambda x: x[1], reverse=True)
x = hashtag_dict
sort_dict = {k: v for k, v in sorted(x.items(), key=lambda item: item[1], reverse=True)}
sort_dict
# for i in sort_dict:
#     print(i[0], i[1])
# Out:
# {'#FallonTonight': 1220,
#  '#ThankYouNoteFriday!': 76,
#  '#FallonLIVE': 24,
#  '#Fallon': 24,
#  '#BTSonFallon': 21,
#  '#TonightShowPuertoRico': 20,
#  '#ArianaOnFallon': 19,
#  '#NBC': 16,
#  '#FallonThanksgiving': 16,
#  '#TonightShowSummerReads': 15,
#  '#FallonOrlando': 15,
#  '#FallonRide': 14,
#  '#HandsHigh': 12,
#  '#FallonTonight!': 11,
#  '#HamiltonPR': 10,
#  '#MyWeirdRoommate': 10,
#  '#TBT': 9,
#  '#EgyptStation': 9,
#  '#ThisIsBaby': 8,
#  '#SNL': 8,
#  '#FallonAtUT': 7,
#  '#FallSongs': 7,
#  '#MomQuotes': 7,
#  '#BTSonFALLON': 7,
#  '#KevinHartOnFallon': 7,
#  '#WhyImSingle': 7,
#  '#FallonFive': 7,
#  '#WorstFirstDate': 7,
#  '#MileyWeekOnFallon': 7,
#  '#ThisIsUs': 6,
#  '#AvengersEndgame': 6,
#  '#SuperBowl': 6,
#  '#TheVoice': 6,
#  '#Sweetener': 6,
#  '#MAMAbook': 6,
#  '#PepsiHalftime': 6,
#  '#12DaysOfChristmasSweaters!': 6,
#  '#HappyThanksgiving': 5,
#  '#1': 5,
#  '#TonightDough': 5,
#  '#PromFail': 5,
#  '#ThankYouNoteFriday': 5,
#  '#NoFlipping': 5,
# ...

# %%
dict_df = pd.DataFrame()
dict_df = pd.DataFrame(list(hashtag_dict.items()),columns = ['text','size']) 
dict_df.sort_values(['Count'], ascending=False, inplace=True)
dict_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-36-109aa25ed4c4> in <module>
#       1 dict_df = pd.DataFrame()
#       2 dict_df = pd.DataFrame(list(hashtag_dict.items()),columns = ['text','size'])
# ----> 3 dict_df.sort_values(['Count'], ascending=False, inplace=True)
#       4 dict_df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    5292
#    5293             by = by[0]
# -> 5294             k = self._get_label_or_level_values(by, axis=axis)
#    5295
#    5296             # need to rewrap column in Series to apply key function
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in _get_label_or_level_values(self, key, axis)
#    1561             values = self.axes[axis].get_level_values(key)._values
#    1562         else:
# ...

# %%
df = pd.DataFrame(list(my_dict.items()),columns = ['column1','column2'])

# %%
sorted_df = pd.DataFrame(sort_dict,columns=[['Hashtag','Count']])
sorted_df

# %%
testjsondf = pd.DataFrame(flatten_list,columns=['Identities'])
testjsondf

# %%
# Set up Pandas, Query Atlas for ALL results matching the twitter Identity 

identity_df = pd.DataFrame(list(mongo_collection.find({"Identity": QueryIdentity})))
# identity_df = pd.DataFrame(list(mongo_collection.find()))

# %%
Identity_List = identity_df["Identity"].unique()
print(Identity_List)

# %%
identity_df['Time'] = pd.to_datetime(identity_df["Time"],format='%H:%M:%S')
# mega_df["Time"] = mega_df["Time"].dt.time
identity_df["Date"] = pd.to_datetime(identity_df["Date"],format="%Y-%M-%d")

# %%
identity_df.head()

# %%
identity_df.groupby(pd.Grouper(key='Date', freq='D'))
identity_df.sum()

# %%
newlist = ['Akshay Kumar', 'Amitabh Bachchan', 'Ariana Grande', 'Barack Obama', 'BBC', 'Bill Gates', 'Britney Spears', 'Bruno Mars', 'CNN Breaking', 'CNN', 'Cristiano Ronaldo', 'Donald Trump', 'Drake', 'ESPN', 'FC Barcelona', 'Harry Styles', 'Instagram', 'Jimmy Fallon', 'J Lo', 'Justin Bieber', 'Justin Timberlake', 'Katy Perry', 'Kevin Hart', 'Kim Kardashian', 'Lady Gaga', 'Le Bron James', 'Liam Payne', 'Lil Wayne', 'Louis Tomlinson', 'Miley Cyrus', 'Narendra Modi', 'NASA', 'Neymar Jr', 'Niall Horan', 'NY Times', 'Oprah', 'Pink', 'Real Madrid', 'Rihanna', 'Salman Khan', 'Selena Gomez', 'Shah Rukh Khan', 'Shakira', 'Sports Center', 'Taylor Swift', 'The Ellen Show', 'Twitter', 'Virat Kohli', 'Wiz Khalifa', 'Youtube']

# %%
for x in newlist:
    print(x)
