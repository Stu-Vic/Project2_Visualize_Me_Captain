# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Akshay Kumar Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd
import os

# %% [markdown]
# ##### READ THE TWEETS CSV

# %%
#Create reference to CSV file
cwd = os.getcwd()
print(cwd)
csv_path = "AkshayKumarTweets.csv"

#Import the CSV into a pandas DataFrame
Tweets_df = pd.read_csv(csv_path, low_memory = False)
Tweets_df
# Out:
# /Users/ankita/Documents/Workspace/projects/Project2/Project2_Visualize_Me_Captain/IYNPB files
#                    Tweet Id  \
# 0     "1220262518519521281"
# 1     "1220236816604749824"
# 2     "1219804361133477890"
# 3     "1219491375793635329"
# 4     "1219156453354655745"
# ...                     ...
# 3195   "941559727670087680"
# 3196   "941559726827073536"
# 3197   "941559726223052800"
# 3198   "941559725099028480"
# 3199   "941559724264296448"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/akshaykumar/status/1220262...  2020-01-23 08:30:30
# 1     https://twitter.com/akshaykumar/status/1220236...  2020-01-23 06:48:22
# 2     https://twitter.com/akshaykumar/status/1219804...  2020-01-22 02:09:57
# 3     https://twitter.com/akshaykumar/status/1219491...  2020-01-21 05:26:15
# 4     https://twitter.com/akshaykumar/status/1219156...  2020-01-20 07:15:23
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3223, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Tweet Content", "Retweets received", "Likes received",
                       "Tweet Posted Time"]]
# "User Id",
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 7)

# %%
#Print the dataframe
Tweets_df.head()
# Out:
#                 Tweet Id            Name     Username  \
# 0  "1220262518519521281"  "Akshay Kumar"  akshaykumar
# 1  "1220236816604749824"  "Akshay Kumar"  akshaykumar
# 2  "1219804361133477890"  "Akshay Kumar"  akshaykumar
# 3  "1219491375793635329"  "Akshay Kumar"  akshaykumar
# 4  "1219156453354655745"  "Akshay Kumar"  akshaykumar
#
#                                        Tweet Content  Retweets received  \
# 0  "The story continues with another melody... #F...                740
# 1  "#Durgavati begins, with blessings and good vi...                790
# 2  "Just like the new #Activa6G, would you like t...               1076
# 3  "Do more of what you love doing and that’s exa...               1445
# 4  "Either you run the day or the day runs you 👊🏻...               1868
#
#    Likes received    Tweet Posted Time
# 0            3495  2020-01-23 08:30:30
# 1            7335  2020-01-23 06:48:22
# 2           11087  2020-01-22 02:09:57
# 3           19572  2020-01-21 05:26:15
# ...

# %% [markdown]
# ##### FILTER THROUGH TWEET CONTENTS TO EXTRACT HASHTAGS (#) AND MENTIONS(@)

# %%
df1 = Tweets_df[['Tweet Content']]
mention = df1['Tweet Content'].str.findall(r'@.*?(?=\s|$)')
hashtag = df1['Tweet Content'].str.findall(r'#.*?(?=\s|$)')
Tweets_df['Mentions(@)'] = mention
Tweets_df['Hashtags(#)'] = hashtag
#Tweets_df.head()
# Out:
# <ipython-input-12-bc7d1911e3f1>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_df['Mentions(@)'] = mention
# <ipython-input-12-bc7d1911e3f1>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_df['Hashtags(#)'] = hashtag

# %% [markdown]
# ##### CREATE COLUMNS FOR THE COUNT OF #COMMENTS AND @MENTIONS PER ROW

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "#" in tag:
                count+=1
    return count 
                
Tweets_df['Total #'] = Tweets_df['Hashtags(#)'].apply(totals)
# Out:
# <ipython-input-13-e2b51ef06bc8>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_df['Total #'] = Tweets_df['Hashtags(#)'].apply(totals)

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "@" in tag:
                count+=1
    return count 
                
Tweets_df['Total @'] = Tweets_df['Mentions(@)'].apply(totals)
# Out:
# <ipython-input-14-7d860a962521>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_df['Total @'] = Tweets_df['Mentions(@)'].apply(totals)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id            Name     Username  \
# 0     "1220262518519521281"  "Akshay Kumar"  akshaykumar
# 1     "1220236816604749824"  "Akshay Kumar"  akshaykumar
# 2     "1219804361133477890"  "Akshay Kumar"  akshaykumar
# 3     "1219491375793635329"  "Akshay Kumar"  akshaykumar
# 4     "1219156453354655745"  "Akshay Kumar"  akshaykumar
# ...                     ...             ...          ...
# 3195   "941559727670087680"  "Akshay Kumar"  akshaykumar
# 3196   "941559726827073536"  "Akshay Kumar"  akshaykumar
# 3197   "941559726223052800"  "Akshay Kumar"  akshaykumar
# 3198   "941559725099028480"  "Akshay Kumar"  akshaykumar
# 3199   "941559724264296448"  "Akshay Kumar"  akshaykumar
#
#                                           Tweet Content  Retweets received  \
# 0     "The story continues with another melody... #F...                740
# 1     "#Durgavati begins, with blessings and good vi...                790
# ...

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Tweets_df['Tweet Posted Time'] = Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Tweets_df["Date"] = date

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Tweets_df["Time"] = time
# Out:
# <ipython-input-16-49974ffbf4b6>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_df['Tweet Posted Time'] = Tweets_df['Tweet Posted Time'].astype(str)
# <ipython-input-16-49974ffbf4b6>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Tweets_df["Date"] = date
# <ipython-input-16-49974ffbf4b6>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 12)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id            Name     Username  \
# 0     "1220262518519521281"  "Akshay Kumar"  akshaykumar
# 1     "1220236816604749824"  "Akshay Kumar"  akshaykumar
# 2     "1219804361133477890"  "Akshay Kumar"  akshaykumar
# 3     "1219491375793635329"  "Akshay Kumar"  akshaykumar
# 4     "1219156453354655745"  "Akshay Kumar"  akshaykumar
# ...                     ...             ...          ...
# 3195   "941559727670087680"  "Akshay Kumar"  akshaykumar
# 3196   "941559726827073536"  "Akshay Kumar"  akshaykumar
# 3197   "941559726223052800"  "Akshay Kumar"  akshaykumar
# 3198   "941559725099028480"  "Akshay Kumar"  akshaykumar
# 3199   "941559724264296448"  "Akshay Kumar"  akshaykumar
#
#                                           Tweet Content  Retweets received  \
# 0     "The story continues with another melody... #F...                740
# 1     "#Durgavati begins, with blessings and good vi...                790
# ...

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE IMAGES CSV

# %%
#Create reference to CSV file
csv_path = "AkshayKumarImages.csv"

#Import the CSV into a pandas DataFrame
Images_df = pd.read_csv(csv_path, low_memory = False)
Images_df
# Out:
#                   Tweet Id               Media Id  \
# 0    "1220262518519521281"  "1220262506276372480"
# 1    "1220236816604749824"  "1220236792542031873"
# 2    "1219156453354655745"  "1219156446757015553"
# 3    "1218071829291495424"  "1218071821754363904"
# 4    "1217363482800082944"  "1217363474059149312"
# ..                     ...                    ...
# 461   "944067326063906816"   "944067299677483008"
# 462   "943842717888544768"   "943842688947892224"
# 463   "943773815997206528"   "943770159491170304"
# 464   "943351717906845696"   "943351704929669120"
# 465   "943052204696485888"   "943052191396331520"
#
#                                            Media URL                Tweet URL
# 0    https://pbs.twimg.com/media/EO8-SMNUwAAIdN9.jpg  https://t.co/V1fG9FRLDE
# 1    https://pbs.twimg.com/media/EO8m5dFUcAE5pe1.jpg  https://t.co/GuIwJDM8Xi
# 2    https://pbs.twimg.com/media/EOtQVDaUUAEl2wV.jpg  https://t.co/yfoAxVaAem
# ...

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Images_df = Images_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (466, 1)

# %% [markdown]
# ##### ADD A IMAGES COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Images column for images
Images_df['Images'] = "Image added"

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (466, 2)
# <ipython-input-22-b38d5ddcb46c>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Images_df['Images'] = "Image added"

# %%
#Print the dataframe
Images_df
# Out:
#                   Tweet Id       Images
# 0    "1220262518519521281"  Image added
# 1    "1220236816604749824"  Image added
# 2    "1219156453354655745"  Image added
# 3    "1218071829291495424"  Image added
# 4    "1217363482800082944"  Image added
# ..                     ...          ...
# 461   "944067326063906816"  Image added
# 462   "943842717888544768"  Image added
# 463   "943773815997206528"  Image added
# 464   "943351717906845696"  Image added
# 465   "943052204696485888"  Image added
#
# [466 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Images_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id            Name     Username  \
# 0     "1220262518519521281"  "Akshay Kumar"  akshaykumar
# 1     "1220236816604749824"  "Akshay Kumar"  akshaykumar
# 2     "1219804361133477890"  "Akshay Kumar"  akshaykumar
# 3     "1219491375793635329"  "Akshay Kumar"  akshaykumar
# 4     "1219156453354655745"  "Akshay Kumar"  akshaykumar
# ...                     ...             ...          ...
# 3218   "941559727670087680"  "Akshay Kumar"  akshaykumar
# 3219   "941559726827073536"  "Akshay Kumar"  akshaykumar
# 3220   "941559726223052800"  "Akshay Kumar"  akshaykumar
# 3221   "941559725099028480"  "Akshay Kumar"  akshaykumar
# 3222   "941559724264296448"  "Akshay Kumar"  akshaykumar
#
#                                           Tweet Content  Retweets received  \
# 0     "The story continues with another melody... #F...                740
# 1     "#Durgavati begins, with blessings and good vi...                790
# ...

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE VIDEOS CSV

# %%
#Create reference to CSV file
csv_path = "AkshayKumarVideos.csv"

#Import the CSV into a pandas DataFrame
Videos_df = pd.read_csv(csv_path, low_memory = False)
Videos_df
# Out:
#                    Tweet Id               Media Id  \
# 0     "1219804361133477890"  "1219804022539988992"
# 1     "1219491375793635329"  "1219491339173158914"
# 2     "1211530822781587456"  "1211530237332217861"
# 3     "1210430713025024000"  "1210430589930573824"
# 4     "1210069252088033282"  "1210069160262156288"
# ...                     ...                    ...
# 1485   "941559727670087680"   "941507853809881089"
# 1486   "941559726827073536"   "941507853809881089"
# 1487   "941559726223052800"   "941507853809881089"
# 1488   "941559725099028480"   "941507853809881089"
# 1489   "941559724264296448"   "941507853809881089"
#
#                                               Media URL  \
# 0     https://video.twimg.com/ext_tw_video/121980402...
# 1     https://video.twimg.com/ext_tw_video/121949133...
# 2     https://video.twimg.com/ext_tw_video/121153023...
# 3     https://video.twimg.com/ext_tw_video/121043058...
# 4     https://video.twimg.com/ext_tw_video/121006916...
# ...

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Videos_df = Videos_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1490, 1)

# %% [markdown]
# ##### ADD A VIDEOS COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Videos column for images
Videos_df['Videos'] = "Video added"

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1490, 2)
# <ipython-input-28-e226fde13210>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   Videos_df['Videos'] = "Video added"

# %%
#Print the dataframe
Videos_df
# Out:
#                    Tweet Id       Videos
# 0     "1219804361133477890"  Video added
# 1     "1219491375793635329"  Video added
# 2     "1211530822781587456"  Video added
# 3     "1210430713025024000"  Video added
# 4     "1210069252088033282"  Video added
# ...                     ...          ...
# 1485   "941559727670087680"  Video added
# 1486   "941559726827073536"  Video added
# 1487   "941559726223052800"  Video added
# 1488   "941559725099028480"  Video added
# 1489   "941559724264296448"  Video added
#
# [1490 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Videos_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id            Name     Username  \
# 0     "1220262518519521281"  "Akshay Kumar"  akshaykumar
# 1     "1220236816604749824"  "Akshay Kumar"  akshaykumar
# 2     "1219804361133477890"  "Akshay Kumar"  akshaykumar
# 3     "1219491375793635329"  "Akshay Kumar"  akshaykumar
# 4     "1219156453354655745"  "Akshay Kumar"  akshaykumar
# ...                     ...             ...          ...
# 3218   "941559727670087680"  "Akshay Kumar"  akshaykumar
# 3219   "941559726827073536"  "Akshay Kumar"  akshaykumar
# 3220   "941559726223052800"  "Akshay Kumar"  akshaykumar
# 3221   "941559725099028480"  "Akshay Kumar"  akshaykumar
# 3222   "941559724264296448"  "Akshay Kumar"  akshaykumar
#
#                                           Tweet Content  Retweets received  \
# 0     "The story continues with another melody... #F...                740
# 1     "#Durgavati begins, with blessings and good vi...                790
# ...

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Gender column 
Tweets_df['Gender'] = "Male"

#Create an Vocation column 
Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3223, 16)

# %%
#REPLACE ALL "NaN" FOR "-"
Tweets_df['Images'] = Tweets_df['Images'].fillna("-")
Tweets_df['Videos'] = Tweets_df['Videos'].fillna("-")

# %% [markdown]
# ##### RENAME THE COLUMNS FOR VISUAL PURPOSES

# %%
Tweets_df = Tweets_df.rename(columns={"Tweet Content":"Tweets"})
Tweets_df = Tweets_df.rename(columns={"Retweets received":"Retweets"})
Tweets_df = Tweets_df.rename(columns={"Likes received":"Likes"})

# %% [markdown]
# ##### REMOVE THE TWEETS COLUMN

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweets'], axis = 1)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id            Name     Username  Retweets  Likes  \
# 0     "1220262518519521281"  "Akshay Kumar"  akshaykumar       740   3495
# 1     "1220236816604749824"  "Akshay Kumar"  akshaykumar       790   7335
# 2     "1219804361133477890"  "Akshay Kumar"  akshaykumar      1076  11087
# 3     "1219491375793635329"  "Akshay Kumar"  akshaykumar      1445  19572
# 4     "1219156453354655745"  "Akshay Kumar"  akshaykumar      1868  30880
# ...                     ...             ...          ...       ...    ...
# 3218   "941559727670087680"  "Akshay Kumar"  akshaykumar         0      1
# 3219   "941559726827073536"  "Akshay Kumar"  akshaykumar         0      1
# 3220   "941559726223052800"  "Akshay Kumar"  akshaykumar         0      0
# 3221   "941559725099028480"  "Akshay Kumar"  akshaykumar         1      1
# 3222   "941559724264296448"  "Akshay Kumar"  akshaykumar         0      6
#
#                                             Mentions(@)  \
# ...

# %% [markdown]
# ##### RE-ORDER THE COLUMNS FOR VISUAL PURPOSES

# %%
#Re-organise the columns for visual purposes
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Gender", "Vocation", "Hashtags(#)", "Total #", "Mentions(@)", 
                       "Total @", "Likes", "Retweets", "Images", "Videos", "Date", "Time"]]

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Tweets_df = Tweets_df.set_index('Tweet Id')
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3223, 14)

# %%
#Print the dataframe
Tweets_df
# Out:
#                                  Name     Username Gender       Vocation  \
# Tweet Id
# "1220262518519521281"  "Akshay Kumar"  akshaykumar   Male  Entertainment
# "1220236816604749824"  "Akshay Kumar"  akshaykumar   Male  Entertainment
# "1219804361133477890"  "Akshay Kumar"  akshaykumar   Male  Entertainment
# "1219491375793635329"  "Akshay Kumar"  akshaykumar   Male  Entertainment
# "1219156453354655745"  "Akshay Kumar"  akshaykumar   Male  Entertainment
# ...                               ...          ...    ...            ...
# "941559727670087680"   "Akshay Kumar"  akshaykumar   Male  Entertainment
# "941559726827073536"   "Akshay Kumar"  akshaykumar   Male  Entertainment
# "941559726223052800"   "Akshay Kumar"  akshaykumar   Male  Entertainment
# "941559725099028480"   "Akshay Kumar"  akshaykumar   Male  Entertainment
# "941559724264296448"   "Akshay Kumar"  akshaykumar   Male  Entertainment
#
#                                                             Hashtags(#)  \
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Tweets_df.to_csv('AkshayKumar_df.csv')

# %%
import sys
import pandas as pd
import pymongo
import json
import os
import warnings
warnings.filterwarnings('ignore')

# %%
def import_content(filepath):
    mng_client = pymongo.MongoClient('localhost', 27017)
    mng_db = mng_client['Twitterer'] # Replace mongo db name
    collection_name = 'AkshayKumar' # Replace mongo db collection name
    db_cm = mng_db[collection_name]
    cdir = os.path.dirname(os.path.abspath("__file__"))
    file_res = os.path.join(cdir, filepath)
    data = pd.read_csv(file_res)
    data_json = json.loads(data.to_json(orient='records'))
    db_cm.remove()
    db_cm.insert(data_json)

if __name__ == "__main__":
  filepath = 'AkshayKumar_df.csv'  # pass csv file path
  import_content(filepath)
