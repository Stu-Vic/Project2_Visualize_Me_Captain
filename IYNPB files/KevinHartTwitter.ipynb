# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# #  Kevin Hart Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %% [markdown]
# ##### READ THE TWEETS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedTweets/KevinHartTweets.csv"

#Import the CSV into a pandas DataFrame
Tweets_df = pd.read_csv(csv_path, low_memory = False)
Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220060656264785922"
# 1     "1219330669387698176"
# 2     "1218585360797556736"
# 3     "1217958222885195777"
# 4     "1217951440238301184"
# ...                     ...
# 3195   "987118723118006272"
# 3196   "987110711254859776"
# 3197   "987110701196918785"
# 3198   "987107607033741312"
# 3199   "987106774581788673"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/kevinhart4real/status/1220...  2020-01-22 19:08:22
# 1     https://twitter.com/kevinhart4real/status/1219...  2020-01-20 18:47:40
# 2     https://twitter.com/kevinhart4real/status/1218...  2020-01-18 17:26:04
# 3     https://twitter.com/kevinhart4real/status/1217...  2020-01-16 23:54:03
# 4     https://twitter.com/kevinhart4real/status/1217...  2020-01-16 23:27:06
# ...                                                 ...                  ...
# 3195  https://twitter.com/kevinhart4real/status/9871...  2018-04-20 00:00:18
# 3196  https://twitter.com/kevinhart4real/status/9871...  2018-04-19 23:28:27
# 3197  https://twitter.com/kevinhart4real/status/9871...  2018-04-19 23:28:25
# 3198  https://twitter.com/kevinhart4real/status/9871...  2018-04-19 23:16:07
# 3199  https://twitter.com/kevinhart4real/status/9871...  2018-04-19 23:12:49
#
#                                           Tweet Content Tweet Type  \
# 0     "The Winter Olympics ain't got shit on the col...      Tweet
# 1     "Happy MLK Day.... #HartBeatProductions #Laugh...      Tweet
# 2               "Big Shit coming in 2020....Stay tuned"      Tweet
# 3     "I am so excited about the partnership between...      Tweet
# 4     "BREAKING NEWS ‼️ My @LOLNetwork just partnere...      Tweet
# ...                                                 ...        ...
# 3195  "Even tho I didn't make it to Miami I felt the...      Tweet
# 3196                          "https://t.co/ACiQ53OCLa"      Reply
# 3197  "Heads up Miami! Bringing the heat tonight wit...      Tweet
# 3198                   "😂😂😂😂😂😂 https://t.co/LFvbSJi1R0"      Tweet
# 3199  "Game time....Lets gooooooooo SIXERS!!!!! Stan...      Tweet
#
#                   Client  Retweets received  Likes received     User Id  \
# 0              Instagram                 35             539  "23151437"
# 1              Instagram                 93            1396  "23151437"
# 2     Twitter for iPhone                804           11275  "23151437"
# 3              Instagram                 95            1619  "23151437"
# 4     Twitter for iPhone                134            1569  "23151437"
# ...                  ...                ...             ...         ...
# 3195           Instagram                 22             434  "23151437"
# 3196  Twitter for iPhone                 73             610  "23151437"
# 3197  Twitter for iPhone                 33             294  "23151437"
# 3198  Twitter for iPhone                202            2025  "23151437"
# 3199  Twitter for iPhone                181            1446  "23151437"
#
#               Name        Username Verified or Non-Verified  \
# 0     "Kevin Hart"  kevinhart4real                 Verified
# 1     "Kevin Hart"  kevinhart4real                 Verified
# 2     "Kevin Hart"  kevinhart4real                 Verified
# 3     "Kevin Hart"  kevinhart4real                 Verified
# 4     "Kevin Hart"  kevinhart4real                 Verified
# ...            ...             ...                      ...
# 3195  "Kevin Hart"  kevinhart4real                 Verified
# 3196  "Kevin Hart"  kevinhart4real                 Verified
# 3197  "Kevin Hart"  kevinhart4real                 Verified
# 3198  "Kevin Hart"  kevinhart4real                 Verified
# 3199  "Kevin Hart"  kevinhart4real                 Verified
#
#                              Profile URL Protected or Not Protected
# 0     https://twitter.com/kevinhart4real              Not Protected
# 1     https://twitter.com/kevinhart4real              Not Protected
# 2     https://twitter.com/kevinhart4real              Not Protected
# 3     https://twitter.com/kevinhart4real              Not Protected
# 4     https://twitter.com/kevinhart4real              Not Protected
# ...                                  ...                        ...
# 3195  https://twitter.com/kevinhart4real              Not Protected
# 3196  https://twitter.com/kevinhart4real              Not Protected
# 3197  https://twitter.com/kevinhart4real              Not Protected
# 3198  https://twitter.com/kevinhart4real              Not Protected
# 3199  https://twitter.com/kevinhart4real              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Tweet Content", "Retweets received", "Likes received",
                       "Tweet Posted Time"]]
# "User Id",
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 7)

# %%
#Print the dataframe
Tweets_df.head()
# Out:
#                 Tweet Id          Name        Username  \
# 0  "1220060656264785922"  "Kevin Hart"  kevinhart4real
# 1  "1219330669387698176"  "Kevin Hart"  kevinhart4real
# 2  "1218585360797556736"  "Kevin Hart"  kevinhart4real
# 3  "1217958222885195777"  "Kevin Hart"  kevinhart4real
# 4  "1217951440238301184"  "Kevin Hart"  kevinhart4real
#
#                                        Tweet Content  Retweets received  \
# 0  "The Winter Olympics ain't got shit on the col...                 35
# 1  "Happy MLK Day.... #HartBeatProductions #Laugh...                 93
# 2            "Big Shit coming in 2020....Stay tuned"                804
# 3  "I am so excited about the partnership between...                 95
# 4  "BREAKING NEWS ‼️ My @LOLNetwork just partnere...                134
#
#    Likes received    Tweet Posted Time
# 0             539  2020-01-22 19:08:22
# 1            1396  2020-01-20 18:47:40
# 2           11275  2020-01-18 17:26:04
# 3            1619  2020-01-16 23:54:03
# 4            1569  2020-01-16 23:27:06

# %% [markdown]
# ##### FILTER THROUGH TWEET CONTENTS TO EXTRACT HASHTAGS (#) AND MENTIONS(@)

# %%
df1 = Tweets_df[['Tweet Content']]
mention = df1['Tweet Content'].str.findall(r'@.*?(?=\s|$)')
hashtag = df1['Tweet Content'].str.findall(r'#.*?(?=\s|$)')
Tweets_df['Mentions(@)'] = mention
Tweets_df['Hashtags(#)'] = hashtag
#Tweets_df.head()
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """

# %% [markdown]
# ##### CREATE COLUMNS FOR THE COUNT OF #COMMENTS AND @MENTIONS PER ROW

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "#" in tag:
                count+=1
    return count 
                
Tweets_df['Total #'] = Tweets_df['Hashtags(#)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Count the amount of #comment's per Row
def totals(hashtag):
    count = 0
    if hashtag!= []:
        for tag in hashtag:
            if "@" in tag:
                count+=1
    return count 
                
Tweets_df['Total @'] = Tweets_df['Mentions(@)'].apply(totals)
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name        Username  \
# 0     "1220060656264785922"  "Kevin Hart"  kevinhart4real
# 1     "1219330669387698176"  "Kevin Hart"  kevinhart4real
# 2     "1218585360797556736"  "Kevin Hart"  kevinhart4real
# 3     "1217958222885195777"  "Kevin Hart"  kevinhart4real
# 4     "1217951440238301184"  "Kevin Hart"  kevinhart4real
# ...                     ...           ...             ...
# 3195   "987118723118006272"  "Kevin Hart"  kevinhart4real
# 3196   "987110711254859776"  "Kevin Hart"  kevinhart4real
# 3197   "987110701196918785"  "Kevin Hart"  kevinhart4real
# 3198   "987107607033741312"  "Kevin Hart"  kevinhart4real
# 3199   "987106774581788673"  "Kevin Hart"  kevinhart4real
#
#                                           Tweet Content  Retweets received  \
# 0     "The Winter Olympics ain't got shit on the col...                 35
# 1     "Happy MLK Day.... #HartBeatProductions #Laugh...                 93
# 2               "Big Shit coming in 2020....Stay tuned"                804
# 3     "I am so excited about the partnership between...                 95
# 4     "BREAKING NEWS ‼️ My @LOLNetwork just partnere...                134
# ...                                                 ...                ...
# 3195  "Even tho I didn't make it to Miami I felt the...                 22
# 3196                          "https://t.co/ACiQ53OCLa"                 73
# 3197  "Heads up Miami! Bringing the heat tonight wit...                 33
# 3198                   "😂😂😂😂😂😂 https://t.co/LFvbSJi1R0"                202
# 3199  "Game time....Lets gooooooooo SIXERS!!!!! Stan...                181
#
#       Likes received    Tweet Posted Time                Mentions(@)  \
# 0                539  2020-01-22 19:08:22               [@lolojones]
# 1               1396  2020-01-20 18:47:40                         []
# 2              11275  2020-01-18 17:26:04                         []
# 3               1619  2020-01-16 23:54:03                         []
# 4               1569  2020-01-16 23:27:06  [@LOLNetwork, @peacockTV]
# ...              ...                  ...                        ...
# 3195             434  2018-04-20 00:00:18                         []
# 3196             610  2018-04-19 23:28:27                         []
# 3197             294  2018-04-19 23:28:25             [@MountainDew]
# 3198            2025  2018-04-19 23:16:07                         []
# 3199            1446  2018-04-19 23:12:49                         []
#
#                                             Hashtags(#)  Total #  Total @
# 0     [#PoweredbyOldSpice, #CABSeason3, #OnlyonLOLNe...        3        1
# 1     [#HartBeatProductions, #LaughOutLoud, #BestBos...        3        0
# 2                                                    []        0        0
# 3                                                    []        0        0
# 4                                                    []        0        2
# ...                                                 ...      ...      ...
# 3195                                                 []        0        0
# 3196                                                 []        0        0
# 3197  [#CantBeBanned, #MtnDewKickstart, #TrustThePro...        4        1
# 3198                                                 []        0        0
# 3199                                                 []        0        0
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Tweets_df['Tweet Posted Time'] = Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Tweets_df["Date"] = date

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Tweets_df["Time"] = time
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 12)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name        Username  \
# 0     "1220060656264785922"  "Kevin Hart"  kevinhart4real
# 1     "1219330669387698176"  "Kevin Hart"  kevinhart4real
# 2     "1218585360797556736"  "Kevin Hart"  kevinhart4real
# 3     "1217958222885195777"  "Kevin Hart"  kevinhart4real
# 4     "1217951440238301184"  "Kevin Hart"  kevinhart4real
# ...                     ...           ...             ...
# 3195   "987118723118006272"  "Kevin Hart"  kevinhart4real
# 3196   "987110711254859776"  "Kevin Hart"  kevinhart4real
# 3197   "987110701196918785"  "Kevin Hart"  kevinhart4real
# 3198   "987107607033741312"  "Kevin Hart"  kevinhart4real
# 3199   "987106774581788673"  "Kevin Hart"  kevinhart4real
#
#                                           Tweet Content  Retweets received  \
# 0     "The Winter Olympics ain't got shit on the col...                 35
# 1     "Happy MLK Day.... #HartBeatProductions #Laugh...                 93
# 2               "Big Shit coming in 2020....Stay tuned"                804
# 3     "I am so excited about the partnership between...                 95
# 4     "BREAKING NEWS ‼️ My @LOLNetwork just partnere...                134
# ...                                                 ...                ...
# 3195  "Even tho I didn't make it to Miami I felt the...                 22
# 3196                          "https://t.co/ACiQ53OCLa"                 73
# 3197  "Heads up Miami! Bringing the heat tonight wit...                 33
# 3198                   "😂😂😂😂😂😂 https://t.co/LFvbSJi1R0"                202
# 3199  "Game time....Lets gooooooooo SIXERS!!!!! Stan...                181
#
#       Likes received                Mentions(@)  \
# 0                539               [@lolojones]
# 1               1396                         []
# 2              11275                         []
# 3               1619                         []
# 4               1569  [@LOLNetwork, @peacockTV]
# ...              ...                        ...
# 3195             434                         []
# 3196             610                         []
# 3197             294             [@MountainDew]
# 3198            2025                         []
# 3199            1446                         []
#
#                                             Hashtags(#)  Total #  Total @  \
# 0     [#PoweredbyOldSpice, #CABSeason3, #OnlyonLOLNe...        3        1
# 1     [#HartBeatProductions, #LaughOutLoud, #BestBos...        3        0
# 2                                                    []        0        0
# 3                                                    []        0        0
# 4                                                    []        0        2
# ...                                                 ...      ...      ...
# 3195                                                 []        0        0
# 3196                                                 []        0        0
# 3197  [#CantBeBanned, #MtnDewKickstart, #TrustThePro...        4        1
# 3198                                                 []        0        0
# 3199                                                 []        0        0
#
#             Date      Time
# 0     2020-01-22  19:08:22
# 1     2020-01-20  18:47:40
# 2     2020-01-18  17:26:04
# 3     2020-01-16  23:54:03
# 4     2020-01-16  23:27:06
# ...          ...       ...
# 3195  2018-04-20  00:00:18
# 3196  2018-04-19  23:28:27
# 3197  2018-04-19  23:28:25
# 3198  2018-04-19  23:16:07
# 3199  2018-04-19  23:12:49
#
# [3200 rows x 12 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE IMAGES CSV

# %%
#Create reference to CSV file
csv_path = "RenamedImages/KevinHartImages.csv"

#Import the CSV into a pandas DataFrame
Images_df = pd.read_csv(csv_path, low_memory = False)
Images_df
# Out:
#                   Tweet Id               Media Id  \
# 0    "1211276589217923074"  "1211276586063822853"
# 1    "1211214096009506816"  "1211214091496411136"
# 2    "1210821489181593600"  "1210821461142720513"
# 3    "1206317456349728768"  "1206317446862258178"
# 4    "1205707106038538240"  "1205707098631356416"
# ..                     ...                    ...
# 139   "993103592633651201"   "993103590993645569"
# 140   "991648319284895745"   "991648002526863362"
# 141   "988175615143669760"   "988116007817379841"
# 142   "987127008575488001"   "987127002363846656"
# 143   "987110711254859776"   "987110705324150784"
#
#                                            Media URL                Tweet URL
# 0    https://pbs.twimg.com/media/EM9Roy0VAAUMy4N.jpg  https://t.co/eZ6yykTw6S
# 1    https://pbs.twimg.com/media/EM8YzIaXUAAq0VC.jpg  https://t.co/raBcfwpsnN
# 2    https://pbs.twimg.com/media/EM2ztCXU0AEFuzR.jpg  https://t.co/1sdoxIG4N7
# 3    https://pbs.twimg.com/media/EL2zU5qUwAIpGQq.jpg  https://t.co/gQAolPap44
# 4    https://pbs.twimg.com/media/ELuIN9UWwAApJDQ.jpg  https://t.co/sjLhbgsMvU
# ..                                               ...                      ...
# 139  https://pbs.twimg.com/media/Dcg2dE5XUAEK8yx.jpg  https://t.co/85FRY6xndg
# 140  https://pbs.twimg.com/media/DcMKmrTW4AIifEg.jpg  https://t.co/6KUyEEtlYd
# 141  https://pbs.twimg.com/media/DbZ-RhrVAAEuvyX.jpg  https://t.co/M2ourloKTW
# 142  https://pbs.twimg.com/media/DbL6x1QX4AASFv8.jpg  https://t.co/euuKyQn2vL
# 143  https://pbs.twimg.com/media/DbLr9ODU0AA7y41.jpg  https://t.co/ACiQ53OCLa
#
# [144 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Images_df = Images_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (144, 1)

# %% [markdown]
# ##### ADD A IMAGES COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Images column for images
Images_df['Images'] = "Image added"

#Show the 'shape' of the dataframe
shape = Images_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (144, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Images_df
# Out:
#                   Tweet Id       Images
# 0    "1211276589217923074"  Image added
# 1    "1211214096009506816"  Image added
# 2    "1210821489181593600"  Image added
# 3    "1206317456349728768"  Image added
# 4    "1205707106038538240"  Image added
# ..                     ...          ...
# 139   "993103592633651201"  Image added
# 140   "991648319284895745"  Image added
# 141   "988175615143669760"  Image added
# 142   "987127008575488001"  Image added
# 143   "987110711254859776"  Image added
#
# [144 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Images_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name        Username  \
# 0     "1220060656264785922"  "Kevin Hart"  kevinhart4real
# 1     "1219330669387698176"  "Kevin Hart"  kevinhart4real
# 2     "1218585360797556736"  "Kevin Hart"  kevinhart4real
# 3     "1217958222885195777"  "Kevin Hart"  kevinhart4real
# 4     "1217951440238301184"  "Kevin Hart"  kevinhart4real
# ...                     ...           ...             ...
# 3208   "987118723118006272"  "Kevin Hart"  kevinhart4real
# 3209   "987110711254859776"  "Kevin Hart"  kevinhart4real
# 3210   "987110701196918785"  "Kevin Hart"  kevinhart4real
# 3211   "987107607033741312"  "Kevin Hart"  kevinhart4real
# 3212   "987106774581788673"  "Kevin Hart"  kevinhart4real
#
#                                           Tweet Content  Retweets received  \
# 0     "The Winter Olympics ain't got shit on the col...                 35
# 1     "Happy MLK Day.... #HartBeatProductions #Laugh...                 93
# 2               "Big Shit coming in 2020....Stay tuned"                804
# 3     "I am so excited about the partnership between...                 95
# 4     "BREAKING NEWS ‼️ My @LOLNetwork just partnere...                134
# ...                                                 ...                ...
# 3208  "Even tho I didn't make it to Miami I felt the...                 22
# 3209                          "https://t.co/ACiQ53OCLa"                 73
# 3210  "Heads up Miami! Bringing the heat tonight wit...                 33
# 3211                   "😂😂😂😂😂😂 https://t.co/LFvbSJi1R0"                202
# 3212  "Game time....Lets gooooooooo SIXERS!!!!! Stan...                181
#
#       Likes received                Mentions(@)  \
# 0                539               [@lolojones]
# 1               1396                         []
# 2              11275                         []
# 3               1619                         []
# 4               1569  [@LOLNetwork, @peacockTV]
# ...              ...                        ...
# 3208             434                         []
# 3209             610                         []
# 3210             294             [@MountainDew]
# 3211            2025                         []
# 3212            1446                         []
#
#                                             Hashtags(#)  Total #  Total @  \
# 0     [#PoweredbyOldSpice, #CABSeason3, #OnlyonLOLNe...        3        1
# 1     [#HartBeatProductions, #LaughOutLoud, #BestBos...        3        0
# 2                                                    []        0        0
# 3                                                    []        0        0
# 4                                                    []        0        2
# ...                                                 ...      ...      ...
# 3208                                                 []        0        0
# 3209                                                 []        0        0
# 3210  [#CantBeBanned, #MtnDewKickstart, #TrustThePro...        4        1
# 3211                                                 []        0        0
# 3212                                                 []        0        0
#
#             Date      Time       Images
# 0     2020-01-22  19:08:22          NaN
# 1     2020-01-20  18:47:40          NaN
# 2     2020-01-18  17:26:04          NaN
# 3     2020-01-16  23:54:03          NaN
# 4     2020-01-16  23:27:06          NaN
# ...          ...       ...          ...
# 3208  2018-04-20  00:00:18          NaN
# 3209  2018-04-19  23:28:27  Image added
# 3210  2018-04-19  23:28:25          NaN
# 3211  2018-04-19  23:16:07          NaN
# 3212  2018-04-19  23:12:49          NaN
#
# [3213 rows x 13 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### READ THE VIDEOS CSV

# %%
#Create reference to CSV file
csv_path = "RenamedVideos/KevinHartVideos.csv"

#Import the CSV into a pandas DataFrame
Videos_df = pd.read_csv(csv_path, low_memory = False)
Videos_df
# Out:
#                   Tweet Id               Media Id  \
# 0    "1214391274310008834"  "1214391204558716928"
# 1    "1210349719697809408"  "1210349105685250050"
# 2    "1206593145825304578"  "1206581162359037952"
# 3    "1206029896796868608"  "1206027248936964097"
# 4    "1205683487715549190"  "1205683469776502784"
# ..                     ...                    ...
# 182   "996173098561892352"   "995013539268984832"
# 183   "992101335385260033"   "992098934796435456"
# 184   "988142303628820480"   "988140785907322880"
# 185   "987540133980327936"   "987540120147517440"
# 186   "987375395874975747"   "987368884217970698"
#
#                                              Media URL  \
# 0    https://video.twimg.com/ext_tw_video/121439120...
# 1    https://video.twimg.com/ext_tw_video/121034910...
# 2    https://video.twimg.com/amplify_video/12065811...
# 3    https://video.twimg.com/amplify_video/12060272...
# 4    https://video.twimg.com/tweet_video/ELtyuk-WwA...
# ..                                                 ...
# 182  https://video.twimg.com/amplify_video/99501353...
# 183  https://video.twimg.com/ext_tw_video/992098934...
# 184  https://video.twimg.com/amplify_video/98814078...
# 185  https://video.twimg.com/tweet_video/DbRygc7W4A...
# 186  https://video.twimg.com/amplify_video/98736888...
#
#                    Tweet URL
# 0    https://t.co/F00qFwuaV3
# 1    https://t.co/oNevBxV2Vi
# 2    https://t.co/7LRjfMxe03
# 3    https://t.co/WRdTW5o2hS
# 4    https://t.co/jGk9P1Eoco
# ..                       ...
# 182  https://t.co/nrLjUN7uas
# 183  https://t.co/4lJLAJO1qR
# 184  https://t.co/ZmRhv2NaJF
# 185  https://t.co/wtEeUBsd28
# 186  https://t.co/mh2fJDgY52
#
# [187 rows x 4 columns]

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Videos_df = Videos_df[["Tweet Id"]]

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (187, 1)

# %% [markdown]
# ##### ADD A VIDEOS COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Videos column for images
Videos_df['Videos'] = "Video added"

#Show the 'shape' of the dataframe
shape = Videos_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (187, 2)
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
#Print the dataframe
Videos_df
# Out:
#                   Tweet Id       Videos
# 0    "1214391274310008834"  Video added
# 1    "1210349719697809408"  Video added
# 2    "1206593145825304578"  Video added
# 3    "1206029896796868608"  Video added
# 4    "1205683487715549190"  Video added
# ..                     ...          ...
# 182   "996173098561892352"  Video added
# 183   "992101335385260033"  Video added
# 184   "988142303628820480"  Video added
# 185   "987540133980327936"  Video added
# 186   "987375395874975747"  Video added
#
# [187 rows x 2 columns]

# %% [markdown]
# ##### MERGE IMAGES_DF WITH TWEET_DF

# %%
#Merge the 2 dataframes together
Tweets_df = Tweets_df.merge(Videos_df, on = 'Tweet Id', how = 'left')

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name        Username  \
# 0     "1220060656264785922"  "Kevin Hart"  kevinhart4real
# 1     "1219330669387698176"  "Kevin Hart"  kevinhart4real
# 2     "1218585360797556736"  "Kevin Hart"  kevinhart4real
# 3     "1217958222885195777"  "Kevin Hart"  kevinhart4real
# 4     "1217951440238301184"  "Kevin Hart"  kevinhart4real
# ...                     ...           ...             ...
# 3208   "987118723118006272"  "Kevin Hart"  kevinhart4real
# 3209   "987110711254859776"  "Kevin Hart"  kevinhart4real
# 3210   "987110701196918785"  "Kevin Hart"  kevinhart4real
# 3211   "987107607033741312"  "Kevin Hart"  kevinhart4real
# 3212   "987106774581788673"  "Kevin Hart"  kevinhart4real
#
#                                           Tweet Content  Retweets received  \
# 0     "The Winter Olympics ain't got shit on the col...                 35
# 1     "Happy MLK Day.... #HartBeatProductions #Laugh...                 93
# 2               "Big Shit coming in 2020....Stay tuned"                804
# 3     "I am so excited about the partnership between...                 95
# 4     "BREAKING NEWS ‼️ My @LOLNetwork just partnere...                134
# ...                                                 ...                ...
# 3208  "Even tho I didn't make it to Miami I felt the...                 22
# 3209                          "https://t.co/ACiQ53OCLa"                 73
# 3210  "Heads up Miami! Bringing the heat tonight wit...                 33
# 3211                   "😂😂😂😂😂😂 https://t.co/LFvbSJi1R0"                202
# 3212  "Game time....Lets gooooooooo SIXERS!!!!! Stan...                181
#
#       Likes received                Mentions(@)  \
# 0                539               [@lolojones]
# 1               1396                         []
# 2              11275                         []
# 3               1619                         []
# 4               1569  [@LOLNetwork, @peacockTV]
# ...              ...                        ...
# 3208             434                         []
# 3209             610                         []
# 3210             294             [@MountainDew]
# 3211            2025                         []
# 3212            1446                         []
#
#                                             Hashtags(#)  Total #  Total @  \
# 0     [#PoweredbyOldSpice, #CABSeason3, #OnlyonLOLNe...        3        1
# 1     [#HartBeatProductions, #LaughOutLoud, #BestBos...        3        0
# 2                                                    []        0        0
# 3                                                    []        0        0
# 4                                                    []        0        2
# ...                                                 ...      ...      ...
# 3208                                                 []        0        0
# 3209                                                 []        0        0
# 3210  [#CantBeBanned, #MtnDewKickstart, #TrustThePro...        4        1
# 3211                                                 []        0        0
# 3212                                                 []        0        0
#
#             Date      Time       Images Videos
# 0     2020-01-22  19:08:22          NaN    NaN
# 1     2020-01-20  18:47:40          NaN    NaN
# 2     2020-01-18  17:26:04          NaN    NaN
# 3     2020-01-16  23:54:03          NaN    NaN
# 4     2020-01-16  23:27:06          NaN    NaN
# ...          ...       ...          ...    ...
# 3208  2018-04-20  00:00:18          NaN    NaN
# 3209  2018-04-19  23:28:27  Image added    NaN
# 3210  2018-04-19  23:28:25          NaN    NaN
# 3211  2018-04-19  23:16:07          NaN    NaN
# 3212  2018-04-19  23:12:49          NaN    NaN
#
# [3213 rows x 14 columns]

# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND POPULATE

# %%
#Create an Gender column 
Tweets_df['Gender'] = "Male"

#Create an Vocation column 
Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3213, 16)

# %%
#REPLACE ALL "NaN" FOR "-"
Tweets_df['Images'] = Tweets_df['Images'].fillna("-")
Tweets_df['Videos'] = Tweets_df['Videos'].fillna("-")

# %% [markdown]
# ##### RENAME THE COLUMNS FOR VISUAL PURPOSES

# %%
Tweets_df = Tweets_df.rename(columns={"Tweet Content":"Tweets"})
Tweets_df = Tweets_df.rename(columns={"Retweets received":"Retweets"})
Tweets_df = Tweets_df.rename(columns={"Likes received":"Likes"})

# %% [markdown]
# ##### REMOVE THE TWEETS COLUMN

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Tweets_df = Tweets_df.drop(['Tweets'], axis = 1)

# %%
#Print the dataframe
Tweets_df
# Out:
#                    Tweet Id          Name        Username  Retweets  Likes  \
# 0     "1220060656264785922"  "Kevin Hart"  kevinhart4real        35    539
# 1     "1219330669387698176"  "Kevin Hart"  kevinhart4real        93   1396
# 2     "1218585360797556736"  "Kevin Hart"  kevinhart4real       804  11275
# 3     "1217958222885195777"  "Kevin Hart"  kevinhart4real        95   1619
# 4     "1217951440238301184"  "Kevin Hart"  kevinhart4real       134   1569
# ...                     ...           ...             ...       ...    ...
# 3208   "987118723118006272"  "Kevin Hart"  kevinhart4real        22    434
# 3209   "987110711254859776"  "Kevin Hart"  kevinhart4real        73    610
# 3210   "987110701196918785"  "Kevin Hart"  kevinhart4real        33    294
# 3211   "987107607033741312"  "Kevin Hart"  kevinhart4real       202   2025
# 3212   "987106774581788673"  "Kevin Hart"  kevinhart4real       181   1446
#
#                     Mentions(@)  \
# 0                  [@lolojones]
# 1                            []
# 2                            []
# 3                            []
# 4     [@LOLNetwork, @peacockTV]
# ...                         ...
# 3208                         []
# 3209                         []
# 3210             [@MountainDew]
# 3211                         []
# 3212                         []
#
#                                             Hashtags(#)  Total #  Total @  \
# 0     [#PoweredbyOldSpice, #CABSeason3, #OnlyonLOLNe...        3        1
# 1     [#HartBeatProductions, #LaughOutLoud, #BestBos...        3        0
# 2                                                    []        0        0
# 3                                                    []        0        0
# 4                                                    []        0        2
# ...                                                 ...      ...      ...
# 3208                                                 []        0        0
# 3209                                                 []        0        0
# 3210  [#CantBeBanned, #MtnDewKickstart, #TrustThePro...        4        1
# 3211                                                 []        0        0
# 3212                                                 []        0        0
#
#             Date      Time       Images Videos Gender       Vocation
# 0     2020-01-22  19:08:22            -      -   Male  Entertainment
# 1     2020-01-20  18:47:40            -      -   Male  Entertainment
# 2     2020-01-18  17:26:04            -      -   Male  Entertainment
# 3     2020-01-16  23:54:03            -      -   Male  Entertainment
# 4     2020-01-16  23:27:06            -      -   Male  Entertainment
# ...          ...       ...          ...    ...    ...            ...
# 3208  2018-04-20  00:00:18            -      -   Male  Entertainment
# 3209  2018-04-19  23:28:27  Image added      -   Male  Entertainment
# 3210  2018-04-19  23:28:25            -      -   Male  Entertainment
# 3211  2018-04-19  23:16:07            -      -   Male  Entertainment
# 3212  2018-04-19  23:12:49            -      -   Male  Entertainment
#
# [3213 rows x 15 columns]

# %% [markdown]
# ##### RE-ORDER THE COLUMNS FOR VISUAL PURPOSES

# %%
#Re-organise the columns for visual purposes
Tweets_df = Tweets_df[["Tweet Id", "Name", "Username", "Gender", "Vocation", "Hashtags(#)", "Total #", "Mentions(@)", 
                       "Total @", "Likes", "Retweets", "Images", "Videos", "Date", "Time"]]

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Tweets_df = Tweets_df.set_index('Tweet Id')
#Show the 'shape' of the dataframe
shape = Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3213, 14)

# %%
#Print the dataframe
Tweets_df
# Out:
#                                Name        Username Gender       Vocation  \
# Tweet Id
# "1220060656264785922"  "Kevin Hart"  kevinhart4real   Male  Entertainment
# "1219330669387698176"  "Kevin Hart"  kevinhart4real   Male  Entertainment
# "1218585360797556736"  "Kevin Hart"  kevinhart4real   Male  Entertainment
# "1217958222885195777"  "Kevin Hart"  kevinhart4real   Male  Entertainment
# "1217951440238301184"  "Kevin Hart"  kevinhart4real   Male  Entertainment
# ...                             ...             ...    ...            ...
# "987118723118006272"   "Kevin Hart"  kevinhart4real   Male  Entertainment
# "987110711254859776"   "Kevin Hart"  kevinhart4real   Male  Entertainment
# "987110701196918785"   "Kevin Hart"  kevinhart4real   Male  Entertainment
# "987107607033741312"   "Kevin Hart"  kevinhart4real   Male  Entertainment
# "987106774581788673"   "Kevin Hart"  kevinhart4real   Male  Entertainment
#
#                                                              Hashtags(#)  \
# Tweet Id
# "1220060656264785922"  [#PoweredbyOldSpice, #CABSeason3, #OnlyonLOLNe...
# "1219330669387698176"  [#HartBeatProductions, #LaughOutLoud, #BestBos...
# "1218585360797556736"                                                 []
# "1217958222885195777"                                                 []
# "1217951440238301184"                                                 []
# ...                                                                  ...
# "987118723118006272"                                                  []
# "987110711254859776"                                                  []
# "987110701196918785"   [#CantBeBanned, #MtnDewKickstart, #TrustThePro...
# "987107607033741312"                                                  []
# "987106774581788673"                                                  []
#
#                        Total #                Mentions(@)  Total @  Likes  \
# Tweet Id
# "1220060656264785922"        3               [@lolojones]        1    539
# "1219330669387698176"        3                         []        0   1396
# "1218585360797556736"        0                         []        0  11275
# "1217958222885195777"        0                         []        0   1619
# "1217951440238301184"        0  [@LOLNetwork, @peacockTV]        2   1569
# ...                        ...                        ...      ...    ...
# "987118723118006272"         0                         []        0    434
# "987110711254859776"         0                         []        0    610
# "987110701196918785"         4             [@MountainDew]        1    294
# "987107607033741312"         0                         []        0   2025
# "987106774581788673"         0                         []        0   1446
#
#                        Retweets       Images Videos        Date      Time
# Tweet Id
# "1220060656264785922"        35            -      -  2020-01-22  19:08:22
# "1219330669387698176"        93            -      -  2020-01-20  18:47:40
# "1218585360797556736"       804            -      -  2020-01-18  17:26:04
# "1217958222885195777"        95            -      -  2020-01-16  23:54:03
# "1217951440238301184"       134            -      -  2020-01-16  23:27:06
# ...                         ...          ...    ...         ...       ...
# "987118723118006272"         22            -      -  2018-04-20  00:00:18
# "987110711254859776"         73  Image added      -  2018-04-19  23:28:27
# "987110701196918785"         33            -      -  2018-04-19  23:28:25
# "987107607033741312"        202            -      -  2018-04-19  23:16:07
# "987106774581788673"        181            -      -  2018-04-19  23:12:49
#
# [3213 rows x 14 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Tweets_df.to_csv('NewDataframes/KevinHart_df.csv')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-33-5bee80e52a99> in <module>
#       1 #Save dataframe as csv file
# ----> 2 Tweets_df.to_csv('NewDataframes/KevinHart_df.csv')
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal)
#    3202             decimal=decimal,
#    3203         )
# -> 3204         formatter.save()
#    3205
#    3206         if path_or_buf is None:
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     186                 self.mode,
#     187                 encoding=self.encoding,
# --> 188                 compression=dict(self.compression_args, method=self.compression),
#     189             )
#     190             close = True
#
# ~\anaconda3\envs\PythonData\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text)
#     426         if encoding:
#     427             # Encoding
# --> 428             f = open(path_or_buf, mode, encoding=encoding, newline="")
#     429         elif is_text:
#     430             # No explicit encoding
#
# PermissionError: [Errno 13] Permission denied: 'NewDataframes/KevinHart_df.csv'
