# %%
import json
from pymongo import MongoClient
import os

# set up database connection
client = MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Arc_Diagram"]

# %%
# read in a JSON file
with open('../ARC_Diagram/arcdata_connections.json') as f:
    file_data = json.load(f)

# %%
# Upload JSON as Mongo Documents
mongo_collection.insert_one(file_data)

# %%
ARC_output =  mongo_collection.find( {} )

# %%
for entry in ARC_output:
    print(entry)
# Out:
# {'_id': ObjectId('60c34cedad8c129d912fd67a'), 'nodes': [{'name': 'Akshay Kumar', 'n': 20, 'grp': 1, 'id': 'Akshay Kumar'}, {'name': 'Amitabh Bachchan', 'n': 30, 'grp': 1, 'id': 'Amitabh Bachchan'}, {'name': 'Ariana Grande', 'n': 60, 'grp': 1, 'id': 'Ariana Grande'}, {'name': 'Barack Obama', 'n': 30, 'grp': 4, 'id': 'Barack Obama'}, {'name': 'BBC Breaking News', 'n': 10, 'grp': 3, 'id': 'BBC Breaking News'}, {'name': 'Bill Gates', 'n': 60, 'grp': 6, 'id': 'Bill Gates'}, {'name': 'Britney Spears', 'n': 90, 'grp': 2, 'id': 'Britney Spears'}, {'name': 'Bruno Mars', 'n': 70, 'grp': 2, 'id': 'Bruno Mars'}, {'name': 'CNN', 'n': 40, 'grp': 3, 'id': 'CNN'}, {'name': 'CNN Breaking News', 'n': 10, 'grp': 3, 'id': 'CNN Breaking News'}, {'name': 'Cristiano Ronaldo', 'n': 80, 'grp': 5, 'id': 'Cristiano Ronaldo'}, {'name': 'Donald J. Trump', 'n': 10, 'grp': 4, 'id': 'Donald J. Trump'}, {'name': 'Drizzy', 'n': 70, 'grp': 2, 'id': 'Drizzy'}, {'name': 'Ellen DeGeneres', 'n': 70, 'grp': 1, 'id': 'Ellen
# ...
