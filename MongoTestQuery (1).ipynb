# %%
# Doesnt work!! 


# import pymongo

# client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
# mongo_db = client["Tweets_DB"]
# mongo_collection = mongo_db["Combined_Tweets"]

# for x in mongo_collection.find({},{ "_id": 0, "Hashtags(#)": 1, "Identity": "Akshay Kumar"}).limit(10):
#   print(x)
#     dict_result = x.to_dict()

# %%
# Set Up PyMongo
import pymongo
import pandas as pd
import numpy as np
from flask import jsonify

client = pymongo.MongoClient("mongodb+srv://AtlasTwitter:1FineTwitterApp!@twittercluster.ycq9k.mongodb.net/")
mongo_db = client["Tweets_DB"]
mongo_collection = mongo_db["Combined_Tweets"]

# Define A Person to Query
# Searches for non-empty hashtag results 
QueryIdentity = "Jimmy Fallon"
testoutput =  mongo_collection.find( { "Identity": QueryIdentity, "Hashtags(#)": {"$ne" : '[]'} },{ "_id": 0, "Hashtags(#)": 1} ).limit(50)

test_df = pd.DataFrame(list(testoutput))
test_df.head(50)
# Out:
#                                           Hashtags(#)
# 0                              ['#ThereShouldBeALaw']
# 1                              ['#ThereShouldBeALaw']
# 2                              ['#happybirthdaylin"']
# 3                                            ['#40"']
# 4                                  ['#FallonTonight']
# 5                            ['#DumbestFamilyFight"']
# 6                            ['#DumbestFamilyFight.']
# 7                                 ['#FallonTonight"']
# 8                         ['#FallonTonight', '#NBC"']
# 9                                 ['#FallonTonight"']
# 10                        ['#RuinAMovieWithOneWord"']
# 11                        ['#RuinAMovieWithOneWord.']
# 12                 ['#CNNNYE', '#JäGer', '#imagine"']
# 13                      ['#CNNNYE', '#HappyNewYear"']
# 14                                 ['#FallonTonight']
# 15                                    ['#ThisIsBaby']
# 16                                           ['#SNL']
# 17      ['#HappyHolidays', '#GetTheF**kOutOfMyHouse']
# 18                                 ['#JonathanGroff']
# 19                                ['#FallonTonight"']
# 20              ['#InTheHeightsMovie', '#Summer2020']
# 21                                 ['#FallonTonight']
# 22                                ['#FallonTonight"']
# 23                                           ['#QLS']
# 24                                      ['#2019MAMA']
# 25            ['#TheSeriousGoose', '#GivingTuesday!']
# 26                                ['#FallonTonight"']
# 27                 ['#FallonTonight', '#PartyPatrol']
# 28      ['#HappyThanksgiving', '#FallonThanksgiving']
# 29  ['#MacysDayParade!', '#FallonThanksgiving', '#...
# 30              ['#babyyoda', '#FallonThanksgiving"']
# 31                           ['#FallonThanksgiving"']
# 32                           ['#FallonThanksgiving"']
# 33                           ['#FallonThanksgiving"']
# 34                           ['#FallonThanksgiving"']
# 35                           ['#FallonThanksgiving"']
# 36                           ['#FallonThanksgiving"']
# 37              ['#thankful', '#FallonThanksgiving"']
# 38                           ['#FallonThanksgiving"']
# 39    ['#FallonThanksGiving', '#ThanksGivingRuined"']
# 40                           ['#FallonThanksgiving"']
# 41                           ['#FallonThanksgiving"']
# 42                           ['#FallonThanksgiving"']
# 43                           ['#FallonThanksgiving"']
# 44                           ['#FallonThanksgiving"']
# 45          ['#HappyThanksgiving', '#FeedingAmerica']
# 46   ['#StarWars', '#ReyRapRecap', '#FallonTonight"']
# 47                          ['#TurkeyDayTraditions"']
# 48                          ['#TurkeyDayTraditions.']
# 49                                ['#AmericanUtopia']

# %%
eval(test_df['Hashtags(#)'][0])
# Out:
# ['#ThereShouldBeALaw']

# %%
import numpy as np 
# [eval(x) for x in test_df["Hashtags(#)"]]
testarray = [eval(x) for x in test_df["Hashtags(#)"]]
testarray
# Out:
# [['#ThereShouldBeALaw'],
#  ['#ThereShouldBeALaw'],
#  ['#happybirthdaylin"'],
#  ['#40"'],
#  ['#FallonTonight'],
#  ['#DumbestFamilyFight"'],
#  ['#DumbestFamilyFight.'],
#  ['#FallonTonight"'],
#  ['#FallonTonight', '#NBC"'],
#  ['#FallonTonight"'],
#  ['#RuinAMovieWithOneWord"'],
#  ['#RuinAMovieWithOneWord.'],
#  ['#CNNNYE', '#JäGer', '#imagine"'],
#  ['#CNNNYE', '#HappyNewYear"'],
#  ['#FallonTonight'],
#  ['#ThisIsBaby'],
#  ['#SNL'],
#  ['#HappyHolidays', '#GetTheF**kOutOfMyHouse'],
#  ['#JonathanGroff'],
#  ['#FallonTonight"'],
#  ['#InTheHeightsMovie', '#Summer2020'],
#  ['#FallonTonight'],
#  ['#FallonTonight"'],
#  ['#QLS'],
#  ['#2019MAMA'],
#  ['#TheSeriousGoose', '#GivingTuesday!'],
#  ['#FallonTonight"'],
#  ['#FallonTonight', '#PartyPatrol'],
#  ['#HappyThanksgiving', '#FallonThanksgiving'],
#  ['#MacysDayParade!', '#FallonThanksgiving', '#HappyThanksgiving"'],
#  ['#babyyoda', '#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#thankful', '#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksGiving', '#ThanksGivingRuined"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#FallonThanksgiving"'],
#  ['#HappyThanksgiving', '#FeedingAmerica'],
#  ['#StarWars', '#ReyRapRecap', '#FallonTonight"'],
#  ['#TurkeyDayTraditions"'],
#  ['#TurkeyDayTraditions.'],
#  ['#AmericanUtopia']]

# %%
flatten_list = []
for l1 in testarray:
    for l2 in l1:
        l2 = l2.replace('"','')
        flatten_list.append(l2)
        
flatten_list
# Out:
# -------------------------------------------------------------------
# NameError                         Traceback (most recent call last)
# <ipython-input-7-6a5b414d9d28> in <module>
#       1 flatten_list = []
# ----> 2 for l1 in testarray:
#       3     for l2 in l1:
#       4         l2 = l2.replace('"','')
#       5         flatten_list.append(l2)
#
# NameError: name 'testarray' is not defined

# %%
print(jsonify(test_df))

# %%
# Set up Pandas, Query Atlas for ALL results matching the twitter Identity 

identity_df = pd.DataFrame(list(mongo_collection.find({"Identity": QueryIdentity})))

# %%
identity_df
# Out:
#                            _id  level_0  index               Tweet Id  \
# 0     60be2af24a7a5d65a6b4f81c    54641      0  "1219730046694383618"
# 1     60be2af24a7a5d65a6b4f81d    54642      1  "1219729849583067136"
# 2     60be2af24a7a5d65a6b4f81e    54643      2  "1218196761271054341"
# 3     60be2af24a7a5d65a6b4f81f    54644      3  "1218195511787782144"
# 4     60be2af24a7a5d65a6b4f820    54645      4  "1217937309410131969"
# ...                        ...      ...    ...                    ...
# 3225  60be2af24a7a5d65a6b504b5    57866   3225   "753569949671645184"
# 3226  60be2af24a7a5d65a6b504b6    57867   3226   "753564046457274368"
# 3227  60be2af24a7a5d65a6b504b7    57868   3227   "753561347351248897"
# 3228  60be2af24a7a5d65a6b504b8    57869   3228   "753561070304890880"
# 3229  60be2af24a7a5d65a6b504b9    57870   3229   "753397108997259265"
#
#                 Name     Username Gender       Vocation  \
# 0     "jimmy fallon"  jimmyfallon   Male  Entertainment
# 1     "jimmy fallon"  jimmyfallon   Male  Entertainment
# 2     "jimmy fallon"  jimmyfallon   Male  Entertainment
# 3     "jimmy fallon"  jimmyfallon   Male  Entertainment
# 4     "jimmy fallon"  jimmyfallon   Male  Entertainment
# ...              ...          ...    ...            ...
# 3225  "jimmy fallon"  jimmyfallon   Male  Entertainment
# 3226  "jimmy fallon"  jimmyfallon   Male  Entertainment
# 3227  "jimmy fallon"  jimmyfallon   Male  Entertainment
# 3228  "jimmy fallon"  jimmyfallon   Male  Entertainment
# 3229  "jimmy fallon"  jimmyfallon   Male  Entertainment
#
#                                            Hashtags(#)  Total #  \
# 0                               ['#ThereShouldBeALaw']        1
# 1                               ['#ThereShouldBeALaw']        1
# 2                               ['#happybirthdaylin"']        1
# 3                                                   []        0
# 4                                                   []        0
# ...                                                ...      ...
# 3225                               ['#FallonTonight"']        1
# 3226  ['#SnapchatDuet', '#IntoYou', '#FallonTonight"']        3
# 3227                                                []        0
# 3228                                                []        0
# 3229                                                []        0
#
#             Mentions(@)  Total @  Likes  Retweets       Images Videos  \
# 0                    []        0   3132       236            -      -
# 1                    []        0   3255       207            -      -
# 2                    []        0   1825        51            -      -
# 3                    []        0   9455       342  Image added      -
# 4        ['@peacockTV']        1    658        63            -      -
# ...                 ...      ...    ...       ...          ...    ...
# 3225                 []        0   2110       563            -      -
# 3226  ['@ArianaGrande']        1  17178      6546            -      -
# 3227                 []        0   8778      1032            -      -
# 3228                 []        0   1563       160            -      -
# 3229                 []        0   2411       219            -      -
#
#             Date      Time      Identity
# 0     2020-01-21  21:14:39  Jimmy Fallon
# 1     2020-01-21  21:13:52  Jimmy Fallon
# 2     2020-01-17  15:41:55  Jimmy Fallon
# 3     2020-01-17  15:36:57  Jimmy Fallon
# 4     2020-01-16  22:30:57  Jimmy Fallon
# ...          ...       ...           ...
# 3225  2016-07-14  12:40:51  Jimmy Fallon
# 3226  2016-07-14  12:17:23  Jimmy Fallon
# 3227  2016-07-14  12:06:40  Jimmy Fallon
# 3228  2016-07-14  12:05:34  Jimmy Fallon
# 3229  2016-07-14  01:14:02  Jimmy Fallon
#
# [3230 rows x 19 columns]

# %%
identity_df['Time'] = pd.to_datetime(identity_df["Time"],format='%H:%M:%S')
# mega_df["Time"] = mega_df["Time"].dt.time
identity_df["Date"] = pd.to_datetime(identity_df["Date"],format="%Y-%M-%d")

# %%
identity_df.head()
# Out:
#                         _id  level_0  index               Tweet Id  \
# 0  60be2af24a7a5d65a6b4f81c    54641      0  "1219730046694383618"
# 1  60be2af24a7a5d65a6b4f81d    54642      1  "1219729849583067136"
# 2  60be2af24a7a5d65a6b4f81e    54643      2  "1218196761271054341"
# 3  60be2af24a7a5d65a6b4f81f    54644      3  "1218195511787782144"
# 4  60be2af24a7a5d65a6b4f820    54645      4  "1217937309410131969"
#
#              Name     Username Gender       Vocation             Hashtags(#)  \
# 0  "jimmy fallon"  jimmyfallon   Male  Entertainment  ['#ThereShouldBeALaw']
# 1  "jimmy fallon"  jimmyfallon   Male  Entertainment  ['#ThereShouldBeALaw']
# 2  "jimmy fallon"  jimmyfallon   Male  Entertainment  ['#happybirthdaylin"']
# 3  "jimmy fallon"  jimmyfallon   Male  Entertainment                      []
# 4  "jimmy fallon"  jimmyfallon   Male  Entertainment                      []
#
#    Total #     Mentions(@)  Total @  Likes  Retweets       Images Videos  \
# 0        1              []        0   3132       236            -      -
# 1        1              []        0   3255       207            -      -
# 2        1              []        0   1825        51            -      -
# 3        0              []        0   9455       342  Image added      -
# 4        0  ['@peacockTV']        1    658        63            -      -
#
#                  Date                Time      Identity
# 0 2020-01-21 00:01:00 1900-01-01 21:14:39  Jimmy Fallon
# 1 2020-01-21 00:01:00 1900-01-01 21:13:52  Jimmy Fallon
# 2 2020-01-17 00:01:00 1900-01-01 15:41:55  Jimmy Fallon
# 3 2020-01-17 00:01:00 1900-01-01 15:36:57  Jimmy Fallon
# 4 2020-01-16 00:01:00 1900-01-01 22:30:57  Jimmy Fallon

# %%
identity_df.groupby(pd.Grouper(key='Date', freq='D'))
identity_df.sum()
# Out:
#   File "<ipython-input-16-d208277961a7>", line 1
#     g=identity_df.groupby(['Date','Time])
#                                          ^
# SyntaxError: EOL while scanning string literal

# %%
identity_df.Date = pd.to_datetime(identity_df.Date)

df_2 = identity_df.groupby(identity_df.Date.dt.strftime('%Y-%d')).Likes.agg(['mean'])

# %%
df_2
# Out:
#                  mean
# Date
# 2016-01   7222.312500
# 2016-02   3740.476190
# 2016-03   2195.473684
# 2016-04   6254.250000
# 2016-05   1960.800000
# ...               ...
# 2020-14    815.000000
# 2020-15   1328.000000
# 2020-16  11738.800000
# 2020-17   5640.000000
# 2020-21   3193.500000
#
# [137 rows x 1 columns]

# %%
identity_df['month'] = pd.to_datetime(identity_df['Date']).dt.month
identity_df['year'] = pd.to_datetime(identity_df['Date']).dt.year
identity_df.groupby(['year','month'],as_index=False).mean()
# Out:
#    year  month  level_0   index   Total #   Total @        Likes     Retweets
# 0  2016      1  57708.5  3067.5  1.092593  1.330247  3052.688272   681.376543
# 1  2017      1  57099.0  2458.0  0.981006  1.287151  3892.875978   839.425698
# 2  2018      1  56084.0  1443.0  0.982379  1.066960  8478.614097  1953.110132
# 3  2019      1  55091.0   450.0  0.782609  1.203290  5580.162162  1040.495887
# 4  2020      1  54653.0    12.0  0.720000  0.520000  5470.680000   417.760000
