# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Neymar Jr Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "NeymarJrTweets.csv"

#Import the CSV into a pandas DataFrame
NJr_Tweets_df = pd.read_csv(csv_path, low_memory = False)
NJr_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220158263641214977"
# 1     "1219622322610626562"
# 2     "1217902956475047937"
# 3     "1217835733173571584"
# 4     "1217526993018900480"
# ...                     ...
# 3195   "464235309707059200"
# 3196   "464235309690269696"
# 3197   "464235309686091776"
# 3198   "464235296805371905"
# 3199   "464235292753686528"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/neymarjr/status/1220158263...  2020-01-23 01:36:14
# 1     https://twitter.com/neymarjr/status/1219622322...  2020-01-21 14:06:35
# 2     https://twitter.com/neymarjr/status/1217902956...  2020-01-16 20:14:27
# 3     https://twitter.com/neymarjr/status/1217835733...  2020-01-16 15:47:19
# 4     https://twitter.com/neymarjr/status/1217526993...  2020-01-15 19:20:30
# ...                                                 ...                  ...
# 3195  https://twitter.com/neymarjr/status/4642353097...  2014-05-08 02:48:17
# ...

# %%
#Show the 'shape' of the dataframe 
shape = NJr_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
NJr_Tweets_df = NJr_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = NJr_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
NJr_Tweets_df
# Out:
#       Username      User Id Tweet Type  \
# 0     neymarjr  "158487331"      Tweet
# 1     neymarjr  "158487331"      Tweet
# 2     neymarjr  "158487331"      Tweet
# 3     neymarjr  "158487331"      Tweet
# 4     neymarjr  "158487331"      Tweet
# ...        ...          ...        ...
# 3195  neymarjr  "158487331"      Reply
# 3196  neymarjr  "158487331"      Tweet
# 3197  neymarjr  "158487331"      Reply
# 3198  neymarjr  "158487331"      Reply
# 3199  neymarjr  "158487331"      Reply
#
#                                           Tweet Content              Client  \
# 0       "Bon Match les gars 👊🏽 https://t.co/3vltfC5YDd"  Twitter for iPhone
# 1     "@GaGaMilanoWorld \n#gagamilano #gagamilanowat...     Twitter Web App
# 2     "Matteo @REPLAY 🤙🏽 \n\nBy; 📸 @gilcebola https:...  Twitter for iPhone
# 3                     "Focus 👀 https://t.co/PVhK0296jo"  Twitter for iPhone
# 4     "Que Deus nos abençoe e nos proteja 🙏🏽⚽️ https...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
NJr_Tweets_df = NJr_Tweets_df.dropna() 

#Confirm rows are dropped
shape = NJr_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NJr_Tweets_df['Tweet Posted Time'] = NJr_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NJr_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
NJr_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NJr_Tweets_df['Tweet Posted Time'] = NJr_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NJr_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
NJr_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
NJr_Tweets_df = NJr_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = NJr_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
NJr_Tweets_df
# Out:
#       Username      User Id Tweet Type  \
# 0     neymarjr  "158487331"      Tweet
# 1     neymarjr  "158487331"      Tweet
# 2     neymarjr  "158487331"      Tweet
# 3     neymarjr  "158487331"      Tweet
# 4     neymarjr  "158487331"      Tweet
# ...        ...          ...        ...
# 3195  neymarjr  "158487331"      Reply
# 3196  neymarjr  "158487331"      Tweet
# 3197  neymarjr  "158487331"      Reply
# 3198  neymarjr  "158487331"      Reply
# 3199  neymarjr  "158487331"      Reply
#
#                                           Tweet Content              Client  \
# 0       "Bon Match les gars 👊🏽 https://t.co/3vltfC5YDd"  Twitter for iPhone
# 1     "@GaGaMilanoWorld \n#gagamilano #gagamilanowat...     Twitter Web App
# 2     "Matteo @REPLAY 🤙🏽 \n\nBy; 📸 @gilcebola https:...  Twitter for iPhone
# 3                     "Focus 👀 https://t.co/PVhK0296jo"  Twitter for iPhone
# 4     "Que Deus nos abençoe e nos proteja 🙏🏽⚽️ https...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
NJr_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
NJr_Tweets_df['Vocation'] = "Sport"

#Show the 'shape' of the dataframe
shape = NJr_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
NJr_Tweets_df.index = [x for x in range(1, len(NJr_Tweets_df.values)+1)]
NJr_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
NJr_Tweets_df
# Out:
#        Username      User Id Tweet Type  \
# Index
# 1      neymarjr  "158487331"      Tweet
# 2      neymarjr  "158487331"      Tweet
# 3      neymarjr  "158487331"      Tweet
# 4      neymarjr  "158487331"      Tweet
# 5      neymarjr  "158487331"      Tweet
# ...         ...          ...        ...
# 3196   neymarjr  "158487331"      Reply
# 3197   neymarjr  "158487331"      Tweet
# 3198   neymarjr  "158487331"      Reply
# 3199   neymarjr  "158487331"      Reply
# 3200   neymarjr  "158487331"      Reply
#
#                                            Tweet Content              Client  \
# Index
# 1        "Bon Match les gars 👊🏽 https://t.co/3vltfC5YDd"  Twitter for iPhone
# 2      "@GaGaMilanoWorld \n#gagamilano #gagamilanowat...     Twitter Web App
# 3      "Matteo @REPLAY 🤙🏽 \n\nBy; 📸 @gilcebola https:...  Twitter for iPhone
# 4                      "Focus 👀 https://t.co/PVhK0296jo"  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
NJr_Tweets_df.to_csv('NJr_Tweets_df.csv')
