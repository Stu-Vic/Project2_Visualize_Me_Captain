# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Shakira Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "ShakiraTweets.csv"

#Import the CSV into a pandas DataFrame
Shakira_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Shakira_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220173541783625729"
# 1     "1220112032613257216"
# 2     "1219711517328801792"
# 3     "1219711263355305986"
# 4     "1219656296821067777"
# ...                     ...
# 3160   "590521927401340928"
# 3161   "590271806239612928"
# 3162   "590271463862755328"
# 3163   "588817413338058752"
# 3164   "588817259478458368"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/shakira/status/12201735417...  2020-01-23 02:36:56
# 1     https://twitter.com/shakira/status/12201120326...  2020-01-22 22:32:31
# 2     https://twitter.com/sonymusiclatin/status/1219...  2020-01-21 20:01:01
# 3     https://twitter.com/amazonmusic/status/1219711...  2020-01-21 20:00:00
# 4     https://twitter.com/shakira/status/12196562968...  2020-01-21 16:21:35
# ...                                                 ...                  ...
# 3160  https://twitter.com/shakira/status/59052192740...  2015-04-21 14:26:13
# 3161  https://twitter.com/shakira/status/59027180623...  2015-04-20 21:52:19
# 3162  https://twitter.com/shakira/status/59027146386...  2015-04-20 21:50:58
# 3163  https://twitter.com/shakira/status/58881741333...  2015-04-16 21:33:05
# 3164  https://twitter.com/shakira/status/58881725947...  2015-04-16 21:32:29
#
#                                           Tweet Content Tweet Type  \
# 0     "Avanza la construcción de nuestro colegio @fp...      Tweet
# 1     "Componiendo Me Gusta! Composing Me Gusta! @an...      Tweet
# 2     "Di: "Alexa play #MeGusta by \n@shakira y @Anu...    Retweet
# 3     ".@shakira is kicking off 2020 with new music,...    Retweet
# 4     ".@TheAnnaKaiser rules: turn off your phone un...      Tweet
# ...                                                 ...        ...
# 3160  ""Sabías que es más fácil enseñarle a leer a u...      Tweet
# 3161  "Acabo de recibir mis 3 @GWR récord enmarcados...      Tweet
# 3162  "Just got my 3 @GWR records framed! So, logica...      Tweet
# 3163  "Just 15 days left to nominate the most extrao...      Tweet
# 3164  "Quedan solo 15 días para nominar a los premio...      Tweet
#
#                     Client  Retweets received  Likes received     User Id  \
# 0       Twitter for iPhone                578            5606  "44409004"
# 1     Twitter Media Studio                723            4737  "44409004"
# 2            Gain Platform                132             814  "44399838"
# 3                 Sprinklr                145             842  "14740219"
# 4       Twitter for iPhone                342            3908  "44409004"
# ...                    ...                ...             ...         ...
# 3160    Twitter Web Client                859            2050  "44409004"
# 3161    Twitter for iPhone               1224            3236  "44409004"
# 3162    Twitter for iPhone                971            2661  "44409004"
# 3163    Twitter for iPhone                457            1360  "44409004"
# 3164    Twitter for iPhone                399            1240  "44409004"
#
#                     Name        Username Verified or Non-Verified  \
# 0              "Shakira"         shakira                 Verified
# 1              "Shakira"         shakira                 Verified
# 2     "Sony Music Latin"  sonymusiclatin                 Verified
# 3         "Amazon Music"     amazonmusic                 Verified
# 4              "Shakira"         shakira                 Verified
# ...                  ...             ...                      ...
# 3160           "Shakira"         shakira                 Verified
# 3161           "Shakira"         shakira                 Verified
# 3162           "Shakira"         shakira                 Verified
# 3163           "Shakira"         shakira                 Verified
# 3164           "Shakira"         shakira                 Verified
#
#                              Profile URL Protected or Not Protected
# 0            https://twitter.com/shakira              Not Protected
# 1            https://twitter.com/shakira              Not Protected
# 2     https://twitter.com/sonymusiclatin              Not Protected
# 3        https://twitter.com/amazonmusic              Not Protected
# 4            https://twitter.com/shakira              Not Protected
# ...                                  ...                        ...
# 3160         https://twitter.com/shakira              Not Protected
# 3161         https://twitter.com/shakira              Not Protected
# 3162         https://twitter.com/shakira              Not Protected
# 3163         https://twitter.com/shakira              Not Protected
# 3164         https://twitter.com/shakira              Not Protected
#
# [3165 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = Shakira_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3165, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Shakira_Tweets_df = Shakira_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Shakira_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3165, 8)

# %%
#Print the dataframe
Shakira_Tweets_df
# Out:
#             Username     User Id Tweet Type  \
# 0            shakira  "44409004"      Tweet
# 1            shakira  "44409004"      Tweet
# 2     sonymusiclatin  "44399838"    Retweet
# 3        amazonmusic  "14740219"    Retweet
# 4            shakira  "44409004"      Tweet
# ...              ...         ...        ...
# 3160         shakira  "44409004"      Tweet
# 3161         shakira  "44409004"      Tweet
# 3162         shakira  "44409004"      Tweet
# 3163         shakira  "44409004"      Tweet
# 3164         shakira  "44409004"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Avanza la construcción de nuestro colegio @fp...    Twitter for iPhone
# 1     "Componiendo Me Gusta! Composing Me Gusta! @an...  Twitter Media Studio
# 2     "Di: "Alexa play #MeGusta by \n@shakira y @Anu...         Gain Platform
# 3     ".@shakira is kicking off 2020 with new music,...              Sprinklr
# 4     ".@TheAnnaKaiser rules: turn off your phone un...    Twitter for iPhone
# ...                                                 ...                   ...
# 3160  ""Sabías que es más fácil enseñarle a leer a u...    Twitter Web Client
# 3161  "Acabo de recibir mis 3 @GWR récord enmarcados...    Twitter for iPhone
# 3162  "Just got my 3 @GWR records framed! So, logica...    Twitter for iPhone
# 3163  "Just 15 days left to nominate the most extrao...    Twitter for iPhone
# 3164  "Quedan solo 15 días para nominar a los premio...    Twitter for iPhone
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                   578            5606  2020-01-23 02:36:56
# 1                   723            4737  2020-01-22 22:32:31
# 2                   132             814  2020-01-21 20:01:01
# 3                   145             842  2020-01-21 20:00:00
# 4                   342            3908  2020-01-21 16:21:35
# ...                 ...             ...                  ...
# 3160                859            2050  2015-04-21 14:26:13
# 3161               1224            3236  2015-04-20 21:52:19
# 3162                971            2661  2015-04-20 21:50:58
# 3163                457            1360  2015-04-16 21:33:05
# 3164                399            1240  2015-04-16 21:32:29
#
# [3165 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Shakira_Tweets_df = Shakira_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Shakira_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3165, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Shakira_Tweets_df['Tweet Posted Time'] = Shakira_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Shakira_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Shakira_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Shakira_Tweets_df['Tweet Posted Time'] = Shakira_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Shakira_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Shakira_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Shakira_Tweets_df = Shakira_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Shakira_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3165, 9)

# %%
#Print the dataframe
Shakira_Tweets_df
# Out:
#             Username     User Id Tweet Type  \
# 0            shakira  "44409004"      Tweet
# 1            shakira  "44409004"      Tweet
# 2     sonymusiclatin  "44399838"    Retweet
# 3        amazonmusic  "14740219"    Retweet
# 4            shakira  "44409004"      Tweet
# ...              ...         ...        ...
# 3160         shakira  "44409004"      Tweet
# 3161         shakira  "44409004"      Tweet
# 3162         shakira  "44409004"      Tweet
# 3163         shakira  "44409004"      Tweet
# 3164         shakira  "44409004"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Avanza la construcción de nuestro colegio @fp...    Twitter for iPhone
# 1     "Componiendo Me Gusta! Composing Me Gusta! @an...  Twitter Media Studio
# 2     "Di: "Alexa play #MeGusta by \n@shakira y @Anu...         Gain Platform
# 3     ".@shakira is kicking off 2020 with new music,...              Sprinklr
# 4     ".@TheAnnaKaiser rules: turn off your phone un...    Twitter for iPhone
# ...                                                 ...                   ...
# 3160  ""Sabías que es más fácil enseñarle a leer a u...    Twitter Web Client
# 3161  "Acabo de recibir mis 3 @GWR récord enmarcados...    Twitter for iPhone
# 3162  "Just got my 3 @GWR records framed! So, logica...    Twitter for iPhone
# 3163  "Just 15 days left to nominate the most extrao...    Twitter for iPhone
# 3164  "Quedan solo 15 días para nominar a los premio...    Twitter for iPhone
#
#       Retweets received  Likes received        Date      Time
# 0                   578            5606  2020-01-23  02:36:56
# 1                   723            4737  2020-01-22  22:32:31
# 2                   132             814  2020-01-21  20:01:01
# 3                   145             842  2020-01-21  20:00:00
# 4                   342            3908  2020-01-21  16:21:35
# ...                 ...             ...         ...       ...
# 3160                859            2050  2015-04-21  14:26:13
# 3161               1224            3236  2015-04-20  21:52:19
# 3162                971            2661  2015-04-20  21:50:58
# 3163                457            1360  2015-04-16  21:33:05
# 3164                399            1240  2015-04-16  21:32:29
#
# [3165 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Shakira_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
Shakira_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = Shakira_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3165, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Shakira_Tweets_df.index = [x for x in range(1, len(Shakira_Tweets_df.values)+1)]
Shakira_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Shakira_Tweets_df
# Out:
#              Username     User Id Tweet Type  \
# Index
# 1             shakira  "44409004"      Tweet
# 2             shakira  "44409004"      Tweet
# 3      sonymusiclatin  "44399838"    Retweet
# 4         amazonmusic  "14740219"    Retweet
# 5             shakira  "44409004"      Tweet
# ...               ...         ...        ...
# 3161          shakira  "44409004"      Tweet
# 3162          shakira  "44409004"      Tweet
# 3163          shakira  "44409004"      Tweet
# 3164          shakira  "44409004"      Tweet
# 3165          shakira  "44409004"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "Avanza la construcción de nuestro colegio @fp...
# 2      "Componiendo Me Gusta! Composing Me Gusta! @an...
# 3      "Di: "Alexa play #MeGusta by \n@shakira y @Anu...
# 4      ".@shakira is kicking off 2020 with new music,...
# 5      ".@TheAnnaKaiser rules: turn off your phone un...
# ...                                                  ...
# 3161   ""Sabías que es más fácil enseñarle a leer a u...
# 3162   "Acabo de recibir mis 3 @GWR récord enmarcados...
# 3163   "Just got my 3 @GWR records framed! So, logica...
# 3164   "Just 15 days left to nominate the most extrao...
# 3165   "Quedan solo 15 días para nominar a los premio...
#
#                      Client  Retweets received  Likes received        Date  \
# Index
# 1        Twitter for iPhone                578            5606  2020-01-23
# 2      Twitter Media Studio                723            4737  2020-01-22
# 3             Gain Platform                132             814  2020-01-21
# 4                  Sprinklr                145             842  2020-01-21
# 5        Twitter for iPhone                342            3908  2020-01-21
# ...                     ...                ...             ...         ...
# 3161     Twitter Web Client                859            2050  2015-04-21
# 3162     Twitter for iPhone               1224            3236  2015-04-20
# 3163     Twitter for iPhone                971            2661  2015-04-20
# 3164     Twitter for iPhone                457            1360  2015-04-16
# 3165     Twitter for iPhone                399            1240  2015-04-16
#
#            Time  Gender Vocation
# Index
# 1      02:36:56  Female    Music
# 2      22:32:31  Female    Music
# 3      20:01:01  Female    Music
# 4      20:00:00  Female    Music
# 5      16:21:35  Female    Music
# ...         ...     ...      ...
# 3161   14:26:13  Female    Music
# 3162   21:52:19  Female    Music
# 3163   21:50:58  Female    Music
# 3164   21:33:05  Female    Music
# 3165   21:32:29  Female    Music
#
# [3165 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Shakira_Tweets_df.to_csv('Shakira_Tweets_df.csv')
