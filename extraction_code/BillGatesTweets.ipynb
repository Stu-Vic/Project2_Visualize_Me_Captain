# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Bill Gates Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "BillGatesTweets.csv"

#Import the CSV into a pandas DataFrame
BGates_Tweets_df = pd.read_csv(csv_path, low_memory = False)
BGates_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220006544789532678"
# 1     "1220006293282230277"
# 2     "1219750261268209664"
# 3     "1218240511137370112"
# 4     "1217863316548116480"
# ...                     ...
# 3195           "8984143579"
# 3196           "8983423241"
# 3197           "8983404594"
# 3198           "8981191030"
# 3199           "8972846963"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/billgates/status/122000654...  2020-01-22 15:33:21
# 1     https://twitter.com/billgates/status/122000629...  2020-01-22 15:32:21
# 2     https://twitter.com/billgates/status/121975026...  2020-01-21 22:34:58
# 3     https://twitter.com/billgates/status/121824051...  2020-01-17 18:35:46
# 4     https://twitter.com/billgates/status/121786331...  2020-01-16 17:36:56
# ...                                                 ...                  ...
# 3195    https://twitter.com/billgates/status/8984143579  2010-02-11 23:59:46
# ...

# %%
#Show the 'shape' of the dataframe 
shape = BGates_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
BGates_Tweets_df = BGates_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = BGates_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
BGates_Tweets_df
# Out:
#        Username     User Id Tweet Type  \
# 0     billgates  "50393960"      Reply
# 1     billgates  "50393960"      Tweet
# 2     billgates  "50393960"      Tweet
# 3     billgates  "50393960"      Tweet
# 4     billgates  "50393960"      Tweet
# ...         ...         ...        ...
# 3195  billgates  "50393960"      Tweet
# 3196  billgates  "50393960"      Tweet
# 3197  billgates  "50393960"      Reply
# 3198  billgates  "50393960"      Tweet
# 3199  billgates  "50393960"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "@gavi There are still too many children—many ...       Twitter Web App
# 1     "For twenty years, @gavi has worked to ensure ...       Twitter Web App
# 2     "I had a fascinating conversation with Vaclav ...  Twitter Media Studio
# 3     "It's great to see Microsoft's leadership in t...       Twitter Web App
# 4     "These global health heroes have helped Bangla...  Twitter Media Studio
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
BGates_Tweets_df = BGates_Tweets_df.dropna() 

#Confirm rows are dropped
shape = BGates_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BGates_Tweets_df['Tweet Posted Time'] = BGates_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BGates_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
BGates_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BGates_Tweets_df['Tweet Posted Time'] = BGates_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BGates_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
BGates_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
BGates_Tweets_df = BGates_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = BGates_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
BGates_Tweets_df
# Out:
#        Username     User Id Tweet Type  \
# 0     billgates  "50393960"      Reply
# 1     billgates  "50393960"      Tweet
# 2     billgates  "50393960"      Tweet
# 3     billgates  "50393960"      Tweet
# 4     billgates  "50393960"      Tweet
# ...         ...         ...        ...
# 3195  billgates  "50393960"      Tweet
# 3196  billgates  "50393960"      Tweet
# 3197  billgates  "50393960"      Reply
# 3198  billgates  "50393960"      Tweet
# 3199  billgates  "50393960"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "@gavi There are still too many children—many ...       Twitter Web App
# 1     "For twenty years, @gavi has worked to ensure ...       Twitter Web App
# 2     "I had a fascinating conversation with Vaclav ...  Twitter Media Studio
# 3     "It's great to see Microsoft's leadership in t...       Twitter Web App
# 4     "These global health heroes have helped Bangla...  Twitter Media Studio
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
BGates_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
BGates_Tweets_df['Vocation'] = "Technology"

#Show the 'shape' of the dataframe
shape = BGates_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
BGates_Tweets_df.index = [x for x in range(1, len(BGates_Tweets_df.values)+1)]
BGates_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
BGates_Tweets_df
# Out:
#         Username     User Id Tweet Type  \
# Index
# 1      billgates  "50393960"      Reply
# 2      billgates  "50393960"      Tweet
# 3      billgates  "50393960"      Tweet
# 4      billgates  "50393960"      Tweet
# 5      billgates  "50393960"      Tweet
# ...          ...         ...        ...
# 3196   billgates  "50393960"      Tweet
# 3197   billgates  "50393960"      Tweet
# 3198   billgates  "50393960"      Reply
# 3199   billgates  "50393960"      Tweet
# 3200   billgates  "50393960"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "@gavi There are still too many children—many ...
# 2      "For twenty years, @gavi has worked to ensure ...
# 3      "I had a fascinating conversation with Vaclav ...
# 4      "It's great to see Microsoft's leadership in t...
# 5      "These global health heroes have helped Bangla...
# ...                                                  ...
# 3196   "RT @bing: Blaise talks Spatial Search to the ...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
BGates_Tweets_df.to_csv('BGates_Tweets_df.csv')
