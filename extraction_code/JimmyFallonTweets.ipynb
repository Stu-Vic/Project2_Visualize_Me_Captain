# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Jimmy Fallon Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "JimmyFallonTweets.csv"

#Import the CSV into a pandas DataFrame
JFallon_Tweets_df = pd.read_csv(csv_path, low_memory = False)
JFallon_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219730046694383618"
# 1     "1219729849583067136"
# 2     "1218196761271054341"
# 3     "1218195511787782144"
# 4     "1217937309410131969"
# ...                     ...
# 3195   "753569949671645184"
# 3196   "753564046457274368"
# 3197   "753561347351248897"
# 3198   "753561070304890880"
# 3199   "753397108997259265"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/jimmyfallon/status/1219730...  2020-01-21 21:14:39
# 1     https://twitter.com/jimmyfallon/status/1219729...  2020-01-21 21:13:52
# 2     https://twitter.com/jimmyfallon/status/1218196...  2020-01-17 15:41:55
# 3     https://twitter.com/jimmyfallon/status/1218195...  2020-01-17 15:36:57
# 4     https://twitter.com/jimmyfallon/status/1217937...  2020-01-16 22:30:57
# ...                                                 ...                  ...
# 3195  https://twitter.com/jimmyfallon/status/7535699...  2016-07-14 12:40:51
# ...

# %%
#Show the 'shape' of the dataframe 
shape = JFallon_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
JFallon_Tweets_df = JFallon_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = JFallon_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
JFallon_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# 0     jimmyfallon  "15485441"      Tweet
# 1     jimmyfallon  "15485441"      Tweet
# 2     jimmyfallon  "15485441"      Reply
# 3     jimmyfallon  "15485441"      Reply
# 4     jimmyfallon  "15485441"      Tweet
# ...           ...         ...        ...
# 3195  jimmyfallon  "15485441"      Tweet
# 3196  jimmyfallon  "15485441"      Tweet
# 3197  jimmyfallon  "15485441"      Tweet
# 3198  jimmyfallon  "15485441"      Tweet
# 3199  jimmyfallon  "15485441"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "#ThereShouldBeALaw that people who pronounce ...  Twitter for iPhone
# 1     "It’s Hashtags time! Tag a tweet with #ThereSh...  Twitter for iPhone
# 2                     "Friend goals. #happybirthdaylin"  Twitter for iPhone
# 3                             "https://t.co/l6mMb0Tdzc"  Twitter for iPhone
# 4     "Kid monologues, kid games, kid interviews, bi...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
JFallon_Tweets_df = JFallon_Tweets_df.dropna() 

#Confirm rows are dropped
shape = JFallon_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
JFallon_Tweets_df['Tweet Posted Time'] = JFallon_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = JFallon_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
JFallon_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
JFallon_Tweets_df['Tweet Posted Time'] = JFallon_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = JFallon_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
JFallon_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
JFallon_Tweets_df = JFallon_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = JFallon_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
JFallon_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# 0     jimmyfallon  "15485441"      Tweet
# 1     jimmyfallon  "15485441"      Tweet
# 2     jimmyfallon  "15485441"      Reply
# 3     jimmyfallon  "15485441"      Reply
# 4     jimmyfallon  "15485441"      Tweet
# ...           ...         ...        ...
# 3195  jimmyfallon  "15485441"      Tweet
# 3196  jimmyfallon  "15485441"      Tweet
# 3197  jimmyfallon  "15485441"      Tweet
# 3198  jimmyfallon  "15485441"      Tweet
# 3199  jimmyfallon  "15485441"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "#ThereShouldBeALaw that people who pronounce ...  Twitter for iPhone
# 1     "It’s Hashtags time! Tag a tweet with #ThereSh...  Twitter for iPhone
# 2                     "Friend goals. #happybirthdaylin"  Twitter for iPhone
# 3                             "https://t.co/l6mMb0Tdzc"  Twitter for iPhone
# 4     "Kid monologues, kid games, kid interviews, bi...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
JFallon_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
JFallon_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = JFallon_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
JFallon_Tweets_df.index = [x for x in range(1, len(JFallon_Tweets_df.values)+1)]
JFallon_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
JFallon_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# Index
# 1      jimmyfallon  "15485441"      Tweet
# 2      jimmyfallon  "15485441"      Tweet
# 3      jimmyfallon  "15485441"      Reply
# 4      jimmyfallon  "15485441"      Reply
# 5      jimmyfallon  "15485441"      Tweet
# ...            ...         ...        ...
# 3196   jimmyfallon  "15485441"      Tweet
# 3197   jimmyfallon  "15485441"      Tweet
# 3198   jimmyfallon  "15485441"      Tweet
# 3199   jimmyfallon  "15485441"      Tweet
# 3200   jimmyfallon  "15485441"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "#ThereShouldBeALaw that people who pronounce ...  Twitter for iPhone
# 2      "It’s Hashtags time! Tag a tweet with #ThereSh...  Twitter for iPhone
# 3                      "Friend goals. #happybirthdaylin"  Twitter for iPhone
# 4                              "https://t.co/l6mMb0Tdzc"  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
JFallon_Tweets_df.to_csv('JFallon_Tweets_df.csv')
