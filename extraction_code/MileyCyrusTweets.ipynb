# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Miley Cyrus Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "MileyCyrusTweets.csv"

#Import the CSV into a pandas DataFrame
MCyrus_Tweets_df = pd.read_csv(csv_path, low_memory = False)
MCyrus_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219648605067173889"
# 1     "1218671432189632514"
# 2     "1218264038758502401"
# 3     "1218225041864675328"
# 4     "1218216622982197248"
# ...                     ...
# 3195   "504509324509847552"
# 3196   "504508496428421122"
# 3197   "504481510963941376"
# 3198   "504397898302246912"
# 3199   "504390761941458944"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/mileycyrus/status/12196486...  2020-01-21 15:51:02
# 1     https://twitter.com/mileycyrus/status/12186714...  2020-01-18 23:08:05
# 2     https://twitter.com/mileycyrus/status/12182640...  2020-01-17 20:09:15
# 3     https://twitter.com/mileycyrus/status/12182250...  2020-01-17 17:34:18
# 4     https://twitter.com/mileycyrus/status/12182166...  2020-01-17 17:00:50
# ...                                                 ...                  ...
# 3195  https://twitter.com/madonna/status/50450932450...  2014-08-27 06:02:50
# ...

# %%
#Show the 'shape' of the dataframe 
shape = MCyrus_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
MCyrus_Tweets_df = MCyrus_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = MCyrus_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
MCyrus_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# 0     mileycyrus  "268414482"      Tweet
# 1     mileycyrus  "268414482"      Tweet
# 2     mileycyrus  "268414482"      Tweet
# 3     mileycyrus  "268414482"      Tweet
# 4     mileycyrus  "268414482"      Tweet
# ...          ...          ...        ...
# 3195     madonna  "512700138"    Retweet
# 3196     madonna  "512700138"    Retweet
# 3197    danecook   "20978103"    Retweet
# 3198  mileycyrus  "268414482"      Reply
# 3199  mileycyrus  "268414482"      Reply
#
#                                           Tweet Content              Client  \
# 0     "A day in Watt’s shoes 👢 ( is definitely safer...  Twitter for iPhone
# 1                          "💀💀 https://t.co/tAFg0TlkG4"  Twitter for iPhone
# 2     "12 years ago today. Don’t say I haven’t alway...  Twitter for iPhone
# 3                "On sale now! https://t.co/hFGNMrrwYm"  Twitter for iPhone
# 4     "It was a year yesterday I had the honor of pe...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
MCyrus_Tweets_df = MCyrus_Tweets_df.dropna() 

#Confirm rows are dropped
shape = MCyrus_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
MCyrus_Tweets_df['Tweet Posted Time'] = MCyrus_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = MCyrus_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
MCyrus_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
MCyrus_Tweets_df['Tweet Posted Time'] = MCyrus_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = MCyrus_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
MCyrus_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
MCyrus_Tweets_df = MCyrus_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = MCyrus_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
MCyrus_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# 0     mileycyrus  "268414482"      Tweet
# 1     mileycyrus  "268414482"      Tweet
# 2     mileycyrus  "268414482"      Tweet
# 3     mileycyrus  "268414482"      Tweet
# 4     mileycyrus  "268414482"      Tweet
# ...          ...          ...        ...
# 3195     madonna  "512700138"    Retweet
# 3196     madonna  "512700138"    Retweet
# 3197    danecook   "20978103"    Retweet
# 3198  mileycyrus  "268414482"      Reply
# 3199  mileycyrus  "268414482"      Reply
#
#                                           Tweet Content              Client  \
# 0     "A day in Watt’s shoes 👢 ( is definitely safer...  Twitter for iPhone
# 1                          "💀💀 https://t.co/tAFg0TlkG4"  Twitter for iPhone
# 2     "12 years ago today. Don’t say I haven’t alway...  Twitter for iPhone
# 3                "On sale now! https://t.co/hFGNMrrwYm"  Twitter for iPhone
# 4     "It was a year yesterday I had the honor of pe...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
MCyrus_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
MCyrus_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = MCyrus_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
MCyrus_Tweets_df.index = [x for x in range(1, len(MCyrus_Tweets_df.values)+1)]
MCyrus_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
MCyrus_Tweets_df
# Out:
#          Username      User Id Tweet Type  \
# Index
# 1      mileycyrus  "268414482"      Tweet
# 2      mileycyrus  "268414482"      Tweet
# 3      mileycyrus  "268414482"      Tweet
# 4      mileycyrus  "268414482"      Tweet
# 5      mileycyrus  "268414482"      Tweet
# ...           ...          ...        ...
# 3196      madonna  "512700138"    Retweet
# 3197      madonna  "512700138"    Retweet
# 3198     danecook   "20978103"    Retweet
# 3199   mileycyrus  "268414482"      Reply
# 3200   mileycyrus  "268414482"      Reply
#
#                                            Tweet Content              Client  \
# Index
# 1      "A day in Watt’s shoes 👢 ( is definitely safer...  Twitter for iPhone
# 2                           "💀💀 https://t.co/tAFg0TlkG4"  Twitter for iPhone
# 3      "12 years ago today. Don’t say I haven’t alway...  Twitter for iPhone
# 4                 "On sale now! https://t.co/hFGNMrrwYm"  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
MCyrus_Tweets_df.to_csv('MCyrus_Tweets_df.csv')
