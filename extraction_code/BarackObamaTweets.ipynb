# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Barack Obama Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "BarackObamaTweets.csv"

#Import the CSV into a pandas DataFrame
BObama_Tweets_df = pd.read_csv(csv_path, low_memory = False)
BObama_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219267208250941440"
# 1     "1218174463046553600"
# 2     "1216725015695183872"
# 3     "1216428587328458754"
# 4     "1215378018790707205"
# ...                     ...
# 3195   "523207203864313856"
# 3196   "523197408457416704"
# 3197   "523162093378232320"
# 3198   "523141731252854784"
# 3199   "522839459197231104"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/barackobama/status/1219267...  2020-01-20 14:35:29
# 1     https://twitter.com/barackobama/status/1218174...  2020-01-17 14:13:19
# 2     https://twitter.com/barackobama/status/1216725...  2020-01-13 14:13:44
# 3     https://twitter.com/barackobama/status/1216428...  2020-01-12 18:35:50
# 4     https://twitter.com/barackobama/status/1215378...  2020-01-09 21:01:14
# ...                                                 ...                  ...
# 3195  https://twitter.com/obamawhitehouse/status/523...  2014-10-17 20:21:32
# ...

# %%
#Show the 'shape' of the dataframe 
shape = BObama_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
BObama_Tweets_df = BObama_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = BObama_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
BObama_Tweets_df
# Out:
#              Username     User Id Tweet Type  \
# 0         barackobama    "813286"      Tweet
# 1         barackobama    "813286"      Tweet
# 2         barackobama    "813286"      Tweet
# 3         barackobama    "813286"      Tweet
# 4         barackobama    "813286"      Reply
# ...               ...         ...        ...
# 3195  obamawhitehouse  "30313925"    Retweet
# 3196      barackobama    "813286"      Tweet
# 3197      barackobama    "813286"      Tweet
# 3198      barackobama    "813286"      Tweet
# 3199      barackobama    "813286"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "Every so often, I re-read Dr. King’s Letter f...  Twitter for iPhone
# 1     "In every scene, you are my star, @MichelleOba...  Twitter for iPhone
# 2     "Glad to see American Factory’s Oscar nod for ...  Twitter for iPhone
# 3     "Our fellow Americans in Puerto Rico can use o...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
BObama_Tweets_df = BObama_Tweets_df.dropna() 

#Confirm rows are dropped
shape = BObama_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BObama_Tweets_df['Tweet Posted Time'] = BObama_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BObama_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
BObama_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BObama_Tweets_df['Tweet Posted Time'] = BObama_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BObama_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
BObama_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
BObama_Tweets_df = BObama_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = BObama_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
BObama_Tweets_df
# Out:
#              Username     User Id Tweet Type  \
# 0         barackobama    "813286"      Tweet
# 1         barackobama    "813286"      Tweet
# 2         barackobama    "813286"      Tweet
# 3         barackobama    "813286"      Tweet
# 4         barackobama    "813286"      Reply
# ...               ...         ...        ...
# 3195  obamawhitehouse  "30313925"    Retweet
# 3196      barackobama    "813286"      Tweet
# 3197      barackobama    "813286"      Tweet
# 3198      barackobama    "813286"      Tweet
# 3199      barackobama    "813286"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "Every so often, I re-read Dr. King’s Letter f...  Twitter for iPhone
# 1     "In every scene, you are my star, @MichelleOba...  Twitter for iPhone
# 2     "Glad to see American Factory’s Oscar nod for ...  Twitter for iPhone
# 3     "Our fellow Americans in Puerto Rico can use o...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
BObama_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
BObama_Tweets_df['Vocation'] = "Politics"

#Show the 'shape' of the dataframe
shape = BObama_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
BObama_Tweets_df.index = [x for x in range(1, len(BObama_Tweets_df.values)+1)]
BObama_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
BObama_Tweets_df
# Out:
#               Username     User Id Tweet Type  \
# Index
# 1          barackobama    "813286"      Tweet
# 2          barackobama    "813286"      Tweet
# 3          barackobama    "813286"      Tweet
# 4          barackobama    "813286"      Tweet
# 5          barackobama    "813286"      Reply
# ...                ...         ...        ...
# 3196   obamawhitehouse  "30313925"    Retweet
# 3197       barackobama    "813286"      Tweet
# 3198       barackobama    "813286"      Tweet
# 3199       barackobama    "813286"      Tweet
# 3200       barackobama    "813286"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "Every so often, I re-read Dr. King’s Letter f...  Twitter for iPhone
# 2      "In every scene, you are my star, @MichelleOba...  Twitter for iPhone
# 3      "Glad to see American Factory’s Oscar nod for ...  Twitter for iPhone
# 4      "Our fellow Americans in Puerto Rico can use o...  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
BObama_Tweets_df.to_csv('BObama_Tweets_df.csv')
