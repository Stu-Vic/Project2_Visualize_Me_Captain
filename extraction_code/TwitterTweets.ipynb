# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Twitter Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "TwitterTweets.csv"

#Import the CSV into a pandas DataFrame
Twitter_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Twitter_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1238533432998838275"
# 1     "1238206067143827457"
# 2     "1237864548587069451"
# 3     "1237766891915087872"
# 4     "1237512543817457664"
# ...                     ...
# 3195  "1126680301693022208"
# 3196  "1126607219049598978"
# 3197  "1126597589028282380"
# 3198  "1126597501358940175"
# 3199  "1126580932813705217"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/twitter/status/12385334329...  2020-03-13 18:32:35
# 1     https://twitter.com/twitter/status/12382060671...  2020-03-12 20:51:45
# 2     https://twitter.com/twitter/status/12378645485...  2020-03-11 22:14:41
# 3     https://twitter.com/twitter/status/12377668919...  2020-03-11 15:46:38
# 4     https://twitter.com/twitter/status/12375125438...  2020-03-10 22:55:56
# ...                                                 ...                  ...
# 3195  https://twitter.com/trevor_norris0/status/1126...  2019-05-10 02:48:11
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Twitter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Twitter_Tweets_df = Twitter_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Twitter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
Twitter_Tweets_df
# Out:
#             Username       User Id Tweet Type  \
# 0            twitter      "783214"      Reply
# 1            twitter      "783214"      Reply
# 2            twitter      "783214"      Reply
# 3            twitter      "783214"      Reply
# 4            twitter      "783214"      Reply
# ...              ...           ...        ...
# 3195  trevor_norris0  "1794348475"    Retweet
# 3196          cosmis    "22081681"    Retweet
# 3197         twitter      "783214"      Reply
# 3198         twitter      "783214"      Reply
# 3199         twitter      "783214"      Reply
#
#                                           Tweet Content               Client  \
# 0     "@litskinayo turns out you're not the only per...             Sprinklr
# 1     "@alicegoldfuss and remember we're all in this...             Sprinklr
# 2     "@cryingyoon yeah they give us the confidence ...             Sprinklr
# 3     "@illustjuan come for the memes, stay for the ...             Sprinklr
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Twitter_Tweets_df = Twitter_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Twitter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Twitter_Tweets_df['Tweet Posted Time'] = Twitter_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Twitter_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Twitter_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Twitter_Tweets_df['Tweet Posted Time'] = Twitter_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Twitter_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Twitter_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Twitter_Tweets_df = Twitter_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Twitter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
Twitter_Tweets_df
# Out:
#             Username       User Id Tweet Type  \
# 0            twitter      "783214"      Reply
# 1            twitter      "783214"      Reply
# 2            twitter      "783214"      Reply
# 3            twitter      "783214"      Reply
# 4            twitter      "783214"      Reply
# ...              ...           ...        ...
# 3195  trevor_norris0  "1794348475"    Retweet
# 3196          cosmis    "22081681"    Retweet
# 3197         twitter      "783214"      Reply
# 3198         twitter      "783214"      Reply
# 3199         twitter      "783214"      Reply
#
#                                           Tweet Content               Client  \
# 0     "@litskinayo turns out you're not the only per...             Sprinklr
# 1     "@alicegoldfuss and remember we're all in this...             Sprinklr
# 2     "@cryingyoon yeah they give us the confidence ...             Sprinklr
# 3     "@illustjuan come for the memes, stay for the ...             Sprinklr
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Twitter_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
Twitter_Tweets_df['Vocation'] = "News/Media"

#Show the 'shape' of the dataframe
shape = Twitter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Twitter_Tweets_df.index = [x for x in range(1, len(Twitter_Tweets_df.values)+1)]
Twitter_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Twitter_Tweets_df
# Out:
#              Username       User Id Tweet Type  \
# Index
# 1             twitter      "783214"      Reply
# 2             twitter      "783214"      Reply
# 3             twitter      "783214"      Reply
# 4             twitter      "783214"      Reply
# 5             twitter      "783214"      Reply
# ...               ...           ...        ...
# 3196   trevor_norris0  "1794348475"    Retweet
# 3197           cosmis    "22081681"    Retweet
# 3198          twitter      "783214"      Reply
# 3199          twitter      "783214"      Reply
# 3200          twitter      "783214"      Reply
#
#                                            Tweet Content               Client  \
# Index
# 1      "@litskinayo turns out you're not the only per...             Sprinklr
# 2      "@alicegoldfuss and remember we're all in this...             Sprinklr
# 3      "@cryingyoon yeah they give us the confidence ...             Sprinklr
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Twitter_Tweets_df.to_csv('Twitter_Tweets_df.csv')
