# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # CNN Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "CNNTweets.csv"

#Import the CSV into a pandas DataFrame
CNN_Tweets_df = pd.read_csv(csv_path, low_memory = False)
CNN_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220260325783756800"
# 1     "1220256373105184768"
# 2     "1220253611504099328"
# 3     "1220252471756566533"
# 4     "1220250580431536128"
# ...                     ...
# 3195  "1213148285172535296"
# 3196  "1213145517099749377"
# 3197  "1213143006934683649"
# 3198  "1213140493716140033"
# 3199  "1213137973279100929"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/cnn/status/122026032578375...  2020-01-23 08:21:47
# 1     https://twitter.com/cnn/status/122025637310518...  2020-01-23 08:06:05
# 2     https://twitter.com/cnn/status/122025361150409...  2020-01-23 07:55:06
# 3     https://twitter.com/cnn/status/122025247175656...  2020-01-23 07:50:35
# 4     https://twitter.com/cnn/status/122025058043153...  2020-01-23 07:43:04
# ...                                                 ...                  ...
# 3195  https://twitter.com/cnn/status/121314828517253...  2020-01-03 17:21:05
# 3196  https://twitter.com/cnn/status/121314551709974...  2020-01-03 17:10:05
# 3197  https://twitter.com/cnn/status/121314300693468...  2020-01-03 17:00:06
# 3198  https://twitter.com/cnn/status/121314049371614...  2020-01-03 16:50:07
# 3199  https://twitter.com/cnn/status/121313797327910...  2020-01-03 16:40:06
#
#                                           Tweet Content Tweet Type  \
# 0     "Airports around the world are increasing heal...      Tweet
# 1     "A state of emergency has been extended in New...      Tweet
# 2     "Three American crew members have died in Aust...      Tweet
# 3     "Police issued an arrest warrant for former NF...      Tweet
# 4     "Here are some things you can do to protect yo...      Tweet
# ...                                                 ...        ...
# 3195  "A rafflesia that recently bloomed in a West S...      Tweet
# 3196  "Kentucky's Attorney General says he's asking ...      Tweet
# 3197  "The American Kennel Club has announced two ne...      Tweet
# 3198  "Google has disabled access of Xiaomi devices ...      Tweet
# 3199  "Republican Sen. Lindsey Graham of South Carol...      Tweet
#
#           Client  Retweets received  Likes received   User Id   Name Username  \
# 0     SocialFlow                158             234  "759251"  "CNN"      cnn
# 1     SocialFlow                 91             251  "759251"  "CNN"      cnn
# 2     SocialFlow                 87             211  "759251"  "CNN"      cnn
# 3     SocialFlow                 41             109  "759251"  "CNN"      cnn
# 4     SocialFlow                135             257  "759251"  "CNN"      cnn
# ...          ...                ...             ...       ...    ...      ...
# 3195  SocialFlow                467            1742  "759251"  "CNN"      cnn
# 3196  SocialFlow                 69             326  "759251"  "CNN"      cnn
# 3197  SocialFlow                 60             246  "759251"  "CNN"      cnn
# 3198  SocialFlow                189             319  "759251"  "CNN"      cnn
# 3199  SocialFlow                630            1397  "759251"  "CNN"      cnn
#
#      Verified or Non-Verified              Profile URL  \
# 0                    Verified  https://twitter.com/cnn
# 1                    Verified  https://twitter.com/cnn
# 2                    Verified  https://twitter.com/cnn
# 3                    Verified  https://twitter.com/cnn
# 4                    Verified  https://twitter.com/cnn
# ...                       ...                      ...
# 3195                 Verified  https://twitter.com/cnn
# 3196                 Verified  https://twitter.com/cnn
# 3197                 Verified  https://twitter.com/cnn
# 3198                 Verified  https://twitter.com/cnn
# 3199                 Verified  https://twitter.com/cnn
#
#      Protected or Not Protected
# 0                 Not Protected
# 1                 Not Protected
# 2                 Not Protected
# 3                 Not Protected
# 4                 Not Protected
# ...                         ...
# 3195              Not Protected
# 3196              Not Protected
# 3197              Not Protected
# 3198              Not Protected
# 3199              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = CNN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
CNN_Tweets_df = CNN_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = CNN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
CNN_Tweets_df
# Out:
#      Username   User Id Tweet Type  \
# 0         cnn  "759251"      Tweet
# 1         cnn  "759251"      Tweet
# 2         cnn  "759251"      Tweet
# 3         cnn  "759251"      Tweet
# 4         cnn  "759251"      Tweet
# ...       ...       ...        ...
# 3195      cnn  "759251"      Tweet
# 3196      cnn  "759251"      Tweet
# 3197      cnn  "759251"      Tweet
# 3198      cnn  "759251"      Tweet
# 3199      cnn  "759251"      Tweet
#
#                                           Tweet Content      Client  \
# 0     "Airports around the world are increasing heal...  SocialFlow
# 1     "A state of emergency has been extended in New...  SocialFlow
# 2     "Three American crew members have died in Aust...  SocialFlow
# 3     "Police issued an arrest warrant for former NF...  SocialFlow
# 4     "Here are some things you can do to protect yo...  SocialFlow
# ...                                                 ...         ...
# 3195  "A rafflesia that recently bloomed in a West S...  SocialFlow
# 3196  "Kentucky's Attorney General says he's asking ...  SocialFlow
# 3197  "The American Kennel Club has announced two ne...  SocialFlow
# 3198  "Google has disabled access of Xiaomi devices ...  SocialFlow
# 3199  "Republican Sen. Lindsey Graham of South Carol...  SocialFlow
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                   158             234  2020-01-23 08:21:47
# 1                    91             251  2020-01-23 08:06:05
# 2                    87             211  2020-01-23 07:55:06
# 3                    41             109  2020-01-23 07:50:35
# 4                   135             257  2020-01-23 07:43:04
# ...                 ...             ...                  ...
# 3195                467            1742  2020-01-03 17:21:05
# 3196                 69             326  2020-01-03 17:10:05
# 3197                 60             246  2020-01-03 17:00:06
# 3198                189             319  2020-01-03 16:50:07
# 3199                630            1397  2020-01-03 16:40:06
#
# [3200 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
CNN_Tweets_df = CNN_Tweets_df.dropna() 

#Confirm rows are dropped
shape = CNN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
CNN_Tweets_df['Tweet Posted Time'] = CNN_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = CNN_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
CNN_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
CNN_Tweets_df['Tweet Posted Time'] = CNN_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = CNN_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
CNN_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
CNN_Tweets_df = CNN_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = CNN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
CNN_Tweets_df
# Out:
#      Username   User Id Tweet Type  \
# 0         cnn  "759251"      Tweet
# 1         cnn  "759251"      Tweet
# 2         cnn  "759251"      Tweet
# 3         cnn  "759251"      Tweet
# 4         cnn  "759251"      Tweet
# ...       ...       ...        ...
# 3195      cnn  "759251"      Tweet
# 3196      cnn  "759251"      Tweet
# 3197      cnn  "759251"      Tweet
# 3198      cnn  "759251"      Tweet
# 3199      cnn  "759251"      Tweet
#
#                                           Tweet Content      Client  \
# 0     "Airports around the world are increasing heal...  SocialFlow
# 1     "A state of emergency has been extended in New...  SocialFlow
# 2     "Three American crew members have died in Aust...  SocialFlow
# 3     "Police issued an arrest warrant for former NF...  SocialFlow
# 4     "Here are some things you can do to protect yo...  SocialFlow
# ...                                                 ...         ...
# 3195  "A rafflesia that recently bloomed in a West S...  SocialFlow
# 3196  "Kentucky's Attorney General says he's asking ...  SocialFlow
# 3197  "The American Kennel Club has announced two ne...  SocialFlow
# 3198  "Google has disabled access of Xiaomi devices ...  SocialFlow
# 3199  "Republican Sen. Lindsey Graham of South Carol...  SocialFlow
#
#       Retweets received  Likes received        Date      Time
# 0                   158             234  2020-01-23  08:21:47
# 1                    91             251  2020-01-23  08:06:05
# 2                    87             211  2020-01-23  07:55:06
# 3                    41             109  2020-01-23  07:50:35
# 4                   135             257  2020-01-23  07:43:04
# ...                 ...             ...         ...       ...
# 3195                467            1742  2020-01-03  17:21:05
# 3196                 69             326  2020-01-03  17:10:05
# 3197                 60             246  2020-01-03  17:00:06
# 3198                189             319  2020-01-03  16:50:07
# 3199                630            1397  2020-01-03  16:40:06
#
# [3200 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
CNN_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
CNN_Tweets_df['Vocation'] = "News/Media"

#Show the 'shape' of the dataframe
shape = CNN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
CNN_Tweets_df.index = [x for x in range(1, len(CNN_Tweets_df.values)+1)]
CNN_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
CNN_Tweets_df
# Out:
#       Username   User Id Tweet Type  \
# Index
# 1          cnn  "759251"      Tweet
# 2          cnn  "759251"      Tweet
# 3          cnn  "759251"      Tweet
# 4          cnn  "759251"      Tweet
# 5          cnn  "759251"      Tweet
# ...        ...       ...        ...
# 3196       cnn  "759251"      Tweet
# 3197       cnn  "759251"      Tweet
# 3198       cnn  "759251"      Tweet
# 3199       cnn  "759251"      Tweet
# 3200       cnn  "759251"      Tweet
#
#                                            Tweet Content      Client  \
# Index
# 1      "Airports around the world are increasing heal...  SocialFlow
# 2      "A state of emergency has been extended in New...  SocialFlow
# 3      "Three American crew members have died in Aust...  SocialFlow
# 4      "Police issued an arrest warrant for former NF...  SocialFlow
# 5      "Here are some things you can do to protect yo...  SocialFlow
# ...                                                  ...         ...
# 3196   "A rafflesia that recently bloomed in a West S...  SocialFlow
# 3197   "Kentucky's Attorney General says he's asking ...  SocialFlow
# 3198   "The American Kennel Club has announced two ne...  SocialFlow
# 3199   "Google has disabled access of Xiaomi devices ...  SocialFlow
# 3200   "Republican Sen. Lindsey Graham of South Carol...  SocialFlow
#
#        Retweets received  Likes received        Date      Time        Gender  \
# Index
# 1                    158             234  2020-01-23  08:21:47  Organisation
# 2                     91             251  2020-01-23  08:06:05  Organisation
# 3                     87             211  2020-01-23  07:55:06  Organisation
# 4                     41             109  2020-01-23  07:50:35  Organisation
# 5                    135             257  2020-01-23  07:43:04  Organisation
# ...                  ...             ...         ...       ...           ...
# 3196                 467            1742  2020-01-03  17:21:05  Organisation
# 3197                  69             326  2020-01-03  17:10:05  Organisation
# 3198                  60             246  2020-01-03  17:00:06  Organisation
# 3199                 189             319  2020-01-03  16:50:07  Organisation
# 3200                 630            1397  2020-01-03  16:40:06  Organisation
#
#          Vocation
# Index
# 1      News/Media
# 2      News/Media
# 3      News/Media
# 4      News/Media
# 5      News/Media
# ...           ...
# 3196   News/Media
# 3197   News/Media
# 3198   News/Media
# 3199   News/Media
# 3200   News/Media
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
CNN_Tweets_df.to_csv('CNN_Tweets_df.csv')
