# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Shah Rukh Khan Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "ShahRukhKhanTweets.csv"

#Import the CSV into a pandas DataFrame
SRK_Tweets_df = pd.read_csv(csv_path, low_memory = False)
SRK_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219947963964723205"
# 1     "1219946775756165125"
# 2     "1219945237159612416"
# 3     "1219943862157766656"
# 4     "1219941641206648832"
# ...                     ...
# 3195   "777243869708640256"
# 3196   "776851369659543552"
# 3197   "776850792980414464"
# 3198   "776706212368756736"
# 3199   "776704899887329280"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/iamsrk/status/121994796396...  2020-01-22 11:40:34
# 1     https://twitter.com/iamsrk/status/121994677575...  2020-01-22 11:35:51
# 2     https://twitter.com/iamsrk/status/121994523715...  2020-01-22 11:29:44
# 3     https://twitter.com/iamsrk/status/121994386215...  2020-01-22 11:24:16
# 4     https://twitter.com/iamsrk/status/121994164120...  2020-01-22 11:15:27
# ...                                                 ...                  ...
# 3195  https://twitter.com/iamsrk/status/777243869708...  2016-09-17 20:32:33
# 3196  https://twitter.com/iamsrk/status/776851369659...  2016-09-16 18:32:54
# 3197  https://twitter.com/iamsrk/status/776850792980...  2016-09-16 18:30:36
# 3198  https://twitter.com/iamsrk/status/776706212368...  2016-09-16 08:56:06
# 3199  https://twitter.com/ahmedzaman94/status/776704...  2016-09-16 08:50:53
#
#                                           Tweet Content Tweet Type  \
# 0     "Need to go now. Nice having a chat with u all...      Tweet
# 1      "My thoughts exactly... https://t.co/XLjMeBCvSw"      Tweet
# 2     "Don’t let any negativity uninspire you in you...      Tweet
# 3     "30 saal ki mehnat mein padega. https://t.co/Y...      Tweet
# 4                       "Sardi https://t.co/n8es8mo06i"      Tweet
# ...                                                 ...        ...
# 3195           "U killed me!!! https://t.co/BgEbDAWo1n"      Tweet
# 3196  "Surrounded by Masters keeping a Nightwatch. R...      Tweet
# 3197  "Surrounded by Masters keeping a Nightwatch. R...      Tweet
# 3198  "Such hardwork and ur video made me nostalgic ...      Tweet
# 3199  "@SRK_FC https://t.co/aKOSk3iKyp\nCheck out th...    Retweet
#
#                   Client  Retweets received  Likes received      User Id  \
# 0     Twitter for iPhone               4432           40569  "101311381"
# 1     Twitter for iPhone               1159            6507  "101311381"
# 2     Twitter for iPhone               1956           10759  "101311381"
# 3     Twitter for iPhone               4242           28664  "101311381"
# 4     Twitter for iPhone               1322            8907  "101311381"
# ...                  ...                ...             ...          ...
# 3195    Tweetbot for iΟS               2318            7030  "101311381"
# 3196    Tweetbot for iΟS               4351           18369  "101311381"
# 3197           Instagram               1982            6330  "101311381"
# 3198    Tweetbot for iΟS               2532            7962  "101311381"
# 3199  Twitter for iPhone               1263            3446  "431033844"
#
#                     Name      Username Verified or Non-Verified  \
# 0       "Shah Rukh Khan"        iamsrk                 Verified
# 1       "Shah Rukh Khan"        iamsrk                 Verified
# 2       "Shah Rukh Khan"        iamsrk                 Verified
# 3       "Shah Rukh Khan"        iamsrk                 Verified
# 4       "Shah Rukh Khan"        iamsrk                 Verified
# ...                  ...           ...                      ...
# 3195    "Shah Rukh Khan"        iamsrk                 Verified
# 3196    "Shah Rukh Khan"        iamsrk                 Verified
# 3197    "Shah Rukh Khan"        iamsrk                 Verified
# 3198    "Shah Rukh Khan"        iamsrk                 Verified
# 3199  "Ahmed Sher Zaman"  ahmedzaman94             Non-Verified
#
#                            Profile URL Protected or Not Protected
# 0           https://twitter.com/iamsrk              Not Protected
# 1           https://twitter.com/iamsrk              Not Protected
# 2           https://twitter.com/iamsrk              Not Protected
# 3           https://twitter.com/iamsrk              Not Protected
# 4           https://twitter.com/iamsrk              Not Protected
# ...                                ...                        ...
# 3195        https://twitter.com/iamsrk              Not Protected
# 3196        https://twitter.com/iamsrk              Not Protected
# 3197        https://twitter.com/iamsrk              Not Protected
# 3198        https://twitter.com/iamsrk              Not Protected
# 3199  https://twitter.com/ahmedzaman94              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = SRK_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
SRK_Tweets_df = SRK_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = SRK_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
SRK_Tweets_df
# Out:
#           Username      User Id Tweet Type  \
# 0           iamsrk  "101311381"      Tweet
# 1           iamsrk  "101311381"      Tweet
# 2           iamsrk  "101311381"      Tweet
# 3           iamsrk  "101311381"      Tweet
# 4           iamsrk  "101311381"      Tweet
# ...            ...          ...        ...
# 3195        iamsrk  "101311381"      Tweet
# 3196        iamsrk  "101311381"      Tweet
# 3197        iamsrk  "101311381"      Tweet
# 3198        iamsrk  "101311381"      Tweet
# 3199  ahmedzaman94  "431033844"    Retweet
#
#                                           Tweet Content              Client  \
# 0     "Need to go now. Nice having a chat with u all...  Twitter for iPhone
# 1      "My thoughts exactly... https://t.co/XLjMeBCvSw"  Twitter for iPhone
# 2     "Don’t let any negativity uninspire you in you...  Twitter for iPhone
# 3     "30 saal ki mehnat mein padega. https://t.co/Y...  Twitter for iPhone
# 4                       "Sardi https://t.co/n8es8mo06i"  Twitter for iPhone
# ...                                                 ...                 ...
# 3195           "U killed me!!! https://t.co/BgEbDAWo1n"    Tweetbot for iΟS
# 3196  "Surrounded by Masters keeping a Nightwatch. R...    Tweetbot for iΟS
# 3197  "Surrounded by Masters keeping a Nightwatch. R...           Instagram
# 3198  "Such hardwork and ur video made me nostalgic ...    Tweetbot for iΟS
# 3199  "@SRK_FC https://t.co/aKOSk3iKyp\nCheck out th...  Twitter for iPhone
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                  4432           40569  2020-01-22 11:40:34
# 1                  1159            6507  2020-01-22 11:35:51
# 2                  1956           10759  2020-01-22 11:29:44
# 3                  4242           28664  2020-01-22 11:24:16
# 4                  1322            8907  2020-01-22 11:15:27
# ...                 ...             ...                  ...
# 3195               2318            7030  2016-09-17 20:32:33
# 3196               4351           18369  2016-09-16 18:32:54
# 3197               1982            6330  2016-09-16 18:30:36
# 3198               2532            7962  2016-09-16 08:56:06
# 3199               1263            3446  2016-09-16 08:50:53
#
# [3200 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
SRK_Tweets_df = SRK_Tweets_df.dropna() 

#Confirm rows are dropped
shape = SRK_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
SRK_Tweets_df['Tweet Posted Time'] = SRK_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = SRK_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
SRK_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
SRK_Tweets_df['Tweet Posted Time'] = SRK_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = SRK_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
SRK_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
SRK_Tweets_df = SRK_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = SRK_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
SRK_Tweets_df
# Out:
#           Username      User Id Tweet Type  \
# 0           iamsrk  "101311381"      Tweet
# 1           iamsrk  "101311381"      Tweet
# 2           iamsrk  "101311381"      Tweet
# 3           iamsrk  "101311381"      Tweet
# 4           iamsrk  "101311381"      Tweet
# ...            ...          ...        ...
# 3195        iamsrk  "101311381"      Tweet
# 3196        iamsrk  "101311381"      Tweet
# 3197        iamsrk  "101311381"      Tweet
# 3198        iamsrk  "101311381"      Tweet
# 3199  ahmedzaman94  "431033844"    Retweet
#
#                                           Tweet Content              Client  \
# 0     "Need to go now. Nice having a chat with u all...  Twitter for iPhone
# 1      "My thoughts exactly... https://t.co/XLjMeBCvSw"  Twitter for iPhone
# 2     "Don’t let any negativity uninspire you in you...  Twitter for iPhone
# 3     "30 saal ki mehnat mein padega. https://t.co/Y...  Twitter for iPhone
# 4                       "Sardi https://t.co/n8es8mo06i"  Twitter for iPhone
# ...                                                 ...                 ...
# 3195           "U killed me!!! https://t.co/BgEbDAWo1n"    Tweetbot for iΟS
# 3196  "Surrounded by Masters keeping a Nightwatch. R...    Tweetbot for iΟS
# 3197  "Surrounded by Masters keeping a Nightwatch. R...           Instagram
# 3198  "Such hardwork and ur video made me nostalgic ...    Tweetbot for iΟS
# 3199  "@SRK_FC https://t.co/aKOSk3iKyp\nCheck out th...  Twitter for iPhone
#
#       Retweets received  Likes received        Date      Time
# 0                  4432           40569  2020-01-22  11:40:34
# 1                  1159            6507  2020-01-22  11:35:51
# 2                  1956           10759  2020-01-22  11:29:44
# 3                  4242           28664  2020-01-22  11:24:16
# 4                  1322            8907  2020-01-22  11:15:27
# ...                 ...             ...         ...       ...
# 3195               2318            7030  2016-09-17  20:32:33
# 3196               4351           18369  2016-09-16  18:32:54
# 3197               1982            6330  2016-09-16  18:30:36
# 3198               2532            7962  2016-09-16  08:56:06
# 3199               1263            3446  2016-09-16  08:50:53
#
# [3200 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
SRK_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
SRK_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = SRK_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
SRK_Tweets_df.index = [x for x in range(1, len(SRK_Tweets_df.values)+1)]
SRK_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
SRK_Tweets_df
# Out:
#            Username      User Id Tweet Type  \
# Index
# 1            iamsrk  "101311381"      Tweet
# 2            iamsrk  "101311381"      Tweet
# 3            iamsrk  "101311381"      Tweet
# 4            iamsrk  "101311381"      Tweet
# 5            iamsrk  "101311381"      Tweet
# ...             ...          ...        ...
# 3196         iamsrk  "101311381"      Tweet
# 3197         iamsrk  "101311381"      Tweet
# 3198         iamsrk  "101311381"      Tweet
# 3199         iamsrk  "101311381"      Tweet
# 3200   ahmedzaman94  "431033844"    Retweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "Need to go now. Nice having a chat with u all...  Twitter for iPhone
# 2       "My thoughts exactly... https://t.co/XLjMeBCvSw"  Twitter for iPhone
# 3      "Don’t let any negativity uninspire you in you...  Twitter for iPhone
# 4      "30 saal ki mehnat mein padega. https://t.co/Y...  Twitter for iPhone
# 5                        "Sardi https://t.co/n8es8mo06i"  Twitter for iPhone
# ...                                                  ...                 ...
# 3196            "U killed me!!! https://t.co/BgEbDAWo1n"    Tweetbot for iΟS
# 3197   "Surrounded by Masters keeping a Nightwatch. R...    Tweetbot for iΟS
# 3198   "Surrounded by Masters keeping a Nightwatch. R...           Instagram
# 3199   "Such hardwork and ur video made me nostalgic ...    Tweetbot for iΟS
# 3200   "@SRK_FC https://t.co/aKOSk3iKyp\nCheck out th...  Twitter for iPhone
#
#        Retweets received  Likes received        Date      Time Gender  \
# Index
# 1                   4432           40569  2020-01-22  11:40:34   Male
# 2                   1159            6507  2020-01-22  11:35:51   Male
# 3                   1956           10759  2020-01-22  11:29:44   Male
# 4                   4242           28664  2020-01-22  11:24:16   Male
# 5                   1322            8907  2020-01-22  11:15:27   Male
# ...                  ...             ...         ...       ...    ...
# 3196                2318            7030  2016-09-17  20:32:33   Male
# 3197                4351           18369  2016-09-16  18:32:54   Male
# 3198                1982            6330  2016-09-16  18:30:36   Male
# 3199                2532            7962  2016-09-16  08:56:06   Male
# 3200                1263            3446  2016-09-16  08:50:53   Male
#
#             Vocation
# Index
# 1      Entertainment
# 2      Entertainment
# 3      Entertainment
# 4      Entertainment
# 5      Entertainment
# ...              ...
# 3196   Entertainment
# 3197   Entertainment
# 3198   Entertainment
# 3199   Entertainment
# 3200   Entertainment
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
SRK_Tweets_df.to_csv('SRK_Tweets_df.csv')
