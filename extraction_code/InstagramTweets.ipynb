# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Instagram Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "InstagramTweets.csv"

#Import the CSV into a pandas DataFrame
Insta_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Insta_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220051665169965056"
# 1     "1220051663341285376"
# 2     "1219687463217614849"
# 3     "1219687461476978689"
# 4     "1219312674086850560"
# ...                     ...
# 3195   "793240596559388673"
# 3196   "793237383009464320"
# 3197   "793231001174548480"
# 3198   "793210871975518208"
# 3199   "793158164338343936"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/instagram/status/122005166...  2020-01-22 18:32:39
# 1     https://twitter.com/instagram/status/122005166...  2020-01-22 18:32:38
# 2     https://twitter.com/instagram/status/121968746...  2020-01-21 18:25:26
# 3     https://twitter.com/instagram/status/121968746...  2020-01-21 18:25:26
# 4     https://twitter.com/instagram/status/121931267...  2020-01-20 17:36:09
# ...                                                 ...                  ...
# 3195  https://twitter.com/newshour/status/7932405965...  2016-10-31 23:57:50
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Insta_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Insta_Tweets_df = Insta_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Insta_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
Insta_Tweets_df
# Out:
#        Username      User Id Tweet Type  \
# 0     instagram  "180505807"      Reply
# 1     instagram  "180505807"      Tweet
# 2     instagram  "180505807"      Reply
# 3     instagram  "180505807"      Tweet
# 4     instagram  "180505807"      Tweet
# ...         ...          ...        ...
# 3195   newshour   "14437914"    Retweet
# 3196  instagram  "180505807"      Tweet
# 3197  instagram  "180505807"      Tweet
# 3198    nerdist  "394216985"    Retweet
# 3199  instagram  "180505807"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "This month, we’re looking to the future with ...  Twitter for iPhone
# 1     "Reality just got warped. 🤯 #2020Vision https:...  Twitter for iPhone
# 2     "This month, we’re looking to the future with ...  Twitter for iPhone
# 3     "“Part of the appeal of climbing is that I can...  Twitter for iPhone
# 4     "“I don’t fit into any one box.” — breakout st...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Insta_Tweets_df = Insta_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Insta_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Insta_Tweets_df['Tweet Posted Time'] = Insta_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Insta_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Insta_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Insta_Tweets_df['Tweet Posted Time'] = Insta_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Insta_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Insta_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Insta_Tweets_df = Insta_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Insta_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
Insta_Tweets_df
# Out:
#        Username      User Id Tweet Type  \
# 0     instagram  "180505807"      Reply
# 1     instagram  "180505807"      Tweet
# 2     instagram  "180505807"      Reply
# 3     instagram  "180505807"      Tweet
# 4     instagram  "180505807"      Tweet
# ...         ...          ...        ...
# 3195   newshour   "14437914"    Retweet
# 3196  instagram  "180505807"      Tweet
# 3197  instagram  "180505807"      Tweet
# 3198    nerdist  "394216985"    Retweet
# 3199  instagram  "180505807"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "This month, we’re looking to the future with ...  Twitter for iPhone
# 1     "Reality just got warped. 🤯 #2020Vision https:...  Twitter for iPhone
# 2     "This month, we’re looking to the future with ...  Twitter for iPhone
# 3     "“Part of the appeal of climbing is that I can...  Twitter for iPhone
# 4     "“I don’t fit into any one box.” — breakout st...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Insta_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
Insta_Tweets_df['Vocation'] = "News/Media"

#Show the 'shape' of the dataframe
shape = Insta_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Insta_Tweets_df.index = [x for x in range(1, len(Insta_Tweets_df.values)+1)]
Insta_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Insta_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# Index
# 1      instagram  "180505807"      Reply
# 2      instagram  "180505807"      Tweet
# 3      instagram  "180505807"      Reply
# 4      instagram  "180505807"      Tweet
# 5      instagram  "180505807"      Tweet
# ...          ...          ...        ...
# 3196    newshour   "14437914"    Retweet
# 3197   instagram  "180505807"      Tweet
# 3198   instagram  "180505807"      Tweet
# 3199     nerdist  "394216985"    Retweet
# 3200   instagram  "180505807"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "This month, we’re looking to the future with ...  Twitter for iPhone
# 2      "Reality just got warped. 🤯 #2020Vision https:...  Twitter for iPhone
# 3      "This month, we’re looking to the future with ...  Twitter for iPhone
# 4      "“Part of the appeal of climbing is that I can...  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Insta_Tweets_df.to_csv('Insta_Tweets_df.csv')
