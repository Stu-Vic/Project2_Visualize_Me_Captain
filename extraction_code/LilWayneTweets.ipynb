# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Lil Wayne Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "LilWayneTweets.csv"

#Import the CSV into a pandas DataFrame
LWayne_Tweets_df = pd.read_csv(csv_path, low_memory = False)
LWayne_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220170944137826304"
# 1     "1218970667070251010"
# 2     "1216931193821724673"
# 3     "1216782663320834048"
# 4     "1216486984123895808"
# ...                     ...
# 2075           "9489148220"
# 2076           "9469553548"
# 2077           "9465475293"
# 2078           "9465225223"
# 2079           "9464235517"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/liltunechi/status/12201709...  2020-01-23 02:26:37
# 1     https://twitter.com/liltunechi/status/12189706...  2020-01-19 18:57:09
# 2     https://twitter.com/liltunechi/status/12169311...  2020-01-14 03:53:00
# 3     https://twitter.com/liltunechi/status/12167826...  2020-01-13 18:02:48
# 4     https://twitter.com/liltunechi/status/12164869...  2020-01-12 22:27:52
# ...                                                 ...                  ...
# 2075   https://twitter.com/liltunechi/status/9489148220  2010-02-22 19:18:58
# 2076   https://twitter.com/liltunechi/status/9469553548  2010-02-22 09:32:54
# 2077    https://twitter.com/treysongz/status/9465475293  2010-02-22 06:35:23
# 2078   https://twitter.com/liltunechi/status/9465225223  2010-02-22 06:25:55
# 2079   https://twitter.com/liltunechi/status/9464235517  2010-02-22 05:50:13
#
#                                           Tweet Content Tweet Type  \
# 0                  "Soon !! ⚰️ https://t.co/oiVqoGJrnW"      Tweet
# 1                                "GO PACK GO!!!!!!!!!!"      Tweet
# 2       "Full video out now !! https://t.co/kDVqT1jCfN"      Tweet
# 3     "BALL LIKE THE PLAYOFFS 🏆 \nYou already know i...      Tweet
# 4                         "GO PACK GO!!!!!!!!!!!!!!!!!"      Tweet
# ...                                                 ...        ...
# 2075  "aint it funny how love finds you in your dark...      Tweet
# 2076         "if its held in your heart,u kant let go."      Tweet
# 2077  "Aye...and get at da homie. Wayne @liltunechi ...    Retweet
# 2078  "im live right now with my bro @liltwist on Us...      Tweet
# 2079  "im super new to this twitter shit but wudup t...      Tweet
#
#                   Client  Retweets received  Likes received      User Id  \
# 0     Twitter for iPhone               9326           28509  "116362700"
# 1     Twitter for iPhone               9947           38673  "116362700"
# 2     Twitter for iPhone                574            2367  "116362700"
# 3     Twitter for iPhone               1219            6928  "116362700"
# 4     Twitter for iPhone              10421           42681  "116362700"
# ...                  ...                ...             ...          ...
# 2075  Twitter Web Client               2715             739  "116362700"
# 2076  Twitter Web Client               2393             702  "116362700"
# 2077  Twitter Web Client               1472              97   "24966423"
# 2078  Twitter Web Client                318              96  "116362700"
# 2079  Twitter Web Client               1884            1144  "116362700"
#
#                      Name    Username Verified or Non-Verified  \
# 0     "Lil Wayne WEEZY F"  liltunechi                 Verified
# 1     "Lil Wayne WEEZY F"  liltunechi                 Verified
# 2     "Lil Wayne WEEZY F"  liltunechi                 Verified
# 3     "Lil Wayne WEEZY F"  liltunechi                 Verified
# 4     "Lil Wayne WEEZY F"  liltunechi                 Verified
# ...                   ...         ...                      ...
# 2075  "Lil Wayne WEEZY F"  liltunechi                 Verified
# 2076  "Lil Wayne WEEZY F"  liltunechi                 Verified
# 2077         "Trey Songz"   treysongz                 Verified
# 2078  "Lil Wayne WEEZY F"  liltunechi                 Verified
# 2079  "Lil Wayne WEEZY F"  liltunechi                 Verified
#
#                          Profile URL Protected or Not Protected
# 0     https://twitter.com/liltunechi              Not Protected
# 1     https://twitter.com/liltunechi              Not Protected
# 2     https://twitter.com/liltunechi              Not Protected
# 3     https://twitter.com/liltunechi              Not Protected
# 4     https://twitter.com/liltunechi              Not Protected
# ...                              ...                        ...
# 2075  https://twitter.com/liltunechi              Not Protected
# 2076  https://twitter.com/liltunechi              Not Protected
# 2077   https://twitter.com/treysongz              Not Protected
# 2078  https://twitter.com/liltunechi              Not Protected
# 2079  https://twitter.com/liltunechi              Not Protected
#
# [2080 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = LWayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2080, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
LWayne_Tweets_df = LWayne_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = LWayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2080, 8)

# %%
#Print the dataframe
LWayne_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# 0     liltunechi  "116362700"      Tweet
# 1     liltunechi  "116362700"      Tweet
# 2     liltunechi  "116362700"      Tweet
# 3     liltunechi  "116362700"      Tweet
# 4     liltunechi  "116362700"      Tweet
# ...          ...          ...        ...
# 2075  liltunechi  "116362700"      Tweet
# 2076  liltunechi  "116362700"      Tweet
# 2077   treysongz   "24966423"    Retweet
# 2078  liltunechi  "116362700"      Tweet
# 2079  liltunechi  "116362700"      Tweet
#
#                                           Tweet Content              Client  \
# 0                  "Soon !! ⚰️ https://t.co/oiVqoGJrnW"  Twitter for iPhone
# 1                                "GO PACK GO!!!!!!!!!!"  Twitter for iPhone
# 2       "Full video out now !! https://t.co/kDVqT1jCfN"  Twitter for iPhone
# 3     "BALL LIKE THE PLAYOFFS 🏆 \nYou already know i...  Twitter for iPhone
# 4                         "GO PACK GO!!!!!!!!!!!!!!!!!"  Twitter for iPhone
# ...                                                 ...                 ...
# 2075  "aint it funny how love finds you in your dark...  Twitter Web Client
# 2076         "if its held in your heart,u kant let go."  Twitter Web Client
# 2077  "Aye...and get at da homie. Wayne @liltunechi ...  Twitter Web Client
# 2078  "im live right now with my bro @liltwist on Us...  Twitter Web Client
# 2079  "im super new to this twitter shit but wudup t...  Twitter Web Client
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                  9326           28509  2020-01-23 02:26:37
# 1                  9947           38673  2020-01-19 18:57:09
# 2                   574            2367  2020-01-14 03:53:00
# 3                  1219            6928  2020-01-13 18:02:48
# 4                 10421           42681  2020-01-12 22:27:52
# ...                 ...             ...                  ...
# 2075               2715             739  2010-02-22 19:18:58
# 2076               2393             702  2010-02-22 09:32:54
# 2077               1472              97  2010-02-22 06:35:23
# 2078                318              96  2010-02-22 06:25:55
# 2079               1884            1144  2010-02-22 05:50:13
#
# [2080 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
LWayne_Tweets_df = LWayne_Tweets_df.dropna() 

#Confirm rows are dropped
shape = LWayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2080, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
LWayne_Tweets_df['Tweet Posted Time'] = LWayne_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = LWayne_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
LWayne_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
LWayne_Tweets_df['Tweet Posted Time'] = LWayne_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = LWayne_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
LWayne_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
LWayne_Tweets_df = LWayne_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = LWayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2080, 9)

# %%
#Print the dataframe
LWayne_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# 0     liltunechi  "116362700"      Tweet
# 1     liltunechi  "116362700"      Tweet
# 2     liltunechi  "116362700"      Tweet
# 3     liltunechi  "116362700"      Tweet
# 4     liltunechi  "116362700"      Tweet
# ...          ...          ...        ...
# 2075  liltunechi  "116362700"      Tweet
# 2076  liltunechi  "116362700"      Tweet
# 2077   treysongz   "24966423"    Retweet
# 2078  liltunechi  "116362700"      Tweet
# 2079  liltunechi  "116362700"      Tweet
#
#                                           Tweet Content              Client  \
# 0                  "Soon !! ⚰️ https://t.co/oiVqoGJrnW"  Twitter for iPhone
# 1                                "GO PACK GO!!!!!!!!!!"  Twitter for iPhone
# 2       "Full video out now !! https://t.co/kDVqT1jCfN"  Twitter for iPhone
# 3     "BALL LIKE THE PLAYOFFS 🏆 \nYou already know i...  Twitter for iPhone
# 4                         "GO PACK GO!!!!!!!!!!!!!!!!!"  Twitter for iPhone
# ...                                                 ...                 ...
# 2075  "aint it funny how love finds you in your dark...  Twitter Web Client
# 2076         "if its held in your heart,u kant let go."  Twitter Web Client
# 2077  "Aye...and get at da homie. Wayne @liltunechi ...  Twitter Web Client
# 2078  "im live right now with my bro @liltwist on Us...  Twitter Web Client
# 2079  "im super new to this twitter shit but wudup t...  Twitter Web Client
#
#       Retweets received  Likes received        Date      Time
# 0                  9326           28509  2020-01-23  02:26:37
# 1                  9947           38673  2020-01-19  18:57:09
# 2                   574            2367  2020-01-14  03:53:00
# 3                  1219            6928  2020-01-13  18:02:48
# 4                 10421           42681  2020-01-12  22:27:52
# ...                 ...             ...         ...       ...
# 2075               2715             739  2010-02-22  19:18:58
# 2076               2393             702  2010-02-22  09:32:54
# 2077               1472              97  2010-02-22  06:35:23
# 2078                318              96  2010-02-22  06:25:55
# 2079               1884            1144  2010-02-22  05:50:13
#
# [2080 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
LWayne_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
LWayne_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = LWayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2080, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
LWayne_Tweets_df.index = [x for x in range(1, len(LWayne_Tweets_df.values)+1)]
LWayne_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
LWayne_Tweets_df
# Out:
#          Username      User Id Tweet Type  \
# Index
# 1      liltunechi  "116362700"      Tweet
# 2      liltunechi  "116362700"      Tweet
# 3      liltunechi  "116362700"      Tweet
# 4      liltunechi  "116362700"      Tweet
# 5      liltunechi  "116362700"      Tweet
# ...           ...          ...        ...
# 2076   liltunechi  "116362700"      Tweet
# 2077   liltunechi  "116362700"      Tweet
# 2078    treysongz   "24966423"    Retweet
# 2079   liltunechi  "116362700"      Tweet
# 2080   liltunechi  "116362700"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1                   "Soon !! ⚰️ https://t.co/oiVqoGJrnW"  Twitter for iPhone
# 2                                 "GO PACK GO!!!!!!!!!!"  Twitter for iPhone
# 3        "Full video out now !! https://t.co/kDVqT1jCfN"  Twitter for iPhone
# 4      "BALL LIKE THE PLAYOFFS 🏆 \nYou already know i...  Twitter for iPhone
# 5                          "GO PACK GO!!!!!!!!!!!!!!!!!"  Twitter for iPhone
# ...                                                  ...                 ...
# 2076   "aint it funny how love finds you in your dark...  Twitter Web Client
# 2077          "if its held in your heart,u kant let go."  Twitter Web Client
# 2078   "Aye...and get at da homie. Wayne @liltunechi ...  Twitter Web Client
# 2079   "im live right now with my bro @liltwist on Us...  Twitter Web Client
# 2080   "im super new to this twitter shit but wudup t...  Twitter Web Client
#
#        Retweets received  Likes received        Date      Time Gender Vocation
# Index
# 1                   9326           28509  2020-01-23  02:26:37   Male    Music
# 2                   9947           38673  2020-01-19  18:57:09   Male    Music
# 3                    574            2367  2020-01-14  03:53:00   Male    Music
# 4                   1219            6928  2020-01-13  18:02:48   Male    Music
# 5                  10421           42681  2020-01-12  22:27:52   Male    Music
# ...                  ...             ...         ...       ...    ...      ...
# 2076                2715             739  2010-02-22  19:18:58   Male    Music
# 2077                2393             702  2010-02-22  09:32:54   Male    Music
# 2078                1472              97  2010-02-22  06:35:23   Male    Music
# 2079                 318              96  2010-02-22  06:25:55   Male    Music
# 2080                1884            1144  2010-02-22  05:50:13   Male    Music
#
# [2080 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
LWayne_Tweets_df.to_csv('LWayne_Tweets_df.csv')
