# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Liam Payne Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "LiamPayneTweets.csv"

#Import the CSV into a pandas DataFrame
LPayne_Tweets_df = pd.read_csv(csv_path, low_memory = False)
LPayne_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219907832239329280"
# 1     "1218122712582889472"
# 2     "1217858564389330946"
# 3     "1217511386877779974"
# 4     "1217504211983880192"
# ...                     ...
# 3195   "423190253588205568"
# 3196   "423189717354807296"
# 3197   "422784589829242881"
# 3198   "422330014093557760"
# 3199   "422158624224722944"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/liampayne/status/121990783...  2020-01-22 09:01:06
# 1     https://twitter.com/liampayne/status/121812271...  2020-01-17 10:47:40
# 2     https://twitter.com/liampayne/status/121785856...  2020-01-16 17:18:03
# 3     https://twitter.com/tenerifeziam/status/121751...  2020-01-15 18:18:29
# 4     https://twitter.com/liampayne/status/121750421...  2020-01-15 17:49:58
# ...                                                 ...                  ...
# 3195  https://twitter.com/liampayne/status/423190253...  2014-01-14 20:29:53
# ...

# %%
#Show the 'shape' of the dataframe 
shape = LPayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
LPayne_Tweets_df = LPayne_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = LPayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
LPayne_Tweets_df
# Out:
#           Username      User Id Tweet Type  \
# 0        liampayne  "158314798"      Tweet
# 1        liampayne  "158314798"      Tweet
# 2        liampayne  "158314798"      Tweet
# 3     tenerifeziam  "930997525"    Retweet
# 4        liampayne  "158314798"      Tweet
# ...            ...          ...        ...
# 3195     liampayne  "158314798"      Tweet
# 3196     liampayne  "158314798"      Tweet
# 3197     liampayne  "158314798"      Tweet
# 3198     liampayne  "158314798"      Tweet
# 3199     liampayne  "158314798"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "Proud to show you my first campaign with HUGO...  Twitter for iPhone
# 1     "Tickets now on sale for @WolvesRaces! See you...  Twitter for iPhone
# 2     "Thanks to the amazing team that worked so har...  Twitter for iPhone
# 3     "I just made this pet playlist for my dog and ...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
LPayne_Tweets_df = LPayne_Tweets_df.dropna() 

#Confirm rows are dropped
shape = LPayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
LPayne_Tweets_df['Tweet Posted Time'] = LPayne_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = LPayne_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
LPayne_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
LPayne_Tweets_df['Tweet Posted Time'] = LPayne_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = LPayne_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
LPayne_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
LPayne_Tweets_df = LPayne_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = LPayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
LPayne_Tweets_df
# Out:
#           Username      User Id Tweet Type  \
# 0        liampayne  "158314798"      Tweet
# 1        liampayne  "158314798"      Tweet
# 2        liampayne  "158314798"      Tweet
# 3     tenerifeziam  "930997525"    Retweet
# 4        liampayne  "158314798"      Tweet
# ...            ...          ...        ...
# 3195     liampayne  "158314798"      Tweet
# 3196     liampayne  "158314798"      Tweet
# 3197     liampayne  "158314798"      Tweet
# 3198     liampayne  "158314798"      Tweet
# 3199     liampayne  "158314798"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "Proud to show you my first campaign with HUGO...  Twitter for iPhone
# 1     "Tickets now on sale for @WolvesRaces! See you...  Twitter for iPhone
# 2     "Thanks to the amazing team that worked so har...  Twitter for iPhone
# 3     "I just made this pet playlist for my dog and ...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
LPayne_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
LPayne_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = LPayne_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
LPayne_Tweets_df.index = [x for x in range(1, len(LPayne_Tweets_df.values)+1)]
LPayne_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
LPayne_Tweets_df
# Out:
#            Username      User Id Tweet Type  \
# Index
# 1         liampayne  "158314798"      Tweet
# 2         liampayne  "158314798"      Tweet
# 3         liampayne  "158314798"      Tweet
# 4      tenerifeziam  "930997525"    Retweet
# 5         liampayne  "158314798"      Tweet
# ...             ...          ...        ...
# 3196      liampayne  "158314798"      Tweet
# 3197      liampayne  "158314798"      Tweet
# 3198      liampayne  "158314798"      Tweet
# 3199      liampayne  "158314798"      Tweet
# 3200      liampayne  "158314798"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "Proud to show you my first campaign with HUGO...  Twitter for iPhone
# 2      "Tickets now on sale for @WolvesRaces! See you...  Twitter for iPhone
# 3      "Thanks to the amazing team that worked so har...  Twitter for iPhone
# 4      "I just made this pet playlist for my dog and ...  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
LPayne_Tweets_df.to_csv('LPayne_Tweets_df.csv')
