# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Louis Tomlinson Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "LouisTomlinsonTweets.csv"

#Import the CSV into a pandas DataFrame
LTomlinson_Tweets_df = pd.read_csv(csv_path, low_memory = False)
LTomlinson_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220048849533853696"
# 1     "1219944777296359426"
# 2     "1219944469027573760"
# 3     "1219942418918838272"
# 4     "1219929592707854337"
# ...                     ...
# 3195   "179923956101427200"
# 3196   "179923884731138048"
# 3197   "179923806545129475"
# 3198   "179923566773542913"
# 3199   "179923467452432384"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/louis_tomlinson/status/122...  2020-01-22 18:21:27
# 1     https://twitter.com/louis_tomlinson/status/121...  2020-01-22 11:27:55
# 2     https://twitter.com/louis_tomlinson/status/121...  2020-01-22 11:26:41
# 3     https://twitter.com/louis_tomlinson/status/121...  2020-01-22 11:18:32
# 4     https://twitter.com/louis_tomlinson/status/121...  2020-01-22 10:27:34
# ...                                                 ...                  ...
# 3195  https://twitter.com/louis_tomlinson/status/179...  2012-03-14 13:36:28
# ...

# %%
#Show the 'shape' of the dataframe 
shape = LTomlinson_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
LTomlinson_Tweets_df = LTomlinson_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = LTomlinson_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
LTomlinson_Tweets_df
# Out:
#              Username     User Id Tweet Type  \
# 0     louis_tomlinson  "84279963"      Tweet
# 1     louis_tomlinson  "84279963"      Tweet
# 2     louis_tomlinson  "84279963"      Reply
# 3     louis_tomlinson  "84279963"      Reply
# 4     louis_tomlinson  "84279963"      Tweet
# ...               ...         ...        ...
# 3195  louis_tomlinson  "84279963"      Reply
# 3196  louis_tomlinson  "84279963"      Reply
# 3197  louis_tomlinson  "84279963"      Tweet
# 3198  louis_tomlinson  "84279963"      Tweet
# 3199  louis_tomlinson  "84279963"      Reply
#
#                                           Tweet Content               Client  \
# 0     "I’m holding an exclusive album event on the 4...   Twitter for iPhone
# 1     "Thanks for all the love for the video for Wal...  Twitter for Android
# 2         "@90lwts @wallslwts Doing vocals with Helene"  Twitter for Android
# 3     "@emilyeavis @GlastoFest This is amazing! Love...  Twitter for Android
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
LTomlinson_Tweets_df = LTomlinson_Tweets_df.dropna() 

#Confirm rows are dropped
shape = LTomlinson_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
LTomlinson_Tweets_df['Tweet Posted Time'] = LTomlinson_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = LTomlinson_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
LTomlinson_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
LTomlinson_Tweets_df['Tweet Posted Time'] = LTomlinson_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = LTomlinson_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
LTomlinson_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
LTomlinson_Tweets_df = LTomlinson_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = LTomlinson_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
LTomlinson_Tweets_df
# Out:
#              Username     User Id Tweet Type  \
# 0     louis_tomlinson  "84279963"      Tweet
# 1     louis_tomlinson  "84279963"      Tweet
# 2     louis_tomlinson  "84279963"      Reply
# 3     louis_tomlinson  "84279963"      Reply
# 4     louis_tomlinson  "84279963"      Tweet
# ...               ...         ...        ...
# 3195  louis_tomlinson  "84279963"      Reply
# 3196  louis_tomlinson  "84279963"      Reply
# 3197  louis_tomlinson  "84279963"      Tweet
# 3198  louis_tomlinson  "84279963"      Tweet
# 3199  louis_tomlinson  "84279963"      Reply
#
#                                           Tweet Content               Client  \
# 0     "I’m holding an exclusive album event on the 4...   Twitter for iPhone
# 1     "Thanks for all the love for the video for Wal...  Twitter for Android
# 2         "@90lwts @wallslwts Doing vocals with Helene"  Twitter for Android
# 3     "@emilyeavis @GlastoFest This is amazing! Love...  Twitter for Android
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
LTomlinson_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
LTomlinson_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = LTomlinson_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
LTomlinson_Tweets_df.index = [x for x in range(1, len(LTomlinson_Tweets_df.values)+1)]
LTomlinson_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
LTomlinson_Tweets_df
# Out:
#               Username     User Id Tweet Type  \
# Index
# 1      louis_tomlinson  "84279963"      Tweet
# 2      louis_tomlinson  "84279963"      Tweet
# 3      louis_tomlinson  "84279963"      Reply
# 4      louis_tomlinson  "84279963"      Reply
# 5      louis_tomlinson  "84279963"      Tweet
# ...                ...         ...        ...
# 3196   louis_tomlinson  "84279963"      Reply
# 3197   louis_tomlinson  "84279963"      Reply
# 3198   louis_tomlinson  "84279963"      Tweet
# 3199   louis_tomlinson  "84279963"      Tweet
# 3200   louis_tomlinson  "84279963"      Reply
#
#                                            Tweet Content               Client  \
# Index
# 1      "I’m holding an exclusive album event on the 4...   Twitter for iPhone
# 2      "Thanks for all the love for the video for Wal...  Twitter for Android
# 3          "@90lwts @wallslwts Doing vocals with Helene"  Twitter for Android
# 4      "@emilyeavis @GlastoFest This is amazing! Love...  Twitter for Android
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
LTomlinson_Tweets_df.to_csv('LTomlinson_Tweets_df.csv')
