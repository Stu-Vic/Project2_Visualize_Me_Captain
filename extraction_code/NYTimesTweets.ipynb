# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # NY Times Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "NYTimesTweets.csv"

#Import the CSV into a pandas DataFrame
NYTimes_Tweets_df = pd.read_csv(csv_path, low_memory = False)
NYTimes_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220264933335732226"
# 1     "1220262461485539330"
# 2     "1220259901609476099"
# 3     "1220257379264102401"
# 4     "1220254899562254336"
# ...                     ...
# 3195  "1207296498742054913"
# 3196  "1207294460767408128"
# 3197  "1207292607988224002"
# 3198  "1207289438977613827"
# 3199  "1207286899368484866"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/nytimes/status/12202649333...  2020-01-23 08:40:06
# 1     https://twitter.com/nytimes/status/12202624614...  2020-01-23 08:30:16
# 2     https://twitter.com/nytimes/status/12202599016...  2020-01-23 08:20:06
# 3     https://twitter.com/nytimes/status/12202573792...  2020-01-23 08:10:05
# 4     https://twitter.com/nytimes/status/12202548995...  2020-01-23 08:00:13
# ...                                                 ...                  ...
# 3195  https://twitter.com/katie_thomas/status/120729...  2019-12-18 13:48:10
# ...

# %%
#Show the 'shape' of the dataframe 
shape = NYTimes_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
NYTimes_Tweets_df = NYTimes_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = NYTimes_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
NYTimes_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0          nytimes    "807095"      Tweet
# 1          nytimes    "807095"      Tweet
# 2          nytimes    "807095"      Tweet
# 3          nytimes    "807095"      Tweet
# 4          nytimes    "807095"      Tweet
# ...            ...         ...        ...
# 3195  katie_thomas  "18318642"    Retweet
# 3196       nytimes    "807095"      Tweet
# 3197       nytimes    "807095"      Tweet
# 3198       nytimes    "807095"      Tweet
# 3199       nytimes    "807095"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "The extraordinary meeting of world leaders in...          SocialFlow
# 1     "Live Updates: Wuhan Railway Station, usually ...          SocialFlow
# 2     "Pictures of 5 starving lions in a park in Sud...          SocialFlow
# 3     "Europe morning briefing: Here's what you need...          SocialFlow
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
NYTimes_Tweets_df = NYTimes_Tweets_df.dropna() 

#Confirm rows are dropped
shape = NYTimes_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NYTimes_Tweets_df['Tweet Posted Time'] = NYTimes_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NYTimes_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
NYTimes_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NYTimes_Tweets_df['Tweet Posted Time'] = NYTimes_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NYTimes_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
NYTimes_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
NYTimes_Tweets_df = NYTimes_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = NYTimes_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
NYTimes_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0          nytimes    "807095"      Tweet
# 1          nytimes    "807095"      Tweet
# 2          nytimes    "807095"      Tweet
# 3          nytimes    "807095"      Tweet
# 4          nytimes    "807095"      Tweet
# ...            ...         ...        ...
# 3195  katie_thomas  "18318642"    Retweet
# 3196       nytimes    "807095"      Tweet
# 3197       nytimes    "807095"      Tweet
# 3198       nytimes    "807095"      Tweet
# 3199       nytimes    "807095"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "The extraordinary meeting of world leaders in...          SocialFlow
# 1     "Live Updates: Wuhan Railway Station, usually ...          SocialFlow
# 2     "Pictures of 5 starving lions in a park in Sud...          SocialFlow
# 3     "Europe morning briefing: Here's what you need...          SocialFlow
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
NYTimes_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
NYTimes_Tweets_df['Vocation'] = "News/Media"

#Show the 'shape' of the dataframe
shape = NYTimes_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
NYTimes_Tweets_df.index = [x for x in range(1, len(NYTimes_Tweets_df.values)+1)]
NYTimes_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
NYTimes_Tweets_df
# Out:
#            Username     User Id Tweet Type  \
# Index
# 1           nytimes    "807095"      Tweet
# 2           nytimes    "807095"      Tweet
# 3           nytimes    "807095"      Tweet
# 4           nytimes    "807095"      Tweet
# 5           nytimes    "807095"      Tweet
# ...             ...         ...        ...
# 3196   katie_thomas  "18318642"    Retweet
# 3197        nytimes    "807095"      Tweet
# 3198        nytimes    "807095"      Tweet
# 3199        nytimes    "807095"      Tweet
# 3200        nytimes    "807095"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "The extraordinary meeting of world leaders in...          SocialFlow
# 2      "Live Updates: Wuhan Railway Station, usually ...          SocialFlow
# 3      "Pictures of 5 starving lions in a park in Sud...          SocialFlow
# 4      "Europe morning briefing: Here's what you need...          SocialFlow
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
NYTimes_Tweets_df.to_csv('NYTimes_Tweets_df.csv')
