# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Salmon Khan Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "SalmonKhanTweets.csv"

#Import the CSV into a pandas DataFrame
SalmonKhan_Tweets_df = pd.read_csv(csv_path, low_memory = False)
SalmonKhan_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1218463651138539520"
# 1     "1216358418153271297"
# 2     "1216324931925041153"
# 3     "1215547133102841857"
# 4     "1215136475391700995"
# ...                     ...
# 3195   "427604739262386177"
# 3196   "427604635998642176"
# 3197   "427604518763630592"
# 3198   "427604275082960896"
# 3199   "427604124029288448"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/beingsalmankhan/status/121...  2020-01-18 09:22:27
# 1     https://twitter.com/beingsalmankhan/status/121...  2020-01-12 13:57:00
# 2     https://twitter.com/beingsalmankhan/status/121...  2020-01-12 11:43:56
# 3     https://twitter.com/beingsalmankhan/status/121...  2020-01-10 08:13:14
# 4     https://twitter.com/beingsalmankhan/status/121...  2020-01-09 05:01:26
# ...                                                 ...                  ...
# 3195  https://twitter.com/beingsalmankhan/status/427...  2014-01-27 00:51:29
# ...

# %%
#Show the 'shape' of the dataframe 
shape = SalmonKhan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
SalmonKhan_Tweets_df = SalmonKhan_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = SalmonKhan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
SalmonKhan_Tweets_df
# Out:
#              Username      User Id Tweet Type  \
# 0     beingsalmankhan  "132385468"      Tweet
# 1     beingsalmankhan  "132385468"      Tweet
# 2     beingsalmankhan  "132385468"      Tweet
# 3     beingsalmankhan  "132385468"      Tweet
# 4     beingsalmankhan  "132385468"      Tweet
# ...               ...          ...        ...
# 3195  beingsalmankhan  "132385468"      Reply
# 3196  beingsalmankhan  "132385468"      Reply
# 3197  beingsalmankhan  "132385468"      Reply
# 3198  beingsalmankhan  "132385468"      Reply
# 3199  beingsalmankhan  "132385468"      Reply
#
#                                           Tweet Content  \
# 0     "Aaj ki taaza khabar....\nHamara Being Strong ...
# 1     "Ouiii ma .... jhakaas trailer\nhttps://t.co/u...
# 2     "Mumbaikars, aa gaya hai #SwachhSurvekshan2020...
# 3     "Announcing my next film... KABHI EID KABHI DI...
# 4     "Best wishes for the film! \n\nhttps://t.co/CU...
# ...                                                 ...
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
SalmonKhan_Tweets_df = SalmonKhan_Tweets_df.dropna() 

#Confirm rows are dropped
shape = SalmonKhan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
SalmonKhan_Tweets_df['Tweet Posted Time'] = SalmonKhan_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = SalmonKhan_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
SalmonKhan_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
SalmonKhan_Tweets_df['Tweet Posted Time'] = SalmonKhan_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = SalmonKhan_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
SalmonKhan_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
SalmonKhan_Tweets_df = SalmonKhan_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = SalmonKhan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
SalmonKhan_Tweets_df
# Out:
#              Username      User Id Tweet Type  \
# 0     beingsalmankhan  "132385468"      Tweet
# 1     beingsalmankhan  "132385468"      Tweet
# 2     beingsalmankhan  "132385468"      Tweet
# 3     beingsalmankhan  "132385468"      Tweet
# 4     beingsalmankhan  "132385468"      Tweet
# ...               ...          ...        ...
# 3195  beingsalmankhan  "132385468"      Reply
# 3196  beingsalmankhan  "132385468"      Reply
# 3197  beingsalmankhan  "132385468"      Reply
# 3198  beingsalmankhan  "132385468"      Reply
# 3199  beingsalmankhan  "132385468"      Reply
#
#                                           Tweet Content  \
# 0     "Aaj ki taaza khabar....\nHamara Being Strong ...
# 1     "Ouiii ma .... jhakaas trailer\nhttps://t.co/u...
# 2     "Mumbaikars, aa gaya hai #SwachhSurvekshan2020...
# 3     "Announcing my next film... KABHI EID KABHI DI...
# 4     "Best wishes for the film! \n\nhttps://t.co/CU...
# ...                                                 ...
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
SalmonKhan_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
SalmonKhan_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = SalmonKhan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
SalmonKhan_Tweets_df.index = [x for x in range(1, len(SalmonKhan_Tweets_df.values)+1)]
SalmonKhan_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
SalmonKhan_Tweets_df
# Out:
#               Username      User Id Tweet Type  \
# Index
# 1      beingsalmankhan  "132385468"      Tweet
# 2      beingsalmankhan  "132385468"      Tweet
# 3      beingsalmankhan  "132385468"      Tweet
# 4      beingsalmankhan  "132385468"      Tweet
# 5      beingsalmankhan  "132385468"      Tweet
# ...                ...          ...        ...
# 3196   beingsalmankhan  "132385468"      Reply
# 3197   beingsalmankhan  "132385468"      Reply
# 3198   beingsalmankhan  "132385468"      Reply
# 3199   beingsalmankhan  "132385468"      Reply
# 3200   beingsalmankhan  "132385468"      Reply
#
#                                            Tweet Content  \
# Index
# 1      "Aaj ki taaza khabar....\nHamara Being Strong ...
# 2      "Ouiii ma .... jhakaas trailer\nhttps://t.co/u...
# 3      "Mumbaikars, aa gaya hai #SwachhSurvekshan2020...
# 4      "Announcing my next film... KABHI EID KABHI DI...
# 5      "Best wishes for the film! \n\nhttps://t.co/CU...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
SalmonKhan_Tweets_df.to_csv('SalmonKhan_Tweets_df.csv')
