# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # BBC Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "BBCTweets.csv"

#Import the CSV into a pandas DataFrame
BBC_Tweets_df = pd.read_csv(csv_path, low_memory = False)
BBC_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220256711589683207"
# 1     "1220221131795390472"
# 2     "1220060752326905857"
# 3     "1219964102484905984"
# 4     "1219819207883415557"
# ...                     ...
# 3195   "908620348161216512"
# 3196   "908607797150998528"
# 3197   "908604541465018370"
# 3198   "908603688272502784"
# 3199   "908597697166364673"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/bbcbreaking/status/1220256...  2020-01-23 08:07:25
# 1     https://twitter.com/bbcbreaking/status/1220221...  2020-01-23 05:46:03
# 2     https://twitter.com/bbcbreaking/status/1220060...  2020-01-22 19:08:45
# 3     https://twitter.com/bbcbreaking/status/1219964...  2020-01-22 12:44:42
# 4     https://twitter.com/bbcbreaking/status/1219819...  2020-01-22 03:08:56
# ...                                                 ...                  ...
# 3195  https://twitter.com/bbcbreaking/status/9086203...  2017-09-15 09:15:47
# ...

# %%
#Show the 'shape' of the dataframe 
shape = BBC_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
BBC_Tweets_df = BBC_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = BBC_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
BBC_Tweets_df
# Out:
#          Username    User Id Tweet Type  \
# 0     bbcbreaking  "5402612"      Tweet
# 1     bbcbreaking  "5402612"      Tweet
# 2     bbcbreaking  "5402612"      Tweet
# 3     bbcbreaking  "5402612"      Tweet
# 4     bbcbreaking  "5402612"      Tweet
# ...           ...        ...        ...
# 3195  bbcbreaking  "5402612"      Reply
# 3196  bbcbreaking  "5402612"      Tweet
# 3197  bbcbreaking  "5402612"      Tweet
# 3198  bbcbreaking  "5402612"      Reply
# 3199  bbcbreaking  "5402612"      Tweet
#
#                                           Tweet Content        Client  \
# 0     "Africa's richest woman, Angolan Isabel Dos Sa...    SocialFlow
# 1     "The crew of the large air tanker were helping...    SocialFlow
# 2     "Wuhan, a Chinese city of nearly 9m people, is...    SocialFlow
# 3     "Monty Python star Terry Jones has died at the...    SocialFlow
# 4     "The new virus could mutate and spread further...    SocialFlow
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
BBC_Tweets_df = BBC_Tweets_df.dropna() 

#Confirm rows are dropped
shape = BBC_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BBC_Tweets_df['Tweet Posted Time'] = BBC_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BBC_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
BBC_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BBC_Tweets_df['Tweet Posted Time'] = BBC_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BBC_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
BBC_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
BBC_Tweets_df = BBC_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = BBC_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
BBC_Tweets_df
# Out:
#          Username    User Id Tweet Type  \
# 0     bbcbreaking  "5402612"      Tweet
# 1     bbcbreaking  "5402612"      Tweet
# 2     bbcbreaking  "5402612"      Tweet
# 3     bbcbreaking  "5402612"      Tweet
# 4     bbcbreaking  "5402612"      Tweet
# ...           ...        ...        ...
# 3195  bbcbreaking  "5402612"      Reply
# 3196  bbcbreaking  "5402612"      Tweet
# 3197  bbcbreaking  "5402612"      Tweet
# 3198  bbcbreaking  "5402612"      Reply
# 3199  bbcbreaking  "5402612"      Tweet
#
#                                           Tweet Content        Client  \
# 0     "Africa's richest woman, Angolan Isabel Dos Sa...    SocialFlow
# 1     "The crew of the large air tanker were helping...    SocialFlow
# 2     "Wuhan, a Chinese city of nearly 9m people, is...    SocialFlow
# 3     "Monty Python star Terry Jones has died at the...    SocialFlow
# 4     "The new virus could mutate and spread further...    SocialFlow
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
BBC_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
BBC_Tweets_df['Vocation'] = "News/Media"

#Show the 'shape' of the dataframe
shape = BBC_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
BBC_Tweets_df.index = [x for x in range(1, len(BBC_Tweets_df.values)+1)]
BBC_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
BBC_Tweets_df
# Out:
#           Username    User Id Tweet Type  \
# Index
# 1      bbcbreaking  "5402612"      Tweet
# 2      bbcbreaking  "5402612"      Tweet
# 3      bbcbreaking  "5402612"      Tweet
# 4      bbcbreaking  "5402612"      Tweet
# 5      bbcbreaking  "5402612"      Tweet
# ...            ...        ...        ...
# 3196   bbcbreaking  "5402612"      Reply
# 3197   bbcbreaking  "5402612"      Tweet
# 3198   bbcbreaking  "5402612"      Tweet
# 3199   bbcbreaking  "5402612"      Reply
# 3200   bbcbreaking  "5402612"      Tweet
#
#                                            Tweet Content        Client  \
# Index
# 1      "Africa's richest woman, Angolan Isabel Dos Sa...    SocialFlow
# 2      "The crew of the large air tanker were helping...    SocialFlow
# 3      "Wuhan, a Chinese city of nearly 9m people, is...    SocialFlow
# 4      "Monty Python star Terry Jones has died at the...    SocialFlow
# 5      "The new virus could mutate and spread further...    SocialFlow
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
BBC_Tweets_df.to_csv('BBC_Tweets_df.csv')
