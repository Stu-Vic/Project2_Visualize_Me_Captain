# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Real Madrid Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "RealMadridTweets.csv"

#Import the CSV into a pandas DataFrame
RMadrid_Tweets_df = pd.read_csv(csv_path, low_memory = False)
RMadrid_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220262391734206464"
# 1     "1220146629052944385"
# 2     "1220111675094945795"
# 3     "1220111398031646722"
# 4     "1220106390452297730"
# ...                     ...
# 3195  "1110529756573982720"
# 3196  "1110270130485813248"
# 3197  "1110239928997367808"
# 3198  "1110164434591338497"
# 3199  "1110104405691547648"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/realmadrid/status/12202623...  2020-01-23 08:30:00
# 1     https://twitter.com/realmadrid/status/12201466...  2020-01-23 00:50:00
# 2     https://twitter.com/realmadrid/status/12201116...  2020-01-22 22:31:06
# 3     https://twitter.com/realmadrid/status/12201113...  2020-01-22 22:30:00
# 4     https://twitter.com/realmadrid/status/12201063...  2020-01-22 22:10:06
# ...                                                 ...                  ...
# 3195  https://twitter.com/realmadrid/status/11105297...  2019-03-26 13:11:41
# 3196  https://twitter.com/realmadrid/status/11102701...  2019-03-25 20:00:01
# 3197  https://twitter.com/realmadrid/status/11102399...  2019-03-25 18:00:00
# 3198  https://twitter.com/realmadrid/status/11101644...  2019-03-25 13:00:01
# 3199  https://twitter.com/realmadrid/status/11101044...  2019-03-25 09:01:29
#
#                                           Tweet Content Tweet Type  \
# 0     "🔀🏆👑 ¡Clasificados para octavos de la Copa del...      Tweet
# 1     "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...      Tweet
# 2     "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...      Tweet
# 3     "💬👔 #Zidane analizó nuestro partido en Salaman...      Tweet
# 4     "💬 @fedeevalverde habló con los medios nada má...      Tweet
# ...                                                 ...        ...
# 3195  "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...      Tweet
# 3196  "💪 La temporada de @Benzema:\n⚽ Pichichi del e...      Tweet
# 3197  "✅ Primera sesión de la semana.\n🌱 #RMCity htt...      Tweet
# 3198  "😃 ¡Así fue la experiencia VIP de 12 Coderista...      Tweet
# 3199  "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...      Tweet
#
#                        Client  Retweets received  Likes received     User Id  \
# 0     Twitter for Advertisers                 91             930  "14872237"
# 1        Twitter Media Studio                629            5256  "14872237"
# 2        Twitter Media Studio               1105           11218  "14872237"
# 3        Twitter Media Studio                192            1984  "14872237"
# 4        Twitter Media Studio                359            3752  "14872237"
# ...                       ...                ...             ...         ...
# 3195                TweetDeck                250            2334  "14872237"
# 3196     Twitter Media Studio                399            4732  "14872237"
# 3197                TweetDeck                243            3074  "14872237"
# 3198     Twitter Media Studio                174            2633  "14872237"
# 3199     Twitter Media Studio                253            3065  "14872237"
#
#                      Name    Username Verified or Non-Verified  \
# 0     "Real Madrid C.F.⚽"  realmadrid                 Verified
# 1     "Real Madrid C.F.⚽"  realmadrid                 Verified
# 2     "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3     "Real Madrid C.F.⚽"  realmadrid                 Verified
# 4     "Real Madrid C.F.⚽"  realmadrid                 Verified
# ...                   ...         ...                      ...
# 3195  "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3196  "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3197  "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3198  "Real Madrid C.F.⚽"  realmadrid                 Verified
# 3199  "Real Madrid C.F.⚽"  realmadrid                 Verified
#
#                          Profile URL Protected or Not Protected
# 0     https://twitter.com/realmadrid              Not Protected
# 1     https://twitter.com/realmadrid              Not Protected
# 2     https://twitter.com/realmadrid              Not Protected
# 3     https://twitter.com/realmadrid              Not Protected
# 4     https://twitter.com/realmadrid              Not Protected
# ...                              ...                        ...
# 3195  https://twitter.com/realmadrid              Not Protected
# 3196  https://twitter.com/realmadrid              Not Protected
# 3197  https://twitter.com/realmadrid              Not Protected
# 3198  https://twitter.com/realmadrid              Not Protected
# 3199  https://twitter.com/realmadrid              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = RMadrid_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
RMadrid_Tweets_df = RMadrid_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = RMadrid_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
RMadrid_Tweets_df
# Out:
#         Username     User Id Tweet Type  \
# 0     realmadrid  "14872237"      Tweet
# 1     realmadrid  "14872237"      Tweet
# 2     realmadrid  "14872237"      Tweet
# 3     realmadrid  "14872237"      Tweet
# 4     realmadrid  "14872237"      Tweet
# ...          ...         ...        ...
# 3195  realmadrid  "14872237"      Tweet
# 3196  realmadrid  "14872237"      Tweet
# 3197  realmadrid  "14872237"      Tweet
# 3198  realmadrid  "14872237"      Tweet
# 3199  realmadrid  "14872237"      Tweet
#
#                                           Tweet Content  \
# 0     "🔀🏆👑 ¡Clasificados para octavos de la Copa del...
# 1     "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...
# 2     "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...
# 3     "💬👔 #Zidane analizó nuestro partido en Salaman...
# 4     "💬 @fedeevalverde habló con los medios nada má...
# ...                                                 ...
# 3195  "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...
# 3196  "💪 La temporada de @Benzema:\n⚽ Pichichi del e...
# 3197  "✅ Primera sesión de la semana.\n🌱 #RMCity htt...
# 3198  "😃 ¡Así fue la experiencia VIP de 12 Coderista...
# 3199  "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...
#
#                        Client  Retweets received  Likes received  \
# 0     Twitter for Advertisers                 91             930
# 1        Twitter Media Studio                629            5256
# 2        Twitter Media Studio               1105           11218
# 3        Twitter Media Studio                192            1984
# 4        Twitter Media Studio                359            3752
# ...                       ...                ...             ...
# 3195                TweetDeck                250            2334
# 3196     Twitter Media Studio                399            4732
# 3197                TweetDeck                243            3074
# 3198     Twitter Media Studio                174            2633
# 3199     Twitter Media Studio                253            3065
#
#         Tweet Posted Time
# 0     2020-01-23 08:30:00
# 1     2020-01-23 00:50:00
# 2     2020-01-22 22:31:06
# 3     2020-01-22 22:30:00
# 4     2020-01-22 22:10:06
# ...                   ...
# 3195  2019-03-26 13:11:41
# 3196  2019-03-25 20:00:01
# 3197  2019-03-25 18:00:00
# 3198  2019-03-25 13:00:01
# 3199  2019-03-25 09:01:29
#
# [3200 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
RMadrid_Tweets_df = RMadrid_Tweets_df.dropna() 

#Confirm rows are dropped
shape = RMadrid_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
RMadrid_Tweets_df['Tweet Posted Time'] = RMadrid_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = RMadrid_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
RMadrid_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
RMadrid_Tweets_df['Tweet Posted Time'] = RMadrid_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = RMadrid_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
RMadrid_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
RMadrid_Tweets_df = RMadrid_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = RMadrid_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
RMadrid_Tweets_df
# Out:
#         Username     User Id Tweet Type  \
# 0     realmadrid  "14872237"      Tweet
# 1     realmadrid  "14872237"      Tweet
# 2     realmadrid  "14872237"      Tweet
# 3     realmadrid  "14872237"      Tweet
# 4     realmadrid  "14872237"      Tweet
# ...          ...         ...        ...
# 3195  realmadrid  "14872237"      Tweet
# 3196  realmadrid  "14872237"      Tweet
# 3197  realmadrid  "14872237"      Tweet
# 3198  realmadrid  "14872237"      Tweet
# 3199  realmadrid  "14872237"      Tweet
#
#                                           Tweet Content  \
# 0     "🔀🏆👑 ¡Clasificados para octavos de la Copa del...
# 1     "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...
# 2     "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...
# 3     "💬👔 #Zidane analizó nuestro partido en Salaman...
# 4     "💬 @fedeevalverde habló con los medios nada má...
# ...                                                 ...
# 3195  "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...
# 3196  "💪 La temporada de @Benzema:\n⚽ Pichichi del e...
# 3197  "✅ Primera sesión de la semana.\n🌱 #RMCity htt...
# 3198  "😃 ¡Así fue la experiencia VIP de 12 Coderista...
# 3199  "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...
#
#                        Client  Retweets received  Likes received        Date  \
# 0     Twitter for Advertisers                 91             930  2020-01-23
# 1        Twitter Media Studio                629            5256  2020-01-23
# 2        Twitter Media Studio               1105           11218  2020-01-22
# 3        Twitter Media Studio                192            1984  2020-01-22
# 4        Twitter Media Studio                359            3752  2020-01-22
# ...                       ...                ...             ...         ...
# 3195                TweetDeck                250            2334  2019-03-26
# 3196     Twitter Media Studio                399            4732  2019-03-25
# 3197                TweetDeck                243            3074  2019-03-25
# 3198     Twitter Media Studio                174            2633  2019-03-25
# 3199     Twitter Media Studio                253            3065  2019-03-25
#
#           Time
# 0     08:30:00
# 1     00:50:00
# 2     22:31:06
# 3     22:30:00
# 4     22:10:06
# ...        ...
# 3195  13:11:41
# 3196  20:00:01
# 3197  18:00:00
# 3198  13:00:01
# 3199  09:01:29
#
# [3200 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
RMadrid_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
RMadrid_Tweets_df['Vocation'] = "Sport"

#Show the 'shape' of the dataframe
shape = RMadrid_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
RMadrid_Tweets_df.index = [x for x in range(1, len(RMadrid_Tweets_df.values)+1)]
RMadrid_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
RMadrid_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# Index
# 1      realmadrid  "14872237"      Tweet
# 2      realmadrid  "14872237"      Tweet
# 3      realmadrid  "14872237"      Tweet
# 4      realmadrid  "14872237"      Tweet
# 5      realmadrid  "14872237"      Tweet
# ...           ...         ...        ...
# 3196   realmadrid  "14872237"      Tweet
# 3197   realmadrid  "14872237"      Tweet
# 3198   realmadrid  "14872237"      Tweet
# 3199   realmadrid  "14872237"      Tweet
# 3200   realmadrid  "14872237"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "🔀🏆👑 ¡Clasificados para octavos de la Copa del...
# 2      "📺💫 RESUMEN Y GOLES\n🆚 @UnionistasCF 1-3 @real...
# 3      "👕🎁🤩 ¡Así agradeció @Brahim el apoyo de nuestr...
# 4      "💬👔 #Zidane analizó nuestro partido en Salaman...
# 5      "💬 @fedeevalverde habló con los medios nada má...
# ...                                                  ...
# 3196   "📌 HORARIO CONFIRMADO\n👉 Jornada 33 | LaLiga\n...
# 3197   "💪 La temporada de @Benzema:\n⚽ Pichichi del e...
# 3198   "✅ Primera sesión de la semana.\n🌱 #RMCity htt...
# 3199   "😃 ¡Así fue la experiencia VIP de 12 Coderista...
# 3200   "🇫🇷 Francia 🆚 Islandia 🇮🇸\n⏰ 20:45 CET | @raph...
#
#                         Client  Retweets received  Likes received        Date  \
# Index
# 1      Twitter for Advertisers                 91             930  2020-01-23
# 2         Twitter Media Studio                629            5256  2020-01-23
# 3         Twitter Media Studio               1105           11218  2020-01-22
# 4         Twitter Media Studio                192            1984  2020-01-22
# 5         Twitter Media Studio                359            3752  2020-01-22
# ...                        ...                ...             ...         ...
# 3196                 TweetDeck                250            2334  2019-03-26
# 3197      Twitter Media Studio                399            4732  2019-03-25
# 3198                 TweetDeck                243            3074  2019-03-25
# 3199      Twitter Media Studio                174            2633  2019-03-25
# 3200      Twitter Media Studio                253            3065  2019-03-25
#
#            Time        Gender Vocation
# Index
# 1      08:30:00  Organisation    Sport
# 2      00:50:00  Organisation    Sport
# 3      22:31:06  Organisation    Sport
# 4      22:30:00  Organisation    Sport
# 5      22:10:06  Organisation    Sport
# ...         ...           ...      ...
# 3196   13:11:41  Organisation    Sport
# 3197   20:00:01  Organisation    Sport
# 3198   18:00:00  Organisation    Sport
# 3199   13:00:01  Organisation    Sport
# 3200   09:01:29  Organisation    Sport
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
RMadrid_Tweets_df.to_csv('RMadrid_Tweets_df.csv')
