# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # CNN Breaking News Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "CNNBreakingTweets.csv"

#Import the CSV into a pandas DataFrame
CNNBreaking_Tweets_df = pd.read_csv(csv_path, low_memory = False)
CNNBreaking_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220182010972557313"
# 1     "1220152440315613185"
# 2     "1220133332702375937"
# 3     "1220108211191209984"
# 4     "1220107262741618688"
# ...                     ...
# 3195  "1126953520912109570"
# 3196  "1126950351607930880"
# 3197  "1126924899082174466"
# 3198  "1126904568556740610"
# 3199  "1126897568154300416"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/cnnbrk/status/122018201097...  2020-01-23 03:10:35
# 1     https://twitter.com/cnnbrk/status/122015244031...  2020-01-23 01:13:05
# 2     https://twitter.com/cnnbrk/status/122013333270...  2020-01-22 23:57:10
# 3     https://twitter.com/cnnbrk/status/122010821119...  2020-01-22 22:17:20
# 4     https://twitter.com/cnnbrk/status/122010726274...  2020-01-22 22:13:34
# ...                                                 ...                  ...
# 3195  https://twitter.com/cnnbrk/status/112695352091...  2019-05-10 20:53:51
# ...

# %%
#Show the 'shape' of the dataframe 
shape = CNNBreaking_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
CNNBreaking_Tweets_df = CNNBreaking_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", 
                                               "Retweets received", "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = CNNBreaking_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
CNNBreaking_Tweets_df
# Out:
#      Username   User Id Tweet Type  \
# 0      cnnbrk  "428333"      Tweet
# 1      cnnbrk  "428333"      Tweet
# 2      cnnbrk  "428333"      Tweet
# 3      cnnbrk  "428333"      Tweet
# 4      cnnbrk  "428333"      Tweet
# ...       ...       ...        ...
# 3195   cnnbrk  "428333"      Tweet
# 3196   cnnbrk  "428333"      Tweet
# 3197   cnnbrk  "428333"      Tweet
# 3198   cnnbrk  "428333"      Tweet
# 3199   cnnbrk  "428333"      Tweet
#
#                                           Tweet Content     Client  \
# 0     "At least one person was killed and several ot...  TweetDeck
# 1     "Another inmate has died at Mississippi's Parc...  TweetDeck
# 2     "Eli Manning, quarterback for the New York Gia...  TweetDeck
# 3     "Rapper and singer Juice WRLD died from an acc...  TweetDeck
# 4     "Four people were killed when a small plane cr...  TweetDeck
# ...                                                 ...        ...
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
CNNBreaking_Tweets_df = CNNBreaking_Tweets_df.dropna() 

#Confirm rows are dropped
shape = CNNBreaking_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
CNNBreaking_Tweets_df['Tweet Posted Time'] = CNNBreaking_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = CNNBreaking_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
CNNBreaking_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
CNNBreaking_Tweets_df['Tweet Posted Time'] = CNNBreaking_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = CNNBreaking_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
CNNBreaking_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
CNNBreaking_Tweets_df = CNNBreaking_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = CNNBreaking_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
CNNBreaking_Tweets_df
# Out:
#      Username   User Id Tweet Type  \
# 0      cnnbrk  "428333"      Tweet
# 1      cnnbrk  "428333"      Tweet
# 2      cnnbrk  "428333"      Tweet
# 3      cnnbrk  "428333"      Tweet
# 4      cnnbrk  "428333"      Tweet
# ...       ...       ...        ...
# 3195   cnnbrk  "428333"      Tweet
# 3196   cnnbrk  "428333"      Tweet
# 3197   cnnbrk  "428333"      Tweet
# 3198   cnnbrk  "428333"      Tweet
# 3199   cnnbrk  "428333"      Tweet
#
#                                           Tweet Content     Client  \
# 0     "At least one person was killed and several ot...  TweetDeck
# 1     "Another inmate has died at Mississippi's Parc...  TweetDeck
# 2     "Eli Manning, quarterback for the New York Gia...  TweetDeck
# 3     "Rapper and singer Juice WRLD died from an acc...  TweetDeck
# 4     "Four people were killed when a small plane cr...  TweetDeck
# ...                                                 ...        ...
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
CNNBreaking_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
CNNBreaking_Tweets_df['Vocation'] = "News/Media"

#Show the 'shape' of the dataframe
shape = CNNBreaking_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
CNNBreaking_Tweets_df.index = [x for x in range(1, len(CNNBreaking_Tweets_df.values)+1)]
CNNBreaking_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
CNNBreaking_Tweets_df
# Out:
#       Username   User Id Tweet Type  \
# Index
# 1       cnnbrk  "428333"      Tweet
# 2       cnnbrk  "428333"      Tweet
# 3       cnnbrk  "428333"      Tweet
# 4       cnnbrk  "428333"      Tweet
# 5       cnnbrk  "428333"      Tweet
# ...        ...       ...        ...
# 3196    cnnbrk  "428333"      Tweet
# 3197    cnnbrk  "428333"      Tweet
# 3198    cnnbrk  "428333"      Tweet
# 3199    cnnbrk  "428333"      Tweet
# 3200    cnnbrk  "428333"      Tweet
#
#                                            Tweet Content     Client  \
# Index
# 1      "At least one person was killed and several ot...  TweetDeck
# 2      "Another inmate has died at Mississippi's Parc...  TweetDeck
# 3      "Eli Manning, quarterback for the New York Gia...  TweetDeck
# 4      "Rapper and singer Juice WRLD died from an acc...  TweetDeck
# 5      "Four people were killed when a small plane cr...  TweetDeck
# ...                                                  ...        ...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
CNNBreaking_Tweets_df.to_csv('CNNBreaking_Tweets_df.csv')
