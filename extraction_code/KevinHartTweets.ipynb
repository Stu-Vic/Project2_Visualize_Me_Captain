# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Kevin Hart Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "KevinHartTweets.csv"

#Import the CSV into a pandas DataFrame
KHart_Tweets_df = pd.read_csv(csv_path, low_memory = False)
KHart_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220060656264785922"
# 1     "1219330669387698176"
# 2     "1218585360797556736"
# 3     "1217958222885195777"
# 4     "1217951440238301184"
# ...                     ...
# 3195   "987118723118006272"
# 3196   "987110711254859776"
# 3197   "987110701196918785"
# 3198   "987107607033741312"
# 3199   "987106774581788673"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/kevinhart4real/status/1220...  2020-01-22 19:08:22
# 1     https://twitter.com/kevinhart4real/status/1219...  2020-01-20 18:47:40
# 2     https://twitter.com/kevinhart4real/status/1218...  2020-01-18 17:26:04
# 3     https://twitter.com/kevinhart4real/status/1217...  2020-01-16 23:54:03
# 4     https://twitter.com/kevinhart4real/status/1217...  2020-01-16 23:27:06
# ...                                                 ...                  ...
# 3195  https://twitter.com/kevinhart4real/status/9871...  2018-04-20 00:00:18
# ...

# %%
#Show the 'shape' of the dataframe 
shape = KHart_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
KHart_Tweets_df = KHart_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = KHart_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
KHart_Tweets_df
# Out:
#             Username     User Id Tweet Type  \
# 0     kevinhart4real  "23151437"      Tweet
# 1     kevinhart4real  "23151437"      Tweet
# 2     kevinhart4real  "23151437"      Tweet
# 3     kevinhart4real  "23151437"      Tweet
# 4     kevinhart4real  "23151437"      Tweet
# ...              ...         ...        ...
# 3195  kevinhart4real  "23151437"      Tweet
# 3196  kevinhart4real  "23151437"      Reply
# 3197  kevinhart4real  "23151437"      Tweet
# 3198  kevinhart4real  "23151437"      Tweet
# 3199  kevinhart4real  "23151437"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "The Winter Olympics ain't got shit on the col...           Instagram
# 1     "Happy MLK Day.... #HartBeatProductions #Laugh...           Instagram
# 2               "Big Shit coming in 2020....Stay tuned"  Twitter for iPhone
# 3     "I am so excited about the partnership between...           Instagram
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
KHart_Tweets_df = KHart_Tweets_df.dropna() 

#Confirm rows are dropped
shape = KHart_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3199, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
KHart_Tweets_df['Tweet Posted Time'] = KHart_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = KHart_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
KHart_Tweets_df["Date"] = date
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
KHart_Tweets_df['Tweet Posted Time'] = KHart_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = KHart_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
KHart_Tweets_df["Time"] = time
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
KHart_Tweets_df = KHart_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = KHart_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3199, 9)

# %%
#Print the dataframe
KHart_Tweets_df
# Out:
#             Username     User Id Tweet Type  \
# 0     kevinhart4real  "23151437"      Tweet
# 1     kevinhart4real  "23151437"      Tweet
# 2     kevinhart4real  "23151437"      Tweet
# 3     kevinhart4real  "23151437"      Tweet
# 4     kevinhart4real  "23151437"      Tweet
# ...              ...         ...        ...
# 3195  kevinhart4real  "23151437"      Tweet
# 3196  kevinhart4real  "23151437"      Reply
# 3197  kevinhart4real  "23151437"      Tweet
# 3198  kevinhart4real  "23151437"      Tweet
# 3199  kevinhart4real  "23151437"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "The Winter Olympics ain't got shit on the col...           Instagram
# 1     "Happy MLK Day.... #HartBeatProductions #Laugh...           Instagram
# 2               "Big Shit coming in 2020....Stay tuned"  Twitter for iPhone
# 3     "I am so excited about the partnership between...           Instagram
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
KHart_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
KHart_Tweets_df['Vocation'] = "Comedian"

#Show the 'shape' of the dataframe
shape = KHart_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3199, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
KHart_Tweets_df.index = [x for x in range(1, len(KHart_Tweets_df.values)+1)]
KHart_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
KHart_Tweets_df
# Out:
#              Username     User Id Tweet Type  \
# Index
# 1      kevinhart4real  "23151437"      Tweet
# 2      kevinhart4real  "23151437"      Tweet
# 3      kevinhart4real  "23151437"      Tweet
# 4      kevinhart4real  "23151437"      Tweet
# 5      kevinhart4real  "23151437"      Tweet
# ...               ...         ...        ...
# 3195   kevinhart4real  "23151437"      Tweet
# 3196   kevinhart4real  "23151437"      Reply
# 3197   kevinhart4real  "23151437"      Tweet
# 3198   kevinhart4real  "23151437"      Tweet
# 3199   kevinhart4real  "23151437"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "The Winter Olympics ain't got shit on the col...           Instagram
# 2      "Happy MLK Day.... #HartBeatProductions #Laugh...           Instagram
# 3                "Big Shit coming in 2020....Stay tuned"  Twitter for iPhone
# 4      "I am so excited about the partnership between...           Instagram
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
KHart_Tweets_df.to_csv('KHart_Tweets_df.csv')
