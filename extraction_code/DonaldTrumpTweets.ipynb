# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Donald Trump Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "DonaldTrumpTweets.csv"

#Import the CSV into a pandas DataFrame
DTrump_Tweets_df = pd.read_csv(csv_path, low_memory = False)
DTrump_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220109701276454922"
# 1     "1220107185276907521"
# 2     "1220105021930426368"
# 3     "1220103850482380802"
# 4     "1220101014734475265"
# ...                     ...
# 3195  "1180322833316171778"
# 3196  "1180322797102522368"
# 3197  "1180322404679241728"
# 3198  "1180319734753046528"
# 3199  "1180316198598270981"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/marshablackburn/status/122...  2020-01-22 22:23:15
# 1     https://twitter.com/realdonaldtrump/status/122...  2020-01-22 22:13:16
# 2     https://twitter.com/realdonaldtrump/status/122...  2020-01-22 22:04:40
# 3     https://twitter.com/senbillcassidy/status/1220...  2020-01-22 22:00:01
# 4     https://twitter.com/repdougcollins/status/1220...  2020-01-22 21:48:44
# ...                                                 ...                  ...
# 3195  https://twitter.com/realdonaldtrump/status/118...  2019-10-05 03:24:27
# 3196  https://twitter.com/realdonaldtrump/status/118...  2019-10-05 03:24:18
# 3197  https://twitter.com/realdonaldtrump/status/118...  2019-10-05 03:22:45
# 3198  https://twitter.com/realdonaldtrump/status/118...  2019-10-05 03:12:08
# 3199  https://twitter.com/realdonaldtrump/status/118...  2019-10-05 02:58:05
#
#                                           Tweet Content Tweet Type  \
# 0     "We all know Adam Schiff loves hearing himself...    Retweet
# 1     "Sorry, if you come you will be immediately se...      Tweet
# 2     "See you on Friday...Big Crowd! https://t.co/M...      Tweet
# 3     "The rules laid out by @senatemajldr for the i...    Retweet
# 4     "Despite Democrats’ best attempts to distort t...    Retweet
# ...                                                 ...        ...
# 3195  "“Report: ‘Whistleblower’ Never Disclosed Cont...      Tweet
# 3196              "GREAT BOOK! https://t.co/LrRr1xhS0d"      Tweet
# 3197  "“Pelosi Blatantly Lies During @GMA Interview ...      Tweet
# 3198  "Where is the LameStream Media on this? https:...      Tweet
# 3199  "Thanks Jim. Would be great to just run our Co...      Tweet
#
#                     Client  Retweets received  Likes received  \
# 0          Twitter Web App              14784           38052
# 1       Twitter for iPhone              20671           77127
# 2       Twitter for iPhone              18522           68211
# 3                TweetDeck               8290           25446
# 4     Twitter Media Studio              10074           29761
# ...                    ...                ...             ...
# 3195    Twitter for iPhone              11569           37533
# 3196    Twitter for iPhone               8302           34169
# 3197    Twitter for iPhone              14957           45787
# 3198    Twitter for iPhone              19134           57490
# 3199    Twitter for iPhone              10061           40396
#
#                     User Id                               Name  \
# 0               "278145569"            "Sen. Marsha Blackburn"
# 1                "25073877"                  "Donald J. Trump"
# 2                "25073877"                  "Donald J. Trump"
# 3     "1017500185356853248"  "U.S. Senator Bill Cassidy, M.D."
# 4              "1060487274"                "Rep. Doug Collins"
# ...                     ...                                ...
# 3195             "25073877"                  "Donald J. Trump"
# 3196             "25073877"                  "Donald J. Trump"
# 3197             "25073877"                  "Donald J. Trump"
# 3198             "25073877"                  "Donald J. Trump"
# 3199             "25073877"                  "Donald J. Trump"
#
#              Username Verified or Non-Verified  \
# 0     marshablackburn                 Verified
# 1     realdonaldtrump                 Verified
# 2     realdonaldtrump                 Verified
# 3      senbillcassidy                 Verified
# 4      repdougcollins                 Verified
# ...               ...                      ...
# 3195  realdonaldtrump                 Verified
# 3196  realdonaldtrump                 Verified
# 3197  realdonaldtrump                 Verified
# 3198  realdonaldtrump                 Verified
# 3199  realdonaldtrump                 Verified
#
#                               Profile URL Protected or Not Protected
# 0     https://twitter.com/marshablackburn              Not Protected
# 1     https://twitter.com/realdonaldtrump              Not Protected
# 2     https://twitter.com/realdonaldtrump              Not Protected
# 3      https://twitter.com/senbillcassidy              Not Protected
# 4      https://twitter.com/repdougcollins              Not Protected
# ...                                   ...                        ...
# 3195  https://twitter.com/realdonaldtrump              Not Protected
# 3196  https://twitter.com/realdonaldtrump              Not Protected
# 3197  https://twitter.com/realdonaldtrump              Not Protected
# 3198  https://twitter.com/realdonaldtrump              Not Protected
# 3199  https://twitter.com/realdonaldtrump              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = DTrump_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
DTrump_Tweets_df = DTrump_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = DTrump_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
DTrump_Tweets_df
# Out:
#              Username                User Id Tweet Type  \
# 0     marshablackburn            "278145569"    Retweet
# 1     realdonaldtrump             "25073877"      Tweet
# 2     realdonaldtrump             "25073877"      Tweet
# 3      senbillcassidy  "1017500185356853248"    Retweet
# 4      repdougcollins           "1060487274"    Retweet
# ...               ...                    ...        ...
# 3195  realdonaldtrump             "25073877"      Tweet
# 3196  realdonaldtrump             "25073877"      Tweet
# 3197  realdonaldtrump             "25073877"      Tweet
# 3198  realdonaldtrump             "25073877"      Tweet
# 3199  realdonaldtrump             "25073877"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "We all know Adam Schiff loves hearing himself...       Twitter Web App
# 1     "Sorry, if you come you will be immediately se...    Twitter for iPhone
# 2     "See you on Friday...Big Crowd! https://t.co/M...    Twitter for iPhone
# 3     "The rules laid out by @senatemajldr for the i...             TweetDeck
# 4     "Despite Democrats’ best attempts to distort t...  Twitter Media Studio
# ...                                                 ...                   ...
# 3195  "“Report: ‘Whistleblower’ Never Disclosed Cont...    Twitter for iPhone
# 3196              "GREAT BOOK! https://t.co/LrRr1xhS0d"    Twitter for iPhone
# 3197  "“Pelosi Blatantly Lies During @GMA Interview ...    Twitter for iPhone
# 3198  "Where is the LameStream Media on this? https:...    Twitter for iPhone
# 3199  "Thanks Jim. Would be great to just run our Co...    Twitter for iPhone
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                 14784           38052  2020-01-22 22:23:15
# 1                 20671           77127  2020-01-22 22:13:16
# 2                 18522           68211  2020-01-22 22:04:40
# 3                  8290           25446  2020-01-22 22:00:01
# 4                 10074           29761  2020-01-22 21:48:44
# ...                 ...             ...                  ...
# 3195              11569           37533  2019-10-05 03:24:27
# 3196               8302           34169  2019-10-05 03:24:18
# 3197              14957           45787  2019-10-05 03:22:45
# 3198              19134           57490  2019-10-05 03:12:08
# 3199              10061           40396  2019-10-05 02:58:05
#
# [3200 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
DTrump_Tweets_df = DTrump_Tweets_df.dropna() 

#Confirm rows are dropped
shape = DTrump_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
DTrump_Tweets_df['Tweet Posted Time'] = DTrump_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = DTrump_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
DTrump_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
DTrump_Tweets_df['Tweet Posted Time'] = DTrump_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = DTrump_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
DTrump_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
DTrump_Tweets_df = DTrump_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = DTrump_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
DTrump_Tweets_df
# Out:
#              Username                User Id Tweet Type  \
# 0     marshablackburn            "278145569"    Retweet
# 1     realdonaldtrump             "25073877"      Tweet
# 2     realdonaldtrump             "25073877"      Tweet
# 3      senbillcassidy  "1017500185356853248"    Retweet
# 4      repdougcollins           "1060487274"    Retweet
# ...               ...                    ...        ...
# 3195  realdonaldtrump             "25073877"      Tweet
# 3196  realdonaldtrump             "25073877"      Tweet
# 3197  realdonaldtrump             "25073877"      Tweet
# 3198  realdonaldtrump             "25073877"      Tweet
# 3199  realdonaldtrump             "25073877"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "We all know Adam Schiff loves hearing himself...       Twitter Web App
# 1     "Sorry, if you come you will be immediately se...    Twitter for iPhone
# 2     "See you on Friday...Big Crowd! https://t.co/M...    Twitter for iPhone
# 3     "The rules laid out by @senatemajldr for the i...             TweetDeck
# 4     "Despite Democrats’ best attempts to distort t...  Twitter Media Studio
# ...                                                 ...                   ...
# 3195  "“Report: ‘Whistleblower’ Never Disclosed Cont...    Twitter for iPhone
# 3196              "GREAT BOOK! https://t.co/LrRr1xhS0d"    Twitter for iPhone
# 3197  "“Pelosi Blatantly Lies During @GMA Interview ...    Twitter for iPhone
# 3198  "Where is the LameStream Media on this? https:...    Twitter for iPhone
# 3199  "Thanks Jim. Would be great to just run our Co...    Twitter for iPhone
#
#       Retweets received  Likes received        Date      Time
# 0                 14784           38052  2020-01-22  22:23:15
# 1                 20671           77127  2020-01-22  22:13:16
# 2                 18522           68211  2020-01-22  22:04:40
# 3                  8290           25446  2020-01-22  22:00:01
# 4                 10074           29761  2020-01-22  21:48:44
# ...                 ...             ...         ...       ...
# 3195              11569           37533  2019-10-05  03:24:27
# 3196               8302           34169  2019-10-05  03:24:18
# 3197              14957           45787  2019-10-05  03:22:45
# 3198              19134           57490  2019-10-05  03:12:08
# 3199              10061           40396  2019-10-05  02:58:05
#
# [3200 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
DTrump_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
DTrump_Tweets_df['Vocation'] = "Politics"

#Show the 'shape' of the dataframe
shape = DTrump_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
DTrump_Tweets_df.index = [x for x in range(1, len(DTrump_Tweets_df.values)+1)]
DTrump_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
DTrump_Tweets_df
# Out:
#               Username                User Id Tweet Type  \
# Index
# 1      marshablackburn            "278145569"    Retweet
# 2      realdonaldtrump             "25073877"      Tweet
# 3      realdonaldtrump             "25073877"      Tweet
# 4       senbillcassidy  "1017500185356853248"    Retweet
# 5       repdougcollins           "1060487274"    Retweet
# ...                ...                    ...        ...
# 3196   realdonaldtrump             "25073877"      Tweet
# 3197   realdonaldtrump             "25073877"      Tweet
# 3198   realdonaldtrump             "25073877"      Tweet
# 3199   realdonaldtrump             "25073877"      Tweet
# 3200   realdonaldtrump             "25073877"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "We all know Adam Schiff loves hearing himself...
# 2      "Sorry, if you come you will be immediately se...
# 3      "See you on Friday...Big Crowd! https://t.co/M...
# 4      "The rules laid out by @senatemajldr for the i...
# 5      "Despite Democrats’ best attempts to distort t...
# ...                                                  ...
# 3196   "“Report: ‘Whistleblower’ Never Disclosed Cont...
# 3197               "GREAT BOOK! https://t.co/LrRr1xhS0d"
# 3198   "“Pelosi Blatantly Lies During @GMA Interview ...
# 3199   "Where is the LameStream Media on this? https:...
# 3200   "Thanks Jim. Would be great to just run our Co...
#
#                      Client  Retweets received  Likes received        Date  \
# Index
# 1           Twitter Web App              14784           38052  2020-01-22
# 2        Twitter for iPhone              20671           77127  2020-01-22
# 3        Twitter for iPhone              18522           68211  2020-01-22
# 4                 TweetDeck               8290           25446  2020-01-22
# 5      Twitter Media Studio              10074           29761  2020-01-22
# ...                     ...                ...             ...         ...
# 3196     Twitter for iPhone              11569           37533  2019-10-05
# 3197     Twitter for iPhone               8302           34169  2019-10-05
# 3198     Twitter for iPhone              14957           45787  2019-10-05
# 3199     Twitter for iPhone              19134           57490  2019-10-05
# 3200     Twitter for iPhone              10061           40396  2019-10-05
#
#            Time Gender  Vocation
# Index
# 1      22:23:15   Male  Politics
# 2      22:13:16   Male  Politics
# 3      22:04:40   Male  Politics
# 4      22:00:01   Male  Politics
# 5      21:48:44   Male  Politics
# ...         ...    ...       ...
# 3196   03:24:27   Male  Politics
# 3197   03:24:18   Male  Politics
# 3198   03:22:45   Male  Politics
# 3199   03:12:08   Male  Politics
# 3200   02:58:05   Male  Politics
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
DTrump_Tweets_df.to_csv('DTrump_Tweets_df.csv')
