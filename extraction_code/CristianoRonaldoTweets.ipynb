# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Cristiano Ronaldo Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "CristianoRonaldoTweets.csv"

#Import the CSV into a pandas DataFrame
CRonaldo_Tweets_df = pd.read_csv(csv_path, low_memory = False)
CRonaldo_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1238497632345096192"
# 1     "1236956939403374592"
# 2     "1234915783949606917"
# 3     "1233495710621995014"
# 4     "1232351249409945604"
# ...                     ...
# 3195    "25288412198076416"
# 3196    "25284859744227328"
# 3197    "25250134770057216"
# 3198    "25114783095201792"
# 3199    "25112508507361280"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/cristiano/status/123849763...  2020-03-13 16:10:20
# 1     https://twitter.com/cristiano/status/123695693...  2020-03-09 10:08:10
# 2     https://twitter.com/cristiano/status/123491578...  2020-03-03 18:57:21
# 3     https://twitter.com/cristiano/status/123349571...  2020-02-28 20:54:29
# 4     https://twitter.com/cristiano/status/123235124...  2020-02-25 17:06:48
# ...                                                 ...                  ...
# 3195  https://twitter.com/cristiano/status/252884121...  2011-01-12 20:30:01
# ...

# %%
#Show the 'shape' of the dataframe 
shape = CRonaldo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
CRonaldo_Tweets_df = CRonaldo_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = CRonaldo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
CRonaldo_Tweets_df
# Out:
#        Username      User Id Tweet Type  \
# 0     cristiano  "155659213"      Tweet
# 1     cristiano  "155659213"      Tweet
# 2     cristiano  "155659213"      Tweet
# 3     cristiano  "155659213"      Tweet
# 4     cristiano  "155659213"      Tweet
# ...         ...          ...        ...
# 3195  cristiano  "155659213"      Tweet
# 3196  cristiano  "155659213"      Tweet
# 3197  cristiano  "155659213"      Tweet
# 3198  cristiano  "155659213"      Tweet
# 3199  cristiano  "155659213"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "For information: https://t.co/rbDpMTcs6s http...  Twitter for iPhone
# 1     "So proud to reach 1000 official games in my c...  Twitter for iPhone
# 2     "Thank you for all your messages of support fo...  Twitter for iPhone
# 3     "Stay focused on your goals 💪 https://t.co/UNu...  Twitter for iPhone
# 4     "Always on my mind... see you tomorrow 💪#UCL #...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
CRonaldo_Tweets_df = CRonaldo_Tweets_df.dropna() 

#Confirm rows are dropped
shape = CRonaldo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
CRonaldo_Tweets_df['Tweet Posted Time'] = CRonaldo_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = CRonaldo_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
CRonaldo_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
CRonaldo_Tweets_df['Tweet Posted Time'] = CRonaldo_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = CRonaldo_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
CRonaldo_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
CRonaldo_Tweets_df = CRonaldo_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = CRonaldo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
CRonaldo_Tweets_df
# Out:
#        Username      User Id Tweet Type  \
# 0     cristiano  "155659213"      Tweet
# 1     cristiano  "155659213"      Tweet
# 2     cristiano  "155659213"      Tweet
# 3     cristiano  "155659213"      Tweet
# 4     cristiano  "155659213"      Tweet
# ...         ...          ...        ...
# 3195  cristiano  "155659213"      Tweet
# 3196  cristiano  "155659213"      Tweet
# 3197  cristiano  "155659213"      Tweet
# 3198  cristiano  "155659213"      Tweet
# 3199  cristiano  "155659213"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "For information: https://t.co/rbDpMTcs6s http...  Twitter for iPhone
# 1     "So proud to reach 1000 official games in my c...  Twitter for iPhone
# 2     "Thank you for all your messages of support fo...  Twitter for iPhone
# 3     "Stay focused on your goals 💪 https://t.co/UNu...  Twitter for iPhone
# 4     "Always on my mind... see you tomorrow 💪#UCL #...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
CRonaldo_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
CRonaldo_Tweets_df['Vocation'] = "Sport"

#Show the 'shape' of the dataframe
shape = CRonaldo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
CRonaldo_Tweets_df.index = [x for x in range(1, len(CRonaldo_Tweets_df.values)+1)]
CRonaldo_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
CRonaldo_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# Index
# 1      cristiano  "155659213"      Tweet
# 2      cristiano  "155659213"      Tweet
# 3      cristiano  "155659213"      Tweet
# 4      cristiano  "155659213"      Tweet
# 5      cristiano  "155659213"      Tweet
# ...          ...          ...        ...
# 3196   cristiano  "155659213"      Tweet
# 3197   cristiano  "155659213"      Tweet
# 3198   cristiano  "155659213"      Tweet
# 3199   cristiano  "155659213"      Tweet
# 3200   cristiano  "155659213"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "For information: https://t.co/rbDpMTcs6s http...  Twitter for iPhone
# 2      "So proud to reach 1000 official games in my c...  Twitter for iPhone
# 3      "Thank you for all your messages of support fo...  Twitter for iPhone
# 4      "Stay focused on your goals 💪 https://t.co/UNu...  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
CRonaldo_Tweets_df.to_csv('CRonaldo_Tweets_df.csv')
