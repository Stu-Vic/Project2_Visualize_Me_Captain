# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # ESPN Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "ESPNTweets.csv"

#Import the CSV into a pandas DataFrame
ESPN_Tweets_df = pd.read_csv(csv_path, low_memory = False)
ESPN_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220229853557018625"
# 1     "1220226518712037376"
# 2     "1220214633442746369"
# 3     "1220212122849857538"
# 4     "1220208628751327232"
# ...                     ...
# 3195  "1179855234413129728"
# 3196  "1179829633606397952"
# 3197  "1179811085765021696"
# 3198  "1179806280694816768"
# 3199  "1179797401755901953"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/sportscenter/status/122022...  2020-01-23 06:20:42
# 1     https://twitter.com/espn/status/12202265187120...  2020-01-23 06:07:27
# 2     https://twitter.com/sportsnation/status/122021...  2020-01-23 05:20:13
# 3     https://twitter.com/espn/status/12202121228498...  2020-01-23 05:10:15
# 4     https://twitter.com/espn/status/12202086287513...  2020-01-23 04:56:22
# ...                                                 ...                  ...
# 3195  https://twitter.com/mcten/status/1179855234413...  2019-10-03 20:26:23
# ...

# %%
#Show the 'shape' of the dataframe 
shape = ESPN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
ESPN_Tweets_df = ESPN_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = ESPN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
ESPN_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0     sportscenter  "26257166"    Retweet
# 1             espn   "2557521"      Tweet
# 2     sportsnation  "21254264"    Retweet
# 3             espn   "2557521"      Tweet
# 4             espn   "2557521"      Tweet
# ...            ...         ...        ...
# 3195         mcten  "22494516"    Retweet
# 3196       espnnba  "74518740"    Retweet
# 3197          espn   "2557521"      Tweet
# 3198          espn   "2557521"      Tweet
# 3199  sportscenter  "26257166"    Retweet
#
#                                           Tweet Content              Client  \
# 0     "“Coach, I can win the game for this team. Lea...              Khoros
# 1     "Fans watching Zion go off in his first game 😮...              Khoros
# 2     "Zion Williamson: 1 career game, 4 three-point...              Khoros
# 3     "Zion put on a show in his NBA debut 🔥 https:/...              Khoros
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
ESPN_Tweets_df = ESPN_Tweets_df.dropna() 

#Confirm rows are dropped
shape = ESPN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
ESPN_Tweets_df['Tweet Posted Time'] = ESPN_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = ESPN_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
ESPN_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
ESPN_Tweets_df['Tweet Posted Time'] = ESPN_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = ESPN_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
ESPN_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
ESPN_Tweets_df = ESPN_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = ESPN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
ESPN_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0     sportscenter  "26257166"    Retweet
# 1             espn   "2557521"      Tweet
# 2     sportsnation  "21254264"    Retweet
# 3             espn   "2557521"      Tweet
# 4             espn   "2557521"      Tweet
# ...            ...         ...        ...
# 3195         mcten  "22494516"    Retweet
# 3196       espnnba  "74518740"    Retweet
# 3197          espn   "2557521"      Tweet
# 3198          espn   "2557521"      Tweet
# 3199  sportscenter  "26257166"    Retweet
#
#                                           Tweet Content              Client  \
# 0     "“Coach, I can win the game for this team. Lea...              Khoros
# 1     "Fans watching Zion go off in his first game 😮...              Khoros
# 2     "Zion Williamson: 1 career game, 4 three-point...              Khoros
# 3     "Zion put on a show in his NBA debut 🔥 https:/...              Khoros
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
ESPN_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
ESPN_Tweets_df['Vocation'] = "News/Media"

#Show the 'shape' of the dataframe
shape = ESPN_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
ESPN_Tweets_df.index = [x for x in range(1, len(ESPN_Tweets_df.values)+1)]
ESPN_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
ESPN_Tweets_df
# Out:
#            Username     User Id Tweet Type  \
# Index
# 1      sportscenter  "26257166"    Retweet
# 2              espn   "2557521"      Tweet
# 3      sportsnation  "21254264"    Retweet
# 4              espn   "2557521"      Tweet
# 5              espn   "2557521"      Tweet
# ...             ...         ...        ...
# 3196          mcten  "22494516"    Retweet
# 3197        espnnba  "74518740"    Retweet
# 3198           espn   "2557521"      Tweet
# 3199           espn   "2557521"      Tweet
# 3200   sportscenter  "26257166"    Retweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "“Coach, I can win the game for this team. Lea...              Khoros
# 2      "Fans watching Zion go off in his first game 😮...              Khoros
# 3      "Zion Williamson: 1 career game, 4 three-point...              Khoros
# 4      "Zion put on a show in his NBA debut 🔥 https:/...              Khoros
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
ESPN_Tweets_df.to_csv('ESPN_Tweets_df.csv')
