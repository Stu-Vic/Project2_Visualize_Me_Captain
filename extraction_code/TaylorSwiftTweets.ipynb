# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Taylor Swift Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "TaylorSwiftTweets.csv"

#Import the CSV into a pandas DataFrame
TSwift_Tweets_df = pd.read_csv(csv_path, low_memory = False)
TSwift_Tweets_df
# Out:
#                   Tweet Id                                          Tweet URL  \
# 0    "1239670332958674944"  https://twitter.com/taylorswift13/status/12396...
# 1    "1237360590110294016"  https://twitter.com/taylorswift13/status/12373...
# 2    "1236339640656973825"  https://twitter.com/taylorswift13/status/12363...
# 3    "1235917883726852098"  https://twitter.com/taylorswift13/status/12359...
# 4    "1234937694121287684"  https://twitter.com/taylorswift13/status/12349...
# ..                     ...                                                ...
# 428   "900923703424413696"  https://twitter.com/taylorswift13/status/90092...
# 429   "900399489126629377"  https://twitter.com/taylorswift13/status/90039...
# 430   "900357555289034752"  https://twitter.com/taylorswift13/status/90035...
# 431   "900010249163112450"  https://twitter.com/taylorswift13/status/90001...
# 432   "899647503859032065"  https://twitter.com/taylorswift13/status/89964...
#
#        Tweet Posted Time                                      Tweet Content  \
# 0    2020-03-16 21:50:13  "For Meredith, self quarantining is a way of l...
# 1    2020-03-10 12:52:08  "No one:\n\nAbsolutely no one:\n\nMe: here’s m...
# 2    2020-03-07 17:15:15  "In honor of International Women’s Day, I chan...
# 3    2020-03-06 13:19:20  "The Man Behind The Scenes - Becoming The Man ...
# 4    2020-03-03 20:24:24  "My heart is with everyone in Tennessee who ha...
# ..                   ...                                                ...
# 428  2017-08-25 03:32:03  "New single #LookWhatYouMadeMeDo out now. Pre-...
# 429  2017-08-23 16:49:01                          "https://t.co/xMBBukfZPs"
# 430  2017-08-23 14:02:23                          "https://t.co/xqhhDZ0y7c"
# 431  2017-08-22 15:02:19                          "https://t.co/12Rfi8bso4"
# 432  2017-08-21 15:00:54                          "https://t.co/p2DyY0e2M3"
#
#     Tweet Type              Client  Retweets received  Likes received  \
# 0        Tweet  Twitter for iPhone              27242          142398
# 1        Tweet  Twitter for iPhone              17683          123611
# 2        Tweet  Twitter for iPhone              13064           85267
# 3        Tweet  Twitter for iPhone              11086           69057
# 4        Tweet  Twitter for iPhone              14762          152138
# ..         ...                 ...                ...             ...
# 428      Tweet  Twitter for iPhone              64327          165550
# 429      Tweet  Twitter for iPhone             155106          375755
# 430      Tweet  Twitter for iPhone              53426          172596
# 431      Tweet  Twitter for iPhone              48701          157628
# 432      Tweet  Twitter for iPhone              72530          210733
#
#         User Id            Name       Username Verified or Non-Verified  \
# 0    "17919972"  "Taylor Swift"  taylorswift13                 Verified
# 1    "17919972"  "Taylor Swift"  taylorswift13                 Verified
# 2    "17919972"  "Taylor Swift"  taylorswift13                 Verified
# 3    "17919972"  "Taylor Swift"  taylorswift13                 Verified
# 4    "17919972"  "Taylor Swift"  taylorswift13                 Verified
# ..          ...             ...            ...                      ...
# 428  "17919972"  "Taylor Swift"  taylorswift13                 Verified
# 429  "17919972"  "Taylor Swift"  taylorswift13                 Verified
# 430  "17919972"  "Taylor Swift"  taylorswift13                 Verified
# 431  "17919972"  "Taylor Swift"  taylorswift13                 Verified
# 432  "17919972"  "Taylor Swift"  taylorswift13                 Verified
#
#                            Profile URL Protected or Not Protected
# 0    https://twitter.com/taylorswift13              Not Protected
# 1    https://twitter.com/taylorswift13              Not Protected
# 2    https://twitter.com/taylorswift13              Not Protected
# 3    https://twitter.com/taylorswift13              Not Protected
# 4    https://twitter.com/taylorswift13              Not Protected
# ..                                 ...                        ...
# 428  https://twitter.com/taylorswift13              Not Protected
# 429  https://twitter.com/taylorswift13              Not Protected
# 430  https://twitter.com/taylorswift13              Not Protected
# 431  https://twitter.com/taylorswift13              Not Protected
# 432  https://twitter.com/taylorswift13              Not Protected
#
# [433 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = TSwift_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (433, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
TSwift_Tweets_df = TSwift_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = TSwift_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (433, 8)

# %%
#Print the dataframe
TSwift_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0    taylorswift13  "17919972"      Tweet
# 1    taylorswift13  "17919972"      Tweet
# 2    taylorswift13  "17919972"      Tweet
# 3    taylorswift13  "17919972"      Tweet
# 4    taylorswift13  "17919972"      Tweet
# ..             ...         ...        ...
# 428  taylorswift13  "17919972"      Tweet
# 429  taylorswift13  "17919972"      Tweet
# 430  taylorswift13  "17919972"      Tweet
# 431  taylorswift13  "17919972"      Tweet
# 432  taylorswift13  "17919972"      Tweet
#
#                                          Tweet Content              Client  \
# 0    "For Meredith, self quarantining is a way of l...  Twitter for iPhone
# 1    "No one:\n\nAbsolutely no one:\n\nMe: here’s m...  Twitter for iPhone
# 2    "In honor of International Women’s Day, I chan...  Twitter for iPhone
# 3    "The Man Behind The Scenes - Becoming The Man ...  Twitter for iPhone
# 4    "My heart is with everyone in Tennessee who ha...  Twitter for iPhone
# ..                                                 ...                 ...
# 428  "New single #LookWhatYouMadeMeDo out now. Pre-...  Twitter for iPhone
# 429                          "https://t.co/xMBBukfZPs"  Twitter for iPhone
# 430                          "https://t.co/xqhhDZ0y7c"  Twitter for iPhone
# 431                          "https://t.co/12Rfi8bso4"  Twitter for iPhone
# 432                          "https://t.co/p2DyY0e2M3"  Twitter for iPhone
#
#      Retweets received  Likes received    Tweet Posted Time
# 0                27242          142398  2020-03-16 21:50:13
# 1                17683          123611  2020-03-10 12:52:08
# 2                13064           85267  2020-03-07 17:15:15
# 3                11086           69057  2020-03-06 13:19:20
# 4                14762          152138  2020-03-03 20:24:24
# ..                 ...             ...                  ...
# 428              64327          165550  2017-08-25 03:32:03
# 429             155106          375755  2017-08-23 16:49:01
# 430              53426          172596  2017-08-23 14:02:23
# 431              48701          157628  2017-08-22 15:02:19
# 432              72530          210733  2017-08-21 15:00:54
#
# [433 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
TSwift_Tweets_df = TSwift_Tweets_df.dropna() 

#Confirm rows are dropped
shape = TSwift_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (433, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
TSwift_Tweets_df['Tweet Posted Time'] = TSwift_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = TSwift_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
TSwift_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
TSwift_Tweets_df['Tweet Posted Time'] = TSwift_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = TSwift_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
TSwift_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
TSwift_Tweets_df = TSwift_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = TSwift_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (433, 9)

# %%
#Print the dataframe
TSwift_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0    taylorswift13  "17919972"      Tweet
# 1    taylorswift13  "17919972"      Tweet
# 2    taylorswift13  "17919972"      Tweet
# 3    taylorswift13  "17919972"      Tweet
# 4    taylorswift13  "17919972"      Tweet
# ..             ...         ...        ...
# 428  taylorswift13  "17919972"      Tweet
# 429  taylorswift13  "17919972"      Tweet
# 430  taylorswift13  "17919972"      Tweet
# 431  taylorswift13  "17919972"      Tweet
# 432  taylorswift13  "17919972"      Tweet
#
#                                          Tweet Content              Client  \
# 0    "For Meredith, self quarantining is a way of l...  Twitter for iPhone
# 1    "No one:\n\nAbsolutely no one:\n\nMe: here’s m...  Twitter for iPhone
# 2    "In honor of International Women’s Day, I chan...  Twitter for iPhone
# 3    "The Man Behind The Scenes - Becoming The Man ...  Twitter for iPhone
# 4    "My heart is with everyone in Tennessee who ha...  Twitter for iPhone
# ..                                                 ...                 ...
# 428  "New single #LookWhatYouMadeMeDo out now. Pre-...  Twitter for iPhone
# 429                          "https://t.co/xMBBukfZPs"  Twitter for iPhone
# 430                          "https://t.co/xqhhDZ0y7c"  Twitter for iPhone
# 431                          "https://t.co/12Rfi8bso4"  Twitter for iPhone
# 432                          "https://t.co/p2DyY0e2M3"  Twitter for iPhone
#
#      Retweets received  Likes received        Date      Time
# 0                27242          142398  2020-03-16  21:50:13
# 1                17683          123611  2020-03-10  12:52:08
# 2                13064           85267  2020-03-07  17:15:15
# 3                11086           69057  2020-03-06  13:19:20
# 4                14762          152138  2020-03-03  20:24:24
# ..                 ...             ...         ...       ...
# 428              64327          165550  2017-08-25  03:32:03
# 429             155106          375755  2017-08-23  16:49:01
# 430              53426          172596  2017-08-23  14:02:23
# 431              48701          157628  2017-08-22  15:02:19
# 432              72530          210733  2017-08-21  15:00:54
#
# [433 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
TSwift_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
TSwift_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = TSwift_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (433, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
TSwift_Tweets_df.index = [x for x in range(1, len(TSwift_Tweets_df.values)+1)]
TSwift_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
TSwift_Tweets_df
# Out:
#             Username     User Id Tweet Type  \
# Index
# 1      taylorswift13  "17919972"      Tweet
# 2      taylorswift13  "17919972"      Tweet
# 3      taylorswift13  "17919972"      Tweet
# 4      taylorswift13  "17919972"      Tweet
# 5      taylorswift13  "17919972"      Tweet
# ...              ...         ...        ...
# 429    taylorswift13  "17919972"      Tweet
# 430    taylorswift13  "17919972"      Tweet
# 431    taylorswift13  "17919972"      Tweet
# 432    taylorswift13  "17919972"      Tweet
# 433    taylorswift13  "17919972"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "For Meredith, self quarantining is a way of l...  Twitter for iPhone
# 2      "No one:\n\nAbsolutely no one:\n\nMe: here’s m...  Twitter for iPhone
# 3      "In honor of International Women’s Day, I chan...  Twitter for iPhone
# 4      "The Man Behind The Scenes - Becoming The Man ...  Twitter for iPhone
# 5      "My heart is with everyone in Tennessee who ha...  Twitter for iPhone
# ...                                                  ...                 ...
# 429    "New single #LookWhatYouMadeMeDo out now. Pre-...  Twitter for iPhone
# 430                            "https://t.co/xMBBukfZPs"  Twitter for iPhone
# 431                            "https://t.co/xqhhDZ0y7c"  Twitter for iPhone
# 432                            "https://t.co/12Rfi8bso4"  Twitter for iPhone
# 433                            "https://t.co/p2DyY0e2M3"  Twitter for iPhone
#
#        Retweets received  Likes received        Date      Time  Gender  \
# Index
# 1                  27242          142398  2020-03-16  21:50:13  Female
# 2                  17683          123611  2020-03-10  12:52:08  Female
# 3                  13064           85267  2020-03-07  17:15:15  Female
# 4                  11086           69057  2020-03-06  13:19:20  Female
# 5                  14762          152138  2020-03-03  20:24:24  Female
# ...                  ...             ...         ...       ...     ...
# 429                64327          165550  2017-08-25  03:32:03  Female
# 430               155106          375755  2017-08-23  16:49:01  Female
# 431                53426          172596  2017-08-23  14:02:23  Female
# 432                48701          157628  2017-08-22  15:02:19  Female
# 433                72530          210733  2017-08-21  15:00:54  Female
#
#       Vocation
# Index
# 1        Music
# 2        Music
# 3        Music
# 4        Music
# 5        Music
# ...        ...
# 429      Music
# 430      Music
# 431      Music
# 432      Music
# 433      Music
#
# [433 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
TSwift_Tweets_df.to_csv('TSwift_Tweets_df.csv')
