# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Bruno Mars Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "BrunoMarsTweets.csv"

#Import the CSV into a pandas DataFrame
BMars_Tweets_df = pd.read_csv(csv_path, low_memory = False)
BMars_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219387020939685890"
# 1     "1219384974631030785"
# 2     "1218996607317753856"
# 3     "1218996210167513088"
# 4     "1218989063706828800"
# ...                     ...
# 3191   "144908780830851072"
# 3192   "144907084541071360"
# 3193   "144906944249995264"
# 3194   "144905630002581504"
# 3195   "144903492132274176"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/brunomars/status/121938702...  2020-01-20 22:31:35
# 1     https://twitter.com/brunomars/status/121938497...  2020-01-20 22:23:27
# 2     https://twitter.com/brunomars/status/121899660...  2020-01-19 20:40:13
# 3     https://twitter.com/brunomars/status/121899621...  2020-01-19 20:38:39
# 4     https://twitter.com/brunomars/status/121898906...  2020-01-19 20:10:15
# ...                                                 ...                  ...
# 3191  https://twitter.com/brunomars/status/144908780...  2011-12-08 22:38:40
# 3192  https://twitter.com/brunomars/status/144907084...  2011-12-08 22:31:55
# 3193  https://twitter.com/brunomars/status/144906944...  2011-12-08 22:31:22
# 3194  https://twitter.com/brunomars/status/144905630...  2011-12-08 22:26:09
# 3195  https://twitter.com/brunomars/status/144903492...  2011-12-08 22:17:39
#
#                                           Tweet Content Tweet Type  \
# 0     "Wanted to wish everyone a Happy Martin Luther...      Tweet
# 1                        "Nah! https://t.co/a01vjusZOJ"      Tweet
# 2                  "We must. 🥂 https://t.co/2jNeKORa2o"      Tweet
# 3              "😢 I miss this. https://t.co/3mKj6wVsTl"      Tweet
# 4     "Here’s a little more sunshine for your Sunday...      Tweet
# ...                                                 ...        ...
# 3191  "To be honest the changes aren't that bad.. Ma...      Tweet
# 3192  "Im so mad I just drank all the water in my po...      Tweet
# 3193  "Im so mad I just threw my car over the mounta...      Tweet
# 3194  "Dear twitter this could very well be the wors...      Tweet
# 3195  "Dear Twitter, what are all these changes? Now...      Tweet
#
#                   Client  Retweets received  Likes received      User Id  \
# 0     Twitter for iPhone                461            4890  "100220864"
# 1     Twitter for iPhone                317            3984  "100220864"
# 2     Twitter for iPhone                556            5645  "100220864"
# 3     Twitter for iPhone               5406           36558  "100220864"
# 4     Twitter for iPhone                625            4055  "100220864"
# ...                  ...                ...             ...          ...
# 3191  Twitter Web Client               2232             871  "100220864"
# 3192  Twitter Web Client               1916             722  "100220864"
# 3193  Twitter Web Client               1974             801  "100220864"
# 3194  Twitter Web Client               2098             768  "100220864"
# 3195  Twitter Web Client               4364            1382  "100220864"
#
#               Name   Username Verified or Non-Verified  \
# 0     "Bruno Mars"  brunomars                 Verified
# 1     "Bruno Mars"  brunomars                 Verified
# 2     "Bruno Mars"  brunomars                 Verified
# 3     "Bruno Mars"  brunomars                 Verified
# 4     "Bruno Mars"  brunomars                 Verified
# ...            ...        ...                      ...
# 3191  "Bruno Mars"  brunomars                 Verified
# 3192  "Bruno Mars"  brunomars                 Verified
# 3193  "Bruno Mars"  brunomars                 Verified
# 3194  "Bruno Mars"  brunomars                 Verified
# 3195  "Bruno Mars"  brunomars                 Verified
#
#                         Profile URL Protected or Not Protected
# 0     https://twitter.com/brunomars              Not Protected
# 1     https://twitter.com/brunomars              Not Protected
# 2     https://twitter.com/brunomars              Not Protected
# 3     https://twitter.com/brunomars              Not Protected
# 4     https://twitter.com/brunomars              Not Protected
# ...                             ...                        ...
# 3191  https://twitter.com/brunomars              Not Protected
# 3192  https://twitter.com/brunomars              Not Protected
# 3193  https://twitter.com/brunomars              Not Protected
# 3194  https://twitter.com/brunomars              Not Protected
# 3195  https://twitter.com/brunomars              Not Protected
#
# [3196 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = BMars_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3196, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
BMars_Tweets_df = BMars_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = BMars_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3196, 8)

# %%
#Print the dataframe
BMars_Tweets_df
# Out:
#        Username      User Id Tweet Type  \
# 0     brunomars  "100220864"      Tweet
# 1     brunomars  "100220864"      Tweet
# 2     brunomars  "100220864"      Tweet
# 3     brunomars  "100220864"      Tweet
# 4     brunomars  "100220864"      Tweet
# ...         ...          ...        ...
# 3191  brunomars  "100220864"      Tweet
# 3192  brunomars  "100220864"      Tweet
# 3193  brunomars  "100220864"      Tweet
# 3194  brunomars  "100220864"      Tweet
# 3195  brunomars  "100220864"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "Wanted to wish everyone a Happy Martin Luther...  Twitter for iPhone
# 1                        "Nah! https://t.co/a01vjusZOJ"  Twitter for iPhone
# 2                  "We must. 🥂 https://t.co/2jNeKORa2o"  Twitter for iPhone
# 3              "😢 I miss this. https://t.co/3mKj6wVsTl"  Twitter for iPhone
# 4     "Here’s a little more sunshine for your Sunday...  Twitter for iPhone
# ...                                                 ...                 ...
# 3191  "To be honest the changes aren't that bad.. Ma...  Twitter Web Client
# 3192  "Im so mad I just drank all the water in my po...  Twitter Web Client
# 3193  "Im so mad I just threw my car over the mounta...  Twitter Web Client
# 3194  "Dear twitter this could very well be the wors...  Twitter Web Client
# 3195  "Dear Twitter, what are all these changes? Now...  Twitter Web Client
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                   461            4890  2020-01-20 22:31:35
# 1                   317            3984  2020-01-20 22:23:27
# 2                   556            5645  2020-01-19 20:40:13
# 3                  5406           36558  2020-01-19 20:38:39
# 4                   625            4055  2020-01-19 20:10:15
# ...                 ...             ...                  ...
# 3191               2232             871  2011-12-08 22:38:40
# 3192               1916             722  2011-12-08 22:31:55
# 3193               1974             801  2011-12-08 22:31:22
# 3194               2098             768  2011-12-08 22:26:09
# 3195               4364            1382  2011-12-08 22:17:39
#
# [3196 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
BMars_Tweets_df = BMars_Tweets_df.dropna() 

#Confirm rows are dropped
shape = BMars_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3196, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BMars_Tweets_df['Tweet Posted Time'] = BMars_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BMars_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
BMars_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BMars_Tweets_df['Tweet Posted Time'] = BMars_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BMars_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
BMars_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
BMars_Tweets_df = BMars_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = BMars_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3196, 9)

# %%
#Print the dataframe
BMars_Tweets_df
# Out:
#        Username      User Id Tweet Type  \
# 0     brunomars  "100220864"      Tweet
# 1     brunomars  "100220864"      Tweet
# 2     brunomars  "100220864"      Tweet
# 3     brunomars  "100220864"      Tweet
# 4     brunomars  "100220864"      Tweet
# ...         ...          ...        ...
# 3191  brunomars  "100220864"      Tweet
# 3192  brunomars  "100220864"      Tweet
# 3193  brunomars  "100220864"      Tweet
# 3194  brunomars  "100220864"      Tweet
# 3195  brunomars  "100220864"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "Wanted to wish everyone a Happy Martin Luther...  Twitter for iPhone
# 1                        "Nah! https://t.co/a01vjusZOJ"  Twitter for iPhone
# 2                  "We must. 🥂 https://t.co/2jNeKORa2o"  Twitter for iPhone
# 3              "😢 I miss this. https://t.co/3mKj6wVsTl"  Twitter for iPhone
# 4     "Here’s a little more sunshine for your Sunday...  Twitter for iPhone
# ...                                                 ...                 ...
# 3191  "To be honest the changes aren't that bad.. Ma...  Twitter Web Client
# 3192  "Im so mad I just drank all the water in my po...  Twitter Web Client
# 3193  "Im so mad I just threw my car over the mounta...  Twitter Web Client
# 3194  "Dear twitter this could very well be the wors...  Twitter Web Client
# 3195  "Dear Twitter, what are all these changes? Now...  Twitter Web Client
#
#       Retweets received  Likes received        Date      Time
# 0                   461            4890  2020-01-20  22:31:35
# 1                   317            3984  2020-01-20  22:23:27
# 2                   556            5645  2020-01-19  20:40:13
# 3                  5406           36558  2020-01-19  20:38:39
# 4                   625            4055  2020-01-19  20:10:15
# ...                 ...             ...         ...       ...
# 3191               2232             871  2011-12-08  22:38:40
# 3192               1916             722  2011-12-08  22:31:55
# 3193               1974             801  2011-12-08  22:31:22
# 3194               2098             768  2011-12-08  22:26:09
# 3195               4364            1382  2011-12-08  22:17:39
#
# [3196 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
BMars_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
BMars_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = BMars_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3196, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
BMars_Tweets_df.index = [x for x in range(1, len(BMars_Tweets_df.values)+1)]
BMars_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
BMars_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# Index
# 1      brunomars  "100220864"      Tweet
# 2      brunomars  "100220864"      Tweet
# 3      brunomars  "100220864"      Tweet
# 4      brunomars  "100220864"      Tweet
# 5      brunomars  "100220864"      Tweet
# ...          ...          ...        ...
# 3192   brunomars  "100220864"      Tweet
# 3193   brunomars  "100220864"      Tweet
# 3194   brunomars  "100220864"      Tweet
# 3195   brunomars  "100220864"      Tweet
# 3196   brunomars  "100220864"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "Wanted to wish everyone a Happy Martin Luther...  Twitter for iPhone
# 2                         "Nah! https://t.co/a01vjusZOJ"  Twitter for iPhone
# 3                   "We must. 🥂 https://t.co/2jNeKORa2o"  Twitter for iPhone
# 4               "😢 I miss this. https://t.co/3mKj6wVsTl"  Twitter for iPhone
# 5      "Here’s a little more sunshine for your Sunday...  Twitter for iPhone
# ...                                                  ...                 ...
# 3192   "To be honest the changes aren't that bad.. Ma...  Twitter Web Client
# 3193   "Im so mad I just drank all the water in my po...  Twitter Web Client
# 3194   "Im so mad I just threw my car over the mounta...  Twitter Web Client
# 3195   "Dear twitter this could very well be the wors...  Twitter Web Client
# 3196   "Dear Twitter, what are all these changes? Now...  Twitter Web Client
#
#        Retweets received  Likes received        Date      Time Gender Vocation
# Index
# 1                    461            4890  2020-01-20  22:31:35   Male    Music
# 2                    317            3984  2020-01-20  22:23:27   Male    Music
# 3                    556            5645  2020-01-19  20:40:13   Male    Music
# 4                   5406           36558  2020-01-19  20:38:39   Male    Music
# 5                    625            4055  2020-01-19  20:10:15   Male    Music
# ...                  ...             ...         ...       ...    ...      ...
# 3192                2232             871  2011-12-08  22:38:40   Male    Music
# 3193                1916             722  2011-12-08  22:31:55   Male    Music
# 3194                1974             801  2011-12-08  22:31:22   Male    Music
# 3195                2098             768  2011-12-08  22:26:09   Male    Music
# 3196                4364            1382  2011-12-08  22:17:39   Male    Music
#
# [3196 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
BMars_Tweets_df.to_csv('BMars_Tweets_df.csv')
