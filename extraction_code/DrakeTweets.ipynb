# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Drake Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "DrakeTweets.csv"

#Import the CSV into a pandas DataFrame
Drake_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Drake_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1209346505959780352"
# 1     "1207898659553267712"
# 2     "1202701945359732737"
# 3     "1197922689723314181"
# 4     "1197746382347608064"
# ...                     ...
# 1743           "1409312886"
# 1744           "1409308328"
# 1745           "1409305026"
# 1746           "1406109879"
# 1747           "1405978002"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/ovosound/status/1209346505...  2019-12-24 05:34:10
# 1     https://twitter.com/popcaanmusic/status/120789...  2019-12-20 05:40:56
# 2     https://twitter.com/cargojetairways/status/120...  2019-12-05 21:31:03
# 3     https://twitter.com/showtime/status/1197922689...  2019-11-22 17:00:00
# 4     https://twitter.com/partynextdoor/status/11977...  2019-11-22 05:19:25
# ...                                                 ...                  ...
# 1743        https://twitter.com/drake/status/1409312886  2009-03-28 22:57:51
# 1744        https://twitter.com/drake/status/1409308328  2009-03-28 22:56:51
# 1745        https://twitter.com/drake/status/1409305026  2009-03-28 22:56:07
# 1746        https://twitter.com/drake/status/1406109879  2009-03-28 08:21:10
# 1747        https://twitter.com/drake/status/1405978002  2009-03-28 07:18:19
#
#                                           Tweet Content Tweet Type  \
# 0       "Drake “War” (Video) \nhttps://t.co/taDWx4vY6p"    Retweet
# 1     "We going live right now #VANQUISH out now #87...    Retweet
# 2     "A night of Champions celebrating Champions. O...    Retweet
# 3     "Skills are being put to the test on and off t...    Retweet
# 4     "Loyal feat. @Drake out now https://t.co/aGmBC...    Retweet
# ...                                                 ...        ...
# 1743           "@jheneaiko Vowed to never get involved"      Reply
# 1744  "@mackmaine Ya'll bus slow...I'm already in th...      Reply
# 1745  "@DaRealAngelLola In Vegas...waiting on that t...      Reply
# 1746  "HA this shit wild...it rivals the day I learn...      Tweet
# 1747                               "Fine...you got me."      Tweet
#
#                     Client  Retweets received  Likes received       User Id  \
# 0       Twitter for iPhone              12100           33456  "2675359291"
# 1          Twitter Web App               1002            4855   "151588971"
# 2       Twitter for iPhone                502            5214  "3327313925"
# 3     Twitter Media Studio                563            2654   "257548783"
# 4       Twitter for iPhone              20386           58055  "1346180581"
# ...                    ...                ...             ...           ...
# 1743    Twitter Web Client                 91             105    "27195114"
# 1744    Twitter Web Client                 12              32    "27195114"
# 1745    Twitter Web Client                 11              27    "27195114"
# 1746    Twitter Web Client                453             848    "27195114"
# 1747    Twitter Web Client              25633           25274    "27195114"
#
#                  Name         Username Verified or Non-Verified  \
# 0         "OVO Sound"         ovosound                 Verified
# 1           "Popcaan"     popcaanmusic                 Verified
# 2          "CargoJet"  cargojetairways             Non-Verified
# 3          "Showtime"         showtime                 Verified
# 4     "PARTYNEXTDOOR"    partynextdoor                 Verified
# ...               ...              ...                      ...
# 1743         "Drizzy"            drake                 Verified
# 1744         "Drizzy"            drake                 Verified
# 1745         "Drizzy"            drake                 Verified
# 1746         "Drizzy"            drake                 Verified
# 1747         "Drizzy"            drake                 Verified
#
#                               Profile URL Protected or Not Protected
# 0            https://twitter.com/ovosound              Not Protected
# 1        https://twitter.com/popcaanmusic              Not Protected
# 2     https://twitter.com/cargojetairways              Not Protected
# 3            https://twitter.com/showtime              Not Protected
# 4       https://twitter.com/partynextdoor              Not Protected
# ...                                   ...                        ...
# 1743            https://twitter.com/drake              Not Protected
# 1744            https://twitter.com/drake              Not Protected
# 1745            https://twitter.com/drake              Not Protected
# 1746            https://twitter.com/drake              Not Protected
# 1747            https://twitter.com/drake              Not Protected
#
# [1748 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = Drake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1748, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Drake_Tweets_df = Drake_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Drake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1748, 8)

# %%
#Print the dataframe
Drake_Tweets_df
# Out:
#              Username       User Id Tweet Type  \
# 0            ovosound  "2675359291"    Retweet
# 1        popcaanmusic   "151588971"    Retweet
# 2     cargojetairways  "3327313925"    Retweet
# 3            showtime   "257548783"    Retweet
# 4       partynextdoor  "1346180581"    Retweet
# ...               ...           ...        ...
# 1743            drake    "27195114"      Reply
# 1744            drake    "27195114"      Reply
# 1745            drake    "27195114"      Reply
# 1746            drake    "27195114"      Tweet
# 1747            drake    "27195114"      Tweet
#
#                                           Tweet Content                Client  \
# 0       "Drake “War” (Video) \nhttps://t.co/taDWx4vY6p"    Twitter for iPhone
# 1     "We going live right now #VANQUISH out now #87...       Twitter Web App
# 2     "A night of Champions celebrating Champions. O...    Twitter for iPhone
# 3     "Skills are being put to the test on and off t...  Twitter Media Studio
# 4     "Loyal feat. @Drake out now https://t.co/aGmBC...    Twitter for iPhone
# ...                                                 ...                   ...
# 1743           "@jheneaiko Vowed to never get involved"    Twitter Web Client
# 1744  "@mackmaine Ya'll bus slow...I'm already in th...    Twitter Web Client
# 1745  "@DaRealAngelLola In Vegas...waiting on that t...    Twitter Web Client
# 1746  "HA this shit wild...it rivals the day I learn...    Twitter Web Client
# 1747                               "Fine...you got me."    Twitter Web Client
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                 12100           33456  2019-12-24 05:34:10
# 1                  1002            4855  2019-12-20 05:40:56
# 2                   502            5214  2019-12-05 21:31:03
# 3                   563            2654  2019-11-22 17:00:00
# 4                 20386           58055  2019-11-22 05:19:25
# ...                 ...             ...                  ...
# 1743                 91             105  2009-03-28 22:57:51
# 1744                 12              32  2009-03-28 22:56:51
# 1745                 11              27  2009-03-28 22:56:07
# 1746                453             848  2009-03-28 08:21:10
# 1747              25633           25274  2009-03-28 07:18:19
#
# [1748 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Drake_Tweets_df = Drake_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Drake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1748, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Drake_Tweets_df['Tweet Posted Time'] = Drake_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Drake_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Drake_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Drake_Tweets_df['Tweet Posted Time'] = Drake_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Drake_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Drake_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Drake_Tweets_df = Drake_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Drake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1748, 9)

# %%
#Print the dataframe
Drake_Tweets_df
# Out:
#              Username       User Id Tweet Type  \
# 0            ovosound  "2675359291"    Retweet
# 1        popcaanmusic   "151588971"    Retweet
# 2     cargojetairways  "3327313925"    Retweet
# 3            showtime   "257548783"    Retweet
# 4       partynextdoor  "1346180581"    Retweet
# ...               ...           ...        ...
# 1743            drake    "27195114"      Reply
# 1744            drake    "27195114"      Reply
# 1745            drake    "27195114"      Reply
# 1746            drake    "27195114"      Tweet
# 1747            drake    "27195114"      Tweet
#
#                                           Tweet Content                Client  \
# 0       "Drake “War” (Video) \nhttps://t.co/taDWx4vY6p"    Twitter for iPhone
# 1     "We going live right now #VANQUISH out now #87...       Twitter Web App
# 2     "A night of Champions celebrating Champions. O...    Twitter for iPhone
# 3     "Skills are being put to the test on and off t...  Twitter Media Studio
# 4     "Loyal feat. @Drake out now https://t.co/aGmBC...    Twitter for iPhone
# ...                                                 ...                   ...
# 1743           "@jheneaiko Vowed to never get involved"    Twitter Web Client
# 1744  "@mackmaine Ya'll bus slow...I'm already in th...    Twitter Web Client
# 1745  "@DaRealAngelLola In Vegas...waiting on that t...    Twitter Web Client
# 1746  "HA this shit wild...it rivals the day I learn...    Twitter Web Client
# 1747                               "Fine...you got me."    Twitter Web Client
#
#       Retweets received  Likes received        Date      Time
# 0                 12100           33456  2019-12-24  05:34:10
# 1                  1002            4855  2019-12-20  05:40:56
# 2                   502            5214  2019-12-05  21:31:03
# 3                   563            2654  2019-11-22  17:00:00
# 4                 20386           58055  2019-11-22  05:19:25
# ...                 ...             ...         ...       ...
# 1743                 91             105  2009-03-28  22:57:51
# 1744                 12              32  2009-03-28  22:56:51
# 1745                 11              27  2009-03-28  22:56:07
# 1746                453             848  2009-03-28  08:21:10
# 1747              25633           25274  2009-03-28  07:18:19
#
# [1748 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Drake_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
Drake_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = Drake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (1748, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Drake_Tweets_df.index = [x for x in range(1, len(Drake_Tweets_df.values)+1)]
Drake_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Drake_Tweets_df
# Out:
#               Username       User Id Tweet Type  \
# Index
# 1             ovosound  "2675359291"    Retweet
# 2         popcaanmusic   "151588971"    Retweet
# 3      cargojetairways  "3327313925"    Retweet
# 4             showtime   "257548783"    Retweet
# 5        partynextdoor  "1346180581"    Retweet
# ...                ...           ...        ...
# 1744             drake    "27195114"      Reply
# 1745             drake    "27195114"      Reply
# 1746             drake    "27195114"      Reply
# 1747             drake    "27195114"      Tweet
# 1748             drake    "27195114"      Tweet
#
#                                            Tweet Content  \
# Index
# 1        "Drake “War” (Video) \nhttps://t.co/taDWx4vY6p"
# 2      "We going live right now #VANQUISH out now #87...
# 3      "A night of Champions celebrating Champions. O...
# 4      "Skills are being put to the test on and off t...
# 5      "Loyal feat. @Drake out now https://t.co/aGmBC...
# ...                                                  ...
# 1744            "@jheneaiko Vowed to never get involved"
# 1745   "@mackmaine Ya'll bus slow...I'm already in th...
# 1746   "@DaRealAngelLola In Vegas...waiting on that t...
# 1747   "HA this shit wild...it rivals the day I learn...
# 1748                                "Fine...you got me."
#
#                      Client  Retweets received  Likes received        Date  \
# Index
# 1        Twitter for iPhone              12100           33456  2019-12-24
# 2           Twitter Web App               1002            4855  2019-12-20
# 3        Twitter for iPhone                502            5214  2019-12-05
# 4      Twitter Media Studio                563            2654  2019-11-22
# 5        Twitter for iPhone              20386           58055  2019-11-22
# ...                     ...                ...             ...         ...
# 1744     Twitter Web Client                 91             105  2009-03-28
# 1745     Twitter Web Client                 12              32  2009-03-28
# 1746     Twitter Web Client                 11              27  2009-03-28
# 1747     Twitter Web Client                453             848  2009-03-28
# 1748     Twitter Web Client              25633           25274  2009-03-28
#
#            Time Gender Vocation
# Index
# 1      05:34:10   Male    Music
# 2      05:40:56   Male    Music
# 3      21:31:03   Male    Music
# 4      17:00:00   Male    Music
# 5      05:19:25   Male    Music
# ...         ...    ...      ...
# 1744   22:57:51   Male    Music
# 1745   22:56:51   Male    Music
# 1746   22:56:07   Male    Music
# 1747   08:21:10   Male    Music
# 1748   07:18:19   Male    Music
#
# [1748 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Drake_Tweets_df.to_csv('Drake_Tweets_df.csv')
