# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Jennifer Lopez Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "JLoTweets.csv"

#Import the CSV into a pandas DataFrame
JLo_Tweets_df = pd.read_csv(csv_path, low_memory = False)
JLo_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220114257200787461"
# 1     "1220039004961284096"
# 2     "1220014088228687872"
# 3     "1219728261233639425"
# 4     "1219727439254913031"
# ...                     ...
# 3195   "915728981982371840"
# 3196   "915274359157256192"
# 3197   "914886651779751936"
# 3198   "914885980988964865"
# 3199   "914284040823431168"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/coach/status/1220114257200...  2020-01-22 22:41:22
# 1     https://twitter.com/jlo/status/122003900496128...  2020-01-22 17:42:20
# 2     https://twitter.com/jlo/status/122001408822868...  2020-01-22 16:03:20
# 3     https://twitter.com/jlo/status/121972826123363...  2020-01-21 21:07:33
# 4     https://twitter.com/jlo/status/121972743925491...  2020-01-21 21:04:17
# ...                                                 ...                  ...
# 3195  https://twitter.com/lin_manuel/status/91572898...  2017-10-05 00:02:57
# ...

# %%
#Show the 'shape' of the dataframe 
shape = JLo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
JLo_Tweets_df = JLo_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = JLo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
JLo_Tweets_df
# Out:
#         Username     User Id Tweet Type  \
# 0          coach  "73200694"    Retweet
# 1            jlo  "85603854"      Tweet
# 2            jlo  "85603854"      Tweet
# 3            jlo  "85603854"      Tweet
# 4            jlo  "85603854"      Tweet
# ...          ...         ...        ...
# 3195  lin_manuel  "79923701"    Retweet
# 3196     variety  "17525171"    Retweet
# 3197         jlo  "85603854"      Tweet
# 3198         jlo  "85603854"      Tweet
# 3199         jlo  "85603854"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "On top of the world with @JLo. Go behind-the-...     Twitter Web App
# 1     "✨🎵✨Add my number to your phone book to be the...  Twitter for iPhone
# 2     "JLovers! Text me at (305) 690-0379 to be the ...  Twitter for iPhone
# 3     "NYC!!!! If you're in the area, you have to st...     Twitter Web App
# 4     "OMG!!!!! Love youuuuu @BarbraStreisand ❤️ htt...     Twitter Web App
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
JLo_Tweets_df = JLo_Tweets_df.dropna() 

#Confirm rows are dropped
shape = JLo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
JLo_Tweets_df['Tweet Posted Time'] = JLo_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = JLo_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
JLo_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
JLo_Tweets_df['Tweet Posted Time'] = JLo_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = JLo_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
JLo_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
JLo_Tweets_df = JLo_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = JLo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
JLo_Tweets_df
# Out:
#         Username     User Id Tweet Type  \
# 0          coach  "73200694"    Retweet
# 1            jlo  "85603854"      Tweet
# 2            jlo  "85603854"      Tweet
# 3            jlo  "85603854"      Tweet
# 4            jlo  "85603854"      Tweet
# ...          ...         ...        ...
# 3195  lin_manuel  "79923701"    Retweet
# 3196     variety  "17525171"    Retweet
# 3197         jlo  "85603854"      Tweet
# 3198         jlo  "85603854"      Tweet
# 3199         jlo  "85603854"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "On top of the world with @JLo. Go behind-the-...     Twitter Web App
# 1     "✨🎵✨Add my number to your phone book to be the...  Twitter for iPhone
# 2     "JLovers! Text me at (305) 690-0379 to be the ...  Twitter for iPhone
# 3     "NYC!!!! If you're in the area, you have to st...     Twitter Web App
# 4     "OMG!!!!! Love youuuuu @BarbraStreisand ❤️ htt...     Twitter Web App
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
JLo_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
JLo_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = JLo_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
JLo_Tweets_df.index = [x for x in range(1, len(JLo_Tweets_df.values)+1)]
JLo_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
JLo_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# Index
# 1           coach  "73200694"    Retweet
# 2             jlo  "85603854"      Tweet
# 3             jlo  "85603854"      Tweet
# 4             jlo  "85603854"      Tweet
# 5             jlo  "85603854"      Tweet
# ...           ...         ...        ...
# 3196   lin_manuel  "79923701"    Retweet
# 3197      variety  "17525171"    Retweet
# 3198          jlo  "85603854"      Tweet
# 3199          jlo  "85603854"      Tweet
# 3200          jlo  "85603854"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "On top of the world with @JLo. Go behind-the-...     Twitter Web App
# 2      "✨🎵✨Add my number to your phone book to be the...  Twitter for iPhone
# 3      "JLovers! Text me at (305) 690-0379 to be the ...  Twitter for iPhone
# 4      "NYC!!!! If you're in the area, you have to st...     Twitter Web App
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
JLo_Tweets_df.to_csv('JLo_Tweets_df.csv')
