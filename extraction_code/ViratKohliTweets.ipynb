# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Virat Kohli Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "ViratKohliTweets.csv"

#Import the CSV into a pandas DataFrame
VKohli_Tweets_df = pd.read_csv(csv_path, low_memory = False)
VKohli_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219870407676678144"
# 1     "1219814892170964992"
# 2     "1219631268738084868"
# 3     "1219175442898276352"
# 4     "1218938883745837056"
# ...                     ...
# 2051           "4168829709"
# 2052           "4168263153"
# 2053           "4167514786"
# 2054           "3889494504"
# 2055           "3754340192"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/imvkohli/status/1219870407...  2020-01-22 06:32:23
# 1     https://twitter.com/imvkohli/status/1219814892...  2020-01-22 02:51:48
# 2     https://twitter.com/imvkohli/status/1219631268...  2020-01-21 14:42:08
# 3     https://twitter.com/imvkohli/status/1219175442...  2020-01-20 08:30:51
# 4     https://twitter.com/imvkohli/status/1218938883...  2020-01-19 16:50:51
# ...                                                 ...                  ...
# 2051     https://twitter.com/imvkohli/status/4168829709  2009-09-22 09:44:31
# 2052     https://twitter.com/imvkohli/status/4168263153  2009-09-22 08:46:33
# 2053     https://twitter.com/imvkohli/status/4167514786  2009-09-22 07:32:46
# 2054     https://twitter.com/imvkohli/status/3889494504  2009-09-10 15:36:10
# 2055     https://twitter.com/imvkohli/status/3754340192  2009-09-04 10:31:36
#
#                                           Tweet Content Tweet Type  \
# 0     "Stylish, elegant and classy. An absolute beas...      Tweet
# 1     "Top team gym session and a good meal out in b...      Tweet
# 2     "Touchdown Auckland. Let’s go 🇮🇳 @imShard @Shr...      Tweet
# 3                      "👊🏼👊🏼👊🏼 https://t.co/ot4qLbfkvM"      Tweet
# 4     "Soaring High 🏆🇮🇳💙 #IndvAus https://t.co/Zjo3m...      Tweet
# ...                                                 ...        ...
# 2051  "@yuvsingh09 Hello Mr.Bond \nwatched it you we...      Reply
# 2052                                 "@hulk7174 ??????"      Reply
# 2053                            "Time for Training...."      Tweet
# 2054           "Will be heading to SriLanka Woohoo !!!"      Tweet
# 2055             "@yuvsingh09 Aiieeeeeee me too me too"      Reply
#
#                    Client  Retweets received  Likes received     User Id  \
# 0     Twitter for Android               1707           35917  "71201743"
# 1     Twitter for Android               3515           81896  "71201743"
# 2     Twitter for Android               3598           79331  "71201743"
# 3     Twitter for Android               1889           31973  "71201743"
# 4     Twitter for Android              14067          189812  "71201743"
# ...                   ...                ...             ...         ...
# 2051   Twitter Web Client                 10              36  "71201743"
# 2052   Twitter Web Client                  9              44  "71201743"
# 2053   Twitter Web Client                 51              86  "71201743"
# 2054   Twitter Web Client                 63             117  "71201743"
# 2055   Twitter Web Client                166             241  "71201743"
#
#                Name  Username Verified or Non-Verified  \
# 0     "Virat Kohli"  imvkohli                 Verified
# 1     "Virat Kohli"  imvkohli                 Verified
# 2     "Virat Kohli"  imvkohli                 Verified
# 3     "Virat Kohli"  imvkohli                 Verified
# 4     "Virat Kohli"  imvkohli                 Verified
# ...             ...       ...                      ...
# 2051  "Virat Kohli"  imvkohli                 Verified
# 2052  "Virat Kohli"  imvkohli                 Verified
# 2053  "Virat Kohli"  imvkohli                 Verified
# 2054  "Virat Kohli"  imvkohli                 Verified
# 2055  "Virat Kohli"  imvkohli                 Verified
#
#                        Profile URL Protected or Not Protected
# 0     https://twitter.com/imvkohli              Not Protected
# 1     https://twitter.com/imvkohli              Not Protected
# 2     https://twitter.com/imvkohli              Not Protected
# 3     https://twitter.com/imvkohli              Not Protected
# 4     https://twitter.com/imvkohli              Not Protected
# ...                            ...                        ...
# 2051  https://twitter.com/imvkohli              Not Protected
# 2052  https://twitter.com/imvkohli              Not Protected
# 2053  https://twitter.com/imvkohli              Not Protected
# 2054  https://twitter.com/imvkohli              Not Protected
# 2055  https://twitter.com/imvkohli              Not Protected
#
# [2056 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = VKohli_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2056, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
VKohli_Tweets_df = VKohli_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = VKohli_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2056, 8)

# %%
#Print the dataframe
VKohli_Tweets_df
# Out:
#       Username     User Id Tweet Type  \
# 0     imvkohli  "71201743"      Tweet
# 1     imvkohli  "71201743"      Tweet
# 2     imvkohli  "71201743"      Tweet
# 3     imvkohli  "71201743"      Tweet
# 4     imvkohli  "71201743"      Tweet
# ...        ...         ...        ...
# 2051  imvkohli  "71201743"      Reply
# 2052  imvkohli  "71201743"      Reply
# 2053  imvkohli  "71201743"      Tweet
# 2054  imvkohli  "71201743"      Tweet
# 2055  imvkohli  "71201743"      Reply
#
#                                           Tweet Content               Client  \
# 0     "Stylish, elegant and classy. An absolute beas...  Twitter for Android
# 1     "Top team gym session and a good meal out in b...  Twitter for Android
# 2     "Touchdown Auckland. Let’s go 🇮🇳 @imShard @Shr...  Twitter for Android
# 3                      "👊🏼👊🏼👊🏼 https://t.co/ot4qLbfkvM"  Twitter for Android
# 4     "Soaring High 🏆🇮🇳💙 #IndvAus https://t.co/Zjo3m...  Twitter for Android
# ...                                                 ...                  ...
# 2051  "@yuvsingh09 Hello Mr.Bond \nwatched it you we...   Twitter Web Client
# 2052                                 "@hulk7174 ??????"   Twitter Web Client
# 2053                            "Time for Training...."   Twitter Web Client
# 2054           "Will be heading to SriLanka Woohoo !!!"   Twitter Web Client
# 2055             "@yuvsingh09 Aiieeeeeee me too me too"   Twitter Web Client
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                  1707           35917  2020-01-22 06:32:23
# 1                  3515           81896  2020-01-22 02:51:48
# 2                  3598           79331  2020-01-21 14:42:08
# 3                  1889           31973  2020-01-20 08:30:51
# 4                 14067          189812  2020-01-19 16:50:51
# ...                 ...             ...                  ...
# 2051                 10              36  2009-09-22 09:44:31
# 2052                  9              44  2009-09-22 08:46:33
# 2053                 51              86  2009-09-22 07:32:46
# 2054                 63             117  2009-09-10 15:36:10
# 2055                166             241  2009-09-04 10:31:36
#
# [2056 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
VKohli_Tweets_df = VKohli_Tweets_df.dropna() 

#Confirm rows are dropped
shape = VKohli_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2056, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
VKohli_Tweets_df['Tweet Posted Time'] = VKohli_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = VKohli_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
VKohli_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
VKohli_Tweets_df['Tweet Posted Time'] = VKohli_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = VKohli_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
VKohli_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
VKohli_Tweets_df = VKohli_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = VKohli_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2056, 9)

# %%
#Print the dataframe
VKohli_Tweets_df
# Out:
#       Username     User Id Tweet Type  \
# 0     imvkohli  "71201743"      Tweet
# 1     imvkohli  "71201743"      Tweet
# 2     imvkohli  "71201743"      Tweet
# 3     imvkohli  "71201743"      Tweet
# 4     imvkohli  "71201743"      Tweet
# ...        ...         ...        ...
# 2051  imvkohli  "71201743"      Reply
# 2052  imvkohli  "71201743"      Reply
# 2053  imvkohli  "71201743"      Tweet
# 2054  imvkohli  "71201743"      Tweet
# 2055  imvkohli  "71201743"      Reply
#
#                                           Tweet Content               Client  \
# 0     "Stylish, elegant and classy. An absolute beas...  Twitter for Android
# 1     "Top team gym session and a good meal out in b...  Twitter for Android
# 2     "Touchdown Auckland. Let’s go 🇮🇳 @imShard @Shr...  Twitter for Android
# 3                      "👊🏼👊🏼👊🏼 https://t.co/ot4qLbfkvM"  Twitter for Android
# 4     "Soaring High 🏆🇮🇳💙 #IndvAus https://t.co/Zjo3m...  Twitter for Android
# ...                                                 ...                  ...
# 2051  "@yuvsingh09 Hello Mr.Bond \nwatched it you we...   Twitter Web Client
# 2052                                 "@hulk7174 ??????"   Twitter Web Client
# 2053                            "Time for Training...."   Twitter Web Client
# 2054           "Will be heading to SriLanka Woohoo !!!"   Twitter Web Client
# 2055             "@yuvsingh09 Aiieeeeeee me too me too"   Twitter Web Client
#
#       Retweets received  Likes received        Date      Time
# 0                  1707           35917  2020-01-22  06:32:23
# 1                  3515           81896  2020-01-22  02:51:48
# 2                  3598           79331  2020-01-21  14:42:08
# 3                  1889           31973  2020-01-20  08:30:51
# 4                 14067          189812  2020-01-19  16:50:51
# ...                 ...             ...         ...       ...
# 2051                 10              36  2009-09-22  09:44:31
# 2052                  9              44  2009-09-22  08:46:33
# 2053                 51              86  2009-09-22  07:32:46
# 2054                 63             117  2009-09-10  15:36:10
# 2055                166             241  2009-09-04  10:31:36
#
# [2056 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
VKohli_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
VKohli_Tweets_df['Vocation'] = "Sport"

#Show the 'shape' of the dataframe
shape = VKohli_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (2056, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
VKohli_Tweets_df.index = [x for x in range(1, len(VKohli_Tweets_df.values)+1)]
VKohli_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
VKohli_Tweets_df
# Out:
#        Username     User Id Tweet Type  \
# Index
# 1      imvkohli  "71201743"      Tweet
# 2      imvkohli  "71201743"      Tweet
# 3      imvkohli  "71201743"      Tweet
# 4      imvkohli  "71201743"      Tweet
# 5      imvkohli  "71201743"      Tweet
# ...         ...         ...        ...
# 2052   imvkohli  "71201743"      Reply
# 2053   imvkohli  "71201743"      Reply
# 2054   imvkohli  "71201743"      Tweet
# 2055   imvkohli  "71201743"      Tweet
# 2056   imvkohli  "71201743"      Reply
#
#                                            Tweet Content               Client  \
# Index
# 1      "Stylish, elegant and classy. An absolute beas...  Twitter for Android
# 2      "Top team gym session and a good meal out in b...  Twitter for Android
# 3      "Touchdown Auckland. Let’s go 🇮🇳 @imShard @Shr...  Twitter for Android
# 4                       "👊🏼👊🏼👊🏼 https://t.co/ot4qLbfkvM"  Twitter for Android
# 5      "Soaring High 🏆🇮🇳💙 #IndvAus https://t.co/Zjo3m...  Twitter for Android
# ...                                                  ...                  ...
# 2052   "@yuvsingh09 Hello Mr.Bond \nwatched it you we...   Twitter Web Client
# 2053                                  "@hulk7174 ??????"   Twitter Web Client
# 2054                             "Time for Training...."   Twitter Web Client
# 2055            "Will be heading to SriLanka Woohoo !!!"   Twitter Web Client
# 2056              "@yuvsingh09 Aiieeeeeee me too me too"   Twitter Web Client
#
#        Retweets received  Likes received        Date      Time Gender Vocation
# Index
# 1                   1707           35917  2020-01-22  06:32:23   Male    Sport
# 2                   3515           81896  2020-01-22  02:51:48   Male    Sport
# 3                   3598           79331  2020-01-21  14:42:08   Male    Sport
# 4                   1889           31973  2020-01-20  08:30:51   Male    Sport
# 5                  14067          189812  2020-01-19  16:50:51   Male    Sport
# ...                  ...             ...         ...       ...    ...      ...
# 2052                  10              36  2009-09-22  09:44:31   Male    Sport
# 2053                   9              44  2009-09-22  08:46:33   Male    Sport
# 2054                  51              86  2009-09-22  07:32:46   Male    Sport
# 2055                  63             117  2009-09-10  15:36:10   Male    Sport
# 2056                 166             241  2009-09-04  10:31:36   Male    Sport
#
# [2056 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
VKohli_Tweets_df.to_csv('VKohli_Tweets_df.csv')
