# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Narendra Modi Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "NarendraModiTweets.csv"

#Import the CSV into a pandas DataFrame
NModi_Tweets_df = pd.read_csv(csv_path, low_memory = False)
NModi_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220177983740219392"
# 1     "1220177665203888128"
# 2     "1220176946044243971"
# 3     "1219991121943621632"
# 4     "1219991120202981377"
# ...                     ...
# 3195  "1103122427213688837"
# 3196  "1103122074044940289"
# 3197  "1103121800395923457"
# 3198  "1102971120460988417"
# 3199  "1102971102207332356"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/narendramodi/status/122017...  2020-01-23 02:54:35
# 1     https://twitter.com/narendramodi/status/122017...  2020-01-23 02:53:19
# 2     https://twitter.com/narendramodi/status/122017...  2020-01-23 02:50:28
# 3     https://twitter.com/narendramodi/status/121999...  2020-01-22 14:32:04
# 4     https://twitter.com/narendramodi/status/121999...  2020-01-22 14:32:04
# ...                                                 ...                  ...
# 3195  https://twitter.com/narendramodi/status/110312...  2019-03-06 02:37:36
# ...

# %%
#Show the 'shape' of the dataframe 
shape = NModi_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
NModi_Tweets_df = NModi_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = NModi_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
NModi_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0     narendramodi  "18839785"      Tweet
# 1     narendramodi  "18839785"      Tweet
# 2     narendramodi  "18839785"      Tweet
# 3     narendramodi  "18839785"      Reply
# 4     narendramodi  "18839785"      Tweet
# ...            ...         ...        ...
# 3195  narendramodi  "18839785"      Tweet
# 3196  narendramodi  "18839785"      Tweet
# 3197  narendramodi  "18839785"      Tweet
# 3198  narendramodi  "18839785"      Reply
# 3199  narendramodi  "18839785"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Tributes to the great Balasaheb Thackeray on ...    Twitter for iPhone
# 1     "India will always remain grateful to Netaji S...  Twitter Media Studio
# 2     "On 23rd January 1897, Janakinath Bose wrote i...    Twitter for iPhone
# 3     "In line with our focus on speedy and timely c...       Twitter Web App
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
NModi_Tweets_df = NModi_Tweets_df.dropna() 

#Confirm rows are dropped
shape = NModi_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NModi_Tweets_df['Tweet Posted Time'] = NModi_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NModi_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
NModi_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NModi_Tweets_df['Tweet Posted Time'] = NModi_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NModi_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
NModi_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
NModi_Tweets_df = NModi_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = NModi_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
NModi_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0     narendramodi  "18839785"      Tweet
# 1     narendramodi  "18839785"      Tweet
# 2     narendramodi  "18839785"      Tweet
# 3     narendramodi  "18839785"      Reply
# 4     narendramodi  "18839785"      Tweet
# ...            ...         ...        ...
# 3195  narendramodi  "18839785"      Tweet
# 3196  narendramodi  "18839785"      Tweet
# 3197  narendramodi  "18839785"      Tweet
# 3198  narendramodi  "18839785"      Reply
# 3199  narendramodi  "18839785"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Tributes to the great Balasaheb Thackeray on ...    Twitter for iPhone
# 1     "India will always remain grateful to Netaji S...  Twitter Media Studio
# 2     "On 23rd January 1897, Janakinath Bose wrote i...    Twitter for iPhone
# 3     "In line with our focus on speedy and timely c...       Twitter Web App
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
NModi_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
NModi_Tweets_df['Vocation'] = "Politics"

#Show the 'shape' of the dataframe
shape = NModi_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
NModi_Tweets_df.index = [x for x in range(1, len(NModi_Tweets_df.values)+1)]
NModi_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
NModi_Tweets_df
# Out:
#            Username     User Id Tweet Type  \
# Index
# 1      narendramodi  "18839785"      Tweet
# 2      narendramodi  "18839785"      Tweet
# 3      narendramodi  "18839785"      Tweet
# 4      narendramodi  "18839785"      Reply
# 5      narendramodi  "18839785"      Tweet
# ...             ...         ...        ...
# 3196   narendramodi  "18839785"      Tweet
# 3197   narendramodi  "18839785"      Tweet
# 3198   narendramodi  "18839785"      Tweet
# 3199   narendramodi  "18839785"      Reply
# 3200   narendramodi  "18839785"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "Tributes to the great Balasaheb Thackeray on ...
# 2      "India will always remain grateful to Netaji S...
# 3      "On 23rd January 1897, Janakinath Bose wrote i...
# 4      "In line with our focus on speedy and timely c...
# 5      "We had an excellent Pragati Session today, du...
# ...                                                  ...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
NModi_Tweets_df.to_csv('NModi_Tweets_df.csv')
