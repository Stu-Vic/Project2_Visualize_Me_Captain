# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Oprah Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "OprahTweets.csv"

#Import the CSV into a pandas DataFrame
Oprah_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Oprah_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220191949010980865"
# 1     "1219620561086631937"
# 2     "1219618754742693888"
# 3     "1219618533421854720"
# 4     "1219618257411493890"
# ...                     ...
# 3195   "518578434994606081"
# 3196   "518577756893093888"
# 3197   "518577724835627008"
# 3198   "518576853389680640"
# 3199   "518575913580392449"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/oprah/status/1220191949010...  2020-01-23 03:50:05
# 1     https://twitter.com/oprahsbookclub/status/1219...  2020-01-21 13:59:35
# 2     https://twitter.com/cbsthismorning/status/1219...  2020-01-21 13:52:25
# 3     https://twitter.com/oprah/status/1219618533421...  2020-01-21 13:51:32
# 4     https://twitter.com/oprah/status/1219618257411...  2020-01-21 13:50:26
# ...                                                 ...                  ...
# 3195  https://twitter.com/sixbrownchicks/status/5185...  2014-10-05 01:48:28
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Oprah_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Oprah_Tweets_df = Oprah_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Oprah_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
Oprah_Tweets_df
# Out:
#             Username                User Id Tweet Type  \
# 0              oprah             "19397785"      Tweet
# 1     oprahsbookclub  "1174003243287859200"    Retweet
# 2     cbsthismorning             "17134268"    Retweet
# 3              oprah             "19397785"      Reply
# 4              oprah             "19397785"      Reply
# ...              ...                    ...        ...
# 3195  sixbrownchicks            "243328891"    Retweet
# 3196           oprah             "19397785"      Reply
# 3197      go__within           "2471772473"    Retweet
# 3198           oprah             "19397785"      Tweet
# 3199           oprah             "19397785"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "My conversation with @amyschumer this past Sa...       Twitter Web App
# 1     "Our next book club selection is “American Dir...    Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Oprah_Tweets_df = Oprah_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Oprah_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Oprah_Tweets_df['Tweet Posted Time'] = Oprah_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Oprah_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Oprah_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Oprah_Tweets_df['Tweet Posted Time'] = Oprah_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Oprah_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Oprah_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Oprah_Tweets_df = Oprah_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Oprah_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
Oprah_Tweets_df
# Out:
#             Username                User Id Tweet Type  \
# 0              oprah             "19397785"      Tweet
# 1     oprahsbookclub  "1174003243287859200"    Retweet
# 2     cbsthismorning             "17134268"    Retweet
# 3              oprah             "19397785"      Reply
# 4              oprah             "19397785"      Reply
# ...              ...                    ...        ...
# 3195  sixbrownchicks            "243328891"    Retweet
# 3196           oprah             "19397785"      Reply
# 3197      go__within           "2471772473"    Retweet
# 3198           oprah             "19397785"      Tweet
# 3199           oprah             "19397785"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "My conversation with @amyschumer this past Sa...       Twitter Web App
# 1     "Our next book club selection is “American Dir...    Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Oprah_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
Oprah_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = Oprah_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Oprah_Tweets_df.index = [x for x in range(1, len(Oprah_Tweets_df.values)+1)]
Oprah_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Oprah_Tweets_df
# Out:
#              Username                User Id Tweet Type  \
# Index
# 1               oprah             "19397785"      Tweet
# 2      oprahsbookclub  "1174003243287859200"    Retweet
# 3      cbsthismorning             "17134268"    Retweet
# 4               oprah             "19397785"      Reply
# 5               oprah             "19397785"      Reply
# ...               ...                    ...        ...
# 3196   sixbrownchicks            "243328891"    Retweet
# 3197            oprah             "19397785"      Reply
# 3198       go__within           "2471772473"    Retweet
# 3199            oprah             "19397785"      Tweet
# 3200            oprah             "19397785"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "My conversation with @amyschumer this past Sa...
# 2      "Our next book club selection is “American Dir...
# 3      "Best-selling author @jeaninecummins joins @Op...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Oprah_Tweets_df.to_csv('Oprah_Tweets_df.csv')
