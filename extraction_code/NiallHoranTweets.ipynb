# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Niall Horan Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "NiallHoranTweets.csv"

#Import the CSV into a pandas DataFrame
NHoran_Tweets_df = pd.read_csv(csv_path, low_memory = False)
NHoran_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219645653900546048"
# 1     "1219625949718859778"
# 2     "1218932300106358787"
# 3     "1218772971260710913"
# 4     "1218673172939231232"
# ...                     ...
# 3195   "865359712245698561"
# 3196   "865281066797383681"
# 3197   "865269249857794049"
# 3198   "865268733195026432"
# 3199   "865191341755650048"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/niallofficial/status/12196...  2020-01-21 15:39:18
# 1     https://twitter.com/niallofficial/status/12196...  2020-01-21 14:21:00
# 2     https://twitter.com/niallofficial/status/12189...  2020-01-19 16:24:41
# 3     https://twitter.com/niallofficial/status/12187...  2020-01-19 05:51:34
# 4     https://twitter.com/niallofficial/status/12186...  2020-01-18 23:15:00
# ...                                                 ...                  ...
# 3195  https://twitter.com/niallofficial/status/86535...  2017-05-19 00:13:27
# 3196  https://twitter.com/theellenshow/status/865281...  2017-05-18 19:00:57
# 3197  https://twitter.com/niallofficial/status/86526...  2017-05-18 18:13:59
# 3198  https://twitter.com/niallofficial/status/86526...  2017-05-18 18:11:56
# 3199  https://twitter.com/challenge_tour/status/8651...  2017-05-18 13:04:25
#
#                                           Tweet Content Tweet Type  \
# 0                            "@SiriusXMHits1 Fuckkkkkk"      Reply
# 1     "Huge congratulations to my beautiful friend P...      Tweet
# 2                            "@nialleraustria Cmon now"      Reply
# 3                                        "🇮🇪🇮🇪🇮🇪🇮🇪🇮🇪🇮🇪"      Tweet
# 4                                "@NJHsSTLRckstr2 😂😂😂😂"      Reply
# ...                                                 ...        ...
# 3195  "Great day with all the radio stations in Chic...      Tweet
# 3196  ".@NiallOfficial's new music is here, and you ...    Retweet
# 3197  "@BezChristiaan happy birthday dude ! Shooting...      Tweet
# 3198  "Sad to hear about Chris Cornell . Was literal...      Tweet
# 3199  "How do you celebrate turning 23? 🤔 \n\nWith a...    Retweet
#
#                   Client  Retweets received  Likes received      User Id  \
# 0     Twitter for iPhone               1175            8208  "105119490"
# 1     Twitter for iPhone               6245           45056  "105119490"
# 2     Twitter for iPhone                278            2007  "105119490"
# 3     Twitter for iPhone               8547           77130  "105119490"
# 4     Twitter for iPhone                257            1887  "105119490"
# ...                  ...                ...             ...          ...
# 3195  Twitter for iPhone              18247           60261  "105119490"
# 3196  Twitter Web Client              10578           30754   "15846407"
# 3197  Twitter for iPhone               1675            4114  "105119490"
# 3198  Twitter for iPhone              17402           58310  "105119490"
# 3199  Twitter Web Client               3319           14614  "179944945"
#
#                    Name        Username Verified or Non-Verified  \
# 0         "Niall Horan"   niallofficial                 Verified
# 1         "Niall Horan"   niallofficial                 Verified
# 2         "Niall Horan"   niallofficial                 Verified
# 3         "Niall Horan"   niallofficial                 Verified
# 4         "Niall Horan"   niallofficial                 Verified
# ...                 ...             ...                      ...
# 3195      "Niall Horan"   niallofficial                 Verified
# 3196  "Ellen DeGeneres"    theellenshow                 Verified
# 3197      "Niall Horan"   niallofficial                 Verified
# 3198      "Niall Horan"   niallofficial                 Verified
# 3199   "Challenge Tour"  challenge_tour                 Verified
#
#                              Profile URL Protected or Not Protected
# 0      https://twitter.com/niallofficial              Not Protected
# 1      https://twitter.com/niallofficial              Not Protected
# 2      https://twitter.com/niallofficial              Not Protected
# 3      https://twitter.com/niallofficial              Not Protected
# 4      https://twitter.com/niallofficial              Not Protected
# ...                                  ...                        ...
# 3195   https://twitter.com/niallofficial              Not Protected
# 3196    https://twitter.com/theellenshow              Not Protected
# 3197   https://twitter.com/niallofficial              Not Protected
# 3198   https://twitter.com/niallofficial              Not Protected
# 3199  https://twitter.com/challenge_tour              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = NHoran_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
NHoran_Tweets_df = NHoran_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = NHoran_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
NHoran_Tweets_df
# Out:
#             Username      User Id Tweet Type  \
# 0      niallofficial  "105119490"      Reply
# 1      niallofficial  "105119490"      Tweet
# 2      niallofficial  "105119490"      Reply
# 3      niallofficial  "105119490"      Tweet
# 4      niallofficial  "105119490"      Reply
# ...              ...          ...        ...
# 3195   niallofficial  "105119490"      Tweet
# 3196    theellenshow   "15846407"    Retweet
# 3197   niallofficial  "105119490"      Tweet
# 3198   niallofficial  "105119490"      Tweet
# 3199  challenge_tour  "179944945"    Retweet
#
#                                           Tweet Content              Client  \
# 0                            "@SiriusXMHits1 Fuckkkkkk"  Twitter for iPhone
# 1     "Huge congratulations to my beautiful friend P...  Twitter for iPhone
# 2                            "@nialleraustria Cmon now"  Twitter for iPhone
# 3                                        "🇮🇪🇮🇪🇮🇪🇮🇪🇮🇪🇮🇪"  Twitter for iPhone
# 4                                "@NJHsSTLRckstr2 😂😂😂😂"  Twitter for iPhone
# ...                                                 ...                 ...
# 3195  "Great day with all the radio stations in Chic...  Twitter for iPhone
# 3196  ".@NiallOfficial's new music is here, and you ...  Twitter Web Client
# 3197  "@BezChristiaan happy birthday dude ! Shooting...  Twitter for iPhone
# 3198  "Sad to hear about Chris Cornell . Was literal...  Twitter for iPhone
# 3199  "How do you celebrate turning 23? 🤔 \n\nWith a...  Twitter Web Client
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                  1175            8208  2020-01-21 15:39:18
# 1                  6245           45056  2020-01-21 14:21:00
# 2                   278            2007  2020-01-19 16:24:41
# 3                  8547           77130  2020-01-19 05:51:34
# 4                   257            1887  2020-01-18 23:15:00
# ...                 ...             ...                  ...
# 3195              18247           60261  2017-05-19 00:13:27
# 3196              10578           30754  2017-05-18 19:00:57
# 3197               1675            4114  2017-05-18 18:13:59
# 3198              17402           58310  2017-05-18 18:11:56
# 3199               3319           14614  2017-05-18 13:04:25
#
# [3200 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
NHoran_Tweets_df = NHoran_Tweets_df.dropna() 

#Confirm rows are dropped
shape = NHoran_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NHoran_Tweets_df['Tweet Posted Time'] = NHoran_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NHoran_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
NHoran_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NHoran_Tweets_df['Tweet Posted Time'] = NHoran_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NHoran_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
NHoran_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
NHoran_Tweets_df = NHoran_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = NHoran_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
NHoran_Tweets_df
# Out:
#             Username      User Id Tweet Type  \
# 0      niallofficial  "105119490"      Reply
# 1      niallofficial  "105119490"      Tweet
# 2      niallofficial  "105119490"      Reply
# 3      niallofficial  "105119490"      Tweet
# 4      niallofficial  "105119490"      Reply
# ...              ...          ...        ...
# 3195   niallofficial  "105119490"      Tweet
# 3196    theellenshow   "15846407"    Retweet
# 3197   niallofficial  "105119490"      Tweet
# 3198   niallofficial  "105119490"      Tweet
# 3199  challenge_tour  "179944945"    Retweet
#
#                                           Tweet Content              Client  \
# 0                            "@SiriusXMHits1 Fuckkkkkk"  Twitter for iPhone
# 1     "Huge congratulations to my beautiful friend P...  Twitter for iPhone
# 2                            "@nialleraustria Cmon now"  Twitter for iPhone
# 3                                        "🇮🇪🇮🇪🇮🇪🇮🇪🇮🇪🇮🇪"  Twitter for iPhone
# 4                                "@NJHsSTLRckstr2 😂😂😂😂"  Twitter for iPhone
# ...                                                 ...                 ...
# 3195  "Great day with all the radio stations in Chic...  Twitter for iPhone
# 3196  ".@NiallOfficial's new music is here, and you ...  Twitter Web Client
# 3197  "@BezChristiaan happy birthday dude ! Shooting...  Twitter for iPhone
# 3198  "Sad to hear about Chris Cornell . Was literal...  Twitter for iPhone
# 3199  "How do you celebrate turning 23? 🤔 \n\nWith a...  Twitter Web Client
#
#       Retweets received  Likes received        Date      Time
# 0                  1175            8208  2020-01-21  15:39:18
# 1                  6245           45056  2020-01-21  14:21:00
# 2                   278            2007  2020-01-19  16:24:41
# 3                  8547           77130  2020-01-19  05:51:34
# 4                   257            1887  2020-01-18  23:15:00
# ...                 ...             ...         ...       ...
# 3195              18247           60261  2017-05-19  00:13:27
# 3196              10578           30754  2017-05-18  19:00:57
# 3197               1675            4114  2017-05-18  18:13:59
# 3198              17402           58310  2017-05-18  18:11:56
# 3199               3319           14614  2017-05-18  13:04:25
#
# [3200 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
NHoran_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
NHoran_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = NHoran_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
NHoran_Tweets_df.index = [x for x in range(1, len(NHoran_Tweets_df.values)+1)]
NHoran_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
NHoran_Tweets_df
# Out:
#              Username      User Id Tweet Type  \
# Index
# 1       niallofficial  "105119490"      Reply
# 2       niallofficial  "105119490"      Tweet
# 3       niallofficial  "105119490"      Reply
# 4       niallofficial  "105119490"      Tweet
# 5       niallofficial  "105119490"      Reply
# ...               ...          ...        ...
# 3196    niallofficial  "105119490"      Tweet
# 3197     theellenshow   "15846407"    Retweet
# 3198    niallofficial  "105119490"      Tweet
# 3199    niallofficial  "105119490"      Tweet
# 3200   challenge_tour  "179944945"    Retweet
#
#                                            Tweet Content              Client  \
# Index
# 1                             "@SiriusXMHits1 Fuckkkkkk"  Twitter for iPhone
# 2      "Huge congratulations to my beautiful friend P...  Twitter for iPhone
# 3                             "@nialleraustria Cmon now"  Twitter for iPhone
# 4                                         "🇮🇪🇮🇪🇮🇪🇮🇪🇮🇪🇮🇪"  Twitter for iPhone
# 5                                 "@NJHsSTLRckstr2 😂😂😂😂"  Twitter for iPhone
# ...                                                  ...                 ...
# 3196   "Great day with all the radio stations in Chic...  Twitter for iPhone
# 3197   ".@NiallOfficial's new music is here, and you ...  Twitter Web Client
# 3198   "@BezChristiaan happy birthday dude ! Shooting...  Twitter for iPhone
# 3199   "Sad to hear about Chris Cornell . Was literal...  Twitter for iPhone
# 3200   "How do you celebrate turning 23? 🤔 \n\nWith a...  Twitter Web Client
#
#        Retweets received  Likes received        Date      Time Gender Vocation
# Index
# 1                   1175            8208  2020-01-21  15:39:18   Male    Music
# 2                   6245           45056  2020-01-21  14:21:00   Male    Music
# 3                    278            2007  2020-01-19  16:24:41   Male    Music
# 4                   8547           77130  2020-01-19  05:51:34   Male    Music
# 5                    257            1887  2020-01-18  23:15:00   Male    Music
# ...                  ...             ...         ...       ...    ...      ...
# 3196               18247           60261  2017-05-19  00:13:27   Male    Music
# 3197               10578           30754  2017-05-18  19:00:57   Male    Music
# 3198                1675            4114  2017-05-18  18:13:59   Male    Music
# 3199               17402           58310  2017-05-18  18:11:56   Male    Music
# 3200                3319           14614  2017-05-18  13:04:25   Male    Music
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
NHoran_Tweets_df.to_csv('NHoran_Tweets_df.csv')
