# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Pink Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "PinkTweets.csv"

#Import the CSV into a pandas DataFrame
Pink_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Pink_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219660451614617606"
# 1     "1219521150390128640"
# 2     "1219517598317985792"
# 3     "1219517497495310336"
# 4     "1219133489770942464"
# ...                     ...
# 3195   "324589537659600896"
# 3196   "324588230307622912"
# 3197   "324286143594110977"
# 3198   "324179337496625152"
# 3199   "324144354065264640"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/pink/status/12196604516146...  2020-01-21 16:38:06
# 1     https://twitter.com/pink/status/12195211503901...  2020-01-21 07:24:34
# 2     https://twitter.com/pink/status/12195175983179...  2020-01-21 07:10:27
# 3     https://twitter.com/pink/status/12195174974953...  2020-01-21 07:10:03
# 4     https://twitter.com/pink/status/12191334897709...  2020-01-20 05:44:09
# ...                                                 ...                  ...
# 3195  https://twitter.com/pink/status/32458953765960...  2013-04-17 18:25:51
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Pink_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Pink_Tweets_df = Pink_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Pink_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
Pink_Tweets_df
# Out:
#              Username     User Id Tweet Type  \
# 0                pink  "28706024"      Tweet
# 1                pink  "28706024"      Tweet
# 2                pink  "28706024"      Tweet
# 3                pink  "28706024"      Tweet
# 4                pink  "28706024"      Tweet
# ...               ...         ...        ...
# 3195             pink  "28706024"      Reply
# 3196             pink  "28706024"      Tweet
# 3197  huffpostparents  "16581734"    Retweet
# 3198             pink  "28706024"      Tweet
# 3199        caketin85  "18933433"    Retweet
#
#                                           Tweet Content               Client  \
# 0     "Willz is becoming quite the baker 😍😍😍 https:/...   Twitter for iPhone
# 1     "This was so fun to watch for real thanks @bil...   Twitter for iPhone
# 2     "Do you mean promising NOT TO? https://t.co/rb...   Twitter for iPhone
# 3                       "Deal! https://t.co/0MT2eFt1zR"   Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Pink_Tweets_df = Pink_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Pink_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Pink_Tweets_df['Tweet Posted Time'] = Pink_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Pink_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Pink_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Pink_Tweets_df['Tweet Posted Time'] = Pink_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Pink_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Pink_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Pink_Tweets_df = Pink_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Pink_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
Pink_Tweets_df
# Out:
#              Username     User Id Tweet Type  \
# 0                pink  "28706024"      Tweet
# 1                pink  "28706024"      Tweet
# 2                pink  "28706024"      Tweet
# 3                pink  "28706024"      Tweet
# 4                pink  "28706024"      Tweet
# ...               ...         ...        ...
# 3195             pink  "28706024"      Reply
# 3196             pink  "28706024"      Tweet
# 3197  huffpostparents  "16581734"    Retweet
# 3198             pink  "28706024"      Tweet
# 3199        caketin85  "18933433"    Retweet
#
#                                           Tweet Content               Client  \
# 0     "Willz is becoming quite the baker 😍😍😍 https:/...   Twitter for iPhone
# 1     "This was so fun to watch for real thanks @bil...   Twitter for iPhone
# 2     "Do you mean promising NOT TO? https://t.co/rb...   Twitter for iPhone
# 3                       "Deal! https://t.co/0MT2eFt1zR"   Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Pink_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
Pink_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = Pink_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Pink_Tweets_df.index = [x for x in range(1, len(Pink_Tweets_df.values)+1)]
Pink_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Pink_Tweets_df
# Out:
#               Username     User Id Tweet Type  \
# Index
# 1                 pink  "28706024"      Tweet
# 2                 pink  "28706024"      Tweet
# 3                 pink  "28706024"      Tweet
# 4                 pink  "28706024"      Tweet
# 5                 pink  "28706024"      Tweet
# ...                ...         ...        ...
# 3196              pink  "28706024"      Reply
# 3197              pink  "28706024"      Tweet
# 3198   huffpostparents  "16581734"    Retweet
# 3199              pink  "28706024"      Tweet
# 3200         caketin85  "18933433"    Retweet
#
#                                            Tweet Content               Client  \
# Index
# 1      "Willz is becoming quite the baker 😍😍😍 https:/...   Twitter for iPhone
# 2      "This was so fun to watch for real thanks @bil...   Twitter for iPhone
# 3      "Do you mean promising NOT TO? https://t.co/rb...   Twitter for iPhone
# 4                        "Deal! https://t.co/0MT2eFt1zR"   Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Pink_Tweets_df.to_csv('Pink_Tweets_df.csv')
