# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Katy Perry Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "KatyPerryTweets.csv"

#Import the CSV into a pandas DataFrame
KPerry_Tweets_df = pd.read_csv(csv_path, low_memory = False)
KPerry_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219799180723359744"
# 1     "1219701567961600001"
# 2     "1219169657250168832"
# 3     "1217216435782422530"
# 4     "1216834918241583104"
# ...                     ...
# 3192   "758966211455569922"
# 3193   "758966024687329281"
# 3194   "758965291191631872"
# 3195   "758964275557769216"
# 3196   "758963797444792321"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/katyperry/status/121979918...  2020-01-22 01:49:22
# 1     https://twitter.com/katyperry/status/121970156...  2020-01-21 19:21:29
# 2     https://twitter.com/katyperry/status/121916965...  2020-01-20 08:07:52
# 3     https://twitter.com/katyperry/status/121721643...  2020-01-14 22:46:27
# 4     https://twitter.com/katyperry/status/121683491...  2020-01-13 21:30:26
# ...                                                 ...                  ...
# 3192  https://twitter.com/katyperry/status/758966211...  2016-07-29 10:03:40
# 3193  https://twitter.com/katyperry/status/758966024...  2016-07-29 10:02:55
# 3194  https://twitter.com/katyperry/status/758965291...  2016-07-29 10:00:00
# 3195  https://twitter.com/katyperry/status/758964275...  2016-07-29 09:55:58
# 3196  https://twitter.com/katyperry/status/758963797...  2016-07-29 09:54:04
#
#                                           Tweet Content Tweet Type  \
# 0     "Step into your destiny with The Bondie 🔮✨ #Sh...      Tweet
# 1     "Y’all! It’s a New Year &amp; a 🎤NEW SEASON OF...      Tweet
# 2       "the darker the night the brighter the stars ✨"      Tweet
# 3     "✨ #ProtectYourEnergy2020 extends from your he...      Tweet
# 4     "That’s sweet and all but I’m livid and flippi...      Tweet
# ...                                                 ...        ...
# 3192                              "@thedutchass untrue"      Reply
# 3193                    "@katyskettle sTaHp ur my fav."      Reply
# 3194                              "@wtfkates miss u bb"      Reply
# 3195                         "@FerrasEU don't.give.up."      Tweet
# 3196  "@katyscrush @katyssunlight @typosqween calm d...      Reply
#
#                   Client  Retweets received  Likes received     User Id  \
# 0     Twitter for iPhone                503            4037  "21447363"
# 1     Twitter for iPhone               1029            7558  "21447363"
# 2     Twitter for iPhone              18934           79726  "21447363"
# 3     Twitter for iPhone                802            7246  "21447363"
# 4     Twitter for iPhone                735            7453  "21447363"
# ...                  ...                ...             ...         ...
# 3192  Twitter for iPhone                740            2693  "21447363"
# 3193  Twitter for iPhone                757            2659  "21447363"
# 3194  Twitter for iPhone                991            3096  "21447363"
# 3195  Twitter for iPhone               1021            2778  "21447363"
# 3196  Twitter for iPhone                644            2310  "21447363"
#
#               Name   Username Verified or Non-Verified  \
# 0     "KATY PERRY"  katyperry                 Verified
# 1     "KATY PERRY"  katyperry                 Verified
# 2     "KATY PERRY"  katyperry                 Verified
# 3     "KATY PERRY"  katyperry                 Verified
# 4     "KATY PERRY"  katyperry                 Verified
# ...            ...        ...                      ...
# 3192  "KATY PERRY"  katyperry                 Verified
# 3193  "KATY PERRY"  katyperry                 Verified
# 3194  "KATY PERRY"  katyperry                 Verified
# 3195  "KATY PERRY"  katyperry                 Verified
# 3196  "KATY PERRY"  katyperry                 Verified
#
#                         Profile URL Protected or Not Protected
# 0     https://twitter.com/katyperry              Not Protected
# 1     https://twitter.com/katyperry              Not Protected
# 2     https://twitter.com/katyperry              Not Protected
# 3     https://twitter.com/katyperry              Not Protected
# 4     https://twitter.com/katyperry              Not Protected
# ...                             ...                        ...
# 3192  https://twitter.com/katyperry              Not Protected
# 3193  https://twitter.com/katyperry              Not Protected
# 3194  https://twitter.com/katyperry              Not Protected
# 3195  https://twitter.com/katyperry              Not Protected
# 3196  https://twitter.com/katyperry              Not Protected
#
# [3197 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = KPerry_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
KPerry_Tweets_df = KPerry_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = KPerry_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 8)

# %%
#Print the dataframe
KPerry_Tweets_df
# Out:
#        Username     User Id Tweet Type  \
# 0     katyperry  "21447363"      Tweet
# 1     katyperry  "21447363"      Tweet
# 2     katyperry  "21447363"      Tweet
# 3     katyperry  "21447363"      Tweet
# 4     katyperry  "21447363"      Tweet
# ...         ...         ...        ...
# 3192  katyperry  "21447363"      Reply
# 3193  katyperry  "21447363"      Reply
# 3194  katyperry  "21447363"      Reply
# 3195  katyperry  "21447363"      Tweet
# 3196  katyperry  "21447363"      Reply
#
#                                           Tweet Content              Client  \
# 0     "Step into your destiny with The Bondie 🔮✨ #Sh...  Twitter for iPhone
# 1     "Y’all! It’s a New Year &amp; a 🎤NEW SEASON OF...  Twitter for iPhone
# 2       "the darker the night the brighter the stars ✨"  Twitter for iPhone
# 3     "✨ #ProtectYourEnergy2020 extends from your he...  Twitter for iPhone
# 4     "That’s sweet and all but I’m livid and flippi...  Twitter for iPhone
# ...                                                 ...                 ...
# 3192                              "@thedutchass untrue"  Twitter for iPhone
# 3193                    "@katyskettle sTaHp ur my fav."  Twitter for iPhone
# 3194                              "@wtfkates miss u bb"  Twitter for iPhone
# 3195                         "@FerrasEU don't.give.up."  Twitter for iPhone
# 3196  "@katyscrush @katyssunlight @typosqween calm d...  Twitter for iPhone
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                   503            4037  2020-01-22 01:49:22
# 1                  1029            7558  2020-01-21 19:21:29
# 2                 18934           79726  2020-01-20 08:07:52
# 3                   802            7246  2020-01-14 22:46:27
# 4                   735            7453  2020-01-13 21:30:26
# ...                 ...             ...                  ...
# 3192                740            2693  2016-07-29 10:03:40
# 3193                757            2659  2016-07-29 10:02:55
# 3194                991            3096  2016-07-29 10:00:00
# 3195               1021            2778  2016-07-29 09:55:58
# 3196                644            2310  2016-07-29 09:54:04
#
# [3197 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
KPerry_Tweets_df = KPerry_Tweets_df.dropna() 

#Confirm rows are dropped
shape = KPerry_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
KPerry_Tweets_df['Tweet Posted Time'] = KPerry_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = KPerry_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
KPerry_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
KPerry_Tweets_df['Tweet Posted Time'] = KPerry_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = KPerry_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
KPerry_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
KPerry_Tweets_df = KPerry_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = KPerry_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 9)

# %%
#Print the dataframe
KPerry_Tweets_df
# Out:
#        Username     User Id Tweet Type  \
# 0     katyperry  "21447363"      Tweet
# 1     katyperry  "21447363"      Tweet
# 2     katyperry  "21447363"      Tweet
# 3     katyperry  "21447363"      Tweet
# 4     katyperry  "21447363"      Tweet
# ...         ...         ...        ...
# 3192  katyperry  "21447363"      Reply
# 3193  katyperry  "21447363"      Reply
# 3194  katyperry  "21447363"      Reply
# 3195  katyperry  "21447363"      Tweet
# 3196  katyperry  "21447363"      Reply
#
#                                           Tweet Content              Client  \
# 0     "Step into your destiny with The Bondie 🔮✨ #Sh...  Twitter for iPhone
# 1     "Y’all! It’s a New Year &amp; a 🎤NEW SEASON OF...  Twitter for iPhone
# 2       "the darker the night the brighter the stars ✨"  Twitter for iPhone
# 3     "✨ #ProtectYourEnergy2020 extends from your he...  Twitter for iPhone
# 4     "That’s sweet and all but I’m livid and flippi...  Twitter for iPhone
# ...                                                 ...                 ...
# 3192                              "@thedutchass untrue"  Twitter for iPhone
# 3193                    "@katyskettle sTaHp ur my fav."  Twitter for iPhone
# 3194                              "@wtfkates miss u bb"  Twitter for iPhone
# 3195                         "@FerrasEU don't.give.up."  Twitter for iPhone
# 3196  "@katyscrush @katyssunlight @typosqween calm d...  Twitter for iPhone
#
#       Retweets received  Likes received        Date      Time
# 0                   503            4037  2020-01-22  01:49:22
# 1                  1029            7558  2020-01-21  19:21:29
# 2                 18934           79726  2020-01-20  08:07:52
# 3                   802            7246  2020-01-14  22:46:27
# 4                   735            7453  2020-01-13  21:30:26
# ...                 ...             ...         ...       ...
# 3192                740            2693  2016-07-29  10:03:40
# 3193                757            2659  2016-07-29  10:02:55
# 3194                991            3096  2016-07-29  10:00:00
# 3195               1021            2778  2016-07-29  09:55:58
# 3196                644            2310  2016-07-29  09:54:04
#
# [3197 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
KPerry_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
KPerry_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = KPerry_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
KPerry_Tweets_df.index = [x for x in range(1, len(KPerry_Tweets_df.values)+1)]
KPerry_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
KPerry_Tweets_df
# Out:
#         Username     User Id Tweet Type  \
# Index
# 1      katyperry  "21447363"      Tweet
# 2      katyperry  "21447363"      Tweet
# 3      katyperry  "21447363"      Tweet
# 4      katyperry  "21447363"      Tweet
# 5      katyperry  "21447363"      Tweet
# ...          ...         ...        ...
# 3193   katyperry  "21447363"      Reply
# 3194   katyperry  "21447363"      Reply
# 3195   katyperry  "21447363"      Reply
# 3196   katyperry  "21447363"      Tweet
# 3197   katyperry  "21447363"      Reply
#
#                                            Tweet Content              Client  \
# Index
# 1      "Step into your destiny with The Bondie 🔮✨ #Sh...  Twitter for iPhone
# 2      "Y’all! It’s a New Year &amp; a 🎤NEW SEASON OF...  Twitter for iPhone
# 3        "the darker the night the brighter the stars ✨"  Twitter for iPhone
# 4      "✨ #ProtectYourEnergy2020 extends from your he...  Twitter for iPhone
# 5      "That’s sweet and all but I’m livid and flippi...  Twitter for iPhone
# ...                                                  ...                 ...
# 3193                               "@thedutchass untrue"  Twitter for iPhone
# 3194                     "@katyskettle sTaHp ur my fav."  Twitter for iPhone
# 3195                               "@wtfkates miss u bb"  Twitter for iPhone
# 3196                          "@FerrasEU don't.give.up."  Twitter for iPhone
# 3197   "@katyscrush @katyssunlight @typosqween calm d...  Twitter for iPhone
#
#        Retweets received  Likes received        Date      Time  Gender  \
# Index
# 1                    503            4037  2020-01-22  01:49:22  Female
# 2                   1029            7558  2020-01-21  19:21:29  Female
# 3                  18934           79726  2020-01-20  08:07:52  Female
# 4                    802            7246  2020-01-14  22:46:27  Female
# 5                    735            7453  2020-01-13  21:30:26  Female
# ...                  ...             ...         ...       ...     ...
# 3193                 740            2693  2016-07-29  10:03:40  Female
# 3194                 757            2659  2016-07-29  10:02:55  Female
# 3195                 991            3096  2016-07-29  10:00:00  Female
# 3196                1021            2778  2016-07-29  09:55:58  Female
# 3197                 644            2310  2016-07-29  09:54:04  Female
#
#       Vocation
# Index
# 1        Music
# 2        Music
# 3        Music
# 4        Music
# 5        Music
# ...        ...
# 3193     Music
# 3194     Music
# 3195     Music
# 3196     Music
# 3197     Music
#
# [3197 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
KPerry_Tweets_df.to_csv('KPerry_Tweets_df.csv')
