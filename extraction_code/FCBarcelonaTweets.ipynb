# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # FC Barcelona Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "FCBarcelonaTweets.csv"

#Import the CSV into a pandas DataFrame
Barca_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Barca_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220255146451570688"
# 1     "1220194795290812418"
# 2     "1220194522640146432"
# 3     "1220164693844733955"
# 4     "1220149195774013441"
# ...                     ...
# 3195  "1158090490467758081"
# 3196  "1158090095490211841"
# 3197  "1158088826436370432"
# 3198  "1158087517536694273"
# 3199  "1158086400421576704"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/fcbarcelona/status/1220255...  2020-01-23 08:01:12
# 1     https://twitter.com/fcbarcelona/status/1220194...  2020-01-23 04:01:23
# 2     https://twitter.com/fcbarcelona/status/1220194...  2020-01-23 04:00:18
# 3     https://twitter.com/fcbarcelona/status/1220164...  2020-01-23 02:01:47
# 4     https://twitter.com/fcbarcelona/status/1220149...  2020-01-23 01:00:12
# ...                                                 ...                  ...
# 3195  https://twitter.com/fcbarcelona/status/1158090...  2019-08-04 19:01:03
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Barca_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Barca_Tweets_df = Barca_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Barca_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
Barca_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# 0     fcbarcelona  "96951800"      Tweet
# 1     fcbarcelona  "96951800"      Tweet
# 2     fcbarcelona  "96951800"      Tweet
# 3     fcbarcelona  "96951800"      Tweet
# 4     fcbarcelona  "96951800"      Tweet
# ...           ...         ...        ...
# 3195  fcbarcelona  "96951800"      Tweet
# 3196  fcbarcelona  "96951800"      Tweet
# 3197  fcbarcelona  "96951800"      Tweet
# 3198  fcbarcelona  "96951800"      Tweet
# 3199  fcbarcelona  "96951800"      Tweet
#
#                                           Tweet Content          Client  \
# 0     "🎥 HIGHLIGHTS 🎥\n\nCOPA DEL REY | Ibiza 1 – 2 ...          Grabyo
# 1     "🗣 @QSetien \n🗣 @AntoGriezmann \n🗣 @SergiRober...          Grabyo
# 2     "He didn't just score both goals against Ibiza...  Hootsuite Inc.
# 3     "🎥 HIGHLIGHTS | Ibiza 1 – 2 Barça | Copa del R...          Grabyo
# 4     "👨‍✈️ @SergiRoberto10 💙❤️ https://t.co/TBV6mWt...  Hootsuite Inc.
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Barca_Tweets_df = Barca_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Barca_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Barca_Tweets_df['Tweet Posted Time'] = Barca_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Barca_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Barca_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Barca_Tweets_df['Tweet Posted Time'] = Barca_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Barca_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Barca_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Barca_Tweets_df = Barca_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Barca_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
Barca_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# 0     fcbarcelona  "96951800"      Tweet
# 1     fcbarcelona  "96951800"      Tweet
# 2     fcbarcelona  "96951800"      Tweet
# 3     fcbarcelona  "96951800"      Tweet
# 4     fcbarcelona  "96951800"      Tweet
# ...           ...         ...        ...
# 3195  fcbarcelona  "96951800"      Tweet
# 3196  fcbarcelona  "96951800"      Tweet
# 3197  fcbarcelona  "96951800"      Tweet
# 3198  fcbarcelona  "96951800"      Tweet
# 3199  fcbarcelona  "96951800"      Tweet
#
#                                           Tweet Content          Client  \
# 0     "🎥 HIGHLIGHTS 🎥\n\nCOPA DEL REY | Ibiza 1 – 2 ...          Grabyo
# 1     "🗣 @QSetien \n🗣 @AntoGriezmann \n🗣 @SergiRober...          Grabyo
# 2     "He didn't just score both goals against Ibiza...  Hootsuite Inc.
# 3     "🎥 HIGHLIGHTS | Ibiza 1 – 2 Barça | Copa del R...          Grabyo
# 4     "👨‍✈️ @SergiRoberto10 💙❤️ https://t.co/TBV6mWt...  Hootsuite Inc.
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Barca_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
Barca_Tweets_df['Vocation'] = "Sport"

#Show the 'shape' of the dataframe
shape = Barca_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Barca_Tweets_df.index = [x for x in range(1, len(Barca_Tweets_df.values)+1)]
Barca_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Barca_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# Index
# 1      fcbarcelona  "96951800"      Tweet
# 2      fcbarcelona  "96951800"      Tweet
# 3      fcbarcelona  "96951800"      Tweet
# 4      fcbarcelona  "96951800"      Tweet
# 5      fcbarcelona  "96951800"      Tweet
# ...            ...         ...        ...
# 3196   fcbarcelona  "96951800"      Tweet
# 3197   fcbarcelona  "96951800"      Tweet
# 3198   fcbarcelona  "96951800"      Tweet
# 3199   fcbarcelona  "96951800"      Tweet
# 3200   fcbarcelona  "96951800"      Tweet
#
#                                            Tweet Content          Client  \
# Index
# 1      "🎥 HIGHLIGHTS 🎥\n\nCOPA DEL REY | Ibiza 1 – 2 ...          Grabyo
# 2      "🗣 @QSetien \n🗣 @AntoGriezmann \n🗣 @SergiRober...          Grabyo
# 3      "He didn't just score both goals against Ibiza...  Hootsuite Inc.
# 4      "🎥 HIGHLIGHTS | Ibiza 1 – 2 Barça | Copa del R...          Grabyo
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Barca_Tweets_df.to_csv('Barca_Tweets_df.csv')
