# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Harry Styles Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "HarryStylesTweets.csv"

#Import the CSV into a pandas DataFrame
HStyles_Tweets_df = pd.read_csv(csv_path, low_memory = False)
HStyles_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1217562122307227649"
# 1     "1216363331864485888"
# 2     "1209062698484412418"
# 3     "1208085367481614337"
# 4     "1206686730285441027"
# ...                     ...
# 3195   "141492074947162113"
# 3196   "141491790871138304"
# 3197   "141490261246222336"
# 3198   "141488568303484928"
# 3199   "141176393508732928"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/harry_styles/status/121756...  2020-01-15 21:40:05
# 1     https://twitter.com/harry_styles/status/121636...  2020-01-12 14:16:31
# 2     https://twitter.com/harry_styles/status/120906...  2019-12-23 10:46:25
# 3     https://twitter.com/harry_styles/status/120808...  2019-12-20 18:02:51
# 4     https://twitter.com/harry_styles/status/120668...  2019-12-16 21:25:10
# ...                                                 ...                  ...
# 3195  https://twitter.com/harry_styles/status/141492...  2011-11-29 12:21:54
# 3196  https://twitter.com/harry_styles/status/141491...  2011-11-29 12:20:46
# 3197  https://twitter.com/harry_styles/status/141490...  2011-11-29 12:14:41
# 3198  https://twitter.com/harry_styles/status/141488...  2011-11-29 12:07:58
# 3199  https://twitter.com/harry_styles/status/141176...  2011-11-28 15:27:29
#
#                                           Tweet Content Tweet Type  \
# 0                 "18 FEB 2020 https://t.co/nk3GRVMufe"      Tweet
# 1     "HAPPY NEW YEAR! Thank you @BRITs for the nomi...      Tweet
# 2     "Wishing everyone a wonderful Christmas time. ...      Tweet
# 3     "FINE LINE LIVE IN LONDON.\nDEC 19 2019. https...      Tweet
# 4     "Thank you to everyone listening to FINE LINE,...      Tweet
# ...                                                 ...        ...
# 3195  "Big thanks to everyone who got involved in ou...      Tweet
# 3196  "@emmaaclaire happy birthday!!! :) have a good...      Reply
# 3197  "@niallervibes very well thank :) woke up in a...      Reply
# 3198  "RT @hotpatooties If you're on Orange please v...      Tweet
# 3199               "Trafalgar Square... Let's Do It!!!"      Tweet
#
#                        Client  Retweets received  Likes received      User Id  \
# 0          Twitter for iPhone              46829          267621  "181561712"
# 1          Twitter for iPhone              55571          273738  "181561712"
# 2          Twitter for iPhone             142828          666466  "181561712"
# 3          Twitter for iPhone              31828          218063  "181561712"
# 4          Twitter for iPhone              66469          320991  "181561712"
# ...                       ...                ...             ...          ...
# 3195       Twitter for iPhone               2924            1045  "181561712"
# 3196       Twitter for iPhone                244             178  "181561712"
# 3197       Twitter for iPhone                250             191  "181561712"
# 3198       Twitter for iPhone                504             376  "181561712"
# 3199  Twitter for BlackBerry®               2794             935  "181561712"
#
#                  Name      Username Verified or Non-Verified  \
# 0     "Harry Styles."  harry_styles                 Verified
# 1     "Harry Styles."  harry_styles                 Verified
# 2     "Harry Styles."  harry_styles                 Verified
# 3     "Harry Styles."  harry_styles                 Verified
# 4     "Harry Styles."  harry_styles                 Verified
# ...               ...           ...                      ...
# 3195  "Harry Styles."  harry_styles                 Verified
# 3196  "Harry Styles."  harry_styles                 Verified
# 3197  "Harry Styles."  harry_styles                 Verified
# 3198  "Harry Styles."  harry_styles                 Verified
# 3199  "Harry Styles."  harry_styles                 Verified
#
#                            Profile URL Protected or Not Protected
# 0     https://twitter.com/harry_styles              Not Protected
# 1     https://twitter.com/harry_styles              Not Protected
# 2     https://twitter.com/harry_styles              Not Protected
# 3     https://twitter.com/harry_styles              Not Protected
# 4     https://twitter.com/harry_styles              Not Protected
# ...                                ...                        ...
# 3195  https://twitter.com/harry_styles              Not Protected
# 3196  https://twitter.com/harry_styles              Not Protected
# 3197  https://twitter.com/harry_styles              Not Protected
# 3198  https://twitter.com/harry_styles              Not Protected
# 3199  https://twitter.com/harry_styles              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = HStyles_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
HStyles_Tweets_df = HStyles_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = HStyles_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
HStyles_Tweets_df
# Out:
#           Username      User Id Tweet Type  \
# 0     harry_styles  "181561712"      Tweet
# 1     harry_styles  "181561712"      Tweet
# 2     harry_styles  "181561712"      Tweet
# 3     harry_styles  "181561712"      Tweet
# 4     harry_styles  "181561712"      Tweet
# ...            ...          ...        ...
# 3195  harry_styles  "181561712"      Tweet
# 3196  harry_styles  "181561712"      Reply
# 3197  harry_styles  "181561712"      Reply
# 3198  harry_styles  "181561712"      Tweet
# 3199  harry_styles  "181561712"      Tweet
#
#                                           Tweet Content  \
# 0                 "18 FEB 2020 https://t.co/nk3GRVMufe"
# 1     "HAPPY NEW YEAR! Thank you @BRITs for the nomi...
# 2     "Wishing everyone a wonderful Christmas time. ...
# 3     "FINE LINE LIVE IN LONDON.\nDEC 19 2019. https...
# 4     "Thank you to everyone listening to FINE LINE,...
# ...                                                 ...
# 3195  "Big thanks to everyone who got involved in ou...
# 3196  "@emmaaclaire happy birthday!!! :) have a good...
# 3197  "@niallervibes very well thank :) woke up in a...
# 3198  "RT @hotpatooties If you're on Orange please v...
# 3199               "Trafalgar Square... Let's Do It!!!"
#
#                        Client  Retweets received  Likes received  \
# 0          Twitter for iPhone              46829          267621
# 1          Twitter for iPhone              55571          273738
# 2          Twitter for iPhone             142828          666466
# 3          Twitter for iPhone              31828          218063
# 4          Twitter for iPhone              66469          320991
# ...                       ...                ...             ...
# 3195       Twitter for iPhone               2924            1045
# 3196       Twitter for iPhone                244             178
# 3197       Twitter for iPhone                250             191
# 3198       Twitter for iPhone                504             376
# 3199  Twitter for BlackBerry®               2794             935
#
#         Tweet Posted Time
# 0     2020-01-15 21:40:05
# 1     2020-01-12 14:16:31
# 2     2019-12-23 10:46:25
# 3     2019-12-20 18:02:51
# 4     2019-12-16 21:25:10
# ...                   ...
# 3195  2011-11-29 12:21:54
# 3196  2011-11-29 12:20:46
# 3197  2011-11-29 12:14:41
# 3198  2011-11-29 12:07:58
# 3199  2011-11-28 15:27:29
#
# [3200 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
HStyles_Tweets_df = HStyles_Tweets_df.dropna() 

#Confirm rows are dropped
shape = HStyles_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
HStyles_Tweets_df['Tweet Posted Time'] = HStyles_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = HStyles_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
HStyles_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
HStyles_Tweets_df['Tweet Posted Time'] = HStyles_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = HStyles_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
HStyles_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
HStyles_Tweets_df = HStyles_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = HStyles_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
HStyles_Tweets_df
# Out:
#           Username      User Id Tweet Type  \
# 0     harry_styles  "181561712"      Tweet
# 1     harry_styles  "181561712"      Tweet
# 2     harry_styles  "181561712"      Tweet
# 3     harry_styles  "181561712"      Tweet
# 4     harry_styles  "181561712"      Tweet
# ...            ...          ...        ...
# 3195  harry_styles  "181561712"      Tweet
# 3196  harry_styles  "181561712"      Reply
# 3197  harry_styles  "181561712"      Reply
# 3198  harry_styles  "181561712"      Tweet
# 3199  harry_styles  "181561712"      Tweet
#
#                                           Tweet Content  \
# 0                 "18 FEB 2020 https://t.co/nk3GRVMufe"
# 1     "HAPPY NEW YEAR! Thank you @BRITs for the nomi...
# 2     "Wishing everyone a wonderful Christmas time. ...
# 3     "FINE LINE LIVE IN LONDON.\nDEC 19 2019. https...
# 4     "Thank you to everyone listening to FINE LINE,...
# ...                                                 ...
# 3195  "Big thanks to everyone who got involved in ou...
# 3196  "@emmaaclaire happy birthday!!! :) have a good...
# 3197  "@niallervibes very well thank :) woke up in a...
# 3198  "RT @hotpatooties If you're on Orange please v...
# 3199               "Trafalgar Square... Let's Do It!!!"
#
#                        Client  Retweets received  Likes received        Date  \
# 0          Twitter for iPhone              46829          267621  2020-01-15
# 1          Twitter for iPhone              55571          273738  2020-01-12
# 2          Twitter for iPhone             142828          666466  2019-12-23
# 3          Twitter for iPhone              31828          218063  2019-12-20
# 4          Twitter for iPhone              66469          320991  2019-12-16
# ...                       ...                ...             ...         ...
# 3195       Twitter for iPhone               2924            1045  2011-11-29
# 3196       Twitter for iPhone                244             178  2011-11-29
# 3197       Twitter for iPhone                250             191  2011-11-29
# 3198       Twitter for iPhone                504             376  2011-11-29
# 3199  Twitter for BlackBerry®               2794             935  2011-11-28
#
#           Time
# 0     21:40:05
# 1     14:16:31
# 2     10:46:25
# 3     18:02:51
# 4     21:25:10
# ...        ...
# 3195  12:21:54
# 3196  12:20:46
# 3197  12:14:41
# 3198  12:07:58
# 3199  15:27:29
#
# [3200 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
HStyles_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
HStyles_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = HStyles_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
HStyles_Tweets_df.index = [x for x in range(1, len(HStyles_Tweets_df.values)+1)]
HStyles_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
HStyles_Tweets_df
# Out:
#            Username      User Id Tweet Type  \
# Index
# 1      harry_styles  "181561712"      Tweet
# 2      harry_styles  "181561712"      Tweet
# 3      harry_styles  "181561712"      Tweet
# 4      harry_styles  "181561712"      Tweet
# 5      harry_styles  "181561712"      Tweet
# ...             ...          ...        ...
# 3196   harry_styles  "181561712"      Tweet
# 3197   harry_styles  "181561712"      Reply
# 3198   harry_styles  "181561712"      Reply
# 3199   harry_styles  "181561712"      Tweet
# 3200   harry_styles  "181561712"      Tweet
#
#                                            Tweet Content  \
# Index
# 1                  "18 FEB 2020 https://t.co/nk3GRVMufe"
# 2      "HAPPY NEW YEAR! Thank you @BRITs for the nomi...
# 3      "Wishing everyone a wonderful Christmas time. ...
# 4      "FINE LINE LIVE IN LONDON.\nDEC 19 2019. https...
# 5      "Thank you to everyone listening to FINE LINE,...
# ...                                                  ...
# 3196   "Big thanks to everyone who got involved in ou...
# 3197   "@emmaaclaire happy birthday!!! :) have a good...
# 3198   "@niallervibes very well thank :) woke up in a...
# 3199   "RT @hotpatooties If you're on Orange please v...
# 3200                "Trafalgar Square... Let's Do It!!!"
#
#                         Client  Retweets received  Likes received        Date  \
# Index
# 1           Twitter for iPhone              46829          267621  2020-01-15
# 2           Twitter for iPhone              55571          273738  2020-01-12
# 3           Twitter for iPhone             142828          666466  2019-12-23
# 4           Twitter for iPhone              31828          218063  2019-12-20
# 5           Twitter for iPhone              66469          320991  2019-12-16
# ...                        ...                ...             ...         ...
# 3196        Twitter for iPhone               2924            1045  2011-11-29
# 3197        Twitter for iPhone                244             178  2011-11-29
# 3198        Twitter for iPhone                250             191  2011-11-29
# 3199        Twitter for iPhone                504             376  2011-11-29
# 3200   Twitter for BlackBerry®               2794             935  2011-11-28
#
#            Time Gender Vocation
# Index
# 1      21:40:05   Male    Music
# 2      14:16:31   Male    Music
# 3      10:46:25   Male    Music
# 4      18:02:51   Male    Music
# 5      21:25:10   Male    Music
# ...         ...    ...      ...
# 3196   12:21:54   Male    Music
# 3197   12:20:46   Male    Music
# 3198   12:14:41   Male    Music
# 3199   12:07:58   Male    Music
# 3200   15:27:29   Male    Music
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
HStyles_Tweets_df.to_csv('HStyles_Tweets_df.csv')
