# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Justin Timberlake Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "JustinTimberLakeTweets.csv"

#Import the CSV into a pandas DataFrame
JTimberlake_Tweets_df = pd.read_csv(csv_path, low_memory = False)
JTimberlake_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1218185336603529217"
# 1     "1212492165844291585"
# 2     "1211717959334408194"
# 3     "1209512769491554305"
# 4     "1194993347930345474"
# ...                     ...
# 3195   "215974474837798913"
# 3196   "215974296642789376"
# 3197   "215974282872889344"
# 3198   "215974100986904576"
# 3199   "215973780676296707"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/jtimberlake/status/1218185...  2020-01-17 14:56:31
# 1     https://twitter.com/timbaland/status/121249216...  2020-01-01 21:53:54
# 2     https://twitter.com/jtimberlake/status/1211717...  2019-12-30 18:37:28
# 3     https://twitter.com/complex/status/12095127694...  2019-12-24 16:34:50
# 4     https://twitter.com/jtimberlake/status/1194993...  2019-11-14 14:59:50
# ...                                                 ...                  ...
# 3195  https://twitter.com/kelly_miller/status/215974...  2012-06-22 01:08:22
# ...

# %%
#Show the 'shape' of the dataframe 
shape = JTimberlake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
JTimberlake_Tweets_df = JTimberlake_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = JTimberlake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
JTimberlake_Tweets_df
# Out:
#              Username      User Id Tweet Type  \
# 0         jtimberlake   "26565946"      Tweet
# 1           timbaland  "207923746"    Retweet
# 2         jtimberlake   "26565946"      Tweet
# 3             complex   "13049362"    Retweet
# 4         jtimberlake   "26565946"      Tweet
# ...               ...          ...        ...
# 3195     kelly_miller   "27341831"    Retweet
# 3196   prophecymaster  "104680144"    Retweet
# 3197         rees1025  "325669429"    Retweet
# 3198    trevorlloyd92  "414946002"    Retweet
# 3199  bambi_allsmiles  "244706714"    Retweet
#
#                                           Tweet Content  \
# 0     "https://t.co/XKS2HL5sHY https://t.co/nA7DDWzojJ"
# 1     "Since we in 2020 what’s y’all fav song off th...
# 2     "What a year. Happy birthday @TigerWoods 🙌 htt...
# 3     "The latest trailer for Michael Jordan's doc #...
# 4     "#TrollsWorldTour 🤘 New trailer drops in ONE H...
# ...                                                 ...
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
JTimberlake_Tweets_df = JTimberlake_Tweets_df.dropna() 

#Confirm rows are dropped
shape = JTimberlake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
JTimberlake_Tweets_df['Tweet Posted Time'] = JTimberlake_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = JTimberlake_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
JTimberlake_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
JTimberlake_Tweets_df['Tweet Posted Time'] = JTimberlake_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = JTimberlake_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
JTimberlake_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
JTimberlake_Tweets_df = JTimberlake_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = JTimberlake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
JTimberlake_Tweets_df
# Out:
#              Username      User Id Tweet Type  \
# 0         jtimberlake   "26565946"      Tweet
# 1           timbaland  "207923746"    Retweet
# 2         jtimberlake   "26565946"      Tweet
# 3             complex   "13049362"    Retweet
# 4         jtimberlake   "26565946"      Tweet
# ...               ...          ...        ...
# 3195     kelly_miller   "27341831"    Retweet
# 3196   prophecymaster  "104680144"    Retweet
# 3197         rees1025  "325669429"    Retweet
# 3198    trevorlloyd92  "414946002"    Retweet
# 3199  bambi_allsmiles  "244706714"    Retweet
#
#                                           Tweet Content  \
# 0     "https://t.co/XKS2HL5sHY https://t.co/nA7DDWzojJ"
# 1     "Since we in 2020 what’s y’all fav song off th...
# 2     "What a year. Happy birthday @TigerWoods 🙌 htt...
# 3     "The latest trailer for Michael Jordan's doc #...
# 4     "#TrollsWorldTour 🤘 New trailer drops in ONE H...
# ...                                                 ...
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
JTimberlake_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
JTimberlake_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = JTimberlake_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
JTimberlake_Tweets_df.index = [x for x in range(1, len(JTimberlake_Tweets_df.values)+1)]
JTimberlake_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
JTimberlake_Tweets_df
# Out:
#               Username      User Id Tweet Type  \
# Index
# 1          jtimberlake   "26565946"      Tweet
# 2            timbaland  "207923746"    Retweet
# 3          jtimberlake   "26565946"      Tweet
# 4              complex   "13049362"    Retweet
# 5          jtimberlake   "26565946"      Tweet
# ...                ...          ...        ...
# 3196      kelly_miller   "27341831"    Retweet
# 3197    prophecymaster  "104680144"    Retweet
# 3198          rees1025  "325669429"    Retweet
# 3199     trevorlloyd92  "414946002"    Retweet
# 3200   bambi_allsmiles  "244706714"    Retweet
#
#                                            Tweet Content  \
# Index
# 1      "https://t.co/XKS2HL5sHY https://t.co/nA7DDWzojJ"
# 2      "Since we in 2020 what’s y’all fav song off th...
# 3      "What a year. Happy birthday @TigerWoods 🙌 htt...
# 4      "The latest trailer for Michael Jordan's doc #...
# 5      "#TrollsWorldTour 🤘 New trailer drops in ONE H...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
JTimberlake_Tweets_df.to_csv('JTimberlake_Tweets_df.csv')
