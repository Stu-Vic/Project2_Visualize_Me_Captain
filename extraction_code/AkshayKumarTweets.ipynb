# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Akshay Kumar Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "AkshayKumarTweets.csv"

#Import the CSV into a pandas DataFrame
AKumar_Tweets_df = pd.read_csv(csv_path, low_memory = False)
AKumar_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220262518519521281"
# 1     "1220236816604749824"
# 2     "1219804361133477890"
# 3     "1219491375793635329"
# 4     "1219156453354655745"
# ...                     ...
# 3195   "941559727670087680"
# 3196   "941559726827073536"
# 3197   "941559726223052800"
# 3198   "941559725099028480"
# 3199   "941559724264296448"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/akshaykumar/status/1220262...  2020-01-23 08:30:30
# 1     https://twitter.com/akshaykumar/status/1220236...  2020-01-23 06:48:22
# 2     https://twitter.com/akshaykumar/status/1219804...  2020-01-22 02:09:57
# 3     https://twitter.com/akshaykumar/status/1219491...  2020-01-21 05:26:15
# 4     https://twitter.com/akshaykumar/status/1219156...  2020-01-20 07:15:23
# ...                                                 ...                  ...
# 3195  https://twitter.com/akshaykumar/status/9415597...  2017-12-15 06:45:07
# ...

# %%
#Show the 'shape' of the dataframe 
shape = AKumar_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
AKumar_Tweets_df = AKumar_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = AKumar_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
AKumar_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# 0     akshaykumar  "31348594"      Tweet
# 1     akshaykumar  "31348594"      Tweet
# 2     akshaykumar  "31348594"      Tweet
# 3     akshaykumar  "31348594"      Tweet
# 4     akshaykumar  "31348594"      Tweet
# ...           ...         ...        ...
# 3195  akshaykumar  "31348594"      Reply
# 3196  akshaykumar  "31348594"      Reply
# 3197  akshaykumar  "31348594"      Reply
# 3198  akshaykumar  "31348594"      Reply
# 3199  akshaykumar  "31348594"      Reply
#
#                                           Tweet Content  \
# 0     "The story continues with another melody... #F...
# 1     "#Durgavati begins, with blessings and good vi...
# 2     "Just like the new #Activa6G, would you like t...
# 3     "Do more of what you love doing and that’s exa...
# 4     "Either you run the day or the day runs you 👊🏻...
# ...                                                 ...
# 3195  "@shiviadarsh #PadManTrailer is here and I can...
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
AKumar_Tweets_df = AKumar_Tweets_df.dropna() 

#Confirm rows are dropped
shape = AKumar_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
AKumar_Tweets_df['Tweet Posted Time'] = AKumar_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = AKumar_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
AKumar_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
AKumar_Tweets_df['Tweet Posted Time'] = AKumar_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = AKumar_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
AKumar_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
AKumar_Tweets_df = AKumar_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = AKumar_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
AKumar_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# 0     akshaykumar  "31348594"      Tweet
# 1     akshaykumar  "31348594"      Tweet
# 2     akshaykumar  "31348594"      Tweet
# 3     akshaykumar  "31348594"      Tweet
# 4     akshaykumar  "31348594"      Tweet
# ...           ...         ...        ...
# 3195  akshaykumar  "31348594"      Reply
# 3196  akshaykumar  "31348594"      Reply
# 3197  akshaykumar  "31348594"      Reply
# 3198  akshaykumar  "31348594"      Reply
# 3199  akshaykumar  "31348594"      Reply
#
#                                           Tweet Content  \
# 0     "The story continues with another melody... #F...
# 1     "#Durgavati begins, with blessings and good vi...
# 2     "Just like the new #Activa6G, would you like t...
# 3     "Do more of what you love doing and that’s exa...
# 4     "Either you run the day or the day runs you 👊🏻...
# ...                                                 ...
# 3195  "@shiviadarsh #PadManTrailer is here and I can...
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
AKumar_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
AKumar_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = AKumar_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
AKumar_Tweets_df.index = [x for x in range(1, len(AKumar_Tweets_df.values)+1)]
AKumar_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
AKumar_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# Index
# 1      akshaykumar  "31348594"      Tweet
# 2      akshaykumar  "31348594"      Tweet
# 3      akshaykumar  "31348594"      Tweet
# 4      akshaykumar  "31348594"      Tweet
# 5      akshaykumar  "31348594"      Tweet
# ...            ...         ...        ...
# 3196   akshaykumar  "31348594"      Reply
# 3197   akshaykumar  "31348594"      Reply
# 3198   akshaykumar  "31348594"      Reply
# 3199   akshaykumar  "31348594"      Reply
# 3200   akshaykumar  "31348594"      Reply
#
#                                            Tweet Content  \
# Index
# 1      "The story continues with another melody... #F...
# 2      "#Durgavati begins, with blessings and good vi...
# 3      "Just like the new #Activa6G, would you like t...
# 4      "Do more of what you love doing and that’s exa...
# 5      "Either you run the day or the day runs you 👊🏻...
# ...                                                  ...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
AKumar_Tweets_df.to_csv('AKumar_Tweets_df.csv')
