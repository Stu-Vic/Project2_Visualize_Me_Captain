# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Britney Spears Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "BritneySpearsTweets.csv"

#Import the CSV into a pandas DataFrame
BSpears_Tweets_df = pd.read_csv(csv_path, low_memory = False)
BSpears_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1197968678957936640"
# 1     "1190678187950379008"
# 2     "1190364370540384257"
# 3     "1190328050350620673"
# 4     "1164720241777111040"
# ...                     ...
# 3195   "354391865765801985"
# 3196   "354320286251884544"
# 3197   "353689421851279360"
# 3198   "353627051439308800"
# 3199   "352869058959515648"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/britneythezone/status/1197...  2019-11-22 20:02:44
# 1     https://twitter.com/britneyspears/status/11906...  2019-11-02 17:12:56
# 2     https://twitter.com/britneyspears/status/11903...  2019-11-01 20:25:56
# 3     https://twitter.com/britneythezone/status/1190...  2019-11-01 18:01:37
# 4     https://twitter.com/britneyspears/status/11647...  2019-08-23 02:05:19
# ...                                                 ...                  ...
# 3195  https://twitter.com/britneyspears/status/35439...  2013-07-09 00:09:39
# ...

# %%
#Show the 'shape' of the dataframe 
shape = BSpears_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
BSpears_Tweets_df = BSpears_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = BSpears_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
BSpears_Tweets_df
# Out:
#             Username                User Id Tweet Type  \
# 0     britneythezone  "1069680229860417536"    Retweet
# 1      britneyspears             "16409683"      Tweet
# 2      britneyspears             "16409683"      Tweet
# 3     britneythezone  "1069680229860417536"    Retweet
# 4      britneyspears             "16409683"      Tweet
# ...              ...                    ...        ...
# 3195   britneyspears             "16409683"      Tweet
# 3196            s_c_             "17560096"    Retweet
# 3197   britneyspears             "16409683"      Tweet
# 3198   britneyspears             "16409683"      Tweet
# 3199   britneyspears             "16409683"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "⭐️ CALLING. ALL. BRITNEY. FANS. ⭐️ We're doin...     Twitter Web App
# 1     "Coming soon !!!! 😜😜😜 I can’t wait to see all ...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
BSpears_Tweets_df = BSpears_Tweets_df.dropna() 

#Confirm rows are dropped
shape = BSpears_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BSpears_Tweets_df['Tweet Posted Time'] = BSpears_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BSpears_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
BSpears_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
BSpears_Tweets_df['Tweet Posted Time'] = BSpears_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = BSpears_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
BSpears_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
BSpears_Tweets_df = BSpears_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = BSpears_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
BSpears_Tweets_df
# Out:
#             Username                User Id Tweet Type  \
# 0     britneythezone  "1069680229860417536"    Retweet
# 1      britneyspears             "16409683"      Tweet
# 2      britneyspears             "16409683"      Tweet
# 3     britneythezone  "1069680229860417536"    Retweet
# 4      britneyspears             "16409683"      Tweet
# ...              ...                    ...        ...
# 3195   britneyspears             "16409683"      Tweet
# 3196            s_c_             "17560096"    Retweet
# 3197   britneyspears             "16409683"      Tweet
# 3198   britneyspears             "16409683"      Tweet
# 3199   britneyspears             "16409683"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "⭐️ CALLING. ALL. BRITNEY. FANS. ⭐️ We're doin...     Twitter Web App
# 1     "Coming soon !!!! 😜😜😜 I can’t wait to see all ...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
BSpears_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
BSpears_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = BSpears_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
BSpears_Tweets_df.index = [x for x in range(1, len(BSpears_Tweets_df.values)+1)]
BSpears_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
BSpears_Tweets_df
# Out:
#              Username                User Id Tweet Type  \
# Index
# 1      britneythezone  "1069680229860417536"    Retweet
# 2       britneyspears             "16409683"      Tweet
# 3       britneyspears             "16409683"      Tweet
# 4      britneythezone  "1069680229860417536"    Retweet
# 5       britneyspears             "16409683"      Tweet
# ...               ...                    ...        ...
# 3196    britneyspears             "16409683"      Tweet
# 3197             s_c_             "17560096"    Retweet
# 3198    britneyspears             "16409683"      Tweet
# 3199    britneyspears             "16409683"      Tweet
# 3200    britneyspears             "16409683"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "⭐️ CALLING. ALL. BRITNEY. FANS. ⭐️ We're doin...     Twitter Web App
# 2      "Coming soon !!!! 😜😜😜 I can’t wait to see all ...  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
BSpears_Tweets_df.to_csv('BSpears_Tweets_df.csv')
