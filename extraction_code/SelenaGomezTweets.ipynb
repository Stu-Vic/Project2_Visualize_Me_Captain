# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Selena Gomez Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "SelenaGomezTweets.csv"

#Import the CSV into a pandas DataFrame
SGomez_Tweets_df = pd.read_csv(csv_path, low_memory = False)
SGomez_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220211174270128128"
# 1     "1220118821706420225"
# 2     "1220089560433954816"
# 3     "1219426990907740161"
# 4     "1219053571670343680"
# ...                     ...
# 3195    "30118610919751681"
# 3196    "29974908003942400"
# 3197    "29218975904698368"
# 3198    "28875425421721600"
# 3199    "28578750350229504"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/selenagomez/status/1220211...  2020-01-23 05:06:29
# 1     https://twitter.com/selenagomez/status/1220118...  2020-01-22 22:59:30
# 2     https://twitter.com/selenagomez/status/1220089...  2020-01-22 21:03:14
# 3     https://twitter.com/selenagomez/status/1219426...  2020-01-21 01:10:25
# 4     https://twitter.com/selenagomez/status/1219053...  2020-01-20 00:26:35
# ...                                                 ...                  ...
# 3195  https://twitter.com/selenagomez/status/3011861...  2011-01-26 04:23:31
# ...

# %%
#Show the 'shape' of the dataframe 
shape = SGomez_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
SGomez_Tweets_df = SGomez_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = SGomez_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
SGomez_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# 0     selenagomez  "23375688"      Tweet
# 1     selenagomez  "23375688"      Reply
# 2     selenagomez  "23375688"      Tweet
# 3     selenagomez  "23375688"      Tweet
# 4     selenagomez  "23375688"      Tweet
# ...           ...         ...        ...
# 3195  selenagomez  "23375688"      Tweet
# 3196  selenagomez  "23375688"      Tweet
# 3197  selenagomez  "23375688"      Tweet
# 3198  selenagomez  "23375688"      Tweet
# 3199  selenagomez  "23375688"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "Just wanted to say how grateful I am that LYT...  Twitter for iPhone
# 1                    "@JoanzMarques This is awesome! 💖"  Twitter for iPhone
# 2     "It’s officially out! Thank YOU so much for ma...  Twitter for iPhone
# 3     "Go behind the scenes of the Rare video! ✨🦋 ht...  Twitter for iPhone
# 4     "Love this cover!! @echosmith 💖 https://t.co/U...  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
SGomez_Tweets_df = SGomez_Tweets_df.dropna() 

#Confirm rows are dropped
shape = SGomez_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
SGomez_Tweets_df['Tweet Posted Time'] = SGomez_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = SGomez_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
SGomez_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
SGomez_Tweets_df['Tweet Posted Time'] = SGomez_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = SGomez_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
SGomez_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
SGomez_Tweets_df = SGomez_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = SGomez_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
SGomez_Tweets_df
# Out:
#          Username     User Id Tweet Type  \
# 0     selenagomez  "23375688"      Tweet
# 1     selenagomez  "23375688"      Reply
# 2     selenagomez  "23375688"      Tweet
# 3     selenagomez  "23375688"      Tweet
# 4     selenagomez  "23375688"      Tweet
# ...           ...         ...        ...
# 3195  selenagomez  "23375688"      Tweet
# 3196  selenagomez  "23375688"      Tweet
# 3197  selenagomez  "23375688"      Tweet
# 3198  selenagomez  "23375688"      Tweet
# 3199  selenagomez  "23375688"      Tweet
#
#                                           Tweet Content              Client  \
# 0     "Just wanted to say how grateful I am that LYT...  Twitter for iPhone
# 1                    "@JoanzMarques This is awesome! 💖"  Twitter for iPhone
# 2     "It’s officially out! Thank YOU so much for ma...  Twitter for iPhone
# 3     "Go behind the scenes of the Rare video! ✨🦋 ht...  Twitter for iPhone
# 4     "Love this cover!! @echosmith 💖 https://t.co/U...  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
SGomez_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
SGomez_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = SGomez_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
SGomez_Tweets_df.index = [x for x in range(1, len(SGomez_Tweets_df.values)+1)]
SGomez_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
SGomez_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# Index
# 1      selenagomez  "23375688"      Tweet
# 2      selenagomez  "23375688"      Reply
# 3      selenagomez  "23375688"      Tweet
# 4      selenagomez  "23375688"      Tweet
# 5      selenagomez  "23375688"      Tweet
# ...            ...         ...        ...
# 3196   selenagomez  "23375688"      Tweet
# 3197   selenagomez  "23375688"      Tweet
# 3198   selenagomez  "23375688"      Tweet
# 3199   selenagomez  "23375688"      Tweet
# 3200   selenagomez  "23375688"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1      "Just wanted to say how grateful I am that LYT...  Twitter for iPhone
# 2                     "@JoanzMarques This is awesome! 💖"  Twitter for iPhone
# 3      "It’s officially out! Thank YOU so much for ma...  Twitter for iPhone
# 4      "Go behind the scenes of the Rare video! ✨🦋 ht...  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
SGomez_Tweets_df.to_csv('SGomez_Tweets_df.csv')
