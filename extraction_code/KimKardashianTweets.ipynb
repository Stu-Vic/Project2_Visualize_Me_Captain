# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Kim Kardashian Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "KimKardashianTweets.csv"

#Import the CSV into a pandas DataFrame
KKardashian_Tweets_df = pd.read_csv(csv_path, low_memory = False)
KKardashian_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220003863425478658"
# 1     "1219746621396701184"
# 2     "1219718526073802752"
# 3     "1219715780817772544"
# 4     "1219666190743638017"
# ...                     ...
# 3195  "1053544465464315905"
# 3196  "1053510498405085184"
# 3197  "1053444214820790272"
# 3198  "1053434735307841536"
# 3199  "1053434602927251456"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/kimkardashian/status/12200...  2020-01-22 15:22:42
# 1     https://twitter.com/kyliejenner/status/1219746...  2020-01-21 22:20:30
# 2     https://twitter.com/nordstrom/status/121971852...  2020-01-21 20:28:52
# 3     https://twitter.com/skims/status/1219715780817...  2020-01-21 20:17:58
# 4     https://twitter.com/kimkardashian/status/12196...  2020-01-21 17:00:54
# ...                                                 ...                  ...
# 3195  https://twitter.com/kimkardashian/status/10535...  2018-10-20 07:12:29
# 3196  https://twitter.com/kimkardashian/status/10535...  2018-10-20 04:57:30
# 3197  https://twitter.com/kimkardashian/status/10534...  2018-10-20 00:34:07
# 3198  https://twitter.com/kimkardashian/status/10534...  2018-10-19 23:56:27
# 3199  https://twitter.com/kimkardashian/status/10534...  2018-10-19 23:55:55
#
#                                           Tweet Content Tweet Type  \
# 0             "Morning Madness https://t.co/1fXrBJfVND"      Tweet
# 1            "New Video LIVE 🖤 https://t.co/GJVCCJjm7z"    Retweet
# 2     "Coming soon: SKIMS. Created by @KimKardashian...    Retweet
# 3     "SKIMS is excited to announce our first retail...    Retweet
# 4     "The @skims Essential Bodysuit collection is a...      Tweet
# ...                                                 ...        ...
# 3195  "Watching the new season of Making A Murderer ...      Tweet
# 3196  "I surprised my adorable goddaughter Sophia Pi...      Tweet
# 3197  "Turquoise Tears @kkwbeauty Flashing Lights Co...      Tweet
# 3198                  "Legends https://t.co/0bpaQNQlZV"      Tweet
# 3199  "Everyone tune in to watch Sophia!!! https://t...      Tweet
#
#                   Client  Retweets received  Likes received  \
# 0     Twitter for iPhone              14976          202723
# 1     Twitter for iPhone                355            4288
# 2       Khoros Marketing                180            2520
# 3        Twitter Web App                167            2310
# 4     Twitter for iPhone                120            2604
# ...                  ...                ...             ...
# 3195  Twitter for iPhone                854           16299
# 3196  Twitter for iPhone                232            4254
# 3197  Twitter for iPhone                340            3769
# 3198  Twitter for iPhone                626           15617
# 3199  Twitter for iPhone                126            2996
#
#                     User Id                   Name       Username  \
# 0                "25365536"  "Kim Kardashian West"  kimkardashian
# 1               "236699098"         "Kylie Jenner"    kyliejenner
# 2                "15162193"            "Nordstrom"      nordstrom
# 3     "1149099376968495104"                "SKIMS"          skims
# 4                "25365536"  "Kim Kardashian West"  kimkardashian
# ...                     ...                    ...            ...
# 3195             "25365536"  "Kim Kardashian West"  kimkardashian
# 3196             "25365536"  "Kim Kardashian West"  kimkardashian
# 3197             "25365536"  "Kim Kardashian West"  kimkardashian
# 3198             "25365536"  "Kim Kardashian West"  kimkardashian
# 3199             "25365536"  "Kim Kardashian West"  kimkardashian
#
#      Verified or Non-Verified                        Profile URL  \
# 0                    Verified  https://twitter.com/kimkardashian
# 1                    Verified    https://twitter.com/kyliejenner
# 2                    Verified      https://twitter.com/nordstrom
# 3                    Verified          https://twitter.com/skims
# 4                    Verified  https://twitter.com/kimkardashian
# ...                       ...                                ...
# 3195                 Verified  https://twitter.com/kimkardashian
# 3196                 Verified  https://twitter.com/kimkardashian
# 3197                 Verified  https://twitter.com/kimkardashian
# 3198                 Verified  https://twitter.com/kimkardashian
# 3199                 Verified  https://twitter.com/kimkardashian
#
#      Protected or Not Protected
# 0                 Not Protected
# 1                 Not Protected
# 2                 Not Protected
# 3                 Not Protected
# 4                 Not Protected
# ...                         ...
# 3195              Not Protected
# 3196              Not Protected
# 3197              Not Protected
# 3198              Not Protected
# 3199              Not Protected
#
# [3200 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = KKardashian_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
KKardashian_Tweets_df = KKardashian_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = KKardashian_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
KKardashian_Tweets_df
# Out:
#            Username                User Id Tweet Type  \
# 0     kimkardashian             "25365536"      Tweet
# 1       kyliejenner            "236699098"    Retweet
# 2         nordstrom             "15162193"    Retweet
# 3             skims  "1149099376968495104"    Retweet
# 4     kimkardashian             "25365536"      Tweet
# ...             ...                    ...        ...
# 3195  kimkardashian             "25365536"      Tweet
# 3196  kimkardashian             "25365536"      Tweet
# 3197  kimkardashian             "25365536"      Tweet
# 3198  kimkardashian             "25365536"      Tweet
# 3199  kimkardashian             "25365536"      Tweet
#
#                                           Tweet Content              Client  \
# 0             "Morning Madness https://t.co/1fXrBJfVND"  Twitter for iPhone
# 1            "New Video LIVE 🖤 https://t.co/GJVCCJjm7z"  Twitter for iPhone
# 2     "Coming soon: SKIMS. Created by @KimKardashian...    Khoros Marketing
# 3     "SKIMS is excited to announce our first retail...     Twitter Web App
# 4     "The @skims Essential Bodysuit collection is a...  Twitter for iPhone
# ...                                                 ...                 ...
# 3195  "Watching the new season of Making A Murderer ...  Twitter for iPhone
# 3196  "I surprised my adorable goddaughter Sophia Pi...  Twitter for iPhone
# 3197  "Turquoise Tears @kkwbeauty Flashing Lights Co...  Twitter for iPhone
# 3198                  "Legends https://t.co/0bpaQNQlZV"  Twitter for iPhone
# 3199  "Everyone tune in to watch Sophia!!! https://t...  Twitter for iPhone
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                 14976          202723  2020-01-22 15:22:42
# 1                   355            4288  2020-01-21 22:20:30
# 2                   180            2520  2020-01-21 20:28:52
# 3                   167            2310  2020-01-21 20:17:58
# 4                   120            2604  2020-01-21 17:00:54
# ...                 ...             ...                  ...
# 3195                854           16299  2018-10-20 07:12:29
# 3196                232            4254  2018-10-20 04:57:30
# 3197                340            3769  2018-10-20 00:34:07
# 3198                626           15617  2018-10-19 23:56:27
# 3199                126            2996  2018-10-19 23:55:55
#
# [3200 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
KKardashian_Tweets_df = KKardashian_Tweets_df.dropna() 

#Confirm rows are dropped
shape = KKardashian_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
KKardashian_Tweets_df['Tweet Posted Time'] = KKardashian_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = KKardashian_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
KKardashian_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
KKardashian_Tweets_df['Tweet Posted Time'] = KKardashian_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = KKardashian_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
KKardashian_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
KKardashian_Tweets_df = KKardashian_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = KKardashian_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
KKardashian_Tweets_df
# Out:
#            Username                User Id Tweet Type  \
# 0     kimkardashian             "25365536"      Tweet
# 1       kyliejenner            "236699098"    Retweet
# 2         nordstrom             "15162193"    Retweet
# 3             skims  "1149099376968495104"    Retweet
# 4     kimkardashian             "25365536"      Tweet
# ...             ...                    ...        ...
# 3195  kimkardashian             "25365536"      Tweet
# 3196  kimkardashian             "25365536"      Tweet
# 3197  kimkardashian             "25365536"      Tweet
# 3198  kimkardashian             "25365536"      Tweet
# 3199  kimkardashian             "25365536"      Tweet
#
#                                           Tweet Content              Client  \
# 0             "Morning Madness https://t.co/1fXrBJfVND"  Twitter for iPhone
# 1            "New Video LIVE 🖤 https://t.co/GJVCCJjm7z"  Twitter for iPhone
# 2     "Coming soon: SKIMS. Created by @KimKardashian...    Khoros Marketing
# 3     "SKIMS is excited to announce our first retail...     Twitter Web App
# 4     "The @skims Essential Bodysuit collection is a...  Twitter for iPhone
# ...                                                 ...                 ...
# 3195  "Watching the new season of Making A Murderer ...  Twitter for iPhone
# 3196  "I surprised my adorable goddaughter Sophia Pi...  Twitter for iPhone
# 3197  "Turquoise Tears @kkwbeauty Flashing Lights Co...  Twitter for iPhone
# 3198                  "Legends https://t.co/0bpaQNQlZV"  Twitter for iPhone
# 3199  "Everyone tune in to watch Sophia!!! https://t...  Twitter for iPhone
#
#       Retweets received  Likes received        Date      Time
# 0                 14976          202723  2020-01-22  15:22:42
# 1                   355            4288  2020-01-21  22:20:30
# 2                   180            2520  2020-01-21  20:28:52
# 3                   167            2310  2020-01-21  20:17:58
# 4                   120            2604  2020-01-21  17:00:54
# ...                 ...             ...         ...       ...
# 3195                854           16299  2018-10-20  07:12:29
# 3196                232            4254  2018-10-20  04:57:30
# 3197                340            3769  2018-10-20  00:34:07
# 3198                626           15617  2018-10-19  23:56:27
# 3199                126            2996  2018-10-19  23:55:55
#
# [3200 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
KKardashian_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
KKardashian_Tweets_df['Vocation'] = "Other"

#Show the 'shape' of the dataframe
shape = KKardashian_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
KKardashian_Tweets_df.index = [x for x in range(1, len(KKardashian_Tweets_df.values)+1)]
KKardashian_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
KKardashian_Tweets_df
# Out:
#             Username                User Id Tweet Type  \
# Index
# 1      kimkardashian             "25365536"      Tweet
# 2        kyliejenner            "236699098"    Retweet
# 3          nordstrom             "15162193"    Retweet
# 4              skims  "1149099376968495104"    Retweet
# 5      kimkardashian             "25365536"      Tweet
# ...              ...                    ...        ...
# 3196   kimkardashian             "25365536"      Tweet
# 3197   kimkardashian             "25365536"      Tweet
# 3198   kimkardashian             "25365536"      Tweet
# 3199   kimkardashian             "25365536"      Tweet
# 3200   kimkardashian             "25365536"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1              "Morning Madness https://t.co/1fXrBJfVND"  Twitter for iPhone
# 2             "New Video LIVE 🖤 https://t.co/GJVCCJjm7z"  Twitter for iPhone
# 3      "Coming soon: SKIMS. Created by @KimKardashian...    Khoros Marketing
# 4      "SKIMS is excited to announce our first retail...     Twitter Web App
# 5      "The @skims Essential Bodysuit collection is a...  Twitter for iPhone
# ...                                                  ...                 ...
# 3196   "Watching the new season of Making A Murderer ...  Twitter for iPhone
# 3197   "I surprised my adorable goddaughter Sophia Pi...  Twitter for iPhone
# 3198   "Turquoise Tears @kkwbeauty Flashing Lights Co...  Twitter for iPhone
# 3199                   "Legends https://t.co/0bpaQNQlZV"  Twitter for iPhone
# 3200   "Everyone tune in to watch Sophia!!! https://t...  Twitter for iPhone
#
#        Retweets received  Likes received        Date      Time  Gender  \
# Index
# 1                  14976          202723  2020-01-22  15:22:42  Female
# 2                    355            4288  2020-01-21  22:20:30  Female
# 3                    180            2520  2020-01-21  20:28:52  Female
# 4                    167            2310  2020-01-21  20:17:58  Female
# 5                    120            2604  2020-01-21  17:00:54  Female
# ...                  ...             ...         ...       ...     ...
# 3196                 854           16299  2018-10-20  07:12:29  Female
# 3197                 232            4254  2018-10-20  04:57:30  Female
# 3198                 340            3769  2018-10-20  00:34:07  Female
# 3199                 626           15617  2018-10-19  23:56:27  Female
# 3200                 126            2996  2018-10-19  23:55:55  Female
#
#       Vocation
# Index
# 1        Other
# 2        Other
# 3        Other
# 4        Other
# 5        Other
# ...        ...
# 3196     Other
# 3197     Other
# 3198     Other
# 3199     Other
# 3200     Other
#
# [3200 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
KKardashian_Tweets_df.to_csv('KKardashian_Tweets_df.csv')
