# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # SportsCenter Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "SportsCenterTweets.csv"

#Import the CSV into a pandas DataFrame
SCenter_Tweets_df = pd.read_csv(csv_path, low_memory = False)
SCenter_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220229853557018625"
# 1     "1220222069020991489"
# 2     "1220206449479028737"
# 3     "1220200064896970752"
# 4     "1220187706791165952"
# ...                     ...
# 3195  "1170365477257961472"
# 3196  "1170360002638471169"
# 3197  "1170340635674415107"
# 3198  "1170328579349143553"
# 3199  "1170326488174006272"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/sportscenter/status/122022...  2020-01-23 06:20:42
# 1     https://twitter.com/sportscenter/status/122022...  2020-01-23 05:49:46
# 2     https://twitter.com/sportscenter/status/122020...  2020-01-23 04:47:42
# 3     https://twitter.com/sportscenter/status/122020...  2020-01-23 04:22:20
# 4     https://twitter.com/sportscenter/status/122018...  2020-01-23 03:33:13
# ...                                                 ...                  ...
# 3195  https://twitter.com/sportscenter/status/117036...  2019-09-07 15:57:28
# ...

# %%
#Show the 'shape' of the dataframe 
shape = SCenter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
SCenter_Tweets_df = SCenter_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = SCenter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
SCenter_Tweets_df
# Out:
#             Username      User Id Tweet Type  \
# 0       sportscenter   "26257166"      Tweet
# 1       sportscenter   "26257166"      Tweet
# 2       sportscenter   "26257166"      Tweet
# 3       sportscenter   "26257166"      Tweet
# 4       sportscenter   "26257166"      Tweet
# ...              ...          ...        ...
# 3195    sportscenter   "26257166"      Tweet
# 3196    sportscenter   "26257166"      Tweet
# 3197      diannaespn  "117189498"    Retweet
# 3198  jeffdarlington   "26144265"    Retweet
# 3199    adamschefter   "51263592"    Retweet
#
#                                           Tweet Content                Client  \
# 0     "“Coach, I can win the game for this team. Lea...                Khoros
# 1     "⚡️ 22 Pts\n⚡️ 8-11 FG\n⚡️ 4-4 3-PT FG\n⚡️ 7 R...  Twitter Media Studio
# 2     "ZION IS TAKING OVER 🔥\n\n17 STRAIGHT 😱 https:...                Khoros
# 3     "LeBron was asked about possibly playing for t...                Khoros
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
SCenter_Tweets_df = SCenter_Tweets_df.dropna() 

#Confirm rows are dropped
shape = SCenter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
SCenter_Tweets_df['Tweet Posted Time'] = SCenter_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = SCenter_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
SCenter_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
SCenter_Tweets_df['Tweet Posted Time'] = SCenter_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = SCenter_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
SCenter_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
SCenter_Tweets_df = SCenter_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = SCenter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
SCenter_Tweets_df
# Out:
#             Username      User Id Tweet Type  \
# 0       sportscenter   "26257166"      Tweet
# 1       sportscenter   "26257166"      Tweet
# 2       sportscenter   "26257166"      Tweet
# 3       sportscenter   "26257166"      Tweet
# 4       sportscenter   "26257166"      Tweet
# ...              ...          ...        ...
# 3195    sportscenter   "26257166"      Tweet
# 3196    sportscenter   "26257166"      Tweet
# 3197      diannaespn  "117189498"    Retweet
# 3198  jeffdarlington   "26144265"    Retweet
# 3199    adamschefter   "51263592"    Retweet
#
#                                           Tweet Content                Client  \
# 0     "“Coach, I can win the game for this team. Lea...                Khoros
# 1     "⚡️ 22 Pts\n⚡️ 8-11 FG\n⚡️ 4-4 3-PT FG\n⚡️ 7 R...  Twitter Media Studio
# 2     "ZION IS TAKING OVER 🔥\n\n17 STRAIGHT 😱 https:...                Khoros
# 3     "LeBron was asked about possibly playing for t...                Khoros
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
SCenter_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
SCenter_Tweets_df['Vocation'] = "Sport"

#Show the 'shape' of the dataframe
shape = SCenter_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
SCenter_Tweets_df.index = [x for x in range(1, len(SCenter_Tweets_df.values)+1)]
SCenter_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
SCenter_Tweets_df
# Out:
#              Username      User Id Tweet Type  \
# Index
# 1        sportscenter   "26257166"      Tweet
# 2        sportscenter   "26257166"      Tweet
# 3        sportscenter   "26257166"      Tweet
# 4        sportscenter   "26257166"      Tweet
# 5        sportscenter   "26257166"      Tweet
# ...               ...          ...        ...
# 3196     sportscenter   "26257166"      Tweet
# 3197     sportscenter   "26257166"      Tweet
# 3198       diannaespn  "117189498"    Retweet
# 3199   jeffdarlington   "26144265"    Retweet
# 3200     adamschefter   "51263592"    Retweet
#
#                                            Tweet Content  \
# Index
# 1      "“Coach, I can win the game for this team. Lea...
# 2      "⚡️ 22 Pts\n⚡️ 8-11 FG\n⚡️ 4-4 3-PT FG\n⚡️ 7 R...
# 3      "ZION IS TAKING OVER 🔥\n\n17 STRAIGHT 😱 https:...
# 4      "LeBron was asked about possibly playing for t...
# 5      "Coach Cal was there to see D-Rose in Detroit ...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
SCenter_Tweets_df.to_csv('SCenter_Tweets_df.csv')
