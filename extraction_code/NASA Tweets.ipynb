# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # NASA Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "NASATweets.csv"

#Import the CSV into a pandas DataFrame
NASA_Tweets_df = pd.read_csv(csv_path, low_memory = False)
NASA_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220149150765002752"
# 1     "1220126500843814912"
# 2     "1220124092336082946"
# 3     "1220107625980973056"
# 4     "1220092526738247680"
# ...                     ...
# 3195  "1124018015740289024"
# 3196  "1123965610004758528"
# 3197  "1123959959249661953"
# 3198  "1123952508920004608"
# 3199  "1123945236219215874"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/nasa/status/12201491507650...  2020-01-23 01:00:01
# 1     https://twitter.com/nasa/status/12201265008438...  2020-01-22 23:30:01
# 2     https://twitter.com/jimbridenstine/status/1220...  2020-01-22 23:20:27
# 3     https://twitter.com/nasa/status/12201076259809...  2020-01-22 22:15:01
# 4     https://twitter.com/nasa/status/12200925267382...  2020-01-22 21:15:01
# ...                                                 ...                  ...
# 3195  https://twitter.com/iss_research/status/112401...  2019-05-02 18:29:12
# ...

# %%
#Show the 'shape' of the dataframe 
shape = NASA_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
NASA_Tweets_df = NASA_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = NASA_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
NASA_Tweets_df
# Out:
#             Username      User Id Tweet Type  \
# 0               nasa   "11348282"      Tweet
# 1               nasa   "11348282"      Tweet
# 2     jimbridenstine  "243418245"    Retweet
# 3               nasa   "11348282"      Tweet
# 4               nasa   "11348282"      Tweet
# ...              ...          ...        ...
# 3195    iss_research  "189253902"    Retweet
# 3196            nasa   "11348282"      Tweet
# 3197            nasa   "11348282"      Tweet
# 3198            nasa   "11348282"      Tweet
# 3199            nasa   "11348282"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Burn scars left by wildfires in southeastern ...              Sprinklr
# 1     "The search is on! Are you:\n\n☑️Curious about...              Sprinklr
# 2     "The team has successfully lowered the @NASA_S...       Twitter Web App
# 3     "To help return astronauts to the Moon, our #A...              Sprinklr
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
NASA_Tweets_df = NASA_Tweets_df.dropna() 

#Confirm rows are dropped
shape = NASA_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NASA_Tweets_df['Tweet Posted Time'] = NASA_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NASA_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
NASA_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
NASA_Tweets_df['Tweet Posted Time'] = NASA_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = NASA_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
NASA_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
NASA_Tweets_df = NASA_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = NASA_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
NASA_Tweets_df
# Out:
#             Username      User Id Tweet Type  \
# 0               nasa   "11348282"      Tweet
# 1               nasa   "11348282"      Tweet
# 2     jimbridenstine  "243418245"    Retweet
# 3               nasa   "11348282"      Tweet
# 4               nasa   "11348282"      Tweet
# ...              ...          ...        ...
# 3195    iss_research  "189253902"    Retweet
# 3196            nasa   "11348282"      Tweet
# 3197            nasa   "11348282"      Tweet
# 3198            nasa   "11348282"      Tweet
# 3199            nasa   "11348282"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Burn scars left by wildfires in southeastern ...              Sprinklr
# 1     "The search is on! Are you:\n\n☑️Curious about...              Sprinklr
# 2     "The team has successfully lowered the @NASA_S...       Twitter Web App
# 3     "To help return astronauts to the Moon, our #A...              Sprinklr
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
NASA_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
NASA_Tweets_df['Vocation'] = "Technology"

#Show the 'shape' of the dataframe
shape = NASA_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
NASA_Tweets_df.index = [x for x in range(1, len(NASA_Tweets_df.values)+1)]
NASA_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
NASA_Tweets_df
# Out:
#              Username      User Id Tweet Type  \
# Index
# 1                nasa   "11348282"      Tweet
# 2                nasa   "11348282"      Tweet
# 3      jimbridenstine  "243418245"    Retweet
# 4                nasa   "11348282"      Tweet
# 5                nasa   "11348282"      Tweet
# ...               ...          ...        ...
# 3196     iss_research  "189253902"    Retweet
# 3197             nasa   "11348282"      Tweet
# 3198             nasa   "11348282"      Tweet
# 3199             nasa   "11348282"      Tweet
# 3200             nasa   "11348282"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "Burn scars left by wildfires in southeastern ...
# 2      "The search is on! Are you:\n\n☑️Curious about...
# 3      "The team has successfully lowered the @NASA_S...
# 4      "To help return astronauts to the Moon, our #A...
# 5      "The legacy of @NASASpitzer will live on! Afte...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
NASA_Tweets_df.to_csv('NASA_Tweets_df.csv')
