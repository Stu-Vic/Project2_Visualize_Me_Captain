# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Lady Gaga Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "LadyGagaTweets.csv"

#Import the CSV into a pandas DataFrame
Gaga_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Gaga_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220142182595620865"
# 1     "1218234214052585472"
# 2     "1216101829584359424"
# 3     "1209210336152211456"
# 4     "1207502813657366529"
# ...                     ...
# 3195   "531242897392558080"
# 3196   "531175474660392962"
# 3197   "531074690044149760"
# 3198   "531014677565018112"
# 3199   "530787941455376384"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/ladygaga/status/1220142182...  2020-01-23 00:32:20
# 1     https://twitter.com/hauslabs/status/1218234214...  2020-01-17 18:10:44
# 2     https://twitter.com/ladygaga/status/1216101829...  2020-01-11 20:57:24
# 3     https://twitter.com/hauslabs/status/1209210336...  2019-12-23 20:33:04
# 4     https://twitter.com/ladygaga/status/1207502813...  2019-12-19 03:27:59
# ...                                                 ...                  ...
# 3195  https://twitter.com/stephaniehurts/status/5312...  2014-11-09 00:32:31
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Gaga_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Gaga_Tweets_df = Gaga_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Gaga_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
Gaga_Tweets_df
# Out:
#             Username      User Id Tweet Type  \
# 0           ladygaga   "14230524"      Tweet
# 1           hauslabs  "582519519"    Retweet
# 2           ladygaga   "14230524"      Tweet
# 3           hauslabs  "582519519"    Retweet
# 4           ladygaga   "14230524"      Tweet
# ...              ...          ...        ...
# 3195  stephaniehurts  "235594994"    Retweet
# 3196        ladygaga   "14230524"      Tweet
# 3197        ladygaga   "14230524"      Reply
# 3198      igagaswife  "290819219"    Retweet
# 3199        ladygaga   "14230524"      Tweet
#
#                                           Tweet Content               Client  \
# 0              "can y’all stop https://t.co/1jvZLdY6jV"   Twitter for iPhone
# 1     "ENTER NOW via our latest post on Instagram #H...   Twitter for iPhone
# 2     "Thank you @Oprah for caring, and for helping ...   Twitter for iPhone
# 3     "Our BURLESQUE SET is SOLD OUT on https://t.co...   Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Gaga_Tweets_df = Gaga_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Gaga_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Gaga_Tweets_df['Tweet Posted Time'] = Gaga_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Gaga_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Gaga_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Gaga_Tweets_df['Tweet Posted Time'] = Gaga_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Gaga_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Gaga_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Gaga_Tweets_df = Gaga_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Gaga_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
Gaga_Tweets_df
# Out:
#             Username      User Id Tweet Type  \
# 0           ladygaga   "14230524"      Tweet
# 1           hauslabs  "582519519"    Retweet
# 2           ladygaga   "14230524"      Tweet
# 3           hauslabs  "582519519"    Retweet
# 4           ladygaga   "14230524"      Tweet
# ...              ...          ...        ...
# 3195  stephaniehurts  "235594994"    Retweet
# 3196        ladygaga   "14230524"      Tweet
# 3197        ladygaga   "14230524"      Reply
# 3198      igagaswife  "290819219"    Retweet
# 3199        ladygaga   "14230524"      Tweet
#
#                                           Tweet Content               Client  \
# 0              "can y’all stop https://t.co/1jvZLdY6jV"   Twitter for iPhone
# 1     "ENTER NOW via our latest post on Instagram #H...   Twitter for iPhone
# 2     "Thank you @Oprah for caring, and for helping ...   Twitter for iPhone
# 3     "Our BURLESQUE SET is SOLD OUT on https://t.co...   Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Gaga_Tweets_df['Gender'] = "Female"

#Create an Gender column for Gender
Gaga_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = Gaga_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Gaga_Tweets_df.index = [x for x in range(1, len(Gaga_Tweets_df.values)+1)]
Gaga_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Gaga_Tweets_df
# Out:
#              Username      User Id Tweet Type  \
# Index
# 1            ladygaga   "14230524"      Tweet
# 2            hauslabs  "582519519"    Retweet
# 3            ladygaga   "14230524"      Tweet
# 4            hauslabs  "582519519"    Retweet
# 5            ladygaga   "14230524"      Tweet
# ...               ...          ...        ...
# 3196   stephaniehurts  "235594994"    Retweet
# 3197         ladygaga   "14230524"      Tweet
# 3198         ladygaga   "14230524"      Reply
# 3199       igagaswife  "290819219"    Retweet
# 3200         ladygaga   "14230524"      Tweet
#
#                                            Tweet Content               Client  \
# Index
# 1               "can y’all stop https://t.co/1jvZLdY6jV"   Twitter for iPhone
# 2      "ENTER NOW via our latest post on Instagram #H...   Twitter for iPhone
# 3      "Thank you @Oprah for caring, and for helping ...   Twitter for iPhone
# 4      "Our BURLESQUE SET is SOLD OUT on https://t.co...   Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Gaga_Tweets_df.to_csv('Gaga_Tweets_df.csv')
