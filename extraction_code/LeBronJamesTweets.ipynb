# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # LeBron James Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "LeBronJamesTweets.csv"

#Import the CSV into a pandas DataFrame
LJames_Tweets_df = pd.read_csv(csv_path, low_memory = False)
LJames_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1219997728480153600"
# 1     "1219398135698554882"
# 2     "1218770028499210240"
# 3     "1218274115921928193"
# 4     "1217598936342507523"
# ...                     ...
# 3195   "399172384453701634"
# 3196   "398315132339900416"
# 3197   "398134815809343488"
# 3198   "398008098851659776"
# 3199   "397013151973384194"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/kingjames/status/121999772...  2020-01-22 14:58:19
# 1     https://twitter.com/kingjames/status/121939813...  2020-01-20 23:15:45
# 2     https://twitter.com/kingjames/status/121877002...  2020-01-19 05:39:53
# 3     https://twitter.com/kingjames/status/121827411...  2020-01-17 20:49:18
# 4     https://twitter.com/ipromiseschool/status/1217...  2020-01-16 00:06:22
# ...                                                 ...                  ...
# 3195  https://twitter.com/kingjames/status/399172384...  2013-11-09 13:51:27
# ...

# %%
#Show the 'shape' of the dataframe 
shape = LJames_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
LJames_Tweets_df = LJames_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = LJames_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
LJames_Tweets_df
# Out:
#             Username                User Id Tweet Type  \
# 0          kingjames             "23083404"      Tweet
# 1          kingjames             "23083404"      Tweet
# 2          kingjames             "23083404"      Tweet
# 3          kingjames             "23083404"      Tweet
# 4     ipromiseschool  "1019672184929902592"    Retweet
# ...              ...                    ...        ...
# 3195       kingjames             "23083404"      Tweet
# 3196       kingjames             "23083404"      Tweet
# 3197       kingjames             "23083404"      Tweet
# 3198       kingjames             "23083404"      Tweet
# 3199       kingjames             "23083404"      Reply
#
#                                           Tweet Content               Client  \
# 0     "Y’all know I love this city. Was great to be ...   Twitter for iPhone
# 1     "Hating has no age limit! 🤦🏾‍♂️. #JamesGang is...   Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
LJames_Tweets_df = LJames_Tweets_df.dropna() 

#Confirm rows are dropped
shape = LJames_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
LJames_Tweets_df['Tweet Posted Time'] = LJames_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = LJames_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
LJames_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
LJames_Tweets_df['Tweet Posted Time'] = LJames_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = LJames_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
LJames_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
LJames_Tweets_df = LJames_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = LJames_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
LJames_Tweets_df
# Out:
#             Username                User Id Tweet Type  \
# 0          kingjames             "23083404"      Tweet
# 1          kingjames             "23083404"      Tweet
# 2          kingjames             "23083404"      Tweet
# 3          kingjames             "23083404"      Tweet
# 4     ipromiseschool  "1019672184929902592"    Retweet
# ...              ...                    ...        ...
# 3195       kingjames             "23083404"      Tweet
# 3196       kingjames             "23083404"      Tweet
# 3197       kingjames             "23083404"      Tweet
# 3198       kingjames             "23083404"      Tweet
# 3199       kingjames             "23083404"      Reply
#
#                                           Tweet Content               Client  \
# 0     "Y’all know I love this city. Was great to be ...   Twitter for iPhone
# 1     "Hating has no age limit! 🤦🏾‍♂️. #JamesGang is...   Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
LJames_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
LJames_Tweets_df['Vocation'] = "Sport"

#Show the 'shape' of the dataframe
shape = LJames_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
LJames_Tweets_df.index = [x for x in range(1, len(LJames_Tweets_df.values)+1)]
LJames_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
LJames_Tweets_df
# Out:
#              Username                User Id Tweet Type  \
# Index
# 1           kingjames             "23083404"      Tweet
# 2           kingjames             "23083404"      Tweet
# 3           kingjames             "23083404"      Tweet
# 4           kingjames             "23083404"      Tweet
# 5      ipromiseschool  "1019672184929902592"    Retweet
# ...               ...                    ...        ...
# 3196        kingjames             "23083404"      Tweet
# 3197        kingjames             "23083404"      Tweet
# 3198        kingjames             "23083404"      Tweet
# 3199        kingjames             "23083404"      Tweet
# 3200        kingjames             "23083404"      Reply
#
#                                            Tweet Content               Client  \
# Index
# 1      "Y’all know I love this city. Was great to be ...   Twitter for iPhone
# 2      "Hating has no age limit! 🤦🏾‍♂️. #JamesGang is...   Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
LJames_Tweets_df.to_csv('LJames_Tweets_df.csv')
