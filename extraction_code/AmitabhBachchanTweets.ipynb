# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Amitabh Bachchan Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "AmitabhBachchanTweets.csv"

#Import the CSV into a pandas DataFrame
ABachchan_Tweets_df = pd.read_csv(csv_path, low_memory = False)
ABachchan_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220078580048154624"
# 1     "1219995578911752193"
# 2     "1219995508292243458"
# 3     "1219995451304230912"
# 4     "1219995368315736064"
# ...                     ...
# 3192  "1023354248401231874"
# 3193  "1023351679595569152"
# 3194  "1023146862273093632"
# 3195  "1023026411584540672"
# 3196  "1022826807031156737"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/srbachchan/status/12200785...  2020-01-22 20:19:36
# 1     https://twitter.com/srbachchan/status/12199955...  2020-01-22 14:49:47
# 2     https://twitter.com/srbachchan/status/12199955...  2020-01-22 14:49:30
# 3     https://twitter.com/srbachchan/status/12199954...  2020-01-22 14:49:16
# 4     https://twitter.com/srbachchan/status/12199953...  2020-01-22 14:48:56
# ...                                                 ...                  ...
# 3192  https://twitter.com/srbachchan/status/10233542...  2018-07-28 23:47:20
# 3193  https://twitter.com/srbachchan/status/10233516...  2018-07-28 23:37:08
# 3194  https://twitter.com/srbachchan/status/10231468...  2018-07-28 10:03:15
# 3195  https://twitter.com/srbachchan/status/10230264...  2018-07-28 02:04:38
# 3196  https://twitter.com/srbachchan/status/10228268...  2018-07-27 12:51:28
#
#                                           Tweet Content Tweet Type  \
# 0     "T 3418 -" मोहब्बत त्याग की माँ है ; वो जहाँ ज...      Tweet
# 1                              "@ashokmistry4545 G eve"      Reply
# 2                                   "@SwetaLoveAB Sahi"      Reply
# 3                                 "@prashantkawadia 💕😀"      Reply
# 4                              "@walaalolylovely Smile"      Reply
# ...                                                 ...        ...
# 3192  "T 2881 - Off to work in the rain and slush an...      Tweet
# 3193  "I am hep B .. but got it detected in time and...      Tweet
# 3194  "T 2881 - https://t.co/L9cLGNNUrm\nHere it is....      Tweet
# 3195  "T 2880 - பிறந்தநாள் வாழ்த்துக்கள் \n(Piṟantan...      Tweet
# 3196                                "@BachchanHolic ❤️"      Reply
#
#                   Client  Retweets received  Likes received      User Id  \
# 0        Twitter Web App                398            7544  "145125358"
# 1     Twitter for iPhone                 23             131  "145125358"
# 2     Twitter for iPhone                 22             106  "145125358"
# 3     Twitter for iPhone                 13              31  "145125358"
# 4     Twitter for iPhone                 14              27  "145125358"
# ...                  ...                ...             ...          ...
# 3192  Twitter Web Client               1647           13759  "145125358"
# 3193  Twitter Web Client                287            3248  "145125358"
# 3194  Twitter Web Client                973            4279  "145125358"
# 3195  Twitter Web Client               1622           15185  "145125358"
# 3196  Twitter Web Client                 10              34  "145125358"
#
#                     Name    Username Verified or Non-Verified  \
# 0     "Amitabh Bachchan"  srbachchan                 Verified
# 1     "Amitabh Bachchan"  srbachchan                 Verified
# 2     "Amitabh Bachchan"  srbachchan                 Verified
# 3     "Amitabh Bachchan"  srbachchan                 Verified
# 4     "Amitabh Bachchan"  srbachchan                 Verified
# ...                  ...         ...                      ...
# 3192  "Amitabh Bachchan"  srbachchan                 Verified
# 3193  "Amitabh Bachchan"  srbachchan                 Verified
# 3194  "Amitabh Bachchan"  srbachchan                 Verified
# 3195  "Amitabh Bachchan"  srbachchan                 Verified
# 3196  "Amitabh Bachchan"  srbachchan                 Verified
#
#                          Profile URL Protected or Not Protected
# 0     https://twitter.com/srbachchan              Not Protected
# 1     https://twitter.com/srbachchan              Not Protected
# 2     https://twitter.com/srbachchan              Not Protected
# 3     https://twitter.com/srbachchan              Not Protected
# 4     https://twitter.com/srbachchan              Not Protected
# ...                              ...                        ...
# 3192  https://twitter.com/srbachchan              Not Protected
# 3193  https://twitter.com/srbachchan              Not Protected
# 3194  https://twitter.com/srbachchan              Not Protected
# 3195  https://twitter.com/srbachchan              Not Protected
# 3196  https://twitter.com/srbachchan              Not Protected
#
# [3197 rows x 14 columns]

# %%
#Show the 'shape' of the dataframe 
shape = ABachchan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
ABachchan_Tweets_df = ABachchan_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = ABachchan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 8)

# %%
#Print the dataframe
ABachchan_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# 0     srbachchan  "145125358"      Tweet
# 1     srbachchan  "145125358"      Reply
# 2     srbachchan  "145125358"      Reply
# 3     srbachchan  "145125358"      Reply
# 4     srbachchan  "145125358"      Reply
# ...          ...          ...        ...
# 3192  srbachchan  "145125358"      Tweet
# 3193  srbachchan  "145125358"      Tweet
# 3194  srbachchan  "145125358"      Tweet
# 3195  srbachchan  "145125358"      Tweet
# 3196  srbachchan  "145125358"      Reply
#
#                                           Tweet Content              Client  \
# 0     "T 3418 -" मोहब्बत त्याग की माँ है ; वो जहाँ ज...     Twitter Web App
# 1                              "@ashokmistry4545 G eve"  Twitter for iPhone
# 2                                   "@SwetaLoveAB Sahi"  Twitter for iPhone
# 3                                 "@prashantkawadia 💕😀"  Twitter for iPhone
# 4                              "@walaalolylovely Smile"  Twitter for iPhone
# ...                                                 ...                 ...
# 3192  "T 2881 - Off to work in the rain and slush an...  Twitter Web Client
# 3193  "I am hep B .. but got it detected in time and...  Twitter Web Client
# 3194  "T 2881 - https://t.co/L9cLGNNUrm\nHere it is....  Twitter Web Client
# 3195  "T 2880 - பிறந்தநாள் வாழ்த்துக்கள் \n(Piṟantan...  Twitter Web Client
# 3196                                "@BachchanHolic ❤️"  Twitter Web Client
#
#       Retweets received  Likes received    Tweet Posted Time
# 0                   398            7544  2020-01-22 20:19:36
# 1                    23             131  2020-01-22 14:49:47
# 2                    22             106  2020-01-22 14:49:30
# 3                    13              31  2020-01-22 14:49:16
# 4                    14              27  2020-01-22 14:48:56
# ...                 ...             ...                  ...
# 3192               1647           13759  2018-07-28 23:47:20
# 3193                287            3248  2018-07-28 23:37:08
# 3194                973            4279  2018-07-28 10:03:15
# 3195               1622           15185  2018-07-28 02:04:38
# 3196                 10              34  2018-07-27 12:51:28
#
# [3197 rows x 8 columns]

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
AKumar_Tweets_df = ABachchan_Tweets_df.dropna() 

#Confirm rows are dropped
shape = ABachchan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
ABachchan_Tweets_df['Tweet Posted Time'] = ABachchan_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = ABachchan_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
ABachchan_Tweets_df["Date"] = date
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
ABachchan_Tweets_df['Tweet Posted Time'] = ABachchan_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = ABachchan_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
ABachchan_Tweets_df["Time"] = time
# Out:
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# C:\Users\booda\anaconda3\envs\PythonData\lib\site-packages\ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
ABachchan_Tweets_df = ABachchan_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = ABachchan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 9)

# %%
#Print the dataframe
ABachchan_Tweets_df
# Out:
#         Username      User Id Tweet Type  \
# 0     srbachchan  "145125358"      Tweet
# 1     srbachchan  "145125358"      Reply
# 2     srbachchan  "145125358"      Reply
# 3     srbachchan  "145125358"      Reply
# 4     srbachchan  "145125358"      Reply
# ...          ...          ...        ...
# 3192  srbachchan  "145125358"      Tweet
# 3193  srbachchan  "145125358"      Tweet
# 3194  srbachchan  "145125358"      Tweet
# 3195  srbachchan  "145125358"      Tweet
# 3196  srbachchan  "145125358"      Reply
#
#                                           Tweet Content              Client  \
# 0     "T 3418 -" मोहब्बत त्याग की माँ है ; वो जहाँ ज...     Twitter Web App
# 1                              "@ashokmistry4545 G eve"  Twitter for iPhone
# 2                                   "@SwetaLoveAB Sahi"  Twitter for iPhone
# 3                                 "@prashantkawadia 💕😀"  Twitter for iPhone
# 4                              "@walaalolylovely Smile"  Twitter for iPhone
# ...                                                 ...                 ...
# 3192  "T 2881 - Off to work in the rain and slush an...  Twitter Web Client
# 3193  "I am hep B .. but got it detected in time and...  Twitter Web Client
# 3194  "T 2881 - https://t.co/L9cLGNNUrm\nHere it is....  Twitter Web Client
# 3195  "T 2880 - பிறந்தநாள் வாழ்த்துக்கள் \n(Piṟantan...  Twitter Web Client
# 3196                                "@BachchanHolic ❤️"  Twitter Web Client
#
#       Retweets received  Likes received        Date      Time
# 0                   398            7544  2020-01-22  20:19:36
# 1                    23             131  2020-01-22  14:49:47
# 2                    22             106  2020-01-22  14:49:30
# 3                    13              31  2020-01-22  14:49:16
# 4                    14              27  2020-01-22  14:48:56
# ...                 ...             ...         ...       ...
# 3192               1647           13759  2018-07-28  23:47:20
# 3193                287            3248  2018-07-28  23:37:08
# 3194                973            4279  2018-07-28  10:03:15
# 3195               1622           15185  2018-07-28  02:04:38
# 3196                 10              34  2018-07-27  12:51:28
#
# [3197 rows x 9 columns]

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
ABachchan_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
ABachchan_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = ABachchan_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3197, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
ABachchan_Tweets_df.index = [x for x in range(1, len(ABachchan_Tweets_df.values)+1)]
ABachchan_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
ABachchan_Tweets_df
# Out:
#          Username      User Id Tweet Type  \
# Index
# 1      srbachchan  "145125358"      Tweet
# 2      srbachchan  "145125358"      Reply
# 3      srbachchan  "145125358"      Reply
# 4      srbachchan  "145125358"      Reply
# 5      srbachchan  "145125358"      Reply
# ...           ...          ...        ...
# 3193   srbachchan  "145125358"      Tweet
# 3194   srbachchan  "145125358"      Tweet
# 3195   srbachchan  "145125358"      Tweet
# 3196   srbachchan  "145125358"      Tweet
# 3197   srbachchan  "145125358"      Reply
#
#                                            Tweet Content              Client  \
# Index
# 1      "T 3418 -" मोहब्बत त्याग की माँ है ; वो जहाँ ज...     Twitter Web App
# 2                               "@ashokmistry4545 G eve"  Twitter for iPhone
# 3                                    "@SwetaLoveAB Sahi"  Twitter for iPhone
# 4                                  "@prashantkawadia 💕😀"  Twitter for iPhone
# 5                               "@walaalolylovely Smile"  Twitter for iPhone
# ...                                                  ...                 ...
# 3193   "T 2881 - Off to work in the rain and slush an...  Twitter Web Client
# 3194   "I am hep B .. but got it detected in time and...  Twitter Web Client
# 3195   "T 2881 - https://t.co/L9cLGNNUrm\nHere it is....  Twitter Web Client
# 3196   "T 2880 - பிறந்தநாள் வாழ்த்துக்கள் \n(Piṟantan...  Twitter Web Client
# 3197                                 "@BachchanHolic ❤️"  Twitter Web Client
#
#        Retweets received  Likes received        Date      Time Gender  \
# Index
# 1                    398            7544  2020-01-22  20:19:36   Male
# 2                     23             131  2020-01-22  14:49:47   Male
# 3                     22             106  2020-01-22  14:49:30   Male
# 4                     13              31  2020-01-22  14:49:16   Male
# 5                     14              27  2020-01-22  14:48:56   Male
# ...                  ...             ...         ...       ...    ...
# 3193                1647           13759  2018-07-28  23:47:20   Male
# 3194                 287            3248  2018-07-28  23:37:08   Male
# 3195                 973            4279  2018-07-28  10:03:15   Male
# 3196                1622           15185  2018-07-28  02:04:38   Male
# 3197                  10              34  2018-07-27  12:51:28   Male
#
#             Vocation
# Index
# 1      Entertainment
# 2      Entertainment
# 3      Entertainment
# 4      Entertainment
# 5      Entertainment
# ...              ...
# 3193   Entertainment
# 3194   Entertainment
# 3195   Entertainment
# 3196   Entertainment
# 3197   Entertainment
#
# [3197 rows x 11 columns]

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
ABachchan_Tweets_df.to_csv('ABachchan_Tweets_df.csv')
