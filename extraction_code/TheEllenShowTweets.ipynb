# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # The Ellen Show Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "TheEllenShowTweets.csv"

#Import the CSV into a pandas DataFrame
Ellen_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Ellen_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220160518394015744"
# 1     "1220144486359027712"
# 2     "1220108865972260866"
# 3     "1220093866948214784"
# 4     "1220072534076346369"
# ...                     ...
# 3195  "1063157548088360960"
# 3196  "1063152461362290688"
# 3197  "1063148880353669122"
# 3198  "1063136353448222720"
# 3199  "1063123541485248512"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/theellenshow/status/122016...  2020-01-23 01:45:11
# 1     https://twitter.com/theellenshow/status/122014...  2020-01-23 00:41:29
# 2     https://twitter.com/theellenshow/status/122010...  2020-01-22 22:19:56
# 3     https://twitter.com/theellenshow/status/122009...  2020-01-22 21:20:20
# 4     https://twitter.com/theellenshow/status/122007...  2020-01-22 19:55:34
# ...                                                 ...                  ...
# 3195  https://twitter.com/theellenshow/status/106315...  2018-11-15 19:51:26
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Ellen_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Ellen_Tweets_df = Ellen_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Ellen_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
Ellen_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0     theellenshow  "15846407"      Tweet
# 1     theellenshow  "15846407"      Tweet
# 2     theellenshow  "15846407"      Tweet
# 3     theellenshow  "15846407"      Tweet
# 4     theellenshow  "15846407"      Tweet
# ...            ...         ...        ...
# 3195  theellenshow  "15846407"      Tweet
# 3196  theellenshow  "15846407"      Tweet
# 3197  theellenshow  "15846407"      Tweet
# 3198  theellenshow  "15846407"      Tweet
# 3199  theellenshow  "15846407"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Didn’t get to see my show today? You can watc...       Twitter Web App
# 1     "My staff’s #TheBachelor Recap is really juicy...       Twitter Web App
# 2     "For those of you with your TVs on who are fee...  Twitter Media Studio
# 3     ".@NikkieTutorials is one of the most popular ...  Twitter Media Studio
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Ellen_Tweets_df = Ellen_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Ellen_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Ellen_Tweets_df['Tweet Posted Time'] = Ellen_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Ellen_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Ellen_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Ellen_Tweets_df['Tweet Posted Time'] = Ellen_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Ellen_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Ellen_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Ellen_Tweets_df = Ellen_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Ellen_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
Ellen_Tweets_df
# Out:
#           Username     User Id Tweet Type  \
# 0     theellenshow  "15846407"      Tweet
# 1     theellenshow  "15846407"      Tweet
# 2     theellenshow  "15846407"      Tweet
# 3     theellenshow  "15846407"      Tweet
# 4     theellenshow  "15846407"      Tweet
# ...            ...         ...        ...
# 3195  theellenshow  "15846407"      Tweet
# 3196  theellenshow  "15846407"      Tweet
# 3197  theellenshow  "15846407"      Tweet
# 3198  theellenshow  "15846407"      Tweet
# 3199  theellenshow  "15846407"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Didn’t get to see my show today? You can watc...       Twitter Web App
# 1     "My staff’s #TheBachelor Recap is really juicy...       Twitter Web App
# 2     "For those of you with your TVs on who are fee...  Twitter Media Studio
# 3     ".@NikkieTutorials is one of the most popular ...  Twitter Media Studio
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Ellen_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
Ellen_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = Ellen_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Ellen_Tweets_df.index = [x for x in range(1, len(Ellen_Tweets_df.values)+1)]
Ellen_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Ellen_Tweets_df
# Out:
#            Username     User Id Tweet Type  \
# Index
# 1      theellenshow  "15846407"      Tweet
# 2      theellenshow  "15846407"      Tweet
# 3      theellenshow  "15846407"      Tweet
# 4      theellenshow  "15846407"      Tweet
# 5      theellenshow  "15846407"      Tweet
# ...             ...         ...        ...
# 3196   theellenshow  "15846407"      Tweet
# 3197   theellenshow  "15846407"      Tweet
# 3198   theellenshow  "15846407"      Tweet
# 3199   theellenshow  "15846407"      Tweet
# 3200   theellenshow  "15846407"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "Didn’t get to see my show today? You can watc...
# 2      "My staff’s #TheBachelor Recap is really juicy...
# 3      "For those of you with your TVs on who are fee...
# 4      ".@NikkieTutorials is one of the most popular ...
# 5      "For a lot of my staff, the 3-day weekend real...
# ...                                                  ...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Ellen_Tweets_df.to_csv('Ellen_Tweets_df.csv')
