# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # YouTube Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "YouTubeTweets.csv"

#Import the CSV into a pandas DataFrame
YouTube_Tweets_df = pd.read_csv(csv_path, low_memory = False)
YouTube_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220238435861970944"
# 1     "1220140861486333952"
# 2     "1220133186048389121"
# 3     "1220114272316878848"
# 4     "1220051182338465792"
# ...                     ...
# 3195   "939962963053727746"
# 3196   "939932776463257601"
# 3197   "939902534210252800"
# 3198   "939600568217194498"
# 3199   "939540173104263168"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/youtube/status/12202384358...  2020-01-23 06:54:48
# 1     https://twitter.com/youtube/status/12201408614...  2020-01-23 00:27:05
# 2     https://twitter.com/youtube/status/12201331860...  2020-01-22 23:56:35
# 3     https://twitter.com/youtube/status/12201142723...  2020-01-22 22:41:25
# 4     https://twitter.com/youtube/status/12200511823...  2020-01-22 18:30:43
# ...                                                 ...                  ...
# 3195  https://twitter.com/youtube/status/93996296305...  2017-12-10 21:00:08
# ...

# %%
#Show the 'shape' of the dataframe 
shape = YouTube_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
YouTube_Tweets_df = YouTube_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = YouTube_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
YouTube_Tweets_df
# Out:
#      Username     User Id Tweet Type  \
# 0     youtube  "10228272"      Tweet
# 1     youtube  "10228272"      Tweet
# 2     youtube  "10228272"      Reply
# 3     youtube  "10228272"      Reply
# 4     youtube  "10228272"      Tweet
# ...       ...         ...        ...
# 3195  youtube  "10228272"      Tweet
# 3196  youtube  "10228272"      Tweet
# 3197  youtube  "10228272"      Tweet
# 3198  youtube  "10228272"      Tweet
# 3199  youtube  "10228272"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Lunar New Year is almost here! 🧧🐭\nFind out w...  Twitter Media Studio
# 1                      "Do it! https://t.co/FK8d5AEfzC"       Twitter Web App
# 2                                     "@__gvby HI DAD!"       Twitter Web App
# 3                "@DunkinJy OR do you know everything?"       Twitter Web App
# 4     "So proud of you @nikkietutorials. 💞 Watch her...  Twitter Media Studio
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
YouTube_Tweets_df = YouTube_Tweets_df.dropna() 

#Confirm rows are dropped
shape = YouTube_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
YouTube_Tweets_df['Tweet Posted Time'] = YouTube_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = YouTube_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
YouTube_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
YouTube_Tweets_df['Tweet Posted Time'] = YouTube_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = YouTube_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
YouTube_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
YouTube_Tweets_df = YouTube_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = YouTube_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
YouTube_Tweets_df
# Out:
#      Username     User Id Tweet Type  \
# 0     youtube  "10228272"      Tweet
# 1     youtube  "10228272"      Tweet
# 2     youtube  "10228272"      Reply
# 3     youtube  "10228272"      Reply
# 4     youtube  "10228272"      Tweet
# ...       ...         ...        ...
# 3195  youtube  "10228272"      Tweet
# 3196  youtube  "10228272"      Tweet
# 3197  youtube  "10228272"      Tweet
# 3198  youtube  "10228272"      Tweet
# 3199  youtube  "10228272"      Tweet
#
#                                           Tweet Content                Client  \
# 0     "Lunar New Year is almost here! 🧧🐭\nFind out w...  Twitter Media Studio
# 1                      "Do it! https://t.co/FK8d5AEfzC"       Twitter Web App
# 2                                     "@__gvby HI DAD!"       Twitter Web App
# 3                "@DunkinJy OR do you know everything?"       Twitter Web App
# 4     "So proud of you @nikkietutorials. 💞 Watch her...  Twitter Media Studio
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
YouTube_Tweets_df['Gender'] = "Organisation"

#Create an Gender column for Gender
YouTube_Tweets_df['Vocation'] = "Entertainment"

#Show the 'shape' of the dataframe
shape = YouTube_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
YouTube_Tweets_df.index = [x for x in range(1, len(YouTube_Tweets_df.values)+1)]
YouTube_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
YouTube_Tweets_df
# Out:
#       Username     User Id Tweet Type  \
# Index
# 1      youtube  "10228272"      Tweet
# 2      youtube  "10228272"      Tweet
# 3      youtube  "10228272"      Reply
# 4      youtube  "10228272"      Reply
# 5      youtube  "10228272"      Tweet
# ...        ...         ...        ...
# 3196   youtube  "10228272"      Tweet
# 3197   youtube  "10228272"      Tweet
# 3198   youtube  "10228272"      Tweet
# 3199   youtube  "10228272"      Tweet
# 3200   youtube  "10228272"      Tweet
#
#                                            Tweet Content  \
# Index
# 1      "Lunar New Year is almost here! 🧧🐭\nFind out w...
# 2                       "Do it! https://t.co/FK8d5AEfzC"
# 3                                      "@__gvby HI DAD!"
# 4                 "@DunkinJy OR do you know everything?"
# 5      "So proud of you @nikkietutorials. 💞 Watch her...
# ...                                                  ...
# 3196   "That one friend who treats your house like th...
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
YouTube_Tweets_df.to_csv('YouTube_Tweets_df.csv')
