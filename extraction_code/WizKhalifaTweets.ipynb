# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Wiz Khalifa Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "WizKhalifaTweets.csv"

#Import the CSV into a pandas DataFrame
Wiz_Tweets_df = pd.read_csv(csv_path, low_memory = False)
Wiz_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220006487021576193"
# 1     "1220006481254408192"
# 2     "1220006329621733377"
# 3     "1219996365121454081"
# 4     "1219720267980627968"
# ...                     ...
# 3195   "952236590964723712"
# 3196   "952234480458072064"
# 3197   "946953124723310594"
# 3198   "944972705396166656"
# 3199   "944619613731483648"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/babushkabadgyal/status/122...  2020-01-22 15:33:07
# 1     https://twitter.com/jassbabyy_/status/12200064...  2020-01-22 15:33:06
# 2     https://twitter.com/wizkhalifa/status/12200063...  2020-01-22 15:32:30
# 3     https://twitter.com/wizkhalifa/status/12199963...  2020-01-22 14:52:54
# 4     https://twitter.com/trappdann/status/121972026...  2020-01-21 20:35:47
# ...                                                 ...                  ...
# 3195  https://twitter.com/wizkhalifa/status/95223659...  2018-01-13 17:51:09
# ...

# %%
#Show the 'shape' of the dataframe 
shape = Wiz_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
Wiz_Tweets_df = Wiz_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = Wiz_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
Wiz_Tweets_df
# Out:
#              Username                User Id Tweet Type  \
# 0     babushkabadgyal  "1216311347182436352"    Retweet
# 1          jassbabyy_           "2225206874"    Retweet
# 2          wizkhalifa             "20322929"      Tweet
# 3          wizkhalifa             "20322929"      Tweet
# 4           trappdann           "2292041053"    Retweet
# ...               ...                    ...        ...
# 3195       wizkhalifa             "20322929"      Tweet
# 3196       wizkhalifa             "20322929"      Tweet
# 3197       wizkhalifa             "20322929"      Tweet
# 3198       wizkhalifa             "20322929"      Tweet
# 3199       wizkhalifa             "20322929"      Tweet
#
#                                           Tweet Content               Client  \
# 0     "@wizkhalifa is my coffee in the Morning. #tay...  Twitter for Android
# 1                "@wizkhalifa #taylorgang #mcqueenteam"   Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
Wiz_Tweets_df = Wiz_Tweets_df.dropna() 

#Confirm rows are dropped
shape = Wiz_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Wiz_Tweets_df['Tweet Posted Time'] = Wiz_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Wiz_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
Wiz_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
Wiz_Tweets_df['Tweet Posted Time'] = Wiz_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = Wiz_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
Wiz_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
Wiz_Tweets_df = Wiz_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = Wiz_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
Wiz_Tweets_df
# Out:
#              Username                User Id Tweet Type  \
# 0     babushkabadgyal  "1216311347182436352"    Retweet
# 1          jassbabyy_           "2225206874"    Retweet
# 2          wizkhalifa             "20322929"      Tweet
# 3          wizkhalifa             "20322929"      Tweet
# 4           trappdann           "2292041053"    Retweet
# ...               ...                    ...        ...
# 3195       wizkhalifa             "20322929"      Tweet
# 3196       wizkhalifa             "20322929"      Tweet
# 3197       wizkhalifa             "20322929"      Tweet
# 3198       wizkhalifa             "20322929"      Tweet
# 3199       wizkhalifa             "20322929"      Tweet
#
#                                           Tweet Content               Client  \
# 0     "@wizkhalifa is my coffee in the Morning. #tay...  Twitter for Android
# 1                "@wizkhalifa #taylorgang #mcqueenteam"   Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
Wiz_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
Wiz_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = Wiz_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
Wiz_Tweets_df.index = [x for x in range(1, len(Wiz_Tweets_df.values)+1)]
Wiz_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
Wiz_Tweets_df
# Out:
#               Username                User Id Tweet Type  \
# Index
# 1      babushkabadgyal  "1216311347182436352"    Retweet
# 2           jassbabyy_           "2225206874"    Retweet
# 3           wizkhalifa             "20322929"      Tweet
# 4           wizkhalifa             "20322929"      Tweet
# 5            trappdann           "2292041053"    Retweet
# ...                ...                    ...        ...
# 3196        wizkhalifa             "20322929"      Tweet
# 3197        wizkhalifa             "20322929"      Tweet
# 3198        wizkhalifa             "20322929"      Tweet
# 3199        wizkhalifa             "20322929"      Tweet
# 3200        wizkhalifa             "20322929"      Tweet
#
#                                            Tweet Content               Client  \
# Index
# 1      "@wizkhalifa is my coffee in the Morning. #tay...  Twitter for Android
# 2                 "@wizkhalifa #taylorgang #mcqueenteam"   Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
Wiz_Tweets_df.to_csv('Wiz_Tweets_df.csv')
