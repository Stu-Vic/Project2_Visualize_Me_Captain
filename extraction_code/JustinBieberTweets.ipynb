# %% [markdown]
# ##### ===================================================================================================================

# %% [markdown]
# # Justin Bieber Tweets

# %% [markdown]
# ##### ===================================================================================================================

# %%
#Import Dependencies
import pandas as pd

# %%
#Create reference to CSV file
csv_path = "JustinBieberTweets.csv"

#Import the CSV into a pandas DataFrame
JBieber_Tweets_df = pd.read_csv(csv_path, low_memory = False)
JBieber_Tweets_df
# Out:
#                    Tweet Id  \
# 0     "1220121967598063616"
# 1     "1220082607020498945"
# 2     "1220038923809771520"
# 3     "1220038669177774080"
# 4     "1219856118295347200"
# ...                     ...
# 3195   "615583285725528064"
# 3196   "615581282974736384"
# 3197   "615574260250185728"
# 3198   "615567653357404160"
# 3199   "615532708756717568"
#
#                                               Tweet URL    Tweet Posted Time  \
# 0     https://twitter.com/justinbieber/status/122012...  2020-01-22 23:12:00
# 1     https://twitter.com/defjam/status/122008260702...  2020-01-22 20:35:36
# 2     https://twitter.com/justinbieber/status/122003...  2020-01-22 17:42:01
# 3     https://twitter.com/justinbieber/status/122003...  2020-01-22 17:41:00
# 4     https://twitter.com/justinbieber/status/121985...  2020-01-22 05:35:37
# ...                                                 ...                  ...
# 3195  https://twitter.com/usatodaylife/status/615583...  2015-06-29 18:11:06
# ...

# %%
#Show the 'shape' of the dataframe 
shape = JBieber_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 14)

# %% [markdown]
# ##### COLLECT ONLY REQUIRED COLUMNS

# %%
#Select only columns we need
JBieber_Tweets_df = JBieber_Tweets_df[["Username", "User Id", "Tweet Type", "Tweet Content", "Client", "Retweets received",
                                     "Likes received", "Tweet Posted Time"]]

#Show the 'shape' of the dataframe
shape = JBieber_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %%
#Print the dataframe
JBieber_Tweets_df
# Out:
#           Username      User Id Tweet Type  \
# 0     justinbieber   "27260086"      Tweet
# 1           defjam   "22085184"    Retweet
# 2     justinbieber   "27260086"      Tweet
# 3     justinbieber   "27260086"      Tweet
# 4     justinbieber   "27260086"      Tweet
# ...            ...          ...        ...
# 3195  usatodaylife   "15764283"    Retweet
# 3196    elitedaily  "331057915"    Retweet
# 3197  vibemagazine   "14691200"    Retweet
# 3198       youtube   "10228272"    Retweet
# 3199  justinbieber   "27260086"      Tweet
#
#                                           Tweet Content              Client  \
# 0                   "Thank you https://t.co/mC3AAnxXmM"  Twitter for iPhone
# 1     "When he hit that “yeah babe” though😩 https://...  Twitter for iPhone
# 2                                   "Big day @JKCorden"  Twitter for iPhone
# 3       "Thanks . R&amp;bieber https://t.co/KNDOUfgpSg"  Twitter for iPhone
# ...

# %% [markdown]
# ##### REMOVE ALL ROWS WITH NO DATA

# %%
#Filter out those rows which does not contain any data 
JBieber_Tweets_df = JBieber_Tweets_df.dropna() 

#Confirm rows are dropped
shape = JBieber_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 8)

# %% [markdown]
# ##### SEPERATE THE DATE AND TIME

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
JBieber_Tweets_df['Tweet Posted Time'] = JBieber_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = JBieber_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to only show yyyy-mm-dd format
date = []
for x in dt_list:
    date.append(x.split(" ")[0])

#Add the formated lists into the dataframe as new columns
JBieber_Tweets_df["Date"] = date

# %%
#Convert the 'Tweet Posted Time' column to string (from TimeStamp due to previous function to_datetime used)
JBieber_Tweets_df['Tweet Posted Time'] = JBieber_Tweets_df['Tweet Posted Time'].astype(str)

#Convert column to list
dt_list = JBieber_Tweets_df["Tweet Posted Time"].tolist()

#Clean up the list to show time
time = []
for x in dt_list:
    time.append(x.split(" ")[1])

#Add the formated lists into the dataframe as new columns
JBieber_Tweets_df["Time"] = time

# %%
#Drop the 'Tweet Posted Time' column as it is now replaced with a 'Date' and 'Time' column
JBieber_Tweets_df = JBieber_Tweets_df.drop(['Tweet Posted Time'], axis = 1)

#Show the 'shape' of the dataframe
shape = JBieber_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 9)

# %%
#Print the dataframe
JBieber_Tweets_df
# Out:
#           Username      User Id Tweet Type  \
# 0     justinbieber   "27260086"      Tweet
# 1           defjam   "22085184"    Retweet
# 2     justinbieber   "27260086"      Tweet
# 3     justinbieber   "27260086"      Tweet
# 4     justinbieber   "27260086"      Tweet
# ...            ...          ...        ...
# 3195  usatodaylife   "15764283"    Retweet
# 3196    elitedaily  "331057915"    Retweet
# 3197  vibemagazine   "14691200"    Retweet
# 3198       youtube   "10228272"    Retweet
# 3199  justinbieber   "27260086"      Tweet
#
#                                           Tweet Content              Client  \
# 0                   "Thank you https://t.co/mC3AAnxXmM"  Twitter for iPhone
# 1     "When he hit that “yeah babe” though😩 https://...  Twitter for iPhone
# 2                                   "Big day @JKCorden"  Twitter for iPhone
# 3       "Thanks . R&amp;bieber https://t.co/KNDOUfgpSg"  Twitter for iPhone
# ...

# %% [markdown]
# ##### ADD A GENDER AND VOCATION COLUMN TO THE DATAFRAME AND FILL

# %%
#Create an Gender column for Gender
JBieber_Tweets_df['Gender'] = "Male"

#Create an Gender column for Gender
JBieber_Tweets_df['Vocation'] = "Music"

#Show the 'shape' of the dataframe
shape = JBieber_Tweets_df.shape
print(f"The dataframes 'shape' is represented as: {shape}")
# Out:
# The dataframes 'shape' is represented as: (3200, 11)

# %% [markdown]
# ##### CORRECT THE INDEX FOR VISUAL PURPOSES

# %%
#The original dataframe had an index, so re-arrange the index 
JBieber_Tweets_df.index = [x for x in range(1, len(JBieber_Tweets_df.values)+1)]
JBieber_Tweets_df.index.name = 'Index'

# %%
#Print the dataframe
JBieber_Tweets_df
# Out:
#            Username      User Id Tweet Type  \
# Index
# 1      justinbieber   "27260086"      Tweet
# 2            defjam   "22085184"    Retweet
# 3      justinbieber   "27260086"      Tweet
# 4      justinbieber   "27260086"      Tweet
# 5      justinbieber   "27260086"      Tweet
# ...             ...          ...        ...
# 3196   usatodaylife   "15764283"    Retweet
# 3197     elitedaily  "331057915"    Retweet
# 3198   vibemagazine   "14691200"    Retweet
# 3199        youtube   "10228272"    Retweet
# 3200   justinbieber   "27260086"      Tweet
#
#                                            Tweet Content              Client  \
# Index
# 1                    "Thank you https://t.co/mC3AAnxXmM"  Twitter for iPhone
# 2      "When he hit that “yeah babe” though😩 https://...  Twitter for iPhone
# 3                                    "Big day @JKCorden"  Twitter for iPhone
# 4        "Thanks . R&amp;bieber https://t.co/KNDOUfgpSg"  Twitter for iPhone
# ...

# %% [markdown]
# ##### SAVE DATAFRAME TO CSV

# %%
#Save dataframe as csv file
JBieber_Tweets_df.to_csv('JBieber_Tweets_df.csv')
